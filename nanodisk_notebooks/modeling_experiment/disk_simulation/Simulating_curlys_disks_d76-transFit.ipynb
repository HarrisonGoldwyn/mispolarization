# %%
import os
import sys
module_path = os.path.abspath(
    os.path.join(
        "/Users",
        "chair",
        "Documents",
        "Academia",
        "SuperRes",
        "Biteen_colab",
        "Mispolarization",
        "python"
        )) 
sys.path.append(module_path)

import numpy as np

## Plotting stuff
import matplotlib.pyplot as plt
import matplotlib as mpl

# %%
## Parameter setting needs to be in cell following mpl import for some reason 
## https://github.com/jupyter/notebook/issues/3385
##
## Default parameters inspired by 
## http://nipunbatra.github.io/2014/08/latexify/
params = {
    'text.latex.preamble': ['\\usepackage{gensymb}'],
    'image.origin': 'lower',
    'image.interpolation': 'nearest',
    'image.cmap': 'magma',
    'axes.grid': False,
    'figure.dpi': 600,  # to adjust notebook inline plot size
    'savefig.dpi': 600,  # to adjust notebook inline plot size
#     'axes.labelsize': 12, # fontsize for x and y labels (was 10)
    'axes.titlesize': 14,
    'font.size': 8, # was 10
#     'savefig.dpi': 150,  # to adjust notebook inline plot size
    'axes.labelsize': 10, # fontsize for x and y labels (was 10)
    'axes.titlesize': 10,
    'font.size': 8, # was 10
    'legend.fontsize': 8, # was 10
    'xtick.labelsize': 8,
    'ytick.labelsize': 8,
    'text.usetex': True,
    'figure.figsize': [3.39, 2.10],
    'font.family': 'serif',
    'figure.max_open_warning':10001
}
mpl.rcParams.update(params)
## For colorbar 
from mpl_toolkits.axes_grid1 import make_axes_locatable

## Get physical constants from Scipy
import scipy.constants as con

## For fitting
import scipy.optimize as opt

## For matlab loading
import scipy.io as sio

## Load custom package modules
from misloc_mispol_package.calc import BEM_simulation_wrapper as bem
from misloc_mispol_package.calc import fitting_misLocalization as fit
from misloc_mispol_package.calc import coupled_dipoles as cp
from misloc_mispol_package.calc import knn as knn

from misloc_mispol_package.optics import diffraction_int as diffi
from misloc_mispol_package.optics import fibonacci as fib

## Some useful numerical constants
hbar = con.physical_constants['Planck constant over 2 pi in eV s'][0]
c = con.physical_constants['speed of light in vacuum'][0]*1e2 #cm/m

cm_per_nm = fit.cm_per_nm

eps_b = 1.778 ## Water

hres_obs_pts = diffi.observation_points(
    -480*cm_per_nm, 480*cm_per_nm, -480*cm_per_nm, 480*cm_per_nm, 201)

# %%
disk_diameter = 76
disk_radius = disk_diameter/2

exp_res_param_file = f'disk_JC_d{disk_diameter}_transFit_expRes'
high_res_param_file = f'disk_JC_d{disk_diameter}_transFit_highRes'

# %%
# param_file = exp_res_param_file

# locations, angles = fit.fixed_ori_mol_placement(
#     mol_grid_pts_1D=2, x_max=150, y_max=150)
# sim_inst_0 = bem.SimulatedExperiment(
#     locations, 
#     mol_angle=0,
#     param_file=param_file,
#     simulation_file_name=f'CurlyDiskJC_NoSub_dipDrive_E_d{disk_diameter}')
# sim_inst_0.trial_images = sim_inst_0.calculate_BEM_fields()

# # Model fit
# # Gaussian guess, checked

# fit_inst_0 = fit.FitModelToData(
#     sim_inst_0.BEM_images, 
# #     ini_guess=simTestInst_few_mol.mol_locations,
#     ini_guess='gauss',
#     param_file=param_file
#     )
# the_fit = fit_inst_0.fit_model_to_image_data(
#     check_ini=True,
#     let_mol_ori_out_of_plane=True)

# sim_inst_0.calculate_polarization()
# bem.save_sim_exp_inst(sim_inst_0, f'test_sim_inst_xmol_grid_d{disk_diameter}')
# bem.save_fit_inst(fit_inst_0, sim_inst_0, f'test_fit_inst_xmol_grid_d{disk_diameter}')

# %%
# ## Plot fit results
# # fit_inst_0.plot_fit_results_as_quiver_map(sim_inst_0)   

# fig5 = bem.fig5_3D(
#     sim_inst_0, 
#     fit_inst_0, 
#     draw_quadrant=True, 
#     show_ax_labels=True,
#     quiv_ax_limits=[-25, 175, -25, 175],
#     quiv_tick_list=np.linspace(0,150,7),
#     quiv_ticklabel_list=[r'$0$', r'$25$',r'$50$',r'$75$',r'$100$',r'$125$', r'$150$'],
#     )

# # ## Histogram fits
# # plt.figure()
# # fit_pos = fit_inst_0.model_fit_results[:, :2]
# # radial_fit_pos = np.sqrt(np.sum(fit_pos**2, axis=1))
# # hist, _, _ = plt.hist(radial_fit_pos)
# # plt.vlines(
# #     sim_inst_0.a_long_meters / fit.cm_per_nm, 0, hist.max(),
# #     lw=1, color='gray', linestyle='--')

# # plt.xlabel('Radial fit location')
# # plt.ylabel('Number of molecules')

# %%
param_file = exp_res_param_file

locations, angles = fit.fixed_ori_mol_placement(
    mol_grid_pts_1D=7, x_max=150, y_max=150)
sim_inst_0 = bem.SimulatedExperiment(
    locations, 
    mol_angle=0,
    param_file=param_file,
    simulation_file_name=f'CurlyDiskJC_NoSub_dipDrive_E_d{disk_diameter}')
sim_inst_0.trial_images = sim_inst_0.calculate_BEM_fields()

# Model fit
# Gaussian guess, checked

fit_inst_0 = fit.FitModelToData(
    sim_inst_0.BEM_images, 
#     ini_guess=simTestInst_few_mol.mol_locations,
    ini_guess='gauss',
    param_file=param_file
    )
the_fit = fit_inst_0.fit_model_to_image_data(
    check_ini=True,
    let_mol_ori_out_of_plane=True)

sim_inst_0.calculate_polarization()
bem.save_sim_exp_inst(sim_inst_0, f'sim_inst_xmol_grid_d{disk_diameter}_transFit')
bem.save_fit_inst(fit_inst_0, sim_inst_0, f'fit_inst_xmol_grid_d{disk_diameter}_transFit')
# Out:
# No 'quench_over_real_disk' param found in file.
# /Users/chair/Documents/Academia/SuperRes/Biteen_colab/Mispolarization/python/misloc_mispol_package/optics/anal_foc_diff_fields.py:27: RuntimeWarning: invalid value encountered in true_divide
#   sphj1_on_krho = spf.spherical_jn( 1, k*rho(xi, y) )/(k*rho(xi, y))
# /Users/chair/Documents/Academia/SuperRes/Biteen_colab/Mispolarization/python/misloc_mispol_package/optics/anal_foc_diff_fields.py:30: RuntimeWarning: invalid value encountered in true_divide
#   j2_on_krho = spf.jv(2, k*rho(xi, y) )/(k*rho(xi, y))
# /Users/chair/Documents/Academia/SuperRes/Biteen_colab/Mispolarization/python/misloc_mispol_package/optics/anal_foc_diff_fields.py:75: RuntimeWarning: invalid value encountered in true_divide
#   j2_on_krho = spf.jv(2, k*rho(xi, y) )/(k*rho(xi, y))
# /Users/chair/Documents/Academia/SuperRes/Biteen_colab/Mispolarization/python/misloc_mispol_package/optics/anal_foc_diff_fields.py:78: RuntimeWarning: divide by zero encountered in true_divide
#   sphj0_on_krhosqrd = spf.spherical_jn(0, k*rho(xi, y) )/(k*rho(xi, y))**2.
# /Users/chair/Documents/Academia/SuperRes/Biteen_colab/Mispolarization/python/misloc_mispol_package/optics/anal_foc_diff_fields.py:82: RuntimeWarning: invalid value encountered in add
#   sphj0_on_krhosqrd
# No 'quench_over_real_disk' param found in file.
# starting Matlab...
# given even number of points for Fibonacci lattice,
#   adding 1...
# 1th molecule
# calculating diffracted fields
# 2th molecule
# calculating diffracted fields
# 3th molecule
# calculating diffracted fields
# 4th molecule
# calculating diffracted fields
# 5th molecule
# calculating diffracted fields
# 6th molecule
# calculating diffracted fields
# 7th molecule
# calculating diffracted fields
# 8th molecule
# calculating diffracted fields
# 9th molecule
# calculating diffracted fields
# 10th molecule
# calculating diffracted fields
# 11th molecule
# calculating diffracted fields
# 12th molecule
# calculating diffracted fields
# 13th molecule
# calculating diffracted fields
# 14th molecule
# calculating diffracted fields
# 15th molecule
# calculating diffracted fields
# 16th molecule
# calculating diffracted fields
# 17th molecule
# calculating diffracted fields
# 18th molecule
# calculating diffracted fields
# 19th molecule
# calculating diffracted fields
# 20th molecule
# calculating diffracted fields
# 21th molecule
# calculating diffracted fields
# 22th molecule
# calculating diffracted fields
# 23th molecule
# calculating diffracted fields
# 24th molecule
# calculating diffracted fields
# 25th molecule
# calculating diffracted fields
# 26th molecule
# calculating diffracted fields
# 27th molecule
# calculating diffracted fields
# 28th molecule
# calculating diffracted fields
# 29th molecule
# calculating diffracted fields
# 30th molecule
# calculating diffracted fields
# 31th molecule
# calculating diffracted fields
# 32th molecule
# calculating diffracted fields
# 33th molecule
# calculating diffracted fields
# 34th molecule
# calculating diffracted fields
# 35th molecule
# calculating diffracted fields
# 36th molecule
# calculating diffracted fields
# 37th molecule
# calculating diffracted fields
# 38th molecule
# calculating diffracted fields
# 39th molecule
# calculating diffracted fields
# 40th molecule
# calculating diffracted fields
# 41th molecule
# calculating diffracted fields
# 42th molecule
# calculating diffracted fields
# 43th molecule
# calculating diffracted fields
# 44th molecule
# calculating diffracted fields
# 45th molecule
# calculating diffracted fields
# No 'quench_over_real_disk' param found in file.
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 0
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (0.0,0.0)
# initial guess angle = [0.07165645550290665, 1.0841692778643743]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? True
# Initial guess in quench. Zone, OG params: [0.0, 0.0, 0.07165645550290665, 1.0841692778643743]
# Params shifted to: [49.26575881, 0.0, 0.07165645550290665, 1.0841692778643743]
# running fit...
# SUCCESS, Resulting fit params: [30.71928202 25.80360051  1.96919598 -1.71363497]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 1
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (0.0,97.0)
# initial guess angle = [0.9466615608647084, 0.8118943707775242]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [-9.86172201 74.96068938  1.16928057 -0.200302  ]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 2
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (0.0,146.0)
# initial guess angle = [1.396222343502426, 1.1959253268030277]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [-5.27049858 93.1012494   1.31689535 -0.11241602]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 3
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (0.0,146.0)
# initial guess angle = [1.0682096953575293, 2.237377363459408]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [  3.41768647 106.54795314   1.42112749   3.2098236 ]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 4
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (0.0,146.0)
# initial guess angle = [0.4360063285800278, 0.8086716664601273]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [-6.72133222e-01  1.26426510e+02  1.54399818e+00 -1.11714232e-02]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 5
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (0.0,0.0)
# initial guess angle = [1.2992635981342109, 2.8751531270578328]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? True
# Initial guess in quench. Zone, OG params: [0.0, 0.0, 1.2992635981342109, 2.8751531270578328]
# Params shifted to: [49.26575881, 0.0, 1.2992635981342109, 2.8751531270578328]
# running fit...
# SUCCESS, Resulting fit params: [ 8.54034206 65.72403664  1.82293968 -0.9669501 ]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 6
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (0.0,97.0)
# initial guess angle = [1.2254378500007033, 0.9039156410417254]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [-8.74588067 92.21119729  0.70846724  0.42553225]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 7
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (49.0,146.0)
# initial guess angle = [0.22043943645113304, 1.0257439741407572]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [ 1.88924355e+01  9.01832806e+01  1.31474117e+00 -1.03792909e-02]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 8
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (49.0,146.0)
# initial guess angle = [0.5641354243152286, 0.9109211597792295]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [ 1.67709078e+01  1.07133486e+02  1.35485098e+00 -3.54675294e-02]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 9
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (49.0,146.0)
# initial guess angle = [0.8730118615544472, 0.846210210345567]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [ 1.77679493e+01  1.28292195e+02  1.38253727e+00 -4.77930746e-02]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 10
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (0.0,0.0)
# initial guess angle = [0.2849968746245779, 1.9024214331064415]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? True
# Initial guess in quench. Zone, OG params: [0.0, 0.0, 0.2849968746245779, 1.9024214331064415]
# Params shifted to: [49.26575881, 0.0, 0.2849968746245779, 1.9024214331064415]
# running fit...
# SUCCESS, Resulting fit params: [ 3.34373604 15.30546909 -0.5458566   0.31891056]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 11
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (0.0,0.0)
# initial guess angle = [1.0912560807277396, 3.092077648970423]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? True
# Initial guess in quench. Zone, OG params: [0.0, 0.0, 1.0912560807277396, 3.092077648970423]
# Params shifted to: [49.26575881, 0.0, 1.0912560807277396, 3.092077648970423]
# running fit...
# SUCCESS, Resulting fit params: [49.681004   31.5456776   1.29644786  2.65126424]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 12
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (0.0,0.0)
# initial guess angle = [1.0722771094541461, 1.6263809552389308]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? True
# Initial guess in quench. Zone, OG params: [0.0, 0.0, 1.0722771094541461, 1.6263809552389308]
# Params shifted to: [49.26575881, 0.0, 1.0722771094541461, 1.6263809552389308]
# running fit...
# SUCCESS, Resulting fit params: [50.07541898 56.2559523   1.67381634 -0.34347855]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 13
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (49.0,97.0)
# initial guess angle = [0.9153485222953281, 0.12684166269088545]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [4.88219912e+01 7.06393317e+01 1.23496358e+00 3.95379267e-02]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 14
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (49.0,97.0)
# initial guess angle = [1.318100032496779, 0.9523692501555037]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [3.93848304e+01 8.81840231e+01 1.22272059e+00 4.67911246e-02]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 15
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (49.0,146.0)
# initial guess angle = [1.1143758697077035, 0.6242785754384348]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [ 3.65341372e+01  1.09131725e+02  1.31261714e+00 -1.85115738e-02]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 16
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (49.0,146.0)
# initial guess angle = [1.521862873767459, 2.2552109573322183]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [ 37.08224232 129.20460661   1.7974231    3.0829133 ]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 17
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (0.0,0.0)
# initial guess angle = [0.5655258617061388, 2.7985731706708132]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? True
# Initial guess in quench. Zone, OG params: [0.0, 0.0, 0.5655258617061388, 2.7985731706708132]
# Params shifted to: [49.26575881, 0.0, 0.5655258617061388, 2.7985731706708132]
# running fit...
# SUCCESS, Resulting fit params: [61.62231527  0.08979591  0.80473876  3.13873027]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 18
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (0.0,0.0)
# initial guess angle = [1.1152422979234404, 1.191434960683088]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? True
# Initial guess in quench. Zone, OG params: [0.0, 0.0, 1.1152422979234404, 1.191434960683088]
# Params shifted to: [49.26575881, 0.0, 1.1152422979234404, 1.191434960683088]
# running fit...
# SUCCESS, Resulting fit params: [73.6747997  25.63508612  1.83680797 -0.11018352]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 19
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (49.0,49.0)
# initial guess angle = [0.1026070227829502, 1.1978075919914364]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [79.30199265 52.82173933  1.37879163  3.03879342]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 20
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (49.0,97.0)
# initial guess angle = [0.23970719803803983, 0.6527267399913946]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [79.73965276 77.42353868  1.27130814  3.1504518 ]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 21
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (97.0,97.0)
# initial guess angle = [1.5146748567761186, 2.640556060522116]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [82.12380904 98.76160117  1.19818384  3.18061956]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 22
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (97.0,146.0)
# initial guess angle = [1.4146177331831093, 0.7957997038805895]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [ 6.22230944e+01  1.12166970e+02  1.31341709e+00 -1.56971859e-02]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 23
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (97.0,146.0)
# initial guess angle = [0.9381841466337247, 2.8035099704661155]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [ 61.94081971 131.84354858   1.79162339   3.08927282]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 24
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (49.0,0.0)
# initial guess angle = [1.2907716711607502, 2.2305592204604774]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? True
# Initial guess in quench. Zone, OG params: [49.0, 0.0, 1.2907716711607502, 2.2305592204604774]
# Params shifted to: [98.26575881, 0.0, 1.2907716711607502, 2.2305592204604774]
# running fit...
# SUCCESS, Resulting fit params: [97.5791077   0.11246893  1.23194932  3.13956965]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 25
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (49.0,0.0)
# initial guess angle = [0.7417102393559425, 1.447605762717972]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? True
# Initial guess in quench. Zone, OG params: [49.0, 0.0, 0.7417102393559425, 1.447605762717972]
# Params shifted to: [98.26575881, 0.0, 0.7417102393559425, 1.447605762717972]
# running fit...
# SUCCESS, Resulting fit params: [9.95066673e+01 2.46710668e+01 1.83920578e+00 7.80542553e-03]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 26
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (97.0,49.0)
# initial guess angle = [0.12135192484248913, 3.050650488009879]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [102.21229264  49.11352392   1.84200028  12.59540561]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 27
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (97.0,97.0)
# initial guess angle = [0.31570132165455395, 2.0502931949091208]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [103.47264912  74.13297077   1.29957424  -3.09770284]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 28
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (97.0,97.0)
# initial guess angle = [0.17631328840810578, 1.590119748494732]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [87.72011955 91.96376115  1.17947068 -6.26316118]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 29
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (97.0,146.0)
# initial guess angle = [0.30719662424040833, 2.649868666190577]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [ 84.54732807 113.36472433   1.82962171   3.11367829]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 30
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (97.0,146.0)
# initial guess angle = [0.31053377493977047, 2.6895833685834614]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [ 83.11226111 132.53290882   1.80293333   3.07671663]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 31
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (97.0,0.0)
# initial guess angle = [0.4815840420296464, 0.4752713018434428]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [ 1.17447949e+02  3.41317221e-02  6.48882514e-01 -1.22648703e-03]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 32
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (97.0,49.0)
# initial guess angle = [0.9826148773282025, 1.001809443639625]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [1.23961302e+02 2.50591881e+01 1.80046188e+00 2.76053244e-02]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 33
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (97.0,49.0)
# initial guess angle = [0.5009274885122788, 1.94009967590218]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [124.3357354   48.22363422   1.32520974   3.16791461]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 34
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (146.0,97.0)
# initial guess angle = [0.06417209960573128, 1.0646458858738603]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [126.91601422  72.57495362  -1.75771054   3.1616884 ]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 35
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (146.0,97.0)
# initial guess angle = [1.198684710890507, 2.384898248912766]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [117.44633878  91.79606008   1.72967038   3.1367855 ]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 36
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (146.0,146.0)
# initial guess angle = [0.9520751673810657, 1.8974488421558797]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [119.66022545 117.05510524   1.44587448   3.14668768]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 37
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (97.0,146.0)
# initial guess angle = [0.4589482759776579, 1.3812635537928257]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [118.67857078 137.56293912   1.45546118  21.96728214]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 38
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (146.0,0.0)
# initial guess angle = [1.0281063032886282, 2.524131839157656]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [1.47316328e+02 5.42796055e-02 1.35287627e+00 3.14050535e+00]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 39
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (146.0,49.0)
# initial guess angle = [1.3201383288670208, 2.386042866038949]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [147.20222202  24.78008618   1.36435618   3.15628833]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 40
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (146.0,49.0)
# initial guess angle = [0.8850837395287751, 2.5152181431926457]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [147.7125388   46.89572981   1.34788177   3.15499297]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 41
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (146.0,97.0)
# initial guess angle = [0.7099249254464384, 1.1164238630341554]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [1.47374934e+02 7.15599650e+01 1.76926156e+00 1.45396002e-02]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 42
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (146.0,97.0)
# initial guess angle = [0.3522103951305109, 0.43676806507250504]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [ 1.47397832e+02  9.26899069e+01  1.76503532e+00 -1.70045456e-03]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 43
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (146.0,146.0)
# initial guess angle = [1.3515329647775822, 2.793702276032532]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [138.13234497 115.75168      1.58694643   3.10627267]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 44
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (146.0,146.0)
# initial guess angle = [0.382719925105065, 3.0300332672917385]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [133.46417167 135.36504773   1.68898755   3.07752083]

# %%
sim_inst_0 = bem.LoadedSimExp(f'sim_inst_xmol_grid_d{disk_diameter}_transFit', exp_res_param_file)
fit_inst_0 = bem.LoadedFit(f'fit_inst_xmol_grid_d{disk_diameter}_transFit', exp_res_param_file)
# Out:
# No 'quench_over_real_disk' param found in file.
# No 'quench_over_real_disk' param found in file.
# No 'quench_over_real_disk' param found in file.
# No 'quench_over_real_disk' param found in file.

# %%
## Plot fit results
# fit_inst_0.plot_fit_results_as_quiver_map(sim_inst_0)   

fig5 = bem.fig5_3D(
    sim_inst_0, 
    fit_inst_0, 
    draw_quadrant=True, 
#     show_ax_labels=True,
    quiv_ax_limits=[-25, 175, -25, 175],
    quiv_tick_list=np.linspace(0,150,7),
    quiv_ticklabel_list=[r'$0$', r'$25$',r'$50$',r'$75$',r'$100$',r'$125$', r'$150$'],
    )

# ## Histogram fits
# plt.figure()
# fit_pos = fit_inst_0.model_fit_results[:, :2]
# radial_fit_pos = np.sqrt(np.sum(fit_pos**2, axis=1))
# hist, _, _ = plt.hist(radial_fit_pos)
# plt.vlines(
#     sim_inst_0.a_long_meters / fit.cm_per_nm, 0, hist.max(),
#     lw=1, color='gray', linestyle='--')

# plt.xlabel('Radial fit location')
# plt.ylabel('Number of molecules')
# Out:
# Calculating Gaussian centroid with BEM_images

# %%
param_file = high_res_param_file

locations, angles = fit.fixed_ori_mol_placement(
    mol_grid_pts_1D=7, x_max=150, y_max=150)
sim_inst_0h = bem.SimulatedExperiment(
    locations, 
    mol_angle=0,
    param_file=param_file,
    simulation_file_name=f'CurlyDiskJC_NoSub_dipDrive_E_d{disk_diameter}')
sim_inst_0h.trial_images = sim_inst_0h.calculate_BEM_fields()

# Model fit
# Gaussian guess, checked

fit_inst_0h = fit.FitModelToData(
    sim_inst_0h.BEM_images, 
#     ini_guess=simTestInst_few_mol.mol_locations,
    ini_guess='gauss',
    param_file=param_file
    )
the_fit = fit_inst_0h.fit_model_to_image_data(
    check_ini=True,
    let_mol_ori_out_of_plane=True)

sim_inst_0h.calculate_polarization()
bem.save_sim_exp_inst(sim_inst_0h, f'sim_inst_xmol_grid_d{disk_diameter}_transFit_hr')
bem.save_fit_inst(fit_inst_0h, sim_inst_0h, f'fit_inst_xmol_grid_d{disk_diameter}_transFit_hr')
# Out:
# No 'quench_over_real_disk' param found in file.
# /Users/chair/Documents/Academia/SuperRes/Biteen_colab/Mispolarization/python/misloc_mispol_package/optics/anal_foc_diff_fields.py:27: RuntimeWarning: divide by zero encountered in true_divide
#   sphj1_on_krho = spf.spherical_jn( 1, k*rho(xi, y) )/(k*rho(xi, y))
# /Users/chair/Documents/Academia/SuperRes/Biteen_colab/Mispolarization/python/misloc_mispol_package/optics/anal_foc_diff_fields.py:27: RuntimeWarning: invalid value encountered in true_divide
#   sphj1_on_krho = spf.spherical_jn( 1, k*rho(xi, y) )/(k*rho(xi, y))
# /Users/chair/Documents/Academia/SuperRes/Biteen_colab/Mispolarization/python/misloc_mispol_package/optics/anal_foc_diff_fields.py:30: RuntimeWarning: divide by zero encountered in true_divide
#   j2_on_krho = spf.jv(2, k*rho(xi, y) )/(k*rho(xi, y))
# /Users/chair/Documents/Academia/SuperRes/Biteen_colab/Mispolarization/python/misloc_mispol_package/optics/anal_foc_diff_fields.py:30: RuntimeWarning: invalid value encountered in true_divide
#   j2_on_krho = spf.jv(2, k*rho(xi, y) )/(k*rho(xi, y))
# /Users/chair/Documents/Academia/SuperRes/Biteen_colab/Mispolarization/python/misloc_mispol_package/optics/anal_foc_diff_fields.py:75: RuntimeWarning: divide by zero encountered in true_divide
#   j2_on_krho = spf.jv(2, k*rho(xi, y) )/(k*rho(xi, y))
# /Users/chair/Documents/Academia/SuperRes/Biteen_colab/Mispolarization/python/misloc_mispol_package/optics/anal_foc_diff_fields.py:75: RuntimeWarning: invalid value encountered in true_divide
#   j2_on_krho = spf.jv(2, k*rho(xi, y) )/(k*rho(xi, y))
# /Users/chair/Documents/Academia/SuperRes/Biteen_colab/Mispolarization/python/misloc_mispol_package/optics/anal_foc_diff_fields.py:78: RuntimeWarning: divide by zero encountered in true_divide
#   sphj0_on_krhosqrd = spf.spherical_jn(0, k*rho(xi, y) )/(k*rho(xi, y))**2.
# /Users/chair/Documents/Academia/SuperRes/Biteen_colab/Mispolarization/python/misloc_mispol_package/optics/anal_foc_diff_fields.py:82: RuntimeWarning: invalid value encountered in add
#   sphj0_on_krhosqrd
# No 'quench_over_real_disk' param found in file.
# starting Matlab...
# given even number of points for Fibonacci lattice,
#   adding 1...
# 1th molecule
# calculating diffracted fields
# 2th molecule
# calculating diffracted fields
# 3th molecule
# calculating diffracted fields
# 4th molecule
# calculating diffracted fields
# 5th molecule
# calculating diffracted fields
# 6th molecule
# calculating diffracted fields
# 7th molecule
# calculating diffracted fields
# 8th molecule
# calculating diffracted fields
# 9th molecule
# calculating diffracted fields
# 10th molecule
# calculating diffracted fields
# 11th molecule
# calculating diffracted fields
# 12th molecule
# calculating diffracted fields
# 13th molecule
# calculating diffracted fields
# 14th molecule
# calculating diffracted fields
# 15th molecule
# calculating diffracted fields
# 16th molecule
# calculating diffracted fields
# 17th molecule
# calculating diffracted fields
# 18th molecule
# calculating diffracted fields
# 19th molecule
# calculating diffracted fields
# 20th molecule
# calculating diffracted fields
# 21th molecule
# calculating diffracted fields
# 22th molecule
# calculating diffracted fields
# 23th molecule
# calculating diffracted fields
# 24th molecule
# calculating diffracted fields
# 25th molecule
# calculating diffracted fields
# 26th molecule
# calculating diffracted fields
# 27th molecule
# calculating diffracted fields
# 28th molecule
# calculating diffracted fields
# 29th molecule
# calculating diffracted fields
# 30th molecule
# calculating diffracted fields
# 31th molecule
# calculating diffracted fields
# 32th molecule
# calculating diffracted fields
# 33th molecule
# calculating diffracted fields
# 34th molecule
# calculating diffracted fields
# 35th molecule
# calculating diffracted fields
# 36th molecule
# calculating diffracted fields
# 37th molecule
# calculating diffracted fields
# 38th molecule
# calculating diffracted fields
# 39th molecule
# calculating diffracted fields
# 40th molecule
# calculating diffracted fields
# 41th molecule
# calculating diffracted fields
# 42th molecule
# calculating diffracted fields
# 43th molecule
# calculating diffracted fields
# 44th molecule
# calculating diffracted fields
# 45th molecule
# calculating diffracted fields
# No 'quench_over_real_disk' param found in file.
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 0
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (3.0,0.0)
# initial guess angle = [0.30767024142271326, 0.45467406173810926]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? True
# Initial guess in quench. Zone, OG params: [3.0, 0.0, 0.30767024142271326, 0.45467406173810926]
# Params shifted to: [52.26575881, 0.0, 0.30767024142271326, 0.45467406173810926]
# running fit...
# SUCCESS, Resulting fit params: [36.41803405 39.83767807  1.67967107 -2.07519366]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 1
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (0.0,102.0)
# initial guess angle = [0.7689004191385893, 2.448528902901444]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [ 4.39905989 76.42583877  1.35653325  3.24640534]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 2
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (0.0,135.0)
# initial guess angle = [1.223385269138474, 3.0655776954321996]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [ 0.55398541 95.21357085  1.53875836  3.15472991]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 3
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (0.0,154.0)
# initial guess angle = [0.6011723398641394, 1.2314707893927246]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [-9.48654875e-03  1.15801203e+02  1.57020747e+00 -9.13916697e-04]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 4
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (0.0,171.0)
# initial guess angle = [0.0028580557178778, 2.607262297584746]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [ 5.44336736e-03  1.43224547e+02  1.57114979e+00 -3.14253242e+00]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 5
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (0.0,10.0)
# initial guess angle = [1.015721584743193, 2.4187816720443966]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? True
# Initial guess in quench. Zone, OG params: [0.0, 10.0, 1.015721584743193, 2.4187816720443966]
# Params shifted to: [3.016657691711601e-15, 59.26575881, 1.015721584743193, 2.4187816720443966]
# running fit...
# SUCCESS, Resulting fit params: [20.22481499 56.60903824  1.67650144  2.91511552]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 6
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (7.0,82.0)
# initial guess angle = [0.7392531937777568, 2.8908731037953035]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [31.4059135  87.30010649  1.16478368  3.05883935]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 7
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (30.0,131.0)
# initial guess angle = [0.04573184669467699, 0.3621665167864925]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [20.30252311 94.18323144  1.71948678  3.1423549 ]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 8
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (30.0,151.0)
# initial guess angle = [0.5906466485844434, 0.26736809570668607]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [ 2.11401273e+01  1.16873275e+02  1.49789956e+00 -7.47717636e-03]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 9
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (26.0,171.0)
# initial guess angle = [0.1380539621605184, 1.7808830449684347]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [ 23.2284139  143.68038037   1.60441509   3.12985476]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 10
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (7.0,0.0)
# initial guess angle = [0.33948367447992117, 1.9683184147016122]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? True
# Initial guess in quench. Zone, OG params: [7.0, 0.0, 0.33948367447992117, 1.9683184147016122]
# Params shifted to: [56.26575881, 0.0, 0.33948367447992117, 1.9683184147016122]
# running fit...
# SUCCESS, Resulting fit params: [6.50642852e+01 5.37482087e-02 1.78213046e+00 3.14025612e+00]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 11
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (7.0,7.0)
# initial guess angle = [1.4598978267496017, 2.588302297426676]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? True
# Initial guess in quench. Zone, OG params: [7.0, 7.0, 1.4598978267496017, 2.588302297426676]
# Params shifted to: [41.8361521348519, 41.83615213485189, 1.4598978267496017, 2.588302297426676]
# running fit...
# SUCCESS, Resulting fit params: [57.76802622 32.08905607  1.64042365  2.99351309]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 12
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (10.0,20.0)
# initial guess angle = [0.39023354023375467, 0.2816843899706967]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? True
# Initial guess in quench. Zone, OG params: [10.0, 20.0, 0.39023354023375467, 0.2816843899706967]
# Params shifted to: [32.032317132453834, 64.06463426490765, 0.39023354023375467, 0.2816843899706967]
# running fit...
# SUCCESS, Resulting fit params: [52.70388102 55.07854874  1.52407586 -0.08920195]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 13
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (33.0,76.0)
# initial guess angle = [1.4925588388217441, 3.1243011120273763]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [51.73112858 75.9958403   1.73555953  3.13089493]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 14
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (53.0,122.0)
# initial guess angle = [0.5882552124833276, 1.4472602992813364]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [4.58591728e+01 9.64929287e+01 1.41545462e+00 1.90722194e-02]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 15
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (56.0,148.0)
# initial guess angle = [0.228289581376922, 2.231098761310939]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [ 45.54810205 119.32630346   1.66257726   3.13405524]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 16
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (53.0,168.0)
# initial guess angle = [0.662614680163085, 2.522746481052593]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [ 47.61872368 144.6790538    1.61933961   3.12238211]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 17
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (20.0,0.0)
# initial guess angle = [0.9068155537764886, 0.1344093005704841]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? True
# Initial guess in quench. Zone, OG params: [20.0, 0.0, 0.9068155537764886, 0.1344093005704841]
# Params shifted to: [69.26575881, 0.0, 0.9068155537764886, 0.1344093005704841]
# running fit...
# SUCCESS, Resulting fit params: [ 8.26453647e+01  9.55887278e-02  1.46949913e+00 -1.70693123e-03]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 18
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (23.0,10.0)
# initial guess angle = [0.5261453618663232, 2.5402797894981934]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? True
# Initial guess in quench. Zone, OG params: [23.0, 10.0, 0.5261453618663232, 2.5402797894981934]
# Params shifted to: [68.18015220324502, 29.64354443619347, 0.5261453618663232, 2.5402797894981934]
# running fit...
# SUCCESS, Resulting fit params: [81.08524912 26.947904    1.61834281  3.11585591]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 19
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (36.0,33.0)
# initial guess angle = [1.0808867572944514, 1.9871577190464464]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? True
# Initial guess in quench. Zone, OG params: [36.0, 33.0, 1.0808867572944514, 1.9871577190464464]
# Params shifted to: [72.31645807692266, 66.29008657051241, 1.0808867572944514, 1.9871577190464464]
# running fit...
# SUCCESS, Resulting fit params: [80.35203109 52.2157376   1.58243575  3.10385165]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 20
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (66.0,82.0)
# initial guess angle = [1.0563678219026114, 1.9007794036100174]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [80.65905515 76.76780777  1.57419886  3.12762344]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 21
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (79.0,118.0)
# initial guess angle = [1.0070757372226136, 1.9491103844718245]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [74.26050398 98.74148864  1.68292168  3.14572597]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 22
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (79.0,145.0)
# initial guess angle = [0.8379066479836875, 2.3805328025215444]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [ 72.10146714 121.21040741   1.64575051   3.1280048 ]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 23
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (76.0,164.0)
# initial guess angle = [0.5803975615571811, 1.4930052733772181]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [ 73.03995804 145.79238783   1.60926958   3.11901522]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 24
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (53.0,0.0)
# initial guess angle = [0.6305954894028876, 0.6572541419625599]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [ 1.04847381e+02  1.04984974e-01  4.74745733e+00 -1.68458095e-03]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 25
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (59.0,20.0)
# initial guess angle = [0.5056219999306385, 0.1728349636559362]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [1.04637382e+02 2.55996096e+01 1.61789882e+00 2.54590303e-03]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 26
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (79.0,49.0)
# initial guess angle = [0.5113376116358708, 1.2270529753750978]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [104.46786291  50.81177304   1.49333994   3.146493  ]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 27
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (99.0,85.0)
# initial guess angle = [0.1466873975678284, 0.6925802159497079]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [1.04592491e+02 7.55686481e+01 1.65188674e+00 8.99145932e-03]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 28
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (105.0,115.0)
# initial guess angle = [0.39197926026519436, 0.7146187350189573]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [ 1.01969174e+02  9.91947653e+01  1.57936269e+00 -5.22786295e-04]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 29
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (105.0,141.0)
# initial guess angle = [0.5501269623176781, 0.45514170736853277]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [ 9.86899444e+01  1.22080678e+02  1.54119453e+00 -1.84497254e-02]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 30
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (102.0,161.0)
# initial guess angle = [1.1490396443767439, 1.0764819761831268]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [ 9.87796723e+01  1.46648571e+02  1.55238890e+00 -2.34698646e-02]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 31
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (112.0,0.0)
# initial guess angle = [0.19221086012868108, 1.864848712188729]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [ 1.28261502e+02  8.00650756e-02 -1.64766581e+00  3.14029134e+00]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 32
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (118.0,26.0)
# initial guess angle = [0.28219069358985394, 0.1823893105354958]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [1.28164104e+02 2.51704484e+01 1.65140230e+00 2.99948204e-03]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 33
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (128.0,59.0)
# initial guess angle = [0.2564986968869366, 1.3194526160794102]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [128.01727968  50.05596389  -1.65472081   3.14602317]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 34
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (135.0,85.0)
# initial guess angle = [1.0893613457029212, 2.015334466868743]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [127.60824684  74.536071     1.50198913   3.14167628]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 35
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (135.0,112.0)
# initial guess angle = [0.00817753325578338, 2.492196086099706]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [125.74494382  98.44674921  -1.54463627  12.55515668]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 36
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (131.0,138.0)
# initial guess angle = [0.5272971293588247, 2.1353898212357283]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [124.01690974 122.3306187    1.56861773   3.12000539]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 37
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (128.0,158.0)
# initial guess angle = [0.051322898101989055, 1.237122252448481]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [ 1.24282279e+02  1.47380342e+02 -1.56894394e+00 -2.16949023e-02]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 38
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (164.0,0.0)
# initial guess angle = [0.030804103438653505, 2.5646251360027223]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [ 1.51202718e+02  5.21251018e-02 -1.64032080e+00  3.14055610e+00]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 39
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (164.0,30.0)
# initial guess angle = [0.2936873603859893, 2.119154750756346]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [151.09111208  24.78725267  -1.63891787   3.1395875 ]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 40
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (164.0,59.0)
# initial guess angle = [0.43521451068933303, 0.4252180664583461]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [ 1.50780853e+02  4.93701044e+01  1.63071369e+00 -5.18276421e-03]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 41
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (164.0,85.0)
# initial guess angle = [1.4613045014087753, 1.8693249616603413]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [150.02631247  73.70133615   1.52753471   3.13019446]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 42
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (161.0,112.0)
# initial guess angle = [1.3989999776265931, 0.9632104278206742]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [ 1.48986657e+02  9.79554041e+01  1.59478082e+00 -1.88584101e-02]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 43
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (154.0,135.0)
# initial guess angle = [1.3035022939866394, 2.958382300644471]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [148.82002938 122.58921575   1.55617309   3.11953445]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 44
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (151.0,158.0)
# initial guess angle = [0.6207533035254376, 2.840411468327458]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [149.55494888 147.9447236    1.55645193   3.12307424]

# %%
sim_inst_0h = bem.LoadedSimExp(f'sim_inst_xmol_grid_d{disk_diameter}_transFit_hr', high_res_param_file)
fit_inst_0h = bem.LoadedFit(f'fit_inst_xmol_grid_d{disk_diameter}_transFit_hr', high_res_param_file)
# Out:
# No 'quench_over_real_disk' param found in file.
# No 'quench_over_real_disk' param found in file.
# No 'quench_over_real_disk' param found in file.
# No 'quench_over_real_disk' param found in file.

# %%
## Plot fit results
# fit_inst_0h.plot_fit_results_as_quiver_map(sim_inst_0h)   

fig5 = bem.fig5_3D(
    sim_inst_0h, 
    fit_inst_0h, 
    draw_quadrant=True, 
#     show_ax_labels=True,
    quiv_ax_limits=[-25, 175, -25, 175],
    quiv_tick_list=np.linspace(0,150,7),
    quiv_ticklabel_list=[r'$0$', r'$25$',r'$50$',r'$75$',r'$100$',r'$125$', r'$150$'],
    )

# ## Histogram fits
# plt.figure()
# fit_pos = fit_inst_0h.model_fit_results[:, :2]
# radial_fit_pos = np.sqrt(np.sum(fit_pos**2, axis=1))
# hist, _, _ = plt.hist(radial_fit_pos)
# plt.vlines(
#     sim_inst_0h.a_long_meters / fit.cm_per_nm, 0, hist.max(),
#     lw=1, color='gray', linestyle='--')

# plt.xlabel('Radial fit location')
# plt.ylabel('Number of molecules')
# Out:
# Calculating Gaussian centroid with BEM_images

# %%
param_file = exp_res_param_file

locations, angles = fit.fixed_ori_mol_placement(
    mol_grid_pts_1D=7, x_max=150, y_max=150)
oop_angles = np.zeros((locations.shape[0], 2))

sim_inst_1 = bem.SimulatedExperiment(
    locations, 
    mol_angle=oop_angles,
    param_file=param_file,
    simulation_file_name=f'CurlyDiskJC_NoSub_dipDrive_E_d{disk_diameter}')
sim_inst_1.trial_images = sim_inst_1.calculate_BEM_fields()

# Model fit
# Gaussian guess, checked

fit_inst_1 = fit.FitModelToData(
    sim_inst_1.BEM_images, 
#     ini_guess=simTestInst_few_mol.mol_locations,
    ini_guess='gauss',
    param_file=param_file
    )
the_fit = fit_inst_1.fit_model_to_image_data(
    check_ini=True,
    let_mol_ori_out_of_plane=True)

sim_inst_1.calculate_polarization()
bem.save_sim_exp_inst(sim_inst_1, f'sim_inst_zmol_grid_d{disk_diameter}_transFit')
bem.save_fit_inst(fit_inst_1, sim_inst_1, f'fit_inst_zmol_grid_d{disk_diameter}_transFit')
# Out:
# No 'quench_over_real_disk' param found in file.
# /Users/chair/Documents/Academia/SuperRes/Biteen_colab/Mispolarization/python/misloc_mispol_package/optics/anal_foc_diff_fields.py:27: RuntimeWarning: invalid value encountered in true_divide
#   sphj1_on_krho = spf.spherical_jn( 1, k*rho(xi, y) )/(k*rho(xi, y))
# /Users/chair/Documents/Academia/SuperRes/Biteen_colab/Mispolarization/python/misloc_mispol_package/optics/anal_foc_diff_fields.py:30: RuntimeWarning: invalid value encountered in true_divide
#   j2_on_krho = spf.jv(2, k*rho(xi, y) )/(k*rho(xi, y))
# /Users/chair/Documents/Academia/SuperRes/Biteen_colab/Mispolarization/python/misloc_mispol_package/optics/anal_foc_diff_fields.py:75: RuntimeWarning: invalid value encountered in true_divide
#   j2_on_krho = spf.jv(2, k*rho(xi, y) )/(k*rho(xi, y))
# /Users/chair/Documents/Academia/SuperRes/Biteen_colab/Mispolarization/python/misloc_mispol_package/optics/anal_foc_diff_fields.py:78: RuntimeWarning: divide by zero encountered in true_divide
#   sphj0_on_krhosqrd = spf.spherical_jn(0, k*rho(xi, y) )/(k*rho(xi, y))**2.
# /Users/chair/Documents/Academia/SuperRes/Biteen_colab/Mispolarization/python/misloc_mispol_package/optics/anal_foc_diff_fields.py:82: RuntimeWarning: invalid value encountered in add
#   sphj0_on_krhosqrd
# No 'quench_over_real_disk' param found in file.
# starting Matlab...
# given even number of points for Fibonacci lattice,
#   adding 1...
# 1th molecule
# mol_orientation = [0.0, 0.0, 1.0]
# calculating diffracted fields
# 2th molecule
# mol_orientation = [0.0, 0.0, 1.0]
# calculating diffracted fields
# 3th molecule
# mol_orientation = [0.0, 0.0, 1.0]
# calculating diffracted fields
# 4th molecule
# mol_orientation = [0.0, 0.0, 1.0]
# calculating diffracted fields
# 5th molecule
# mol_orientation = [0.0, 0.0, 1.0]
# calculating diffracted fields
# 6th molecule
# mol_orientation = [0.0, 0.0, 1.0]
# calculating diffracted fields
# 7th molecule
# mol_orientation = [0.0, 0.0, 1.0]
# calculating diffracted fields
# 8th molecule
# mol_orientation = [0.0, 0.0, 1.0]
# calculating diffracted fields
# 9th molecule
# mol_orientation = [0.0, 0.0, 1.0]
# calculating diffracted fields
# 10th molecule
# mol_orientation = [0.0, 0.0, 1.0]
# calculating diffracted fields
# 11th molecule
# mol_orientation = [0.0, 0.0, 1.0]
# calculating diffracted fields
# 12th molecule
# mol_orientation = [0.0, 0.0, 1.0]
# calculating diffracted fields
# 13th molecule
# mol_orientation = [0.0, 0.0, 1.0]
# calculating diffracted fields
# 14th molecule
# mol_orientation = [0.0, 0.0, 1.0]
# calculating diffracted fields
# 15th molecule
# mol_orientation = [0.0, 0.0, 1.0]
# calculating diffracted fields
# 16th molecule
# mol_orientation = [0.0, 0.0, 1.0]
# calculating diffracted fields
# 17th molecule
# mol_orientation = [0.0, 0.0, 1.0]
# calculating diffracted fields
# 18th molecule
# mol_orientation = [0.0, 0.0, 1.0]
# calculating diffracted fields
# 19th molecule
# mol_orientation = [0.0, 0.0, 1.0]
# calculating diffracted fields
# 20th molecule
# mol_orientation = [0.0, 0.0, 1.0]
# calculating diffracted fields
# 21th molecule
# mol_orientation = [0.0, 0.0, 1.0]
# calculating diffracted fields
# 22th molecule
# mol_orientation = [0.0, 0.0, 1.0]
# calculating diffracted fields
# 23th molecule
# mol_orientation = [0.0, 0.0, 1.0]
# calculating diffracted fields
# 24th molecule
# mol_orientation = [0.0, 0.0, 1.0]
# calculating diffracted fields
# 25th molecule
# mol_orientation = [0.0, 0.0, 1.0]
# calculating diffracted fields
# 26th molecule
# mol_orientation = [0.0, 0.0, 1.0]
# calculating diffracted fields
# 27th molecule
# mol_orientation = [0.0, 0.0, 1.0]
# calculating diffracted fields
# 28th molecule
# mol_orientation = [0.0, 0.0, 1.0]
# calculating diffracted fields
# 29th molecule
# mol_orientation = [0.0, 0.0, 1.0]
# calculating diffracted fields
# 30th molecule
# mol_orientation = [0.0, 0.0, 1.0]
# calculating diffracted fields
# 31th molecule
# mol_orientation = [0.0, 0.0, 1.0]
# calculating diffracted fields
# 32th molecule
# mol_orientation = [0.0, 0.0, 1.0]
# calculating diffracted fields
# 33th molecule
# mol_orientation = [0.0, 0.0, 1.0]
# calculating diffracted fields
# 34th molecule
# mol_orientation = [0.0, 0.0, 1.0]
# calculating diffracted fields
# 35th molecule
# mol_orientation = [0.0, 0.0, 1.0]
# calculating diffracted fields
# 36th molecule
# mol_orientation = [0.0, 0.0, 1.0]
# calculating diffracted fields
# 37th molecule
# mol_orientation = [0.0, 0.0, 1.0]
# calculating diffracted fields
# 38th molecule
# mol_orientation = [0.0, 0.0, 1.0]
# calculating diffracted fields
# 39th molecule
# mol_orientation = [0.0, 0.0, 1.0]
# calculating diffracted fields
# 40th molecule
# mol_orientation = [0.0, 0.0, 1.0]
# calculating diffracted fields
# 41th molecule
# mol_orientation = [0.0, 0.0, 1.0]
# calculating diffracted fields
# 42th molecule
# mol_orientation = [0.0, 0.0, 1.0]
# calculating diffracted fields
# 43th molecule
# mol_orientation = [0.0, 0.0, 1.0]
# calculating diffracted fields
# 44th molecule
# mol_orientation = [0.0, 0.0, 1.0]
# calculating diffracted fields
# 45th molecule
# mol_orientation = [0.0, 0.0, 1.0]
# calculating diffracted fields
# No 'quench_over_real_disk' param found in file.
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 0
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (0.0,97.0)
# initial guess angle = [0.30505365361851144, 1.468278184790785]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [8.61043721e-02 9.50064351e+01 3.32901945e-01 1.57605269e+00]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 1
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (0.0,97.0)
# initial guess angle = [0.8485121281137109, 3.0590080796378034]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [-2.27225711e-02  7.29201197e+01 -8.27519746e-03  1.66962254e+00]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 2
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (0.0,97.0)
# initial guess angle = [1.421031592810306, 2.0750874205478054]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [-3.22233635e-02  9.31679118e+01  3.11605655e+00  1.61488772e+00]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 3
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (0.0,146.0)
# initial guess angle = [1.4844020580565025, 0.5775069436244353]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [-3.46095831e-02  1.19761490e+02 -2.14683599e-02  1.62281698e+00]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 4
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (0.0,146.0)
# initial guess angle = [0.8441529959586556, 2.1883564298262836]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [-3.37952136e-02  1.40900457e+02 -3.40972444e-02  1.59828783e+00]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 5
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (49.0,49.0)
# initial guess angle = [1.4277258261955246, 0.08058432741410813]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [ 1.82399464e+01  3.48703222e+01  1.01692161e-02 -2.94749406e+00]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 6
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (49.0,97.0)
# initial guess angle = [1.1322158340238382, 0.5692827582763391]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [ 2.55229453e+01  7.30289836e+01  9.20478165e-03 -4.28560408e-01]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 7
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (49.0,97.0)
# initial guess angle = [0.7006332941683334, 2.242854778007737]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [ 2.11251754e+01  9.37881237e+01 -2.96186573e-02  2.61730194e+00]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 8
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (0.0,146.0)
# initial guess angle = [1.4363555145610976, 2.395762575630309]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [ 2.16029964e+01  1.20074101e+02 -2.06008278e-02  2.73170944e+00]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 9
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (0.0,146.0)
# initial guess angle = [0.8391885751014042, 1.729360099865371]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [ 2.10302901e+01  1.41773178e+02 -2.45435659e-02  2.48675026e+00]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 10
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (97.0,0.0)
# initial guess angle = [1.4935719640696816, 0.30636737577597306]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [ 72.62988925 -13.61395751   2.41450029   1.12444939]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 11
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (49.0,49.0)
# initial guess angle = [0.5266879632137635, 3.0533645759829113]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [ 5.55956554e+01  2.69430489e+01 -4.96823208e-02  1.90086623e+00]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 12
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (49.0,49.0)
# initial guess angle = [0.7620465731779543, 2.5270020885908613]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [ 4.73156960e+01  4.71345101e+01 -1.16503055e-02  3.73563816e+00]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 13
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (49.0,97.0)
# initial guess angle = [1.267096811955517, 2.6028504922330216]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [ 4.70884223e+01  7.31996265e+01 -2.80719414e-02  3.43424069e+00]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 14
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (49.0,97.0)
# initial guess angle = [1.441675834542656, 0.3222749438580792]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [ 4.63629595e+01  9.41165712e+01  4.90448164e-02 -3.89817711e-02]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 15
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (49.0,97.0)
# initial guess angle = [1.1039712101665702, 1.5777953015064803]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [ 4.65155597e+01  1.20644687e+02 -3.32872902e-02  3.16338532e+00]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 16
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (49.0,146.0)
# initial guess angle = [0.31958063012874244, 2.593940022158697]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [ 4.61526843e+01  1.42266119e+02 -3.97885532e-02  3.14182494e+00]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 17
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (97.0,0.0)
# initial guess angle = [1.124064194163585, 1.2327442450000383]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [ 7.38221209e+01 -1.16119107e-03  9.64613236e-03  3.24694111e+00]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 18
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (97.0,49.0)
# initial guess angle = [0.023837174061627543, 1.3986531339025974]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [7.33357512e+01 2.21960487e+01 1.79877224e-02 1.78557273e+00]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 19
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (97.0,49.0)
# initial guess angle = [0.35695631158053465, 1.6797404417561006]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [6.80496163e+01 4.83129471e+01 3.38530452e-02 1.37984701e+00]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 20
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (97.0,97.0)
# initial guess angle = [1.3699650252821, 2.442003553281166]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [7.30495189e+01 7.36940955e+01 1.26773358e-02 7.69086239e+00]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 21
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (97.0,97.0)
# initial guess angle = [0.007916507514750419, 0.6729534165148652]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [6.82820397e+01 9.55117301e+01 3.80325001e-02 5.73967516e-01]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 22
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (49.0,97.0)
# initial guess angle = [0.5074504523464423, 2.691802208886549]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [ 7.25708394e+01  1.21622238e+02 -2.94280060e-02  4.28033523e+00]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 23
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (49.0,146.0)
# initial guess angle = [0.27635907743495525, 2.320481937406806]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [7.26664288e+01 1.44092615e+02 4.65105203e-02 1.13667753e+00]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 24
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (97.0,0.0)
# initial guess angle = [0.16466301078363807, 1.1056496386922317]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [ 9.51108410e+01 -2.41915737e-02  4.44079228e-02  3.18029997e+00]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 25
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (97.0,49.0)
# initial guess angle = [0.34844358561481054, 1.9891241000628272]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [9.55018556e+01 2.60657531e+01 4.57509637e-02 3.37354509e+00]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 26
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (97.0,49.0)
# initial guess angle = [1.070929943277344, 0.9389069556838368]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [ 9.55975052e+01  4.89355940e+01 -5.05869205e-02 -4.86401808e-01]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 27
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (97.0,97.0)
# initial guess angle = [1.1968217674312323, 1.9390748538707057]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [9.56807798e+01 7.47748163e+01 4.09748458e-02 2.36925448e+00]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 28
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (97.0,97.0)
# initial guess angle = [0.24003250917762056, 0.9424249377660862]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [9.49909821e+01 9.69492268e+01 4.98423452e-02 1.64423283e+00]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 29
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (97.0,97.0)
# initial guess angle = [0.4838590156871738, 0.03506439298724573]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [9.52296283e+01 1.23048335e+02 5.43348177e-02 1.72487618e+00]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 30
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (97.0,146.0)
# initial guess angle = [1.0435960979100263, 0.8347324789157456]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [9.50913577e+01 1.45072506e+02 6.76017029e-02 1.62390131e+00]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 31
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (146.0,0.0)
# initial guess angle = [1.325239074372448, 0.3324949861185314]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [ 1.17760429e+02 -2.87360127e-02  3.07525901e+00  6.30410093e+00]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 32
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (146.0,0.0)
# initial guess angle = [1.096281406733268, 0.9667199076766858]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [ 1.21423728e+02  2.49860441e+01 -6.18995393e-02  3.76555598e-01]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 33
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (97.0,49.0)
# initial guess angle = [1.0170851625640118, 2.0835586476491277]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [1.22174739e+02 4.82801208e+01 6.91950646e-02 3.00664037e+00]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 34
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (97.0,49.0)
# initial guess angle = [0.3626255497470782, 3.1208015352668887]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [1.22172701e+02 7.40665846e+01 6.70340650e-02 2.85687852e+00]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 35
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (97.0,97.0)
# initial guess angle = [1.4227577516051257, 0.24076075898114563]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [122.20545291  97.19693525   3.21339896   2.30172975]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 36
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (97.0,97.0)
# initial guess angle = [0.250378528845731, 1.6577440537988901]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# FAILURE, fit not converged, randomize angle guess and try again. Unconverged counter = 1.
# running fit...
# SUCCESS, Resulting fit params: [1.18008869e+02 1.23214497e+02 7.66559666e-02 2.06938891e+00]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 37
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (97.0,146.0)
# initial guess angle = [0.6977839263437754, 1.33363052377728]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [1.17810104e+02 1.45432646e+02 8.54828361e-02 1.98435690e+00]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 38
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (146.0,0.0)
# initial guess angle = [0.5535848315353754, 0.08717682420887288]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [ 1.44723317e+02  1.55266970e-02 -9.59467269e-02 -3.31983441e-03]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 39
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (146.0,0.0)
# initial guess angle = [0.7849669188398204, 0.20618649621390606]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [ 1.44538054e+02  2.22480391e+01 -8.58778123e-02 -8.46291713e-02]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 40
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (146.0,49.0)
# initial guess angle = [1.5271942158395901, 1.8191656725826695]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [1.45053291e+02 4.83684931e+01 9.97249013e-02 2.93355537e+00]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 41
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (146.0,49.0)
# initial guess angle = [1.3613539066635778, 1.3557184161248506]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [1.44924712e+02 7.46617879e+01 8.88992703e-02 2.75648893e+00]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 42
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (146.0,97.0)
# initial guess angle = [0.6783912115079878, 0.5659663192924391]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [ 1.44619593e+02  9.73829383e+01 -9.27390192e-02 -7.37903187e-01]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 43
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (146.0,97.0)
# initial guess angle = [1.1796433535264381, 2.3362380667338867]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [1.44539640e+02 1.23683282e+02 9.16342614e-02 2.27702833e+00]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 44
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (146.0,146.0)
# initial guess angle = [1.3974788331027146, 3.037198514727366]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [1.44404840e+02 1.45567276e+02 9.70108039e-02 2.15228485e+00]

# %%
sim_inst_1 = bem.LoadedSimExp(f'sim_inst_zmol_grid_d{disk_diameter}_transFit', exp_res_param_file)
fit_inst_1 = bem.LoadedFit(f'fit_inst_zmol_grid_d{disk_diameter}_transFit', exp_res_param_file)
# Out:
# No 'quench_over_real_disk' param found in file.
# No 'quench_over_real_disk' param found in file.
# No 'quench_over_real_disk' param found in file.
# No 'quench_over_real_disk' param found in file.

# %%
## Plot fit results
# fit_inst_0.plot_fit_results_as_quiver_map(sim_inst_0)   

fig5 = bem.fig5_3D(
    sim_inst_1, 
    fit_inst_1, 
    draw_quadrant=True, 
#     show_ax_labels=True,
    quiv_ax_limits=[-25, 175, -25, 175],
    quiv_tick_list=np.linspace(0,150,7),
    quiv_ticklabel_list=[r'$0$', r'$25$',r'$50$',r'$75$',r'$100$',r'$125$', r'$150$'],
    )

# ## Histogram fits
# plt.figure()
# fit_pos = fit_inst_0.model_fit_results[:, :2]
# radial_fit_pos = np.sqrt(np.sum(fit_pos**2, axis=1))
# hist, _, _ = plt.hist(radial_fit_pos)
# plt.vlines(
#     sim_inst_0.a_long_meters / fit.cm_per_nm, 0, hist.max(),
#     lw=1, color='gray', linestyle='--')

# plt.xlabel('Radial fit location')
# plt.ylabel('Number of molecules')
# Out:
# Calculating Gaussian centroid with BEM_images

# %%
param_file = high_res_param_file

locations, angles = fit.fixed_ori_mol_placement(
    mol_grid_pts_1D=7, x_max=150, y_max=150)
oop_angles = np.zeros((locations.shape[0], 2))

sim_inst_1h = bem.SimulatedExperiment(
    locations, 
    mol_angle=oop_angles,
    param_file=param_file,
    simulation_file_name=f'CurlyDiskJC_NoSub_dipDrive_E_d{disk_diameter}')
sim_inst_1h.trial_images = sim_inst_1h.calculate_BEM_fields()

# Model fit
# Gaussian guess, checked

fit_inst_1h = fit.FitModelToData(
    sim_inst_1h.BEM_images, 
#     ini_guess=simTestInst_few_mol.mol_locations,
    ini_guess='gauss',
    param_file=param_file
    )
the_fit = fit_inst_1h.fit_model_to_image_data(
    check_ini=True,
    let_mol_ori_out_of_plane=True)

sim_inst_1h.calculate_polarization()
bem.save_sim_exp_inst(sim_inst_1h, f'sim_inst_zmol_grid_d{disk_diameter}_transFit_hr')
bem.save_fit_inst(fit_inst_1h, sim_inst_1h, f'fit_inst_zmol_grid_d{disk_diameter}_transFit_hr')
# Out:
# No 'quench_over_real_disk' param found in file.
# /Users/chair/Documents/Academia/SuperRes/Biteen_colab/Mispolarization/python/misloc_mispol_package/optics/anal_foc_diff_fields.py:27: RuntimeWarning: divide by zero encountered in true_divide
#   sphj1_on_krho = spf.spherical_jn( 1, k*rho(xi, y) )/(k*rho(xi, y))
# /Users/chair/Documents/Academia/SuperRes/Biteen_colab/Mispolarization/python/misloc_mispol_package/optics/anal_foc_diff_fields.py:27: RuntimeWarning: invalid value encountered in true_divide
#   sphj1_on_krho = spf.spherical_jn( 1, k*rho(xi, y) )/(k*rho(xi, y))
# /Users/chair/Documents/Academia/SuperRes/Biteen_colab/Mispolarization/python/misloc_mispol_package/optics/anal_foc_diff_fields.py:30: RuntimeWarning: divide by zero encountered in true_divide
#   j2_on_krho = spf.jv(2, k*rho(xi, y) )/(k*rho(xi, y))
# /Users/chair/Documents/Academia/SuperRes/Biteen_colab/Mispolarization/python/misloc_mispol_package/optics/anal_foc_diff_fields.py:30: RuntimeWarning: invalid value encountered in true_divide
#   j2_on_krho = spf.jv(2, k*rho(xi, y) )/(k*rho(xi, y))
# /Users/chair/Documents/Academia/SuperRes/Biteen_colab/Mispolarization/python/misloc_mispol_package/optics/anal_foc_diff_fields.py:75: RuntimeWarning: divide by zero encountered in true_divide
#   j2_on_krho = spf.jv(2, k*rho(xi, y) )/(k*rho(xi, y))
# /Users/chair/Documents/Academia/SuperRes/Biteen_colab/Mispolarization/python/misloc_mispol_package/optics/anal_foc_diff_fields.py:75: RuntimeWarning: invalid value encountered in true_divide
#   j2_on_krho = spf.jv(2, k*rho(xi, y) )/(k*rho(xi, y))
# /Users/chair/Documents/Academia/SuperRes/Biteen_colab/Mispolarization/python/misloc_mispol_package/optics/anal_foc_diff_fields.py:78: RuntimeWarning: divide by zero encountered in true_divide
#   sphj0_on_krhosqrd = spf.spherical_jn(0, k*rho(xi, y) )/(k*rho(xi, y))**2.
# /Users/chair/Documents/Academia/SuperRes/Biteen_colab/Mispolarization/python/misloc_mispol_package/optics/anal_foc_diff_fields.py:82: RuntimeWarning: invalid value encountered in add
#   sphj0_on_krhosqrd
# No 'quench_over_real_disk' param found in file.
# starting Matlab...
# given even number of points for Fibonacci lattice,
#   adding 1...
# 1th molecule
# mol_orientation = [0.0, 0.0, 1.0]
# calculating diffracted fields
# 2th molecule
# mol_orientation = [0.0, 0.0, 1.0]
# calculating diffracted fields
# 3th molecule
# mol_orientation = [0.0, 0.0, 1.0]
# calculating diffracted fields
# 4th molecule
# mol_orientation = [0.0, 0.0, 1.0]
# calculating diffracted fields
# 5th molecule
# mol_orientation = [0.0, 0.0, 1.0]
# calculating diffracted fields
# 6th molecule
# mol_orientation = [0.0, 0.0, 1.0]
# calculating diffracted fields
# 7th molecule
# mol_orientation = [0.0, 0.0, 1.0]
# calculating diffracted fields
# 8th molecule
# mol_orientation = [0.0, 0.0, 1.0]
# calculating diffracted fields
# 9th molecule
# mol_orientation = [0.0, 0.0, 1.0]
# calculating diffracted fields
# 10th molecule
# mol_orientation = [0.0, 0.0, 1.0]
# calculating diffracted fields
# 11th molecule
# mol_orientation = [0.0, 0.0, 1.0]
# calculating diffracted fields
# 12th molecule
# mol_orientation = [0.0, 0.0, 1.0]
# calculating diffracted fields
# 13th molecule
# mol_orientation = [0.0, 0.0, 1.0]
# calculating diffracted fields
# 14th molecule
# mol_orientation = [0.0, 0.0, 1.0]
# calculating diffracted fields
# 15th molecule
# mol_orientation = [0.0, 0.0, 1.0]
# calculating diffracted fields
# 16th molecule
# mol_orientation = [0.0, 0.0, 1.0]
# calculating diffracted fields
# 17th molecule
# mol_orientation = [0.0, 0.0, 1.0]
# calculating diffracted fields
# 18th molecule
# mol_orientation = [0.0, 0.0, 1.0]
# calculating diffracted fields
# 19th molecule
# mol_orientation = [0.0, 0.0, 1.0]
# calculating diffracted fields
# 20th molecule
# mol_orientation = [0.0, 0.0, 1.0]
# calculating diffracted fields
# 21th molecule
# mol_orientation = [0.0, 0.0, 1.0]
# calculating diffracted fields
# 22th molecule
# mol_orientation = [0.0, 0.0, 1.0]
# calculating diffracted fields
# 23th molecule
# mol_orientation = [0.0, 0.0, 1.0]
# calculating diffracted fields
# 24th molecule
# mol_orientation = [0.0, 0.0, 1.0]
# calculating diffracted fields
# 25th molecule
# mol_orientation = [0.0, 0.0, 1.0]
# calculating diffracted fields
# 26th molecule
# mol_orientation = [0.0, 0.0, 1.0]
# calculating diffracted fields
# 27th molecule
# mol_orientation = [0.0, 0.0, 1.0]
# calculating diffracted fields
# 28th molecule
# mol_orientation = [0.0, 0.0, 1.0]
# calculating diffracted fields
# 29th molecule
# mol_orientation = [0.0, 0.0, 1.0]
# calculating diffracted fields
# 30th molecule
# mol_orientation = [0.0, 0.0, 1.0]
# calculating diffracted fields
# 31th molecule
# mol_orientation = [0.0, 0.0, 1.0]
# calculating diffracted fields
# 32th molecule
# mol_orientation = [0.0, 0.0, 1.0]
# calculating diffracted fields
# 33th molecule
# mol_orientation = [0.0, 0.0, 1.0]
# calculating diffracted fields
# 34th molecule
# mol_orientation = [0.0, 0.0, 1.0]
# calculating diffracted fields
# 35th molecule
# mol_orientation = [0.0, 0.0, 1.0]
# calculating diffracted fields
# 36th molecule
# mol_orientation = [0.0, 0.0, 1.0]
# calculating diffracted fields
# 37th molecule
# mol_orientation = [0.0, 0.0, 1.0]
# calculating diffracted fields
# 38th molecule
# mol_orientation = [0.0, 0.0, 1.0]
# calculating diffracted fields
# 39th molecule
# mol_orientation = [0.0, 0.0, 1.0]
# calculating diffracted fields
# 40th molecule
# mol_orientation = [0.0, 0.0, 1.0]
# calculating diffracted fields
# 41th molecule
# mol_orientation = [0.0, 0.0, 1.0]
# calculating diffracted fields
# 42th molecule
# mol_orientation = [0.0, 0.0, 1.0]
# calculating diffracted fields
# 43th molecule
# mol_orientation = [0.0, 0.0, 1.0]
# calculating diffracted fields
# 44th molecule
# mol_orientation = [0.0, 0.0, 1.0]
# calculating diffracted fields
# 45th molecule
# mol_orientation = [0.0, 0.0, 1.0]
# calculating diffracted fields
# No 'quench_over_real_disk' param found in file.
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 0
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (0.0,85.0)
# initial guess angle = [0.5263514537616858, 1.019760972613551]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [  0.80696384 104.33067241   0.42478979   1.62957843]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 1
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (0.0,82.0)
# initial guess angle = [1.5640932239537233, 2.9920856671961324]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [-4.03150407e-02  7.72986069e+01  3.13803543e+00  4.33316008e+00]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 2
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (0.0,105.0)
# initial guess angle = [0.3591128580899178, 2.6301477377103795]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [-5.74345533e-02  1.00630918e+02 -2.22565165e-03  2.54900920e+00]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 3
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (0.0,128.0)
# initial guess angle = [0.5379315762803051, 3.0763837897658517]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [-4.99687698e-02  1.25122924e+02 -3.87754739e-03  1.95599760e+00]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 4
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (0.0,154.0)
# initial guess angle = [1.3348904097018564, 2.8428878290950785]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [-3.03612040e-02  1.49933800e+02 -3.41533353e-03  1.80944755e+00]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 5
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (33.0,66.0)
# initial guess angle = [0.9011242446273283, 0.9241037274957232]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [34.24857262 59.60601537  0.15883786  3.66905273]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 6
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (26.0,82.0)
# initial guess angle = [0.3102715544666746, 1.6583585476240668]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [ 2.58243993e+01  7.65665900e+01 -1.28927408e-02  2.42537160e-01]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 7
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (26.0,105.0)
# initial guess angle = [1.0548144345809796, 2.3303977266210176]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [ 2.51239757e+01  1.00535611e+02 -1.90853230e-03  2.40012525e+00]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 8
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (26.0,128.0)
# initial guess angle = [0.26763732444141614, 1.6835417806082305]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [ 2.49568275e+01  1.25115033e+02 -4.49652502e-03  2.45127258e+00]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 9
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (26.0,154.0)
# initial guess angle = [0.6850397034847516, 0.6541556515074252]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [ 2.49073545e+01  1.49963503e+02  3.81239900e-03 -4.45757177e+01]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 10
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (85.0,0.0)
# initial guess angle = [0.8685911769632345, 0.8668085214517847]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [ 8.64331731e+01  6.46273786e-02  3.14983244e-01 -3.82955358e-03]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 11
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (66.0,33.0)
# initial guess angle = [0.8404617329425517, 0.6286620478552623]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [63.56613528 26.90412651  0.0747886  -0.89680154]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 12
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (56.0,56.0)
# initial guess angle = [1.4136264313138274, 1.0621813509253417]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [ 5.26701087e+01  5.11732124e+01 -3.59422145e-02  9.95267768e-01]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 13
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (53.0,79.0)
# initial guess angle = [0.958711351970684, 0.3830637775086016]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [ 5.07326911e+01  7.56888785e+01 -7.52845902e-03  7.52993835e-01]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 14
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (53.0,102.0)
# initial guess angle = [0.9896286918413495, 0.8546399313979632]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [5.01660157e+01 1.00339952e+02 2.91154654e-03 5.97722678e+00]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 15
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (53.0,128.0)
# initial guess angle = [1.50251630861831, 1.2382721465765218]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [ 4.99505941e+01  1.25128417e+02  4.69270327e-03 -6.43290150e+00]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 16
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (53.0,154.0)
# initial guess angle = [0.9541119881541225, 0.6779976841142995]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [4.98863407e+01 1.50073021e+02 4.09416032e-03 3.77601483e-01]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 17
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (82.0,0.0)
# initial guess angle = [1.3532036550994642, 2.526886386607697]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [ 7.72566196e+01 -3.06450731e-03 -9.52102297e-03  2.90676963e+00]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 18
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (82.0,26.0)
# initial guess angle = [0.38584304625389926, 2.8621432998159233]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [7.67729567e+01 2.52373836e+01 1.23467583e-02 4.94763071e+00]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 19
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (79.0,53.0)
# initial guess angle = [0.06307536111357591, 2.3642781867045355]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [ 7.59854616e+01  5.03985180e+01 -8.46237799e-03  1.18740692e+00]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 20
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (79.0,79.0)
# initial guess angle = [0.7192186061702667, 2.6246730960614073]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [7.54651580e+01 7.54449616e+01 1.10944304e-03 3.48161049e+00]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 21
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (76.0,102.0)
# initial guess angle = [0.7311836478230502, 0.20603222996516093]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [7.51081520e+01 1.00324682e+02 3.54624964e-03 7.95540793e-01]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 22
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (76.0,128.0)
# initial guess angle = [0.355856889982111, 3.1239206756612985]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [ 7.49467844e+01  1.25240174e+02 -5.03676370e-03  4.04300202e+00]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 23
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (76.0,151.0)
# initial guess angle = [0.5249249509272484, 0.5036136921392174]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [7.49177956e+01 1.50200609e+02 6.71315272e-03 1.33990593e+00]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 24
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (105.0,0.0)
# initial guess angle = [1.26579610119336, 0.14159103862855738]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [ 1.00729863e+02 -4.61794829e-02  3.13826378e+00  1.30734859e+00]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 25
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (105.0,26.0)
# initial guess angle = [0.10431462287416744, 0.9346828118388385]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [ 1.00694722e+02  2.51060497e+01 -6.14766924e-03  9.69530957e-01]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 26
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (102.0,53.0)
# initial guess angle = [0.07445727684377923, 3.1281236528022434]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [1.00553143e+02 5.02733492e+01 7.20084913e-03 3.50262210e+00]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 27
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (102.0,76.0)
# initial guess angle = [1.0856227155996623, 1.6323289455023409]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [ 1.00377597e+02  7.53738040e+01 -6.81066514e-03 -4.48661643e-01]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 28
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (102.0,102.0)
# initial guess angle = [1.2647524078020063, 2.081263665902657]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [1.00183017e+02 1.00384684e+02 7.29276530e-03 2.03619774e+00]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 29
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (102.0,128.0)
# initial guess angle = [0.2721639527963831, 0.689999931456963]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [1.00071176e+02 1.25347354e+02 8.65721379e-03 1.83921646e+00]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 30
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (102.0,151.0)
# initial guess angle = [1.3629709967919261, 1.058595228736507]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [1.00053262e+02 1.50290382e+02 1.05386143e-02 1.88419152e+00]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 31
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (128.0,0.0)
# initial guess angle = [0.703151805920368, 1.2287890797633176]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [ 1.25414742e+02 -5.37938877e-02 -6.79755016e-03  3.91019193e-01]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 32
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (128.0,26.0)
# initial guess angle = [0.08172823758134964, 2.213483614130671]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [ 1.25439214e+02  2.50292317e+01 -8.80926624e-03  3.75035936e-01]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 33
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (128.0,53.0)
# initial guess angle = [0.8483463822961178, 2.124156713824245]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [1.25456768e+02 5.01492436e+01 1.10391383e-02 3.24384141e+00]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 34
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (128.0,76.0)
# initial guess angle = [0.4370448448881883, 1.2783577450435408]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [1.25410450e+02 7.52608550e+01 1.18675678e-02 1.54046238e+01]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 35
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (128.0,102.0)
# initial guess angle = [0.3026135389342147, 1.3184718717623332]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [1.25292219e+02 1.00325892e+02 1.17107252e-02 2.45973975e+00]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 36
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (128.0,128.0)
# initial guess angle = [1.0265019092427918, 2.9678281580202284]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [1.25199607e+02 1.25321717e+02 1.20937770e-02 2.24868703e+00]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 37
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (125.0,151.0)
# initial guess angle = [1.0421561325665685, 1.6498379497072042]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [1.25140410e+02 1.50268825e+02 1.30852613e-02 2.17849117e+00]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 38
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (154.0,0.0)
# initial guess angle = [0.6540281036979053, 0.331594112663018]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [ 1.50341253e+02 -4.35488883e-02 -1.00717664e-02  1.68314688e-01]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 39
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (154.0,26.0)
# initial guess angle = [0.7493865532290281, 0.48728644598579973]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [ 1.50373254e+02  2.49926714e+01 -1.13532826e-02  1.54480495e-01]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 40
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (154.0,53.0)
# initial guess angle = [0.9144974886877028, 2.294138854326826]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [1.50411189e+02 5.00688023e+01 1.30269628e-02 3.13741165e+00]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 41
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (151.0,76.0)
# initial guess angle = [1.4867518301673015, 0.9325907883255787]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [1.50370183e+02 7.51518773e+01 1.36527751e-02 2.87194275e+00]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 42
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (151.0,102.0)
# initial guess angle = [0.6234577623648823, 0.574760469172788]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [ 1.50288388e+02  1.00219219e+02 -1.33632706e-02 -5.31337189e-01]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 43
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (151.0,125.0)
# initial guess angle = [1.3790657280646221, 2.5889149543209737]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [1.50216518e+02 1.25213282e+02 1.34988119e-02 2.43248928e+00]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 44
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (151.0,151.0)
# initial guess angle = [1.2173041559660789, 0.17998196423224608]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [ 1.50187015e+02  1.50198888e+02 -1.41998922e-02 -7.85816519e-01]

# %%
sim_inst_1h = bem.LoadedSimExp(f'sim_inst_zmol_grid_d{disk_diameter}_transFit_hr', high_res_param_file)
fit_inst_1h = bem.LoadedFit(f'fit_inst_zmol_grid_d{disk_diameter}_transFit_hr', high_res_param_file)
# Out:
# No 'quench_over_real_disk' param found in file.
# No 'quench_over_real_disk' param found in file.
# No 'quench_over_real_disk' param found in file.
# No 'quench_over_real_disk' param found in file.

# %%
## Plot fit results
# fit_inst_0.plot_fit_results_as_quiver_map(sim_inst_0)   

fig5 = bem.fig5_3D(
    sim_inst_1h, 
    fit_inst_1h, 
    draw_quadrant=True, 
#     show_ax_labels=True,
    quiv_ax_limits=[-25, 175, -25, 175],
    quiv_tick_list=np.linspace(0,150,7),
    quiv_ticklabel_list=[r'$0$', r'$25$',r'$50$',r'$75$',r'$100$',r'$125$', r'$150$'],
    )

# ## Histogram fits
# plt.figure()
# fit_pos = fit_inst_0.model_fit_results[:, :2]
# radial_fit_pos = np.sqrt(np.sum(fit_pos**2, axis=1))
# hist, _, _ = plt.hist(radial_fit_pos)
# plt.vlines(
#     sim_inst_0.a_long_meters / fit.cm_per_nm, 0, hist.max(),
#     lw=1, color='gray', linestyle='--')

# plt.xlabel('Radial fit location')
# plt.ylabel('Number of molecules')
# Out:
# Calculating Gaussian centroid with BEM_images

# %%
param_file = exp_res_param_file
# disk_radius = 70/2

## Set up molucule locations
## Set molecule positions 
num_per_arc = 1000

## The angle and radii ranges must be defined as lists in order to 
## expand them below to get a spherical coordinate for each dipole.
angle_range = np.linspace(0, np.pi/2, num_per_arc).tolist()
radii_range = [disk_radius,]

number_of_mols = len(angle_range) * len(radii_range)

## Build list of angles for each molecule
angles = (angle_range)*len(radii_range)
## Build list of radii for each molecule
# radii = [[val]*len(angle_range)for val in radii_range]
## Flatten
# radii = [item for sublist in radii for item in sublist]
radii = [disk_radius + 10,] * num_per_arc

locations = fib.sphere_to_cart(
    thetas=np.ones(number_of_mols)*np.pi/2,
    phis=angles,
    rs=radii
    )

## Generate random thetas and phis for molecule orientations
## but fixed to the cylindrical tangent... 
np.random.seed(0)
thetas = np.ones(number_of_mols) * np.pi/2
phis = np.random.random(number_of_mols) * np.pi * 2
mol_ori_angles = np.hstack((
    thetas[:, None],
    phis[:, None],
    np.ones((number_of_mols, 1))
    ))

## Convert random angles into a cartesien vector for rotation
mol_ori_vec = fib.sphere_to_cart(*mol_ori_angles.T)

## Rotate each molecule into y-z plane
mol_ori_vec = cp.rotation_by(np.pi/2, 'y') @ mol_ori_vec.T

## rotare each by angle between molecule-plasmon vector and x-axis about z
mol_ori_vec = (cp.rotation_by(np.asarray(angles), 'z') @ mol_ori_vec.T[..., None])

## reshape to be list of row vectors
mol_ori_vec = mol_ori_vec.reshape(number_of_mols, 3)

## Convert back to spherical coods (r, theta, phi) and keep just angles
mol_ori_angles = fib.cart_to_sphere(*mol_ori_vec.T).T[:, 1:]

## ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

## Run simulations
sim_inst_5 = bem.SimulatedExperiment(
    locations, 
    mol_angle=mol_ori_angles,
    param_file=param_file,
    simulation_file_name=f'CurlyDiskJC_NoSub_dipDrive_E_d{disk_diameter}',
    auto_quench=False
    )
sim_inst_5.trial_images = sim_inst_5.calculate_BEM_fields()

# Model fit
# Gaussian guess, checked

fit_inst_5 = fit.FitModelToData(
    sim_inst_5.BEM_images, 
#     ini_guess=simTestInst_few_mol.mol_locations,
    ini_guess='gauss',
    param_file=param_file,
    )
the_fit = fit_inst_5.fit_model_to_image_data(
    check_ini=True,
    let_mol_ori_out_of_plane=True)

## Plot fit results
# fit_inst_5.plot_fit_results_as_quiver_map(sim_inst_5)   

sim_inst_5.calculate_polarization()
bem.save_sim_exp_inst(sim_inst_5, f'sim_inst_randomOriTangent_d{disk_diameter}_transFit')
bem.save_fit_inst(fit_inst_5, sim_inst_5, f'fit_inst_randomOriTangent_d{disk_diameter}_transFit')
# Out:
# No 'quench_over_real_disk' param found in file.
# /Users/chair/Documents/Academia/SuperRes/Biteen_colab/Mispolarization/python/misloc_mispol_package/optics/anal_foc_diff_fields.py:27: RuntimeWarning: invalid value encountered in true_divide
#   sphj1_on_krho = spf.spherical_jn( 1, k*rho(xi, y) )/(k*rho(xi, y))
# /Users/chair/Documents/Academia/SuperRes/Biteen_colab/Mispolarization/python/misloc_mispol_package/optics/anal_foc_diff_fields.py:30: RuntimeWarning: invalid value encountered in true_divide
#   j2_on_krho = spf.jv(2, k*rho(xi, y) )/(k*rho(xi, y))
# /Users/chair/Documents/Academia/SuperRes/Biteen_colab/Mispolarization/python/misloc_mispol_package/optics/anal_foc_diff_fields.py:75: RuntimeWarning: invalid value encountered in true_divide
#   j2_on_krho = spf.jv(2, k*rho(xi, y) )/(k*rho(xi, y))
# /Users/chair/Documents/Academia/SuperRes/Biteen_colab/Mispolarization/python/misloc_mispol_package/optics/anal_foc_diff_fields.py:78: RuntimeWarning: divide by zero encountered in true_divide
#   sphj0_on_krhosqrd = spf.spherical_jn(0, k*rho(xi, y) )/(k*rho(xi, y))**2.
# /Users/chair/Documents/Academia/SuperRes/Biteen_colab/Mispolarization/python/misloc_mispol_package/optics/anal_foc_diff_fields.py:82: RuntimeWarning: invalid value encountered in add
#   sphj0_on_krhosqrd
# No 'quench_over_real_disk' param found in file.
# starting Matlab...
# given even number of points for Fibonacci lattice,
#   adding 1...
# 1th molecule
# mol_orientation = [-5.54615049542981e-17, -0.30191837076569106, 0.9533337806844939]
# calculating diffracted fields
# 2th molecule
# mol_orientation = [0.0015349073586720869, -0.9761744164296905, 0.21698191806589195]
# calculating diffracted fields
# 3th molecule
# mol_orientation = [0.0018923198170377694, -0.601739777861433, 0.7986899641694414]
# calculating diffracted fields
# 4th molecule
# mol_orientation = [0.001312700621076247, -0.27828309574949, 0.9604982016834595]
# calculating diffracted fields
# 5th molecule
# mol_orientation = [-0.002902605616104776, 0.4614959823134064, 0.8871375503208178]
# calculating diffracted fields
# 6th molecule
# mol_orientation = [0.006238982780077937, -0.7935612374562367, 0.6084584106582767]
# calculating diffracted fields
# 7th molecule
# mol_orientation = [-0.0036054865694726697, 0.3821601141397875, 0.924089090741397]
# calculating diffracted fields
# 8th molecule
# mol_orientation = [0.006920809606776412, -0.6287629386298258, -0.7775662475956455]
# calculating diffracted fields
# 9th molecule
# mol_orientation = [0.002846984213295498, -0.22631731193718016, -0.9740494694821297]
# calculating diffracted fields
# 10th molecule
# mol_orientation = [-0.009461613605146598, 0.6685583512177836, 0.743599494946672]
# calculating diffracted fields
# 11th molecule
# mol_orientation = [0.01518579597676653, -0.9657114464512458, -0.25917328912060844]
# calculating diffracted fields
# 12th molecule
# mol_orientation = [0.0031227581099849307, -0.18052940925798613, 0.9835646296887404]
# calculating diffracted fields
# 13th molecule
# mol_orientation = [0.007822957777341212, -0.41455657569089693, 0.9099899158139345]
# calculating diffracted fields
# 14th molecule
# mol_orientation = [0.009210943097480653, -0.4505529793228316, -0.8927021739362883]
# calculating diffracted fields
# 15th molecule
# mol_orientation = [-0.009501443282802918, 0.43155583975468054, -0.9020361853879123]
# calculating diffracted fields
# 16th molecule
# mol_orientation = [-0.01227539453825243, 0.520366430376205, -0.8538548429484115]
# calculating diffracted fields
# 17th molecule
# mol_orientation = [-0.003187031897732952, 0.126654434638752, -0.9919417810607742]
# calculating diffracted fields
# 18th molecule
# mol_orientation = [0.02320601003701975, -0.8679480120878962, -0.4961126176694471]
# calculating diffracted fields
# 19th molecule
# mol_orientation = [0.027857154724309406, -0.9839972358725803, -0.175992666681847]
# calculating diffracted fields
# 20th molecule
# mol_orientation = [0.02177314132513358, -0.7285911134849464, -0.6846027458808515]
# calculating diffracted fields
# 21th molecule
# mol_orientation = [0.00421140353962448, -0.13387493622767482, -0.990989286284298]
# calculating diffracted fields
# 22th molecule
# mol_orientation = [0.03145143194808588, -0.9521576518192101, -0.3039845613029432]
# calculating diffracted fields
# 23th molecule
# mol_orientation = [-0.008289252013430833, 0.23953280365381527, 0.9708528849804179]
# calculating diffracted fields
# 24th molecule
# mol_orientation = [0.03549344190274756, -0.9810169248671802, -0.1906462921381835]
# calculating diffracted fields
# 25th molecule
# mol_orientation = [-0.025526823263517587, 0.6761217661752301, -0.736347566437318]
# calculating diffracted fields
# 26th molecule
# mol_orientation = [0.03026803827662531, -0.7696018510808729, 0.637806268918532]
# calculating diffracted fields
# 27th molecule
# mol_orientation = [-0.03203289047760682, 0.7831164587712669, -0.6210495197077286]
# calculating diffracted fields
# 28th molecule
# mol_orientation = [0.014459482733284141, -0.34038748109737205, -0.9401740722181569]
# calculating diffracted fields
# 29th molecule
# mol_orientation = [0.00602289314879007, -0.1367136918376229, 0.990592293136912]
# calculating diffracted fields
# 30th molecule
# mol_orientation = [-0.023286866539747778, 0.5103375453975562, 0.8596588344246555]
# calculating diffracted fields
# 31th molecule
# mol_orientation = [-0.046956507513096664, 0.9947131504625952, 0.0913281703471114]
# calculating diffracted fields
# 32th molecule
# mol_orientation = [0.048160396812493234, -0.9872561168336617, -0.1516770778772535]
# calculating diffracted fields
# 33th molecule
# mol_orientation = [-0.013682291642193454, 0.2716988257008226, 0.962285063278139]
# calculating diffracted fields
# 34th molecule
# mol_orientation = [0.02162016390770416, -0.4162944742031379, 0.9089727604612456]
# calculating diffracted fields
# 35th molecule
# mol_orientation = [-0.006293889406359709, 0.11761745647175302, -0.9930390329132364]
# calculating diffracted fields
# 36th molecule
# mol_orientation = [0.03705376313041115, -0.6726221113519057, 0.7390578556232116]
# calculating diffracted fields
# 37th molecule
# mol_orientation = [0.03663315963152377, -0.6464773187480783, 0.7620532054651479]
# calculating diffracted fields
# 38th molecule
# mol_orientation = [0.03897900895441855, -0.6692437379158567, 0.742019848872888]
# calculating diffracted fields
# 39th molecule
# mol_orientation = [0.02066887122440027, -0.3455107174763641, -0.9381871571660301]
# calculating diffracted fields
# 40th molecule
# mol_orientation = [0.05574618332594051, -0.9079277415419954, 0.41540291186153494]
# calculating diffracted fields
# 41th molecule
# mol_orientation = [-0.04855293720100547, 0.7709530749337776, 0.6350385567343988]
# calculating diffracted fields
# 42th molecule
# mol_orientation = [-0.024828339203533438, 0.3845981549792857, 0.9227501356049337]
# calculating diffracted fields
# 43th molecule
# mol_orientation = [0.0624511853855729, -0.944289179818627, 0.3231374232759207]
# calculating diffracted fields
# 44th molecule
# mol_orientation = [-0.024959589814032037, 0.3685972749594689, -0.9292540383386929]
# calculating diffracted fields
# 45th molecule
# mol_orientation = [0.0598892250515548, -0.864267023685305, 0.49945549600827194]
# calculating diffracted fields
# 46th molecule
# mol_orientation = [0.06208875382124067, -0.8760329236065926, 0.47823770596452475]
# calculating diffracted fields
# 47th molecule
# mol_orientation = [-0.07003854201610656, 0.9666441265635656, -0.24636098557283692]
# calculating diffracted fields
# 48th molecule
# mol_orientation = [-0.053480529276174235, 0.7223568929376161, -0.6894493108371736]
# calculating diffracted fields
# 49th molecule
# mol_orientation = [-0.06911974672631252, 0.9140728156217884, 0.3996165016034078]
# calculating diffracted fields
# 50th molecule
# mol_orientation = [-0.058146370138196846, 0.7532022513721852, 0.6552139865476189]
# calculating diffracted fields
# 51th molecule
# mol_orientation = [0.03352746159820483, -0.42557902673998543, 0.9042999509663968]
# calculating diffracted fields
# 52th molecule
# mol_orientation = [-0.030141877272285608, 0.37507093692428195, 0.9265059414322413]
# calculating diffracted fields
# 53th molecule
# mol_orientation = [0.005960787678745274, -0.07274055721853406, -0.9973330839522903]
# calculating diffracted fields
# 54th molecule
# mol_orientation = [-0.04978786609374274, 0.5960548931118342, -0.8013986104225982]
# calculating diffracted fields
# 55th molecule
# mol_orientation = [-0.08199069958632148, 0.9633209903306705, -0.255519460647681]
# calculating diffracted fields
# 56th molecule
# mol_orientation = [-0.07330505561544579, 0.8455363506629541, -0.5288616534867985]
# calculating diffracted fields
# 57th molecule
# mol_orientation = [0.0721399389592386, -0.8171634233127106, 0.5718739098846958]
# calculating diffracted fields
# 58th molecule
# mol_orientation = [-0.08948593465997705, 0.9957733646519709, 0.020680274362865573]
# calculating diffracted fields
# 59th molecule
# mol_orientation = [-0.019133880776285146, 0.20922536562613311, 0.9776802345271433]
# calculating diffracted fields
# 60th molecule
# mol_orientation = [-0.09257992861408157, 0.9950892950182183, -0.03501787769064495]
# calculating diffracted fields
# 61th molecule
# mol_orientation = [-0.07920911695217991, 0.8371020005695092, -0.5412819565015826]
# calculating diffracted fields
# 62th molecule
# mol_orientation = [-0.06121825881274232, 0.6363002679833063, -0.7690086434834844]
# calculating diffracted fields
# 63th molecule
# mol_orientation = [0.08095606279180419, -0.827798131002842, 0.5551543661050058]
# calculating diffracted fields
# 64th molecule
# mol_orientation = [-0.07547701619426889, 0.7594444016560747, -0.6461790934560299]
# calculating diffracted fields
# 65th molecule
# mol_orientation = [-0.09485627182285697, 0.9394252349996681, -0.32936684037966935]
# calculating diffracted fields
# 66th molecule
# mol_orientation = [-0.07493088502077407, 0.7305959449938804, 0.6786861775728916]
# calculating diffracted fields
# 67th molecule
# mol_orientation = [0.09345410578938922, -0.8972987930134525, -0.4314176702080096]
# calculating diffracted fields
# 68th molecule
# mol_orientation = [-0.06024834935564364, 0.5697772924705519, -0.8195876849885236]
# calculating diffracted fields
# 69th molecule
# mol_orientation = [0.09083536914159308, -0.8463154842789228, -0.5248800213216759]
# calculating diffracted fields
# 70th molecule
# mol_orientation = [-0.06147941663433875, 0.5644397113233597, -0.8231816893077152]
# calculating diffracted fields
# 71th molecule
# mol_orientation = [0.016187758344920363, -0.14647906477407208, -0.9890813111482188]
# calculating diffracted fields
# 72th molecule
# mol_orientation = [-0.021802140698105175, 0.19448088371183328, 0.9806639855381886]
# calculating diffracted fields
# 73th molecule
# mol_orientation = [0.016436530139688803, -0.14456471007790045, -0.9893588252383761]
# calculating diffracted fields
# 74th molecule
# mol_orientation = [0.07010900657535732, -0.6081117368525862, 0.7907495448618023]
# calculating diffracted fields
# 75th molecule
# mol_orientation = [0.11582886192805564, -0.9909792468163855, 0.06740776753224059]
# calculating diffracted fields
# 76th molecule
# mol_orientation = [-0.0286775503038881, 0.2420508460895727, -0.9698396702630234]
# calculating diffracted fields
# 77th molecule
# mol_orientation = [-0.1166919949424566, 0.9718492161251899, 0.20467554673972121]
# calculating diffracted fields
# 78th molecule
# mol_orientation = [-0.08278609186448993, 0.6804291963356923, -0.7281226351156569]
# calculating diffracted fields
# 79th molecule
# mol_orientation = [-0.11723242198563719, 0.9510723515761984, 0.2858635011726777]
# calculating diffracted fields
# 80th molecule
# mol_orientation = [-0.08408926975145908, 0.6734685471569657, -0.7344175315874155]
# calculating diffracted fields
# 81th molecule
# mol_orientation = [-0.114185596022004, 0.9029586007991588, 0.4142793923234961]
# calculating diffracted fields
# 82th molecule
# mol_orientation = [-0.06516291279452809, 0.5088665644901927, 0.858375567184948]
# calculating diffracted fields
# 83th molecule
# mol_orientation = [-0.05043139944774545, 0.3889706422876378, -0.919868747913573]
# calculating diffracted fields
# 84th molecule
# mol_orientation = [0.1217273079836353, -0.9274276932620171, 0.3536387086586409]
# calculating diffracted fields
# 85th molecule
# mol_orientation = [0.05351599928865087, -0.4028229752490631, 0.9137120380249074]
# calculating diffracted fields
# 86th molecule
# mol_orientation = [-0.13263132769437108, 0.9864522834127047, 0.09654441187292666]
# calculating diffracted fields
# 87th molecule
# mol_orientation = [0.01962227823189655, -0.14422420268942726, 0.9893504664958667]
# calculating diffracted fields
# 88th molecule
# mol_orientation = [-0.07589868887873283, 0.5513656837485138, -0.8308039912103355]
# calculating diffracted fields
# 89th molecule
# mol_orientation = [0.06334744190690832, -0.45489161304418707, 0.8882908994163502]
# calculating diffracted fields
# 90th molecule
# mol_orientation = [0.05994714527827917, -0.42557498534435517, -0.9029353640334046]
# calculating diffracted fields
# 91th molecule
# mol_orientation = [-0.1281528106640275, 0.8995360159360756, 0.41762640380220506]
# calculating diffracted fields
# 92th molecule
# mol_orientation = [0.12382514637637185, -0.8594784444454167, 0.49594771565010454]
# calculating diffracted fields
# 93th molecule
# mol_orientation = [-0.10619168586387437, 0.7289606480376278, -0.6762689549771967]
# calculating diffracted fields
# 94th molecule
# mol_orientation = [0.14246065146719147, -0.9672672883932251, 0.20999751328994626]
# calculating diffracted fields
# 95th molecule
# mol_orientation = [-0.14277417180879223, 0.9589339821768247, 0.24507377193573945]
# calculating diffracted fields
# 96th molecule
# mol_orientation = [-0.13589992013466246, 0.903013329757645, -0.40755139306276816]
# calculating diffracted fields
# 97th molecule
# mol_orientation = [0.07777394047022275, -0.5113194916750388, 0.8558642366736177]
# calculating diffracted fields
# 98th molecule
# mol_orientation = [-0.019143618045941925, 0.12454088249268659, -0.9920297830589835]
# calculating diffracted fields
# 99th molecule
# mol_orientation = [0.13498768384452078, -0.8690747999160178, -0.4759068368506861]
# calculating diffracted fields
# 100th molecule
# mol_orientation = [-0.0045733110693311355, 0.029141595766356325, -0.9995648314251825]
# calculating diffracted fields
# 101th molecule
# mol_orientation = [0.14075866052215505, -0.8878116945412269, 0.4381522503923081]
# calculating diffracted fields
# 102th molecule
# mol_orientation = [-0.1568945471289804, 0.9796240200130235, 0.12538293542071535]
# calculating diffracted fields
# 103th molecule
# mol_orientation = [0.1590043989468357, -0.9828978576998384, 0.09289457704636789]
# calculating diffracted fields
# 104th molecule
# mol_orientation = [0.03794910356940622, -0.23226803568508453, -0.971911222868257]
# calculating diffracted fields
# 105th molecule
# mol_orientation = [-0.16279351629790254, 0.9866290575197721, -0.007834150177944922]
# calculating diffracted fields
# 106th molecule
# mol_orientation = [0.07567607176428724, -0.4541963735578535, 0.887681692054771]
# calculating diffracted fields
# 107th molecule
# mol_orientation = [0.0906836919009449, -0.5390402669067863, 0.8373840568557984]
# calculating diffracted fields
# 108th molecule
# mol_orientation = [0.07343369452001637, -0.432346789124071, 0.8987122712210216]
# calculating diffracted fields
# 109th molecule
# mol_orientation = [-0.16658935815618178, 0.9715522183895468, -0.16832787259233625]
# calculating diffracted fields
# 110th molecule
# mol_orientation = [0.04989357833912227, -0.28825846434198904, -0.9562518959854229]
# calculating diffracted fields
# 111th molecule
# mol_orientation = [-0.05612911548298059, 0.32127723051298795, 0.9453202968036827]
# calculating diffracted fields
# 112th molecule
# mol_orientation = [0.1427515254190164, -0.8095841308315649, -0.5693817147540334]
# calculating diffracted fields
# 113th molecule
# mol_orientation = [0.16644369603080578, -0.935346580260024, 0.31212701076241894]
# calculating diffracted fields
# 114th molecule
# mol_orientation = [-0.16895151872051467, 0.9408603566234536, 0.29366166528237786]
# calculating diffracted fields
# 115th molecule
# mol_orientation = [0.16415818388125528, -0.9059760801946115, -0.39020434746426763]
# calculating diffracted fields
# 116th molecule
# mol_orientation = [-0.1088750591036432, 0.5955337647044076, 0.7959181846158394]
# calculating diffracted fields
# 117th molecule
# mol_orientation = [0.12324717094110786, -0.6682067042144576, -0.7336960782898228]
# calculating diffracted fields
# 118th molecule
# mol_orientation = [0.08940700545922016, -0.4804993769929722, 0.8724257768338695]
# calculating diffracted fields
# 119th molecule
# mol_orientation = [0.12480929432955364, -0.6649463310647807, -0.7363891748609873]
# calculating diffracted fields
# 120th molecule
# mol_orientation = [0.1740261799847297, -0.9191853215175158, 0.3532891639813816]
# calculating diffracted fields
# 121th molecule
# mol_orientation = [0.18530403932083023, -0.9704029859571119, 0.15485624900825054]
# calculating diffracted fields
# 122th molecule
# mol_orientation = [0.001573637238391163, -0.008171090386114539, 0.9999653778745261]
# calculating diffracted fields
# 123th molecule
# mol_orientation = [0.051943163972862486, -0.2674489232641038, -0.9621709729363903]
# calculating diffracted fields
# 124th molecule
# mol_orientation = [0.151115700539893, -0.7715916727963475, 0.6179080316047619]
# calculating diffracted fields
# 125th molecule
# mol_orientation = [-0.08919602279913369, 0.4516654547084617, 0.8877175150574731]
# calculating diffracted fields
# 126th molecule
# mol_orientation = [0.12103652787169103, -0.6078672912510401, 0.7847595269557984]
# calculating diffracted fields
# 127th molecule
# mol_orientation = [-0.02367849965459491, 0.1179490567302571, -0.992737300936431]
# calculating diffracted fields
# 128th molecule
# mol_orientation = [-0.18804180378736204, 0.9291145753800637, 0.3184122890918615]
# calculating diffracted fields
# 129th molecule
# mol_orientation = [0.16890391411016745, -0.8278569932393435, 0.5349058482976033]
# calculating diffracted fields
# 130th molecule
# mol_orientation = [-0.19509426988174888, 0.9486076346919496, 0.2491621585703814]
# calculating diffracted fields
# 131th molecule
# mol_orientation = [0.13709859832502203, -0.6613432885614391, 0.7374476449294928]
# calculating diffracted fields
# 132th molecule
# mol_orientation = [-0.0885123942905334, 0.4236183834218415, 0.9015059740700684]
# calculating diffracted fields
# 133th molecule
# mol_orientation = [-0.15497739428798463, 0.7359365737078257, -0.6590746291118272]
# calculating diffracted fields
# 134th molecule
# mol_orientation = [-0.19812407080377015, 0.933543935810326, 0.2987349535623654]
# calculating diffracted fields
# 135th molecule
# mol_orientation = [0.08900658025033721, -0.41616822050144153, 0.9049209031273417]
# calculating diffracted fields
# 136th molecule
# mol_orientation = [0.1138613531343086, -0.5283185302112241, 0.8413769208255454]
# calculating diffracted fields
# 137th molecule
# mol_orientation = [0.09554157746756364, -0.4399544172217299, 0.892923242917384]
# calculating diffracted fields
# 138th molecule
# mol_orientation = [0.17542096422478407, -0.8017062307359599, 0.5713970641415536]
# calculating diffracted fields
# 139th molecule
# mol_orientation = [0.17582880527491357, -0.7975623714397148, 0.5770428882665958]
# calculating diffracted fields
# 140th molecule
# mol_orientation = [-0.09056677652074975, 0.40776171570067493, 0.9085857373960272]
# calculating diffracted fields
# 141th molecule
# mol_orientation = [0.13215027255613837, -0.590595617967047, -0.7960735653829113]
# calculating diffracted fields
# 142th molecule
# mol_orientation = [-0.16258158212639195, 0.7212727333680621, 0.6732999875635256]
# calculating diffracted fields
# 143th molecule
# mol_orientation = [-0.08683314235812353, 0.3824201587153231, 0.9198993573192455]
# calculating diffracted fields
# 144th molecule
# mol_orientation = [0.14003294131861274, -0.6122563981074527, -0.7781599310695368]
# calculating diffracted fields
# 145th molecule
# mol_orientation = [0.21064322638079194, -0.9143636465966894, -0.34578686059810715]
# calculating diffracted fields
# 146th molecule
# mol_orientation = [0.21660317026194154, -0.9335224543765617, 0.28569020600510064]
# calculating diffracted fields
# 147th molecule
# mol_orientation = [-0.13401564107561612, 0.5734873488974154, -0.8081782406138548]
# calculating diffracted fields
# 148th molecule
# mol_orientation = [0.1110148480692078, -0.47171253844334016, -0.8747359513496122]
# calculating diffracted fields
# 149th molecule
# mol_orientation = [0.2248195198327117, -0.9485881430240222, 0.22279299454073145]
# calculating diffracted fields
# 150th molecule
# mol_orientation = [0.001681757232489498, -0.007046498437863297, -0.9999737589318912]
# calculating diffracted fields
# 151th molecule
# mol_orientation = [-0.18856955288510777, 0.7846334099597724, -0.59058609507811]
# calculating diffracted fields
# 152th molecule
# mol_orientation = [0.17333961491927, -0.7163029679769888, -0.675916737451438]
# calculating diffracted fields
# 153th molecule
# mol_orientation = [-0.20184104683798978, 0.8283814861328461, -0.5225364152321651]
# calculating diffracted fields
# 154th molecule
# mol_orientation = [0.15819061183973368, -0.6448245937062763, 0.7477813675649498]
# calculating diffracted fields
# 155th molecule
# mol_orientation = [-0.168292104366902, 0.6813690431014382, -0.7123299760018458]
# calculating diffracted fields
# 156th molecule
# mol_orientation = [0.1969849098079641, -0.7921855578555107, -0.5776149125785288]
# calculating diffracted fields
# 157th molecule
# mol_orientation = [0.2272580893026656, -0.907832901563122, -0.3524105328817293]
# calculating diffracted fields
# 158th molecule
# mol_orientation = [0.10279340884979585, -0.4079073283966864, 0.9072183455692001]
# calculating diffracted fields
# 159th molecule
# mol_orientation = [-0.1354060310762828, 0.5337781104188242, 0.8347132055897273]
# calculating diffracted fields
# 160th molecule
# mol_orientation = [-0.10416909247353094, 0.4079479552511107, -0.907043144497371]
# calculating diffracted fields
# 161th molecule
# mol_orientation = [0.23547628139934662, -0.916162634926035, 0.3243407887758192]
# calculating diffracted fields
# 162th molecule
# mol_orientation = [-0.07207433490640636, 0.2786004151031015, 0.9576988560879556]
# calculating diffracted fields
# 163th molecule
# mol_orientation = [0.24810400384583756, -0.9528544567249602, 0.174679098849993]
# calculating diffracted fields
# 164th molecule
# mol_orientation = [0.18868949812363206, -0.7200256565359802, -0.6678018622524069]
# calculating diffracted fields
# 165th molecule
# mol_orientation = [0.03906837700650397, -0.14813190897997242, -0.9881956281324193]
# calculating diffracted fields
# 166th molecule
# mol_orientation = [0.2019102459478818, -0.7607114907224845, -0.6168875752226181]
# calculating diffracted fields
# 167th molecule
# mol_orientation = [-0.0189764947773087, 0.07104461229874484, -0.9972926128821409]
# calculating diffracted fields
# 168th molecule
# mol_orientation = [-0.200031367356627, 0.7441864615092505, 0.6373177877478229]
# calculating diffracted fields
# 169th molecule
# mol_orientation = [0.2590357455131631, -0.9576937469162573, 0.12539206379966697]
# calculating diffracted fields
# 170th molecule
# mol_orientation = [-0.23141378940798815, 0.8502645603052866, -0.47275557697471204]
# calculating diffracted fields
# 171th molecule
# mol_orientation = [0.034810430589248875, -0.12711199805595846, 0.9912773445773958]
# calculating diffracted fields
# 172th molecule
# mol_orientation = [-0.08894431578905936, 0.3227913524945056, -0.9422816200285262]
# calculating diffracted fields
# 173th molecule
# mol_orientation = [-0.2540849442984396, 0.9164804982956813, -0.3090377603539065]
# calculating diffracted fields
# 174th molecule
# mol_orientation = [-0.0311970468922106, 0.11184389225619532, -0.9932359679503103]
# calculating diffracted fields
# 175th molecule
# mol_orientation = [0.2600715216416335, -0.9267440214403426, -0.27112418253558096]
# calculating diffracted fields
# 176th molecule
# mol_orientation = [-0.2680668335785142, 0.9494931505963508, -0.16310404564511835]
# calculating diffracted fields
# 177th molecule
# mol_orientation = [-0.22563353314589205, 0.7944151877197052, 0.5639095833911384]
# calculating diffracted fields
# 178th molecule
# mol_orientation = [0.1199627445572516, -0.4198543470482916, -0.8996284050556342]
# calculating diffracted fields
# 179th molecule
# mol_orientation = [0.2649879728557668, -0.9219340495518461, 0.28252253453260256]
# calculating diffracted fields
# 180th molecule
# mol_orientation = [-0.05519453038308182, 0.19089918500239098, -0.9800566641685643]
# calculating diffracted fields
# 181th molecule
# mol_orientation = [-0.24009967873588145, 0.8255563172529136, -0.5106945381681043]
# calculating diffracted fields
# 182th molecule
# mol_orientation = [0.19409481278528717, -0.6634814007648386, 0.722578462513914]
# calculating diffracted fields
# 183th molecule
# mol_orientation = [0.13166213161328652, -0.4474534476183415, 0.8845623185019277]
# calculating diffracted fields
# 184th molecule
# mol_orientation = [-0.2829684607934573, 0.9561135439119003, -0.07599829829942513]
# calculating diffracted fields
# 185th molecule
# mol_orientation = [0.11459662627913542, -0.3849815314839863, -0.9157820885241666]
# calculating diffracted fields
# 186th molecule
# mol_orientation = [0.18826464069910492, -0.6288476933287096, 0.7543918104391101]
# calculating diffracted fields
# 187th molecule
# mol_orientation = [0.06401091677664805, -0.21259414139828234, 0.975041708634323]
# calculating diffracted fields
# 188th molecule
# mol_orientation = [0.1551519049769004, -0.5123734720506251, 0.8446308729384844]
# calculating diffracted fields
# 189th molecule
# mol_orientation = [0.2890497362335058, -0.9491743465084981, 0.12457250865863698]
# calculating diffracted fields
# 190th molecule
# mol_orientation = [-0.27092208904504644, 0.8846534991853064, 0.379459362839634]
# calculating diffracted fields
# 191th molecule
# mol_orientation = [-0.17565103631585968, 0.5703562668336656, 0.8023966863869323]
# calculating diffracted fields
# 192th molecule
# mol_orientation = [-0.28646185920593203, 0.9249968298648906, -0.24964067769532947]
# calculating diffracted fields
# 193th molecule
# mol_orientation = [-0.27375330102796314, 0.8790667067462876, -0.39025742179557543]
# calculating diffracted fields
# 194th molecule
# mol_orientation = [0.10233324854494787, -0.32679787617481215, -0.9395376811868006]
# calculating diffracted fields
# 195th molecule
# mol_orientation = [0.2996838240771089, -0.9517800741393077, 0.06560713419967593]
# calculating diffracted fields
# 196th molecule
# mol_orientation = [-0.018083609713214308, 0.05711892142538042, 0.9982035923973333]
# calculating diffracted fields
# 197th molecule
# mol_orientation = [-0.30027986607820056, 0.9433074342183042, -0.14143226851230825]
# calculating diffracted fields
# 198th molecule
# mol_orientation = [-0.30471267096748716, 0.9520510054631561, 0.02736916418989431]
# calculating diffracted fields
# 199th molecule
# mol_orientation = [-0.10922995632901103, 0.33944115170861777, -0.9342636250904182]
# calculating diffracted fields
# 200th molecule
# mol_orientation = [-0.12328491013341013, 0.3810622640656738, 0.9162927380693027]
# calculating diffracted fields
# 201th molecule
# mol_orientation = [-0.2862916616022023, 0.8801732262744066, 0.3785923615800407]
# calculating diffracted fields
# 202th molecule
# mol_orientation = [0.2933143424501671, -0.8969665005283298, 0.3307836051605157]
# calculating diffracted fields
# 203th molecule
# mol_orientation = [-0.21698192342058176, 0.6600242226695086, 0.719226577928135]
# calculating diffracted fields
# 204th molecule
# mol_orientation = [-0.28359967424233873, 0.8581145425015129, -0.4280311398917825]
# calculating diffracted fields
# 205th molecule
# mol_orientation = [-0.048693655848770764, 0.14656316818489554, -0.9880021081008317]
# calculating diffracted fields
# 206th molecule
# mol_orientation = [-0.12990629218940833, 0.3889602195733782, -0.9120495067917254]
# calculating diffracted fields
# 207th molecule
# mol_orientation = [0.28746354237062033, -0.8562287687955581, 0.4292283859375767]
# calculating diffracted fields
# 208th molecule
# mol_orientation = [-0.09172252920181533, 0.2717843921808351, 0.957977150982066]
# calculating diffracted fields
# 209th molecule
# mol_orientation = [0.07318660502316435, -0.21574008537177153, 0.9737042345645643]
# calculating diffracted fields
# 210th molecule
# mol_orientation = [0.1951220357212855, -0.5722232811904587, -0.7965474923942744]
# calculating diffracted fields
# 211th molecule
# mol_orientation = [0.019669371964188644, -0.05738769325426585, -0.9981581880992054]
# calculating diffracted fields
# 212th molecule
# mol_orientation = [-0.31869679322010236, 0.9250901411474644, -0.2064959678613309]
# calculating diffracted fields
# 213th molecule
# mol_orientation = [0.27960571378438465, -0.8074941875226859, 0.519397518222991]
# calculating diffracted fields
# 214th molecule
# mol_orientation = [-0.32753758793960275, 0.9411315652432162, 0.08360924224965231]
# calculating diffracted fields
# 215th molecule
# mol_orientation = [-0.04272118027714906, 0.12213411822825206, -0.9915937464104615]
# calculating diffracted fields
# 216th molecule
# mol_orientation = [0.3311973522720156, -0.9420931035027575, -0.05262032098485315]
# calculating diffracted fields
# 217th molecule
# mol_orientation = [-0.3014186114184695, 0.8530977530580637, 0.4258767948806846]
# calculating diffracted fields
# 218th molecule
# mol_orientation = [-0.22370170627370634, 0.6299821756524628, 0.7436934885895007]
# calculating diffracted fields
# 219th molecule
# mol_orientation = [0.17708244037566914, -0.4962186419974974, 0.849946391629941]
# calculating diffracted fields
# 220th molecule
# mol_orientation = [0.29474909977177505, -0.8218583494033239, -0.4875159707125215]
# calculating diffracted fields
# 221th molecule
# mol_orientation = [0.2456766759801485, -0.6816532794046349, 0.6891964723910389]
# calculating diffracted fields
# 222th molecule
# mol_orientation = [0.24432785230834023, -0.6745836668195664, -0.6965922602546357]
# calculating diffracted fields
# 223th molecule
# mol_orientation = [-0.3382852567942438, 0.9294311043765939, 0.1473801453824678]
# calculating diffracted fields
# 224th molecule
# mol_orientation = [0.3279633187796963, -0.896682419252573, -0.29732255302677624]
# calculating diffracted fields
# 225th molecule
# mol_orientation = [-0.3171459680712175, 0.8628984923727765, -0.39347760647457414]
# calculating diffracted fields
# 226th molecule
# mol_orientation = [0.10126297803023127, -0.2741865506982032, -0.956330248761729]
# calculating diffracted fields
# 227th molecule
# mol_orientation = [0.3214296037402944, -0.8661318086524036, 0.3827514857970815]
# calculating diffracted fields
# 228th molecule
# mol_orientation = [-0.34122398671027726, 0.9150566455762169, -0.21502912891128567]
# calculating diffracted fields
# 229th molecule
# mol_orientation = [0.11392279570127856, -0.30404435491031084, -0.9458216675815677]
# calculating diffracted fields
# 230th molecule
# mol_orientation = [0.3497961013709123, -0.9291089764491531, 0.1199966555672175]
# calculating diffracted fields
# 231th molecule
# mol_orientation = [-0.35370461757196137, 0.9350293100411298, 0.02476353917115548]
# calculating diffracted fields
# 232th molecule
# mol_orientation = [-0.34588547792814184, 0.9100326573540449, -0.2284815062703243]
# calculating diffracted fields
# 233th molecule
# mol_orientation = [0.040708821200886376, -0.10660083524285416, 0.9934681946604834]
# calculating diffracted fields
# 234th molecule
# mol_orientation = [-0.057510905629804494, 0.149891472144851, -0.9870283898206217]
# calculating diffracted fields
# 235th molecule
# mol_orientation = [-0.34692258085014804, 0.8999555518002514, -0.26405440287974297]
# calculating diffracted fields
# 236th molecule
# mol_orientation = [-0.1645967519029745, 0.42498988341649696, 0.8901075824059825]
# calculating diffracted fields
# 237th molecule
# mol_orientation = [-0.25774565734572963, 0.662406407673781, 0.7034095017783982]
# calculating diffracted fields
# 238th molecule
# mol_orientation = [-0.08260010461779731, 0.2112985571985003, 0.9739251215791495]
# calculating diffracted fields
# 239th molecule
# mol_orientation = [-0.36005588175769043, 0.9168018318339375, 0.1727256876021299]
# calculating diffracted fields
# 240th molecule
# mol_orientation = [0.1903548230977018, -0.48246506529737154, 0.854980995163662]
# calculating diffracted fields
# 241th molecule
# mol_orientation = [0.27814245819898886, -0.7017338563902843, -0.6559011874837882]
# calculating diffracted fields
# 242th molecule
# mol_orientation = [-0.24902677048178437, 0.6254044957451169, -0.7394963720568267]
# calculating diffracted fields
# 243th molecule
# mol_orientation = [0.040474579319652176, -0.10118443908744583, 0.9940440220208843]
# calculating diffracted fields
# 244th molecule
# mol_orientation = [-0.27509427048199514, 0.6845984185978979, -0.6750171461535153]
# calculating diffracted fields
# 245th molecule
# mol_orientation = [0.3662294311346142, -0.9072709941136528, 0.20672529359234476]
# calculating diffracted fields
# 246th molecule
# mol_orientation = [-0.22833160859089668, 0.5631001886716402, 0.7942183919025401]
# calculating diffracted fields
# 247th molecule
# mol_orientation = [0.1507317448233872, -0.37005524944297546, 0.9167000891579505]
# calculating diffracted fields
# 248th molecule
# mol_orientation = [-0.3458941686738585, 0.8453831419447672, -0.40704369224078896]
# calculating diffracted fields
# 249th molecule
# mol_orientation = [-0.30014636111574544, 0.7302947173726307, -0.6136626008537638]
# calculating diffracted fields
# 250th molecule
# mol_orientation = [-0.028609672965014526, 0.0693009007326253, 0.9971854751100628]
# calculating diffracted fields
# 251th molecule
# mol_orientation = [-0.3017600692926786, 0.7277040350219842, 0.6159445575643967]
# calculating diffracted fields
# 252th molecule
# mol_orientation = [0.14057258742919, -0.3374945289202313, -0.9307721475271883]
# calculating diffracted fields
# 253th molecule
# mol_orientation = [0.384161672065625, -0.9182463697939309, -0.096142675623319]
# calculating diffracted fields
# 254th molecule
# mol_orientation = [0.38738596596539293, -0.9218793901883711, 0.008396625451724031]
# calculating diffracted fields
# 255th molecule
# mol_orientation = [0.22114536833931467, -0.5239610421137221, -0.8225324020421148]
# calculating diffracted fields
# 256th molecule
# mol_orientation = [-0.19533763752587452, 0.46079084628710587, -0.865745345551348]
# calculating diffracted fields
# 257th molecule
# mol_orientation = [0.12617634197063646, -0.29634553595886676, 0.9467094876698771]
# calculating diffracted fields
# 258th molecule
# mol_orientation = [0.1990349316984286, -0.46543392398375305, 0.8624131019232534]
# calculating diffracted fields
# 259th molecule
# mol_orientation = [0.09348417164747222, -0.2176610715557176, -0.9715371159047927]
# calculating diffracted fields
# 260th molecule
# mol_orientation = [-0.3822722036628991, 0.8862065793615663, 0.26173624319719807]
# calculating diffracted fields
# 261th molecule
# mol_orientation = [-0.39686322912160565, 0.9160691409549976, -0.05759258946379231]
# calculating diffracted fields
# 262th molecule
# mol_orientation = [-0.23510167081262393, 0.5403482743296667, -0.8079300383140016]
# calculating diffracted fields
# 263th molecule
# mol_orientation = [-0.0412607693213138, 0.09442598083131758, -0.9946764715519599]
# calculating diffracted fields
# 264th molecule
# mol_orientation = [0.1721726903223114, -0.3923376601292506, -0.9035639020852272]
# calculating diffracted fields
# 265th molecule
# mol_orientation = [0.35330057599062453, -0.8016540570430644, 0.48221310209396884]
# calculating diffracted fields
# 266th molecule
# mol_orientation = [0.39489256946580076, -0.8922238911350261, -0.2190807765838234]
# calculating diffracted fields
# 267th molecule
# mol_orientation = [-0.39811686000968344, 0.8957008047247852, 0.19804806030709407]
# calculating diffracted fields
# 268th molecule
# mol_orientation = [0.21058477451781404, -0.4717827888242724, 0.8561980220197156]
# calculating diffracted fields
# 269th molecule
# mol_orientation = [-0.15997919313935122, 0.35689998810180795, -0.9203418149010787]
# calculating diffracted fields
# 270th molecule
# mol_orientation = [-0.03701673501254469, 0.08223452265627426, 0.9959253208009654]
# calculating diffracted fields
# 271th molecule
# mol_orientation = [0.058049846392267034, -0.12842076619285897, -0.9900193544291309]
# calculating diffracted fields
# 272th molecule
# mol_orientation = [0.2894936873693281, -0.6377587582266138, -0.7137626855465038]
# calculating diffracted fields
# 273th molecule
# mol_orientation = [-0.3527448180050361, 0.7738666254757087, 0.5260242763841162]
# calculating diffracted fields
# 274th molecule
# mol_orientation = [0.09952151371402294, -0.21742803147525408, -0.9709894538237094]
# calculating diffracted fields
# 275th molecule
# mol_orientation = [-0.414867052399308, 0.9026211235070297, -0.11471894452276464]
# calculating diffracted fields
# 276th molecule
# mol_orientation = [0.13119886387251645, -0.28426897487124086, -0.9497252276549332]
# calculating diffracted fields
# 277th molecule
# mol_orientation = [0.15139884924863417, -0.3266853184721689, -0.9329282347216891]
# calculating diffracted fields
# 278th molecule
# mol_orientation = [0.4019042587232062, -0.8636585445276415, -0.30424806537519006]
# calculating diffracted fields
# 279th molecule
# mol_orientation = [0.3094091487157037, -0.6621704031971544, 0.6824927368263649]
# calculating diffracted fields
# 280th molecule
# mol_orientation = [0.3016875929538323, -0.6430072893846099, -0.7039362343678434]
# calculating diffracted fields
# 281th molecule
# mol_orientation = [-0.4107029555760245, 0.8717917357091619, 0.2670248150085025]
# calculating diffracted fields
# 282th molecule
# mol_orientation = [0.3475959706491425, -0.7348365099871528, -0.5824022190706192]
# calculating diffracted fields
# 283th molecule
# mol_orientation = [0.2894862907639357, -0.6095083020346865, 0.7380361218873582]
# calculating diffracted fields
# 284th molecule
# mol_orientation = [-0.03575828914007562, 0.07498398285488089, -0.9965433994929642]
# calculating diffracted fields
# 285th molecule
# mol_orientation = [-0.35374048108911704, 0.738790260586844, 0.5736345726164552]
# calculating diffracted fields
# 286th molecule
# mol_orientation = [-0.34752928467232136, 0.7228977443239056, -0.5971953177533744]
# calculating diffracted fields
# 287th molecule
# mol_orientation = [0.04952086467359963, -0.10259522395880367, -0.9934897603814656]
# calculating diffracted fields
# 288th molecule
# mol_orientation = [-0.05908634847625256, 0.12192251035788651, 0.9907793421805755]
# calculating diffracted fields
# 289th molecule
# mol_orientation = [-0.007170914678520016, 0.014737826496471306, 0.9998656782052444]
# calculating diffracted fields
# 290th molecule
# mol_orientation = [0.33727712106198277, -0.6904181299902946, 0.6399741786891446]
# calculating diffracted fields
# 291th molecule
# mol_orientation = [-0.3236683501164147, 0.6599274644599612, 0.6780372709404437]
# calculating diffracted fields
# 292th molecule
# mol_orientation = [-0.33483329404909873, 0.6799852207226106, -0.652308795583083]
# calculating diffracted fields
# 293th molecule
# mol_orientation = [0.3984458911884644, -0.8059706519829026, -0.4377809725619485]
# calculating diffracted fields
# 294th molecule
# mol_orientation = [-0.41320237190458564, 0.8325222499446547, -0.36901287673943617]
# calculating diffracted fields
# 295th molecule
# mol_orientation = [0.031691516597144115, -0.06360090986400806, 0.9974720908578061]
# calculating diffracted fields
# 296th molecule
# mol_orientation = [-0.44158094803299247, 0.8827179410098586, -0.16067141299434523]
# calculating diffracted fields
# 297th molecule
# mol_orientation = [-0.2588560376570753, 0.515424748084045, -0.8169032261112558]
# calculating diffracted fields
# 298th molecule
# mol_orientation = [0.34290368400387916, -0.6801088836473679, -0.647972970023055]
# calculating diffracted fields
# 299th molecule
# mol_orientation = [0.07647156177779012, -0.15108089046216114, -0.9855590620436839]
# calculating diffracted fields
# 300th molecule
# mol_orientation = [0.11035626529623037, -0.21717696805083264, -0.9698740429860547]
# calculating diffracted fields
# 301th molecule
# mol_orientation = [0.25173137429719067, -0.49347504396157393, -0.8325345014962264]
# calculating diffracted fields
# 302th molecule
# mol_orientation = [0.45061779604282653, -0.879936048592334, -0.15051960761713146]
# calculating diffracted fields
# 303th molecule
# mol_orientation = [-0.3962253245481625, 0.7707326135672672, 0.4989756813417593]
# calculating diffracted fields
# 304th molecule
# mol_orientation = [-0.22371171310074123, 0.4334836735515598, -0.8729518739230567]
# calculating diffracted fields
# 305th molecule
# mol_orientation = [-0.25317780276145774, 0.4886927639599711, 0.8349133982887353]
# calculating diffracted fields
# 306th molecule
# mol_orientation = [-0.45852826978069844, 0.8816706246802783, -0.11139450340033269]
# calculating diffracted fields
# 307th molecule
# mol_orientation = [-0.3422728720230807, 0.6556112330233362, -0.6730699757162643]
# calculating diffracted fields
# 308th molecule
# mol_orientation = [-0.15291428443310506, 0.29178251464376703, -0.9441822841827056]
# calculating diffracted fields
# 309th molecule
# mol_orientation = [0.4601164592639777, -0.8746209759675324, 0.15274486018187805]
# calculating diffracted fields
# 310th molecule
# mol_orientation = [-0.03350008789502143, 0.0634369891642382, -0.9974234268939156]
# calculating diffracted fields
# 311th molecule
# mol_orientation = [0.4644500830506002, -0.8761605762778346, -0.12895256853115955]
# calculating diffracted fields
# 312th molecule
# mol_orientation = [-0.37466833371377256, 0.7041143868054602, -0.6031969578883135]
# calculating diffracted fields
# 313th molecule
# mol_orientation = [-0.2257310643843565, 0.4226127673546868, -0.8777493579836552]
# calculating diffracted fields
# 314th molecule
# mol_orientation = [-0.25219462409585736, 0.47037650428254274, -0.8456617620515215]
# calculating diffracted fields
# 315th molecule
# mol_orientation = [0.41819205451779995, -0.7770473987879521, 0.4704388861213097]
# calculating diffracted fields
# 316th molecule
# mol_orientation = [-0.47509087661784366, 0.8794552763214363, -0.02910456845368068]
# calculating diffracted fields
# 317th molecule
# mol_orientation = [-0.22822277106698993, 0.4208862548504598, 0.8779345802760352]
# calculating diffracted fields
# 318th molecule
# mol_orientation = [0.16861228728700617, -0.30978973634731294, 0.9357351205494568]
# calculating diffracted fields
# 319th molecule
# mol_orientation = [0.36835212136113477, -0.6742428094397879, -0.6400885474740926]
# calculating diffracted fields
# 320th molecule
# mol_orientation = [0.47582370760476983, -0.867716478228036, 0.14373556516320143]
# calculating diffracted fields
# 321th molecule
# mol_orientation = [-0.4782667570401632, 0.8689280790508763, 0.1273770094924496]
# calculating diffracted fields
# 322th molecule
# mol_orientation = [-0.35557714437369453, 0.6436244901496051, -0.6777259107328787]
# calculating diffracted fields
# 323th molecule
# mol_orientation = [-0.16534265930787165, 0.29817547411560386, -0.9400814813881486]
# calculating diffracted fields
# 324th molecule
# mol_orientation = [-0.4609865528033918, 0.8282600152140622, 0.3185541481946942]
# calculating diffracted fields
# 325th molecule
# mol_orientation = [-0.4862819483651207, 0.8704847349422165, 0.07606702917033886]
# calculating diffracted fields
# 326th molecule
# mol_orientation = [-0.13307619776924684, 0.23734007396552792, 0.9622683694673322]
# calculating diffracted fields
# 327th molecule
# mol_orientation = [0.4479721452402487, -0.7960172075627215, 0.4070350873731852]
# calculating diffracted fields
# 328th molecule
# mol_orientation = [0.4633834199581631, -0.820381280561448, 0.3350378495218643]
# calculating diffracted fields
# 329th molecule
# mol_orientation = [-0.48227913535094913, 0.8507080731297486, 0.2090516919735666]
# calculating diffracted fields
# 330th molecule
# mol_orientation = [-0.33870360457219284, 0.5952668860516284, 0.7286543780285695]
# calculating diffracted fields
# 331th molecule
# mol_orientation = [-0.4502273802212614, 0.7883818216465146, -0.41922477192601937]
# calculating diffracted fields
# 332th molecule
# mol_orientation = [0.48276137054980356, -0.842273130722807, -0.2398279224095406]
# calculating diffracted fields
# 333th molecule
# mol_orientation = [-0.1743437570951575, 0.3030717713149707, -0.9368840674245404]
# calculating diffracted fields
# 334th molecule
# mol_orientation = [0.4725287049110827, -0.818443724940718, 0.32690440826060646]
# calculating diffracted fields
# 335th molecule
# mol_orientation = [0.4932341347602742, -0.851212820847368, -0.17932323310812312]
# calculating diffracted fields
# 336th molecule
# mol_orientation = [0.4952852089051315, -0.8516627090039888, -0.1713569138721497]
# calculating diffracted fields
# 337th molecule
# mol_orientation = [-0.5031963941622696, 0.8621440726335204, 0.05916913828151278]
# calculating diffracted fields
# 338th molecule
# mol_orientation = [-0.36005312507742326, 0.6146696226088822, 0.701814079485326]
# calculating diffracted fields
# 339th molecule
# mol_orientation = [0.26506909453089655, -0.45088922879189314, 0.8523128994002276]
# calculating diffracted fields
# 340th molecule
# mol_orientation = [-0.502932595556735, 0.8524303142062921, 0.14290333708044667]
# calculating diffracted fields
# 341th molecule
# mol_orientation = [-0.36953643203915554, 0.6240902679855389, 0.6884432894592764]
# calculating diffracted fields
# 342th molecule
# mol_orientation = [-0.4828460312666711, 0.8125358805784834, -0.3265656945586501]
# calculating diffracted fields
# 343th molecule
# mol_orientation = [-0.12782936833553493, 0.21434379667942305, 0.9683575731185192]
# calculating diffracted fields
# 344th molecule
# mol_orientation = [-0.14207544447091697, 0.2373822987013268, -0.9609704534176197]
# calculating diffracted fields
# 345th molecule
# mol_orientation = [0.4899057894096724, -0.8156306240480176, -0.30779701528430575]
# calculating diffracted fields
# 346th molecule
# mol_orientation = [-0.2400094380682179, 0.39816538838643406, -0.8853585675472161]
# calculating diffracted fields
# 347th molecule
# mol_orientation = [0.061111941673463385, -0.10102248922345229, 0.9930054316346898]
# calculating diffracted fields
# 348th molecule
# mol_orientation = [-0.48623109628793326, 0.8009290615546629, 0.3494165985751129]
# calculating diffracted fields
# 349th molecule
# mol_orientation = [0.24358080194763132, -0.3998123774117952, 0.8836393244932442]
# calculating diffracted fields
# 350th molecule
# mol_orientation = [0.13152136422260188, -0.2151165553973417, -0.9676915822445745]
# calculating diffracted fields
# 351th molecule
# mol_orientation = [0.4143713546382701, -0.6753580445648466, 0.6100720384485686]
# calculating diffracted fields
# 352th molecule
# mol_orientation = [-0.11553901715671161, 0.18764728764876995, -0.9754174649618085]
# calculating diffracted fields
# 353th molecule
# mol_orientation = [-0.2226056273704691, 0.36026448941623623, 0.9059007850358992]
# calculating diffracted fields
# 354th molecule
# mol_orientation = [0.03314519624981126, -0.053453975496318744, 0.9980200741814768]
# calculating diffracted fields
# 355th molecule
# mol_orientation = [0.11906043712051942, -0.191338940870635, 0.974276152853581]
# calculating diffracted fields
# 356th molecule
# mol_orientation = [0.48119870848881025, -0.7706180565956422, 0.4178463997660583]
# calculating diffracted fields
# 357th molecule
# mol_orientation = [-0.5230236493721824, 0.8346746514635454, 0.17252387777236391]
# calculating diffracted fields
# 358th molecule
# mol_orientation = [-0.38542390268480914, 0.6129400865847489, -0.6897484073897462]
# calculating diffracted fields
# 359th molecule
# mol_orientation = [-0.33319943159649146, 0.5280431419146194, 0.7811200797961297]
# calculating diffracted fields
# 360th molecule
# mol_orientation = [0.14471050322259496, -0.22853527887311154, -0.9627203626014422]
# calculating diffracted fields
# 361th molecule
# mol_orientation = [-0.49500357525307564, 0.7790257691485825, -0.3848250401015144]
# calculating diffracted fields
# 362th molecule
# mol_orientation = [0.3050260622396125, -0.47837993186005373, -0.8234754047014193]
# calculating diffracted fields
# 363th molecule
# mol_orientation = [0.14647686411558922, -0.22892844528859332, 0.962359753531189]
# calculating diffracted fields
# 364th molecule
# mol_orientation = [-0.14449157540659088, 0.2250454078446181, 0.9635749836128846]
# calculating diffracted fields
# 365th molecule
# mol_orientation = [0.36565797634174657, -0.5675468878096249, -0.7376888059847917]
# calculating diffracted fields
# 366th molecule
# mol_orientation = [-0.13962702727009488, 0.21597197205329915, 0.9663645277756863]
# calculating diffracted fields
# 367th molecule
# mol_orientation = [0.5370902115016903, -0.827901113374189, 0.16159780686274094]
# calculating diffracted fields
# 368th molecule
# mol_orientation = [-0.32337012633540735, 0.4967484859241873, 0.8054021996033102]
# calculating diffracted fields
# 369th molecule
# mol_orientation = [0.31010177104054876, -0.47473189139919536, -0.8236907932507548]
# ...
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? True
# Initial guess in quench. Zone, OG params: [0.0, 0.0, 1.0376399972060417, 1.7787477115350878]
# Params shifted to: [49.26575881, 0.0, 1.0376399972060417, 1.7787477115350878]
# running fit...
# SUCCESS, Resulting fit params: [32.32207479 43.63538226  1.30922986 -1.93690993]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 973
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (0.0,97.0)
# initial guess angle = [1.1186982215502888, 0.2956395894787419]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [-0.87139415 75.95587388  1.9221907   2.51711434]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 974
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (0.0,97.0)
# initial guess angle = [0.5931658252325692, 0.5249261671168722]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [-0.86362428 80.23204658  1.96016679  0.88697083]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 975
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (0.0,0.0)
# initial guess angle = [0.3802016690800809, 0.6309080718348339]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? True
# Initial guess in quench. Zone, OG params: [0.0, 0.0, 0.3802016690800809, 0.6309080718348339]
# Params shifted to: [49.26575881, 0.0, 0.3802016690800809, 0.6309080718348339]
# running fit...
# SUCCESS, Resulting fit params: [29.86199874 25.09448519  2.1835784  -1.71759222]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 976
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (0.0,0.0)
# initial guess angle = [0.790616818940473, 0.05966823317247596]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? True
# Initial guess in quench. Zone, OG params: [0.0, 0.0, 0.790616818940473, 0.05966823317247596]
# Params shifted to: [49.26575881, 0.0, 0.790616818940473, 0.05966823317247596]
# running fit...
# SUCCESS, Resulting fit params: [-24.00887738  53.08192118   1.95237744  -3.8747046 ]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 977
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (0.0,0.0)
# initial guess angle = [1.5141967683841489, 1.6303729445271575]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? True
# Initial guess in quench. Zone, OG params: [0.0, 0.0, 1.5141967683841489, 1.6303729445271575]
# Params shifted to: [49.26575881, 0.0, 1.5141967683841489, 1.6303729445271575]
# running fit...
# SUCCESS, Resulting fit params: [28.73763413 28.64987401  1.92431297 -1.77474821]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 978
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (0.0,0.0)
# initial guess angle = [0.08257914140629996, 2.1427353342332083]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? True
# Initial guess in quench. Zone, OG params: [0.0, 0.0, 0.08257914140629996, 2.1427353342332083]
# Params shifted to: [49.26575881, 0.0, 0.08257914140629996, 2.1427353342332083]
# running fit...
# SUCCESS, Resulting fit params: [21.44476622 24.74768757 -2.59351149  1.3044811 ]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 979
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (0.0,0.0)
# initial guess angle = [0.42236836141278655, 0.3354202845172792]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? True
# Initial guess in quench. Zone, OG params: [0.0, 0.0, 0.42236836141278655, 0.3354202845172792]
# Params shifted to: [49.26575881, 0.0, 0.42236836141278655, 0.3354202845172792]
# running fit...
# SUCCESS, Resulting fit params: [35.50801598 20.30980459  2.3453191  -1.5187343 ]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 980
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (0.0,0.0)
# initial guess angle = [1.304237980053785, 0.6217450714052069]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? True
# Initial guess in quench. Zone, OG params: [0.0, 0.0, 1.304237980053785, 0.6217450714052069]
# Params shifted to: [49.26575881, 0.0, 1.304237980053785, 0.6217450714052069]
# running fit...
# SUCCESS, Resulting fit params: [30.40156163 40.47777708  1.39067417 -1.87767058]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 981
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (0.0,0.0)
# initial guess angle = [0.16454762074079393, 0.1787768934420543]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? True
# Initial guess in quench. Zone, OG params: [0.0, 0.0, 0.16454762074079393, 0.1787768934420543]
# Params shifted to: [49.26575881, 0.0, 0.16454762074079393, 0.1787768934420543]
# running fit...
# FAILURE, fit not converged, randomize angle guess and try again. Unconverged counter = 1.
# running fit...
# SUCCESS, Resulting fit params: [27.87131102 30.44573143  1.24175013  1.33273422]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 982
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (0.0,0.0)
# initial guess angle = [0.012879179915480108, 0.6958016387854878]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? True
# Initial guess in quench. Zone, OG params: [0.0, 0.0, 0.012879179915480108, 0.6958016387854878]
# Params shifted to: [49.26575881, 0.0, 0.012879179915480108, 0.6958016387854878]
# running fit...
# SUCCESS, Resulting fit params: [26.5732779  28.2894982   2.21282553 -8.11812005]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 983
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (0.0,0.0)
# initial guess angle = [1.106911946036557, 0.47796459144880876]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? True
# Initial guess in quench. Zone, OG params: [0.0, 0.0, 1.106911946036557, 0.47796459144880876]
# Params shifted to: [49.26575881, 0.0, 1.106911946036557, 0.47796459144880876]
# running fit...
# SUCCESS, Resulting fit params: [-26.59301954  31.44156246   2.47597733  -4.18446696]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 984
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (0.0,0.0)
# initial guess angle = [0.9059580116106594, 0.6696507900135773]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? True
# Initial guess in quench. Zone, OG params: [0.0, 0.0, 0.9059580116106594, 0.6696507900135773]
# Params shifted to: [49.26575881, 0.0, 0.9059580116106594, 0.6696507900135773]
# running fit...
# SUCCESS, Resulting fit params: [29.21171282 41.20816706  1.40561968 -1.8980249 ]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 985
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (0.0,49.0)
# initial guess angle = [0.7056555644511171, 2.7250899185108404]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? True
# Initial guess in quench. Zone, OG params: [0.0, 49.0, 0.7056555644511171, 2.7250899185108404]
# Params shifted to: [3.016657691711601e-15, 98.26575881, 0.7056555644511171, 2.7250899185108404]
# running fit...
# SUCCESS, Resulting fit params: [ 6.69741411 74.18757831  1.88412603  0.7368585 ]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 986
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (0.0,0.0)
# initial guess angle = [0.47531735650564777, 2.1550458207545393]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? True
# Initial guess in quench. Zone, OG params: [0.0, 0.0, 0.47531735650564777, 2.1550458207545393]
# Params shifted to: [49.26575881, 0.0, 0.47531735650564777, 2.1550458207545393]
# running fit...
# SUCCESS, Resulting fit params: [28.24114675 35.24336685  1.51307983  1.30505404]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 987
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (0.0,0.0)
# initial guess angle = [0.6884505505583631, 0.302080640517614]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? True
# Initial guess in quench. Zone, OG params: [0.0, 0.0, 0.6884505505583631, 0.302080640517614]
# Params shifted to: [49.26575881, 0.0, 0.6884505505583631, 0.302080640517614]
# running fit...
# SUCCESS, Resulting fit params: [18.43329886 25.93314084  2.78078824 -1.90542552]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 988
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (0.0,0.0)
# initial guess angle = [0.5664841233419498, 2.6429592760507488]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? True
# Initial guess in quench. Zone, OG params: [0.0, 0.0, 0.5664841233419498, 2.6429592760507488]
# Params shifted to: [49.26575881, 0.0, 0.5664841233419498, 2.6429592760507488]
# running fit...
# SUCCESS, Resulting fit params: [24.6818397  29.21949135  0.83804548  1.2464592 ]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 989
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (0.0,0.0)
# initial guess angle = [1.52845746315651, 2.6549023680906316]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? True
# Initial guess in quench. Zone, OG params: [0.0, 0.0, 1.52845746315651, 2.6549023680906316]
# Params shifted to: [49.26575881, 0.0, 1.52845746315651, 2.6549023680906316]
# running fit...
# SUCCESS, Resulting fit params: [24.45979271 30.45697749 -2.14727939  1.24956224]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 990
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (0.0,49.0)
# initial guess angle = [0.2548277603289405, 1.0854494737546077]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? True
# Initial guess in quench. Zone, OG params: [0.0, 49.0, 0.2548277603289405, 1.0854494737546077]
# Params shifted to: [3.016657691711601e-15, 98.26575881, 0.2548277603289405, 1.0854494737546077]
# running fit...
# SUCCESS, Resulting fit params: [-11.20165984  70.90907793   1.93412565   2.54239137]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 991
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (0.0,0.0)
# initial guess angle = [1.3056273064148969, 1.7401153983509907]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? True
# Initial guess in quench. Zone, OG params: [0.0, 0.0, 1.3056273064148969, 1.7401153983509907]
# Params shifted to: [49.26575881, 0.0, 1.3056273064148969, 1.7401153983509907]
# running fit...
# SUCCESS, Resulting fit params: [17.83265833 26.69288481  2.77879462 -1.95784747]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 992
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (0.0,0.0)
# initial guess angle = [1.2192297990176812, 2.443478196488379]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? True
# Initial guess in quench. Zone, OG params: [0.0, 0.0, 1.2192297990176812, 2.443478196488379]
# Params shifted to: [49.26575881, 0.0, 1.2192297990176812, 2.443478196488379]
# running fit...
# SUCCESS, Resulting fit params: [ 6.42308628 15.61451587 -1.11412026  0.80773365]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 993
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (0.0,97.0)
# initial guess angle = [0.11166461318935249, 1.0757019510330859]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? False
# running fit...
# SUCCESS, Resulting fit params: [-5.1098871  74.79837056  2.00351091  2.47343925]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 994
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (0.0,0.0)
# initial guess angle = [0.7524452212212823, 2.9695110413084045]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? True
# Initial guess in quench. Zone, OG params: [0.0, 0.0, 0.7524452212212823, 2.9695110413084045]
# Params shifted to: [49.26575881, 0.0, 0.7524452212212823, 2.9695110413084045]
# running fit...
# SUCCESS, Resulting fit params: [20.6592543  28.88325861  0.6338601   1.15554342]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 995
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (0.0,0.0)
# initial guess angle = [1.4109345012573236, 1.3289941698102428]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? True
# Initial guess in quench. Zone, OG params: [0.0, 0.0, 1.4109345012573236, 1.3289941698102428]
# Params shifted to: [49.26575881, 0.0, 1.4109345012573236, 1.3289941698102428]
# running fit...
# SUCCESS, Resulting fit params: [30.65809552 26.08752548  2.39161247 -1.72504512]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 996
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (0.0,49.0)
# initial guess angle = [0.15027168749587308, 1.2709070765298218]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? True
# Initial guess in quench. Zone, OG params: [0.0, 49.0, 0.15027168749587308, 1.2709070765298218]
# Params shifted to: [3.016657691711601e-15, 98.26575881, 0.15027168749587308, 1.2709070765298218]
# running fit...
# SUCCESS, Resulting fit params: [-14.82249378  67.583459     1.9601929    2.53212243]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 997
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (0.0,0.0)
# initial guess angle = [0.8417949864300674, 2.8412475724264388]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? True
# Initial guess in quench. Zone, OG params: [0.0, 0.0, 0.8417949864300674, 2.8412475724264388]
# Params shifted to: [49.26575881, 0.0, 0.8417949864300674, 2.8412475724264388]
# running fit...
# SUCCESS, Resulting fit params: [25.90057597 45.47260459  1.78490991  1.13464853]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 998
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (0.0,0.0)
# initial guess angle = [0.46319526967339475, 0.9703253309909784]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? True
# Initial guess in quench. Zone, OG params: [0.0, 0.0, 0.46319526967339475, 0.9703253309909784]
# Params shifted to: [49.26575881, 0.0, 0.46319526967339475, 0.9703253309909784]
# running fit...
# SUCCESS, Resulting fit params: [20.5674723  29.02105527  2.51488592 -1.99487992]
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Fitting model to molecule 999
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# initial guess position: (0.0,0.0)
# initial guess angle = [0.9851771210550907, 1.5871060780678476]
# Checking inital guess
#     self.quench_radius_a_nm,  49.26575881     self.quench_radius_c_nm,  49.26575881
#     In quenching zone? True
# Initial guess in quench. Zone, OG params: [0.0, 0.0, 0.9851771210550907, 1.5871060780678476]
# Params shifted to: [49.26575881, 0.0, 0.9851771210550907, 1.5871060780678476]
# running fit...
# SUCCESS, Resulting fit params: [ 2.82079154  1.99943217 -2.31569586 -1.15132099]

# %%
sim_inst_5 = bem.LoadedSimExp(f'sim_inst_randomOriTangent_d{disk_diameter}_transFit', exp_res_param_file)
fit_inst_5 = bem.LoadedFit(f'fit_inst_randomOriTangent_d{disk_diameter}_transFit', exp_res_param_file)
# Out:
# No 'quench_over_real_disk' param found in file.
# No 'quench_over_real_disk' param found in file.
# No 'quench_over_real_disk' param found in file.
# No 'quench_over_real_disk' param found in file.

# %%
sim_inst_5 = bem.LoadedSimExp(f'sim_inst_randomOriTangent_d{disk_diameter}_transFit', exp_res_param_file)
fit_inst_5 = bem.LoadedFit(f'fit_inst_randomOriTangent_d{disk_diameter}_transFit', exp_res_param_file)
# Out:
# No 'quench_over_real_disk' param found in file.
# No 'quench_over_real_disk' param found in file.
# No 'quench_over_real_disk' param found in file.
# No 'quench_over_real_disk' param found in file.

# %%
sim_inst_5.calculate_localization(save_fields=False)
# Out:
# Calculating Gaussian centroid with BEM_images
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-e13027a9daef> in <module>()
# ----> 1 sim_inst_5.calculate_localization(save_fields=False)
#
# ~/Documents/Academia/SuperRes/Biteen_colab/Mispolarization/python/misloc_mispol_package/calc/fitting_misLocalization.py in calculate_localization(self, save_fields)
#    1352     def calculate_localization(self, save_fields=True):
#    1353         """ """
# -> 1354         FitModelToData.calculate_localization(self, save_fields=save_fields)
#    1355
#    1356
#
# ~/Documents/Academia/SuperRes/Biteen_colab/Mispolarization/python/misloc_mispol_package/calc/fitting_misLocalization.py in calculate_localization(self, save_fields, images)
#    1934
#    1935         if save_fields == False:
# -> 1936             del self.mol_E
#    1937             del self.plas_E
#    1938
#
# AttributeError: mol_E

# %%
# fig5 = bem.fig5_3D(
#     sim_inst_5, 
#     fit_inst_5, 
#     draw_quadrant=True, 
#     show_ax_labels=True,
#     quiv_ax_limits=[-25, 60, -25,60],
#     )
# plt.gcf().axes[0].set_xlim([-10,60])
# plt.gcf().axes[1].set_xlim([-10,60])
# plt.gcf().axes[0].set_ylim([-60,60])
# plt.gcf().axes[1].set_ylim([-60,60])

## Histogram fits
plt.figure()
fit_pos = fit_inst_5.model_fit_results[:, :2]
radial_fit_pos = np.sqrt(np.sum(fit_pos**2, axis=1))
hist, _, _ = plt.hist(radial_fit_pos, bins=np.arange(0, 150, 2.5))
plt.vlines(
    disk_radius, 0, hist.max(),
    lw=1, color='gray', linestyle='--')
plt.vlines(
    disk_radius+10, 0, hist.max(),
    lw=1, color='limegreen', linestyle='--')

plt.xlabel('Radial fit location [nm]')
plt.ylabel('Number of molecules')
# Out:
# Text(0,0.5,'Number of molecules')

# %%
## Histogram fits
plt.figure(figsize=(3.5, 2))
fit_pos = fit_inst_5.model_fit_results[:, :2]
radial_fit_pos = np.sqrt(np.sum(fit_pos**2, axis=1))
hist, _, _ = plt.hist(radial_fit_pos, bins=np.arange(0, 150, 5))
# plt.vlines(
#     disk_radius, 0, hist.max(),
#     lw=2, color='gray', linestyle='--')
plt.vlines(
    disk_radius+10, 0, hist.max(),
    lw=2, color='limegreen', linestyle='--')

plt.xlabel('Radial fit location [nm]')
plt.ylabel('Number of molecules')
# Out:
# Text(0,0.5,'Number of molecules')

# %%
## Histogram fits
bins=np.arange(0, 150, 5)

plt.figure(figsize=(3.5, 2))
fit_pos = fit_inst_5.model_fit_results[:, :2]
radial_fit_pos = np.sqrt(np.sum(fit_pos**2, axis=1))

gau_hist = plt.hist(
    np.sqrt(np.sum(sim_inst_5.appar_cents**2., axis=0)),
    bins=bins,
    label='Gaussian',
    alpha=.75
    )
hist, _, _ = plt.hist(
    radial_fit_pos, 
    bins=bins,
    label='Image model',
    alpha=.75
    )

# plt.vlines(
#     disk_radius, 0, hist.max(),
#     lw=2, color='gray', 
#     linestyle='--'
#     )
ylims = plt.gca().get_ylim()

plt.vlines(
    disk_radius+10, 0, ylims[1],
    lw=1.5, color='limegreen', 
    linestyle='--'
    )
plt.ylim(ylims)

plt.xlabel('Radial fit location [nm]')
plt.ylabel('Number of molecules')
plt.legend()

# %%
param_file = high_res_param_file
# disk_radius = 70/2

## Set up molucule locations
## Set molecule positions 
num_per_arc = 1000

## The angle and radii ranges must be defined as lists in order to 
## expand them below to get a spherical coordinate for each dipole.
angle_range = np.linspace(0, np.pi/2, num_per_arc).tolist()
radii_range = [disk_radius,]

number_of_mols = len(angle_range) * len(radii_range)

## Build list of angles for each molecule
angles = (angle_range)*len(radii_range)
## Build list of radii for each molecule
# radii = [[val]*len(angle_range)for val in radii_range]
## Flatten
# radii = [item for sublist in radii for item in sublist]
radii = [disk_radius + 10,] * num_per_arc

locations = fib.sphere_to_cart(
    thetas=np.ones(number_of_mols)*np.pi/2,
    phis=angles,
    rs=radii
    )

## Generate random thetas and phis for molecule orientations
## but fixed to the cylindrical tangent... 
np.random.seed(0)
thetas = np.ones(number_of_mols) * np.pi/2
phis = np.random.random(number_of_mols) * np.pi * 2
mol_ori_angles = np.hstack((
    thetas[:, None],
    phis[:, None],
    np.ones((number_of_mols, 1))
    ))

## Convert random angles into a cartesien vector for rotation
mol_ori_vec = fib.sphere_to_cart(*mol_ori_angles.T)

## Rotate each molecule into y-z plane
mol_ori_vec = cp.rotation_by(np.pi/2, 'y') @ mol_ori_vec.T

## rotare each by angle between molecule-plasmon vector and x-axis about z
mol_ori_vec = (cp.rotation_by(np.asarray(angles), 'z') @ mol_ori_vec.T[..., None])

## reshape to be list of row vectors
mol_ori_vec = mol_ori_vec.reshape(number_of_mols, 3)

## Convert back to spherical coods (r, theta, phi) and keep just angles
mol_ori_angles = fib.cart_to_sphere(*mol_ori_vec.T).T[:, 1:]

## ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

## Run simulations
sim_inst_5h = bem.SimulatedExperiment(
    locations, 
    mol_angle=mol_ori_angles,
    param_file=param_file,
    simulation_file_name=f'CurlyDiskJC_NoSub_dipDrive_E_d{disk_diameter}',
    auto_quench=False
    )
sim_inst_5h.trial_images = sim_inst_5h.calculate_BEM_fields()

# Model fit
# Gaussian guess, checked

fit_inst_5h = fit.FitModelToData(
    sim_inst_5h.BEM_images, 
#     ini_guess=simTestInst_few_mol.mol_locations,
    ini_guess='gauss',
    param_file=param_file,
    )
the_fit = fit_inst_5h.fit_model_to_image_data(
    check_ini=True,
    let_mol_ori_out_of_plane=True)

## Plot fit results
# fit_inst_5h.plot_fit_results_as_quiver_map(sim_inst_5h)   

sim_inst_5h.calculate_polarization()
bem.save_sim_exp_inst(sim_inst_5h, f'sim_inst_randomOriTangent_d{disk_diameter}_transFit_hr')
bem.save_fit_inst(fit_inst_5h, sim_inst_5h, f'fit_inst_randomOriTangent_d{disk_diameter}_transFit_hr')
# Out:
# No 'quench_over_real_disk' param found in file.
