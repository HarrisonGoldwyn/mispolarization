# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
sys.path.append(module_path)

import numpy as np

## Plotting stuff
import matplotlib.pyplot as plt
import matplotlib as mpl

# %%
## Parameter setting needs to be in cell following mpl import for some reason 
## https://github.com/jupyter/notebook/issues/3385
##
## Default parameters inspired by 
## http://nipunbatra.github.io/2014/08/latexify/
params = {
    'text.latex.preamble': ['\\usepackage{gensymb}'],
    'image.origin': 'lower',
    'image.interpolation': 'nearest',
    'image.cmap': 'magma',
    'axes.grid': False,
    'figure.dpi': 200,  # to adjust notebook inline plot size
    'savefig.dpi': 200,  # to adjust notebook inline plot size
#     'axes.labelsize': 12, # fontsize for x and y labels (was 10)
    'axes.titlesize': 14,
    'font.size': 8, # was 10
#     'savefig.dpi': 150,  # to adjust notebook inline plot size
    'axes.labelsize': 10, # fontsize for x and y labels (was 10)
    'axes.titlesize': 10,
    'font.size': 8, # was 10
    'legend.fontsize': 8, # was 10
    'xtick.labelsize': 8,
    'ytick.labelsize': 8,
    'text.usetex': True,
    'figure.figsize': [3.39, 2.10],
    'font.family': 'serif',
    'figure.max_open_warning':10001
}
mpl.rcParams.update(params)
## For colorbar 
from mpl_toolkits.axes_grid1 import make_axes_locatable

## Get physical constants from Scipy
import scipy.constants as con

## For fitting
import scipy.optimize as opt

## For matlab loading
import scipy.io as sio

## Load custom package modules
from misloc_mispol_package.calc import BEM_simulation_wrapper as bem
from misloc_mispol_package.calc import fitting_misLocalization as fit
from misloc_mispol_package.calc import coupled_dipoles as cp
from misloc_mispol_package.optics import diffraction_int as diffi
from misloc_mispol_package.optics import fibonacci as fib
from misloc_mispol_package.parameterize import spec_fit as spit

## Some useful numerical constants
hbar = con.physical_constants['Planck constant over 2 pi in eV s'][0]
c = con.physical_constants['speed of light in vacuum'][0]*1e2 #cm/m

m_per_nm = fit.m_per_nm

eps_b = 1.778 ## Water
cm_per_nm = 1E-7

hres_obs_pts = diffi.observation_points(
    -480*m_per_nm, 480*m_per_nm, -480*m_per_nm, 480*m_per_nm, 201)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-a8e2ebb684cf> in <module>
#      41
#      42 ## Load custom package modules
# ---> 43 from misloc_mispol_package.calc import BEM_simulation_wrapper as bem
#      44 from misloc_mispol_package.calc import fitting_misLocalization as fit
#      45 from misloc_mispol_package.calc import coupled_dipoles as cp
#
# ~/Documents/Academia/SuperRes/Biteen_colab/Mispolarization/python/gitted/misloc_mispol_package/calc/BEM_simulation_wrapper.py in <module>
#      31 # sys.path.append(modules_path)
#      32
# ---> 33 from . import fitting_misLocalization as fit
#      34
#      35 ## plotting stuff
#
# ~/Documents/Academia/SuperRes/Biteen_colab/Mispolarization/python/gitted/misloc_mispol_package/calc/fitting_misLocalization.py in <module>
#      95 # modules_path = project_path + '/solving_problems/modules'
#      96 # sys.path.append(modules_path)
# ---> 97 from . import coupled_dipoles as cp
#      98
#      99 txt_file_path = project_path + '/txt'
#
# ~/Documents/Academia/SuperRes/Biteen_colab/Mispolarization/python/gitted/misloc_mispol_package/calc/coupled_dipoles.py in <module>
#      53
#      54 ## Driving force
# ---> 55 ficticious_field_amp = parameters['general']['drive_amp']
#      56
#      57 # normalization = 1
#
# NameError: name 'parameters' is not defined

# %%
def label_offset(ax, axis="y"):
    if axis == "y":
        fmt = ax.yaxis.get_major_formatter()
        ax.yaxis.offsetText.set_visible(False)
        set_label = ax.set_ylabel
        label = ax.get_ylabel()

    elif axis == "x":
        fmt = ax.xaxis.get_major_formatter()
        ax.xaxis.offsetText.set_visible(False)
        set_label = ax.set_xlabel
        label = ax.get_xlabel()

    def update_label(event_axes):
        offset = fmt.get_offset()
        if offset == '':
            set_label("{}".format(label))
        else:
            set_label("{} ({})".format(label, offset))
        return

    ax.callbacks.connect("ylim_changed", update_label)
    ax.callbacks.connect("xlim_changed", update_label)
    ax.figure.canvas.draw()
    update_label(None)
    return

# %%
locations, angles = fit.fixed_ori_mol_placement(
    mol_grid_pts_1D=5, x_max=325, y_max=325)
sim_inst = bem.SimulatedExperiment(
    locations, 
    mol_angle=0,
    param_file='sphere_80nmDrude',
    simulation_file_name='SphereDrude_NoSub_dipDrive_E')
sim_inst.trial_images = sim_inst.calculate_BEM_fields()

fit_inst = fit.FitModelToData(
    sim_inst.BEM_images, 
#     ini_guess=simTestInst_few_mol.mol_locations,
    ini_guess='gauss',
    param_file='sphere_80nmDrude'
    )
the_fit = fit_inst.fit_model_to_image_data(
    check_ini=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-85a6194a84f9> in <module>
# ----> 1 locations, angles = fit.fixed_ori_mol_placement(
#       2     mol_grid_pts_1D=5, x_max=325, y_max=325)
#       3 sim_inst = bem.SimulatedExperiment(
#       4     locations,
#       5     mol_angle=0,
#
# NameError: name 'fit' is not defined

# %%
axs, fig5 = bem.fig5(
    sim_inst, 
    fit_inst, 
    draw_quadrant=True,
    quiv_ax_limits=[-55,380,-55,380],
    quiv_tick_list=np.linspace(0,325,6),
    quiv_ticklabel_list=[r'$0$', r'$65$',r'$130$',r'$195$',r'$260$',r'$325$'],
    )

axs[1].set_title('Gaussian Localization')
axs[2].set_title('Image Model')
# Out:
# Text(0.5, 1.0, 'Image Model')

# %%
def lr_fig5(sim, fit):
    
    fig5 = bem.fig5(
        sim_inst, 
        fit_inst, 
        draw_quadrant=True,
        quiv_ax_limits=[-55,380,-55,380],
        quiv_tick_list=np.linspace(0,325,6),
        quiv_ticklabel_list=[r'$0$', r'$65$',r'$130$',r'$195$',r'$260$',r'$325$'],
        )

# %% [markdown]
# ## Higher res simulation

# %%
sim_inst_hr = bem.SimulatedExperiment(
    locations, 
    mol_angle=0,
    param_file='sphere_80nmDrude',
    simulation_file_name='SphereDrudeHighDisc_NoSub_dipDrive_E')
sim_inst_hr.trial_images = sim_inst_hr.calculate_BEM_fields()

fit_inst_hr = fit.FitModelToData(
    sim_inst_hr.BEM_images, 
#     ini_guess=simTestInst_few_mol.mol_locations,
    ini_guess='gauss',
    param_file='sphere_80nmDrude'
    )
the_fit = fit_inst_hr.fit_model_to_image_data(
    check_ini=True)

fig5 = bem.fig5(sim_inst_hr, fit_inst_hr, draw_quadrant=True)
# Out:
# starting Matlab...
# given even number of points for Fibonacci lattice,
#   adding 1...
# 1th molecule
# calculating diffracted fields
# 2th molecule
# calculating diffracted fields
# 3th molecule
# calculating diffracted fields
# 4th molecule
# calculating diffracted fields
# 5th molecule
# calculating diffracted fields
# 6th molecule
# calculating diffracted fields
# 7th molecule
# calculating diffracted fields
# 8th molecule
# calculating diffracted fields
# 9th molecule
# calculating diffracted fields
# 10th molecule
# calculating diffracted fields
# 11th molecule
# calculating diffracted fields
# 12th molecule
# calculating diffracted fields
# 13th molecule
# calculating diffracted fields
# 14th molecule
# calculating diffracted fields
# 15th molecule
# calculating diffracted fields
# 16th molecule
# calculating diffracted fields
# 17th molecule
# calculating diffracted fields
# 18th molecule
# calculating diffracted fields
# 19th molecule
# calculating diffracted fields
# 20th molecule
# calculating diffracted fields
# 21th molecule
# calculating diffracted fields
#
#  initial guess for molecule 0 location: (0.002032793952649366,24.393339863421257)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  0.002032793952649366
#  ini_y,  24.393339863421257
#  self.quel_a,  50.3368752
#  self.quel_c,  50.3368752
#
# In quenching zone? True
# Params modified, OG params: (0.002032793952649366, 24.393339863421257, array([0.5638009]))
# but now they are: (0.004194771840162637, 50.3368750252165, array([0.5638009]))
#
#  initial guess for molecule 1 location: (-0.00929108467242875,142.19349409218455)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  -0.00929108467242875
#  ini_y,  142.19349409218455
#  self.quel_a,  50.3368752
#  self.quel_c,  50.3368752
#
# In quenching zone? False
#
#  initial guess for molecule 2 location: (-0.0068895810159803,159.27964625825254)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  -0.0068895810159803
#  ini_y,  159.27964625825254
#  self.quel_a,  50.3368752
#  self.quel_c,  50.3368752
#
# In quenching zone? False
#
#  initial guess for molecule 3 location: (11.407766056091134,25.703084901397762)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  11.407766056091134
#  ini_y,  25.703084901397762
#  self.quel_a,  50.3368752
#  self.quel_c,  50.3368752
#
# In quenching zone? True
# Params modified, OG params: (11.407766056091134, 25.703084901397762, array([1.56002986]))
# but now they are: (20.420080732995174, 46.00892639215063, array([1.56002986]))
#
#  initial guess for molecule 4 location: (47.08790779895447,119.56111213731296)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  47.08790779895447
#  ini_y,  119.56111213731296
#  self.quel_a,  50.3368752
#  self.quel_c,  50.3368752
#
# In quenching zone? False
#
#  initial guess for molecule 5 location: (41.133743801901964,154.51916658195913)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  41.133743801901964
#  ini_y,  154.51916658195913
#  self.quel_a,  50.3368752
#  self.quel_c,  50.3368752
#
# In quenching zone? False
#
#  initial guess for molecule 6 location: (17.56224106077202,-0.0006237222780827876)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  17.56224106077202
#  ini_y,  -0.0006237222780827876
#  self.quel_a,  50.3368752
#  self.quel_c,  50.3368752
#
# In quenching zone? True
# Params modified, OG params: (17.56224106077202, -0.0006237222780827876, array([0.63308356]))
# but now they are: (50.33687516825475, -0.0017877120774364712, array([0.63308356]))
#
#  initial guess for molecule 7 location: (19.73044224527156,10.472847769544382)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  19.73044224527156
#  ini_y,  10.472847769544382
#  self.quel_a,  50.3368752
#  self.quel_c,  50.3368752
#
# In quenching zone? True
# Params modified, OG params: (19.73044224527156, 10.472847769544382, array([0.49363442]))
# but now they are: (44.46163881268337, 23.60007794459297, array([0.49363442]))
#
#  initial guess for molecule 8 location: (35.320098636427566,35.52218473964679)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  35.320098636427566
#  ini_y,  35.52218473964679
#  self.quel_a,  50.3368752
#  self.quel_c,  50.3368752
#
# In quenching zone? True
# Params modified, OG params: (35.320098636427566, 35.52218473964679, array([1.54745758]))
# but now they are: (35.49186653649457, 35.694935420252996, array([1.54745758]))
#
#  initial guess for molecule 9 location: (69.44267142230206,99.39168335767185)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  69.44267142230206
#  ini_y,  99.39168335767185
#  self.quel_a,  50.3368752
#  self.quel_c,  50.3368752
#
# In quenching zone? False
#
#  initial guess for molecule 10 location: (74.30248560954185,146.03357867398944)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  74.30248560954185
#  ini_y,  146.03357867398944
#  self.quel_a,  50.3368752
#  self.quel_c,  50.3368752
#
# In quenching zone? False
#
#  initial guess for molecule 11 location: (46.14632730456225,0.0005229904328367749)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  46.14632730456225
#  ini_y,  0.0005229904328367749
#  self.quel_a,  50.3368752
#  self.quel_c,  50.3368752
#
# In quenching zone? True
# Params modified, OG params: (46.14632730456225, 0.0005229904328367749, array([1.55518291]))
# but now they are: (50.336875196767274, 0.0005704831930093956, array([1.55518291]))
#
#  initial guess for molecule 12 location: (52.561338792621484,17.983464575636095)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  52.561338792621484
#  ini_y,  17.983464575636095
#  self.quel_a,  50.3368752
#  self.quel_c,  50.3368752
#
# In quenching zone? False
#
#  initial guess for molecule 13 location: (74.32590989230194,50.098538396815975)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  74.32590989230194
#  ini_y,  50.098538396815975
#  self.quel_a,  50.3368752
#  self.quel_c,  50.3368752
#
# In quenching zone? False
#
#  initial guess for molecule 14 location: (100.64771288826108,100.77810878366672)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  100.64771288826108
#  ini_y,  100.77810878366672
#  self.quel_a,  50.3368752
#  self.quel_c,  50.3368752
#
# In quenching zone? False
#
#  initial guess for molecule 15 location: (103.64594443690576,140.11959652704343)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  103.64594443690576
#  ini_y,  140.11959652704343
#  self.quel_a,  50.3368752
#  self.quel_c,  50.3368752
#
# In quenching zone? False
#
#  initial guess for molecule 16 location: (100.72424675766473,0.017943001159966044)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  100.72424675766473
#  ini_y,  0.017943001159966044
#  self.quel_a,  50.3368752
#  self.quel_c,  50.3368752
#
# In quenching zone? False
#
#  initial guess for molecule 17 location: (107.56775982434442,27.764054851044566)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  107.56775982434442
#  ini_y,  27.764054851044566
#  self.quel_a,  50.3368752
#  self.quel_c,  50.3368752
#
# In quenching zone? False
#
#  initial guess for molecule 18 location: (123.87141776898324,63.50740254807363)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  123.87141776898324
#  ini_y,  63.50740254807363
#  self.quel_a,  50.3368752
#  self.quel_c,  50.3368752
#
# In quenching zone? False
#
#  initial guess for molecule 19 location: (134.3937287846604,102.9748233718447)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  134.3937287846604
#  ini_y,  102.9748233718447
#  self.quel_a,  50.3368752
#  self.quel_c,  50.3368752
#
# In quenching zone? False
#
#  initial guess for molecule 20 location: (132.89849555682235,136.53221589712138)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  132.89849555682235
#  ini_y,  136.53221589712138
#  self.quel_a,  50.3368752
#  self.quel_c,  50.3368752
#
# In quenching zone? False
# Calculating Gaussian centroid with BEM_images

# %% [markdown]
# And even higher (1024)

# %%
# locations, angles = fit.fixed_ori_mol_placement(
#     mol_grid_pts_1D=5, x_max=125, y_max=125)
sim_inst_hd = bem.SimulatedExperiment(
    locations, 
    mol_angle=0,
    param_file='sphere_80nmDrude',
    simulation_file_name='SphereDrudeHigherDisc_NoSub_dipDrive_E')
sim_inst_hd.trial_images = sim_inst_hd.calculate_BEM_fields()

fit_inst_hd = fit.FitModelToData(
    sim_inst_hd.BEM_images, 
#     ini_guess=simTestInst_few_mol.mol_locations,
    ini_guess='gauss',
    param_file='sphere_80nmDrude'
    )
the_fit_hd = fit_inst_hd.fit_model_to_image_data(
    check_ini=True)

# ## Plot fit results
# fit_inst_hd.plot_fit_results_as_quiver_map(sim_inst_hd)   
axs, fig5_HD = lr_fig5(sim_inst_hd, fit_inst_hd)
# Out:
# starting Matlab...
# given even number of points for Fibonacci lattice,
#   adding 1...
# 1th molecule
# calculating diffracted fields
# 2th molecule
# calculating diffracted fields
# 3th molecule
# calculating diffracted fields
# 4th molecule
# calculating diffracted fields
# 5th molecule
# calculating diffracted fields
# 6th molecule
# calculating diffracted fields
# 7th molecule
# calculating diffracted fields
# 8th molecule
# calculating diffracted fields
# 9th molecule
# calculating diffracted fields
# 10th molecule
# calculating diffracted fields
# 11th molecule
# calculating diffracted fields
# 12th molecule
# calculating diffracted fields
# 13th molecule
# calculating diffracted fields
# 14th molecule
# calculating diffracted fields
# 15th molecule
# calculating diffracted fields
# 16th molecule
# calculating diffracted fields
# 17th molecule
# calculating diffracted fields
# 18th molecule
# calculating diffracted fields
# 19th molecule
# calculating diffracted fields
# 20th molecule
# calculating diffracted fields
# 21th molecule
# calculating diffracted fields
#
#  initial guess for molecule 0 location: (0.008262294861257423,23.64414619699159)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  0.008262294861257423
#  ini_y,  23.64414619699159
#  self.quel_a,  50.3368752
#  self.quel_c,  50.3368752
#
# In quenching zone? True
# Params modified, OG params: (0.008262294861257423, 23.64414619699159, array([0.56283272]))
# but now they are: (0.017589896308328575, 50.33687212666201, array([0.56283272]))
#
#  initial guess for molecule 1 location: (-0.008110296533166689,142.35375494612225)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  -0.008110296533166689
#  ini_y,  142.35375494612225
#  self.quel_a,  50.3368752
#  self.quel_c,  50.3368752
#
# In quenching zone? False
#
#  initial guess for molecule 2 location: (-0.00683317201786287,159.36865351977514)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  -0.00683317201786287
#  ini_y,  159.36865351977514
#  self.quel_a,  50.3368752
#  self.quel_c,  50.3368752
#
# In quenching zone? False
#
#  initial guess for molecule 3 location: (11.288572364854529,25.50578840542132)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  11.288572364854529
#  ini_y,  25.50578840542132
#  self.quel_a,  50.3368752
#  self.quel_c,  50.3368752
#
# In quenching zone? True
# Params modified, OG params: (11.288572364854529, 25.50578840542132, array([0.20371286]))
# but now they are: (20.372384500648376, 46.03006576856171, array([0.20371286]))
#
#  initial guess for molecule 4 location: (47.04180478021803,119.6109473107511)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  47.04180478021803
#  ini_y,  119.6109473107511
#  self.quel_a,  50.3368752
#  self.quel_c,  50.3368752
#
# In quenching zone? False
#
#  initial guess for molecule 5 location: (41.121867935551876,154.60622656532053)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  41.121867935551876
#  ini_y,  154.60622656532053
#  self.quel_a,  50.3368752
#  self.quel_c,  50.3368752
#
# In quenching zone? False
#
#  initial guess for molecule 6 location: (17.46661469466912,-0.0005280367219035374)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  17.46661469466912
#  ini_y,  -0.0005280367219035374
#  self.quel_a,  50.3368752
#  self.quel_c,  50.3368752
#
# In quenching zone? True
# Params modified, OG params: (17.46661469466912, -0.0005280367219035374, array([0.60900689]))
# but now they are: (50.33687517699792, -0.001521744140131247, array([0.60900689]))
#
#  initial guess for molecule 7 location: (19.627868056338414,10.42437043151778)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  19.627868056338414
#  ini_y,  10.42437043151778
#  self.quel_a,  50.3368752
#  self.quel_c,  50.3368752
#
# In quenching zone? True
# Params modified, OG params: (19.627868056338414, 10.42437043151778, array([0.51371118]))
# but now they are: (44.45603918928922, 23.610624398790392, array([0.51371118]))
#
#  initial guess for molecule 8 location: (35.17161436209586,35.397276691046635)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  35.17161436209586
#  ini_y,  35.397276691046635
#  self.quel_a,  50.3368752
#  self.quel_c,  50.3368752
#
# In quenching zone? True
# Params modified, OG params: (35.17161436209586, 35.397276691046635, array([0.41036195]))
# but now they are: (35.47954480441342, 35.707182826036494, array([0.41036195]))
#
#  initial guess for molecule 9 location: (69.3917607303338,99.38520968952943)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  69.3917607303338
#  ini_y,  99.38520968952943
#  self.quel_a,  50.3368752
#  self.quel_c,  50.3368752
#
# In quenching zone? False
#
#  initial guess for molecule 10 location: (74.2992397025065,146.11544080455087)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  74.2992397025065
#  ini_y,  146.11544080455087
#  self.quel_a,  50.3368752
#  self.quel_c,  50.3368752
#
# In quenching zone? False
#
#  initial guess for molecule 11 location: (46.01556363649297,0.0010007567688368089)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  46.01556363649297
#  ini_y,  0.0010007567688368089
#  self.quel_a,  50.3368752
#  self.quel_c,  50.3368752
#
# In quenching zone? True
# Params modified, OG params: (46.01556363649297, 0.0010007567688368089, array([1.20305851]))
# but now they are: (50.3368751880957, 0.0010947376188665235, array([1.20305851]))
#
#  initial guess for molecule 12 location: (52.43688205848009,17.947325827537757)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  52.43688205848009
#  ini_y,  17.947325827537757
#  self.quel_a,  50.3368752
#  self.quel_c,  50.3368752
#
# In quenching zone? False
#
#  initial guess for molecule 13 location: (74.26406538721662,50.07166917193281)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  74.26406538721662
#  ini_y,  50.07166917193281
#  self.quel_a,  50.3368752
#  self.quel_c,  50.3368752
#
# In quenching zone? False
#
#  initial guess for molecule 14 location: (100.70133493946904,100.87020861115212)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  100.70133493946904
#  ini_y,  100.87020861115212
#  self.quel_a,  50.3368752
#  self.quel_c,  50.3368752
#
# In quenching zone? False
#
#  initial guess for molecule 15 location: (103.66141728126374,140.19254974464667)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  103.66141728126374
#  ini_y,  140.19254974464667
#  self.quel_a,  50.3368752
#  self.quel_c,  50.3368752
#
# In quenching zone? False
#
#  initial guess for molecule 16 location: (100.77086878934668,0.018518729088233266)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  100.77086878934668
#  ini_y,  0.018518729088233266
#  self.quel_a,  50.3368752
#  self.quel_c,  50.3368752
#
# In quenching zone? False
#
#  initial guess for molecule 17 location: (107.64314454892799,27.787518572516504)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  107.64314454892799
#  ini_y,  27.787518572516504
#  self.quel_a,  50.3368752
#  self.quel_c,  50.3368752
#
# In quenching zone? False
#
#  initial guess for molecule 18 location: (124.00313258475671,63.58434352254538)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  124.00313258475671
#  ini_y,  63.58434352254538
#  self.quel_a,  50.3368752
#  self.quel_c,  50.3368752
#
# In quenching zone? False
#
#  initial guess for molecule 19 location: (134.49236395128585,103.06840263241317)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  134.49236395128585
#  ini_y,  103.06840263241317
#  self.quel_a,  50.3368752
#  self.quel_c,  50.3368752
#
# In quenching zone? False
#
#  initial guess for molecule 20 location: (132.92597585146896,136.5871700234762)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  132.92597585146896
#  ini_y,  136.5871700234762
#  self.quel_a,  50.3368752
#  self.quel_c,  50.3368752
#
# In quenching zone? False
# Calculating Gaussian centroid with BEM_images

# %% [markdown]
# Drop down to 144 surface elements and see how that goes.

# %%
# locations, angles = fit.fixed_ori_mol_placement(
#     mol_grid_pts_1D=5, x_max=125, y_max=125)
sim_inst_ld = bem.SimulatedExperiment(
    locations, 
    mol_angle=0,
    param_file='sphere_80nmDrude',
    simulation_file_name='SphereDrudeLowDisc_NoSub_dipDrive_E')
sim_inst_ld.trial_images = sim_inst_ld.calculate_BEM_fields()

fit_inst_ld = fit.FitModelToData(
    sim_inst_ld.BEM_images, 
#     ini_guess=simTestInst_few_mol.mol_locations,
    ini_guess='gauss',
    param_file='sphere_80nmDrude'
    )
the_fit_ld = fit_inst_ld.fit_model_to_image_data(
    check_ini=True)

# ## Plot fit results
# fit_inst_ld.plot_fit_results_as_quiver_map(sim_inst_ld)   
fig5_HD = bem.fig5(sim_inst_ld, fit_inst_ld, draw_quadrant=True)
# Out:
# starting Matlab...
# given even number of points for Fibonacci lattice,
#   adding 1...
# 1th molecule
# calculating diffracted fields
# 2th molecule
# calculating diffracted fields
# 3th molecule
# calculating diffracted fields
# 4th molecule
# calculating diffracted fields
# 5th molecule
# calculating diffracted fields
# 6th molecule
# calculating diffracted fields
# 7th molecule
# calculating diffracted fields
# 8th molecule
# calculating diffracted fields
# 9th molecule
# calculating diffracted fields
# 10th molecule
# calculating diffracted fields
# 11th molecule
# calculating diffracted fields
# 12th molecule
# calculating diffracted fields
# 13th molecule
# calculating diffracted fields
# 14th molecule
# calculating diffracted fields
# 15th molecule
# calculating diffracted fields
# 16th molecule
# calculating diffracted fields
# 17th molecule
# calculating diffracted fields
# 18th molecule
# calculating diffracted fields
# 19th molecule
# calculating diffracted fields
# 20th molecule
# calculating diffracted fields
# 21th molecule
# calculating diffracted fields
#
#  initial guess for molecule 0 location: (-0.04029413327533559,28.724773471567698)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  -0.04029413327533559
#  ini_y,  28.724773471567698
#  self.quel_a,  50.3368752
#  self.quel_c,  50.3368752
#
# In quenching zone? True
# Params modified, OG params: (-0.04029413327533559, 28.724773471567698, array([0.18806833]))
# but now they are: (-0.07061078355956711, 50.336825674824, array([0.18806833]))
#
#  initial guess for molecule 1 location: (0.04448876107027804,141.37993655325985)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  0.04448876107027804
#  ini_y,  141.37993655325985
#  self.quel_a,  50.3368752
#  self.quel_c,  50.3368752
#
# In quenching zone? False
#
#  initial guess for molecule 2 location: (0.028250381773899613,158.83013271917446)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  0.028250381773899613
#  ini_y,  158.83013271917446
#  self.quel_a,  50.3368752
#  self.quel_c,  50.3368752
#
# In quenching zone? False
#
#  initial guess for molecule 3 location: (11.899702884756469,26.51899243875368)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  11.899702884756469
#  ini_y,  26.51899243875368
#  self.quel_a,  50.3368752
#  self.quel_c,  50.3368752
#
# In quenching zone? True
# Params modified, OG params: (11.899702884756469, 26.51899243875368, array([0.81627695]))
# but now they are: (20.607723759492, 45.92518618745975, array([0.81627695]))
#
#  initial guess for molecule 4 location: (47.20896768487521,119.15504394753057)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  47.20896768487521
#  ini_y,  119.15504394753057
#  self.quel_a,  50.3368752
#  self.quel_c,  50.3368752
#
# In quenching zone? False
#
#  initial guess for molecule 5 location: (41.17854534945061,154.05832154943144)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  41.17854534945061
#  ini_y,  154.05832154943144
#  self.quel_a,  50.3368752
#  self.quel_c,  50.3368752
#
# In quenching zone? False
#
#  initial guess for molecule 6 location: (17.957987589090926,-0.010918845015660778)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  17.957987589090926
#  ini_y,  -0.010918845015660778
#  self.quel_a,  50.3368752
#  self.quel_c,  50.3368752
#
# In quenching zone? True
# Params modified, OG params: (17.957987589090926, -0.010918845015660778, array([1.22213924]))
# but now they are: (50.33686589547505, -0.030605903615889836, array([1.22213924]))
#
#  initial guess for molecule 7 location: (20.219262422077055,10.687676857114122)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  20.219262422077055
#  ini_y,  10.687676857114122
#  self.quel_a,  50.3368752
#  self.quel_c,  50.3368752
#
# In quenching zone? True
# Params modified, OG params: (20.219262422077055, 10.687676857114122, array([1.22651166]))
# but now they are: (44.502256194061566, 23.523396832483275, array([1.22651166]))
#
#  initial guess for molecule 8 location: (36.05997977991696,36.137089563973376)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  36.05997977991696
#  ini_y,  36.137089563973376
#  self.quel_a,  50.3368752
#  self.quel_c,  50.3368752
#
# In quenching zone? False
#
#  initial guess for molecule 9 location: (69.61886456301997,99.3450657049244)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  69.61886456301997
#  ini_y,  99.3450657049244
#  self.quel_a,  50.3368752
#  self.quel_c,  50.3368752
#
# In quenching zone? False
#
#  initial guess for molecule 10 location: (74.27877199899561,145.59573882593165)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  74.27877199899561
#  ini_y,  145.59573882593165
#  self.quel_a,  50.3368752
#  self.quel_c,  50.3368752
#
# In quenching zone? False
#
#  initial guess for molecule 11 location: (46.799580472808756,-0.010369296655082131)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  46.799580472808756
#  ini_y,  -0.010369296655082131
#  self.quel_a,  50.3368752
#  self.quel_c,  50.3368752
#
# In quenching zone? True
# Params modified, OG params: (46.799580472808756, -0.010369296655082131, array([0.18645354]))
# but now they are: (50.33687396441986, -0.01115304824433363, array([0.18645354]))
#
#  initial guess for molecule 12 location: (53.2041938596768,18.16371213627906)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  53.2041938596768
#  ini_y,  18.16371213627906
#  self.quel_a,  50.3368752
#  self.quel_c,  50.3368752
#
# In quenching zone? False
#
#  initial guess for molecule 13 location: (74.6737225057475,50.25146900820747)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  74.6737225057475
#  ini_y,  50.25146900820747
#  self.quel_a,  50.3368752
#  self.quel_c,  50.3368752
#
# In quenching zone? False
#
#  initial guess for molecule 14 location: (100.37248446043449,100.32231125617115)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  100.37248446043449
#  ini_y,  100.32231125617115
#  self.quel_a,  50.3368752
#  self.quel_c,  50.3368752
#
# In quenching zone? False
#
#  initial guess for molecule 15 location: (103.53125647283467,139.73424311858923)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  103.53125647283467
#  ini_y,  139.73424311858923
#  self.quel_a,  50.3368752
#  self.quel_c,  50.3368752
#
# In quenching zone? False
#
#  initial guess for molecule 16 location: (100.59153759929139,0.008533879532675053)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  100.59153759929139
#  ini_y,  0.008533879532675053
#  self.quel_a,  50.3368752
#  self.quel_c,  50.3368752
#
# In quenching zone? False
#
#  initial guess for molecule 17 location: (107.30045423418315,27.667029029888635)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  107.30045423418315
#  ini_y,  27.667029029888635
#  self.quel_a,  50.3368752
#  self.quel_c,  50.3368752
#
# In quenching zone? False
#
#  initial guess for molecule 18 location: (123.29055791604941,63.154700686807274)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  123.29055791604941
#  ini_y,  63.154700686807274
#  self.quel_a,  50.3368752
#  self.quel_c,  50.3368752
#
# In quenching zone? False
#
#  initial guess for molecule 19 location: (133.89812583081982,102.50659225266108)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  133.89812583081982
#  ini_y,  102.50659225266108
#  self.quel_a,  50.3368752
#  self.quel_c,  50.3368752
#
# In quenching zone? False
#
#  initial guess for molecule 20 location: (132.73067726853634,136.24074459871784)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  132.73067726853634
#  ini_y,  136.24074459871784
#  self.quel_a,  50.3368752
#  self.quel_c,  50.3368752
#
# In quenching zone? False
# Calculating Gaussian centroid with BEM_images

# %% [markdown]
# And way down to 30 surface elements. Not convinced anything is changing.

# %%
# locations, angles = fit.fixed_ori_mol_placement(
#     mol_grid_pts_1D=5, x_max=125, y_max=125)
sim_inst_lld = bem.SimulatedExperiment(
    locations, 
    mol_angle=0,
    param_file='sphere_80nmDrude',
    simulation_file_name='SphereDrudeLowLowDisc_NoSub_dipDrive_E')
sim_inst_lld.trial_images = sim_inst_lld.calculate_BEM_fields()

fit_inst_lld = fit.FitModelToData(
    sim_inst_lld.BEM_images, 
#     ini_guess=simTestInst_few_mol.mol_locations,
    ini_guess='gauss',
    param_file='sphere_80nmDrude'
    )
the_fit_lld = fit_inst_lld.fit_model_to_image_data(
    check_ini=True)

# ## Plot fit results
# fit_inst_lld.plot_fit_results_as_quiver_map(sim_inst_lld)   
fig5_HD = bem.fig5(sim_inst_lld, fit_inst_lld, draw_quadrant=True)
# Out:
# starting Matlab...
# given even number of points for Fibonacci lattice,
#   adding 1...
# 1th molecule
# calculating diffracted fields
# 2th molecule
# calculating diffracted fields
# 3th molecule
# calculating diffracted fields
# 4th molecule
# calculating diffracted fields
# 5th molecule
# calculating diffracted fields
# 6th molecule
# calculating diffracted fields
# 7th molecule
# calculating diffracted fields
# 8th molecule
# calculating diffracted fields
# 9th molecule
# calculating diffracted fields
# 10th molecule
# calculating diffracted fields
# 11th molecule
# calculating diffracted fields
# 12th molecule
# calculating diffracted fields
# 13th molecule
# calculating diffracted fields
# 14th molecule
# calculating diffracted fields
# 15th molecule
# calculating diffracted fields
# 16th molecule
# calculating diffracted fields
# 17th molecule
# calculating diffracted fields
# 18th molecule
# calculating diffracted fields
# 19th molecule
# calculating diffracted fields
# 20th molecule
# calculating diffracted fields
# 21th molecule
# calculating diffracted fields
#
#  initial guess for molecule 0 location: (-1.758767986785885,59.126291839471406)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  -1.758767986785885
#  ini_y,  59.126291839471406
#  self.quel_a,  50.3368752
#  self.quel_c,  50.3368752
#
# In quenching zone? False
#
#  initial guess for molecule 1 location: (-0.08395759040725483,138.21826816814243)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  -0.08395759040725483
#  ini_y,  138.21826816814243
#  self.quel_a,  50.3368752
#  self.quel_c,  50.3368752
#
# In quenching zone? False
#
#  initial guess for molecule 2 location: (-0.011538394755877613,157.05762521430623)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  -0.011538394755877613
#  ini_y,  157.05762521430623
#  self.quel_a,  50.3368752
#  self.quel_c,  50.3368752
#
# In quenching zone? False
#
#  initial guess for molecule 3 location: (15.855582842413996,32.48880945167179)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  15.855582842413996
#  ini_y,  32.48880945167179
#  self.quel_a,  50.3368752
#  self.quel_c,  50.3368752
#
# In quenching zone? True
# Params modified, OG params: (15.855582842413996, 32.48880945167179, array([0.5408263]))
# but now they are: (22.077179450147373, 45.237143504274954, array([0.5408263]))
#
#  initial guess for molecule 4 location: (47.87314532634653,118.06353782848458)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  47.87314532634653
#  ini_y,  118.06353782848458
#  self.quel_a,  50.3368752
#  self.quel_c,  50.3368752
#
# In quenching zone? False
#
#  initial guess for molecule 5 location: (41.28441895605782,152.41258370859924)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  41.28441895605782
#  ini_y,  152.41258370859924
#  self.quel_a,  50.3368752
#  self.quel_c,  50.3368752
#
# In quenching zone? False
#
#  initial guess for molecule 6 location: (22.139605998590312,0.000976936586523198)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  22.139605998590312
#  ini_y,  0.000976936586523198
#  self.quel_a,  50.3368752
#  self.quel_c,  50.3368752
#
# In quenching zone? True
# Params modified, OG params: (22.139605998590312, 0.000976936586523198, array([1.25424884]))
# but now they are: (50.336875150994004, 0.0022211748027124055, array([1.25424884]))
#
#  initial guess for molecule 7 location: (22.259269275637,11.54671757222572)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  22.259269275637
#  ini_y,  11.54671757222572
#  self.quel_a,  50.3368752
#  self.quel_c,  50.3368752
#
# In quenching zone? True
# Params modified, OG params: (22.259269275637, 11.54671757222572, array([1.29290588]))
# but now they are: (44.68278998799645, 23.178638523195858, array([1.29290588]))
#
#  initial guess for molecule 8 location: (38.702731558654506,38.302922647677846)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  38.702731558654506
#  ini_y,  38.302922647677846
#  self.quel_a,  50.3368752
#  self.quel_c,  50.3368752
#
# In quenching zone? False
#
#  initial guess for molecule 9 location: (70.54516064998968,99.37718475949062)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  70.54516064998968
#  ini_y,  99.37718475949062
#  self.quel_a,  50.3368752
#  self.quel_c,  50.3368752
#
# In quenching zone? False
#
#  initial guess for molecule 10 location: (74.29573586413478,144.15256659813866)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  74.29573586413478
#  ini_y,  144.15256659813866
#  self.quel_a,  50.3368752
#  self.quel_c,  50.3368752
#
# In quenching zone? False
#
#  initial guess for molecule 11 location: (49.47687154446718,0.002297323336570568)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  49.47687154446718
#  ini_y,  0.002297323336570568
#  self.quel_a,  50.3368752
#  self.quel_c,  50.3368752
#
# In quenching zone? True
# Params modified, OG params: (49.47687154446718, 0.002297323336570568, array([1.1268862]))
# but now they are: (50.33687514573797, 0.002337255253862826, array([1.1268862]))
#
#  initial guess for molecule 12 location: (55.633060382894136,18.868126551453745)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  55.633060382894136
#  ini_y,  18.868126551453745
#  self.quel_a,  50.3368752
#  self.quel_c,  50.3368752
#
# In quenching zone? False
#
#  initial guess for molecule 13 location: (76.22477826107817,50.94597794896942)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  76.22477826107817
#  ini_y,  50.94597794896942
#  self.quel_a,  50.3368752
#  self.quel_c,  50.3368752
#
# In quenching zone? False
#
#  initial guess for molecule 14 location: (99.85608692462857,99.05848954853806)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  99.85608692462857
#  ini_y,  99.05848954853806
#  self.quel_a,  50.3368752
#  self.quel_c,  50.3368752
#
# In quenching zone? False
#
#  initial guess for molecule 15 location: (103.30180600720406,138.49015243263926)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  103.30180600720406
#  ini_y,  138.49015243263926
#  self.quel_a,  50.3368752
#  self.quel_c,  50.3368752
#
# In quenching zone? False
#
#  initial guess for molecule 16 location: (100.80535971094815,0.017108324461351545)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  100.80535971094815
#  ini_y,  0.017108324461351545
#  self.quel_a,  50.3368752
#  self.quel_c,  50.3368752
#
# In quenching zone? False
#
#  initial guess for molecule 17 location: (106.98911269764037,27.480381785614867)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  106.98911269764037
#  ini_y,  27.480381785614867
#  self.quel_a,  50.3368752
#  self.quel_c,  50.3368752
#
# In quenching zone? False
#
#  initial guess for molecule 18 location: (121.90232295487012,62.19025891377852)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  121.90232295487012
#  ini_y,  62.19025891377852
#  self.quel_a,  50.3368752
#  self.quel_c,  50.3368752
#
# In quenching zone? False
#
#  initial guess for molecule 19 location: (132.55335942743594,101.06793927996178)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  132.55335942743594
#  ini_y,  101.06793927996178
#  self.quel_a,  50.3368752
#  self.quel_c,  50.3368752
#
# In quenching zone? False
#
#  initial guess for molecule 20 location: (132.31248869096618,135.28374920731068)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  132.31248869096618
#  ini_y,  135.28374920731068
#  self.quel_a,  50.3368752
#  self.quel_c,  50.3368752
#
# In quenching zone? False
# Calculating Gaussian centroid with BEM_images

# %%
# locations, angles = fit.fixed_ori_mol_placement(
#     mol_grid_pts_1D=5, x_max=125, y_max=125)
sim_inst_sh = bem.SimulatedExperiment(
    locations, 
    mol_angle=0,
    param_file='sphere_80nmDrude',
    simulation_file_name='SphereDrudeTestShift_NoSub_dipDrive_E')
sim_inst_sh.trial_images = sim_inst_sh.calculate_BEM_fields()

fit_inst_sh = fit.FitModelToData(
    sim_inst_sh.BEM_images, 
#     ini_guess=simTestInst_few_mol.mol_locations,
    ini_guess='gauss',
    param_file='sphere_80nmDrude'
    )
the_fit_sh = fit_inst_sh.fit_model_to_image_data(
    check_ini=True)

# ## Plot fit results
# fit_inst_sh.plot_fit_results_as_quiver_map(sim_inst_sh)   
fig5_HD = bem.fig5(sim_inst_sh, fit_inst_sh, draw_quadrant=True)
# Out:
# starting Matlab...
# given even number of points for Fibonacci lattice,
#   adding 1...
# 1th molecule
# calculating diffracted fields
# 2th molecule
# calculating diffracted fields
# 3th molecule
# calculating diffracted fields
# 4th molecule
# calculating diffracted fields
# 5th molecule
# calculating diffracted fields
# 6th molecule
# calculating diffracted fields
# 7th molecule
# calculating diffracted fields
# 8th molecule
# calculating diffracted fields
# 9th molecule
# calculating diffracted fields
# 10th molecule
# calculating diffracted fields
# 11th molecule
# calculating diffracted fields
# 12th molecule
# calculating diffracted fields
# 13th molecule
# calculating diffracted fields
# 14th molecule
# calculating diffracted fields
# 15th molecule
# calculating diffracted fields
# 16th molecule
# calculating diffracted fields
# 17th molecule
# calculating diffracted fields
# 18th molecule
# calculating diffracted fields
# 19th molecule
# calculating diffracted fields
# 20th molecule
# calculating diffracted fields
# 21th molecule
# calculating diffracted fields
#
#  initial guess for molecule 0 location: (7.439363055536026,21.002177625276197)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  7.439363055536026
#  ini_y,  21.002177625276197
#  self.quel_a,  50.3368752
#  self.quel_c,  50.3368752
#
# In quenching zone? True
# Params modified, OG params: (7.439363055536026, 21.002177625276197, array([0.1014872]))
# but now they are: (16.807013627257426, 47.4481327117681, array([0.1014872]))
#
#  initial guess for molecule 1 location: (-10.16251129293379,135.6397222371721)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  -10.16251129293379
#  ini_y,  135.6397222371721
#  self.quel_a,  50.3368752
#  self.quel_c,  50.3368752
#
# In quenching zone? False
#
#  initial guess for molecule 2 location: (-3.888695560506182,156.51769086486985)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  -3.888695560506182
#  ini_y,  156.51769086486985
#  self.quel_a,  50.3368752
#  self.quel_c,  50.3368752
#
# In quenching zone? False
#
#  initial guess for molecule 3 location: (19.04035056488242,29.82610767698853)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  19.04035056488242
#  ini_y,  29.82610767698853
#  self.quel_a,  50.3368752
#  self.quel_c,  50.3368752
#
# In quenching zone? True
# Params modified, OG params: (19.04035056488242, 29.82610767698853, array([1.2927252]))
# but now they are: (27.08545875676111, 42.428515515348494, array([1.2927252]))
#
#  initial guess for molecule 4 location: (47.67001309816758,127.59918553814116)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  47.67001309816758
#  ini_y,  127.59918553814116
#  self.quel_a,  50.3368752
#  self.quel_c,  50.3368752
#
# In quenching zone? False
#
#  initial guess for molecule 5 location: (38.9227504462091,154.74043013398773)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  38.9227504462091
#  ini_y,  154.74043013398773
#  self.quel_a,  50.3368752
#  self.quel_c,  50.3368752
#
# In quenching zone? False
#
#  initial guess for molecule 6 location: (41.484324187805186,0.007701057936581126)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  41.484324187805186
#  ini_y,  0.007701057936581126
#  self.quel_a,  50.3368752
#  self.quel_c,  50.3368752
#
# In quenching zone? True
# Params modified, OG params: (41.484324187805186, 0.007701057936581126, array([0.55441052]))
# but now they are: (50.33687433266078, 0.009344425711914909, array([0.55441052]))
#
#  initial guess for molecule 7 location: (27.625015101758063,11.28088225500957)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  27.625015101758063
#  ini_y,  11.28088225500957
#  self.quel_a,  50.3368752
#  self.quel_c,  50.3368752
#
# In quenching zone? True
# Params modified, OG params: (27.625015101758063, 11.28088225500957, array([1.15763255]))
# but now they are: (46.601109647853, 19.029912887061705, array([1.15763255]))
#
#  initial guess for molecule 8 location: (39.49032865946712,34.90614878014699)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  39.49032865946712
#  ini_y,  34.90614878014699
#  self.quel_a,  50.3368752
#  self.quel_c,  50.3368752
#
# In quenching zone? False
#
#  initial guess for molecule 9 location: (72.894292728133,102.36268125849342)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  72.894292728133
#  ini_y,  102.36268125849342
#  self.quel_a,  50.3368752
#  self.quel_c,  50.3368752
#
# In quenching zone? False
#
#  initial guess for molecule 10 location: (74.50447340667168,146.66156941922827)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  74.50447340667168
#  ini_y,  146.66156941922827
#  self.quel_a,  50.3368752
#  self.quel_c,  50.3368752
#
# In quenching zone? False
#
#  initial guess for molecule 11 location: (47.461852529865396,0.0005018862107587792)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  47.461852529865396
#  ini_y,  0.0005018862107587792
#  self.quel_a,  50.3368752
#  self.quel_c,  50.3368752
#
# In quenching zone? True
# Params modified, OG params: (47.461852529865396, 0.0005018862107587792, array([0.00887903]))
# but now they are: (50.33687519718565, 0.0005322881894984005, array([0.00887903]))
#
#  initial guess for molecule 12 location: (52.590116604461926,16.154320034844197)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  52.590116604461926
#  ini_y,  16.154320034844197
#  self.quel_a,  50.3368752
#  self.quel_c,  50.3368752
#
# In quenching zone? False
#
#  initial guess for molecule 13 location: (72.88344277882861,46.719795508331465)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  72.88344277882861
#  ini_y,  46.719795508331465
#  self.quel_a,  50.3368752
#  self.quel_c,  50.3368752
#
# In quenching zone? False
#
#  initial guess for molecule 14 location: (99.83745678809186,98.42245889255828)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  99.83745678809186
#  ini_y,  98.42245889255828
#  self.quel_a,  50.3368752
#  self.quel_c,  50.3368752
#
# In quenching zone? False
#
#  initial guess for molecule 15 location: (104.14654095210656,139.94834599829906)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  104.14654095210656
#  ini_y,  139.94834599829906
#  self.quel_a,  50.3368752
#  self.quel_c,  50.3368752
#
# In quenching zone? False
#
#  initial guess for molecule 16 location: (92.73203334047632,0.011273936385879485)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  92.73203334047632
#  ini_y,  0.011273936385879485
#  self.quel_a,  50.3368752
#  self.quel_c,  50.3368752
#
# In quenching zone? False
#
#  initial guess for molecule 17 location: (99.44905117504422,24.89066348157115)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  99.44905117504422
#  ini_y,  24.89066348157115
#  self.quel_a,  50.3368752
#  self.quel_c,  50.3368752
#
# In quenching zone? False
#
#  initial guess for molecule 18 location: (117.22435319855238,59.18734738027414)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  117.22435319855238
#  ini_y,  59.18734738027414
#  self.quel_a,  50.3368752
#  self.quel_c,  50.3368752
#
# In quenching zone? False
#
#  initial guess for molecule 19 location: (132.06511775468113,100.5893259455362)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  132.06511775468113
#  ini_y,  100.5893259455362
#  self.quel_a,  50.3368752
#  self.quel_c,  50.3368752
#
# In quenching zone? False
#
#  initial guess for molecule 20 location: (132.9737765477806,136.15750229355086)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  132.9737765477806
#  ini_y,  136.15750229355086
#  self.quel_a,  50.3368752
#  self.quel_c,  50.3368752
#
# In quenching zone? False
# Calculating Gaussian centroid with BEM_images

# %% [markdown]
# ### Changing height of molecule

# %%
sph_sub_locations = locations - np.array([[0, 0, 40]])
sph_sub_locations
# Out:
# array([[  0.  ,   0.  , -40.  ],
#        [  0.  ,  31.25, -40.  ],
#        [  0.  ,  62.5 , -40.  ],
#        [  0.  ,  93.75, -40.  ],
#        [  0.  , 125.  , -40.  ],
#        [ 31.25,   0.  , -40.  ],
#        [ 31.25,  31.25, -40.  ],
#        [ 31.25,  62.5 , -40.  ],
#        [ 31.25,  93.75, -40.  ],
#        [ 31.25, 125.  , -40.  ],
#        [ 62.5 ,   0.  , -40.  ],
#        [ 62.5 ,  31.25, -40.  ],
#        [ 62.5 ,  62.5 , -40.  ],
#        [ 62.5 ,  93.75, -40.  ],
#        [ 62.5 , 125.  , -40.  ],
#        [ 93.75,   0.  , -40.  ],
#        [ 93.75,  31.25, -40.  ],
#        [ 93.75,  62.5 , -40.  ],
#        [ 93.75,  93.75, -40.  ],
#        [ 93.75, 125.  , -40.  ],
#        [125.  ,   0.  , -40.  ],
#        [125.  ,  31.25, -40.  ],
#        [125.  ,  62.5 , -40.  ],
#        [125.  ,  93.75, -40.  ],
#        [125.  , 125.  , -40.  ]])

# %%
# locations, angles = fit.fixed_ori_mol_placement(
#     mol_grid_pts_1D=5, x_max=125, y_max=125)
sim_inst_ms = bem.SimulatedExperiment(
    sph_sub_locations, 
    mol_angle=0,
    param_file='sphere_80nmDrude',
    simulation_file_name='SphereDrude_NoSub_dipDrive_E')
sim_inst_ms.trial_images = sim_inst_ms.calculate_BEM_fields()

fit_inst_ms = fit.FitModelToData(
    sim_inst_ms.BEM_images, 
#     ini_guess=simTestInst_few_mol.mol_locations,
    ini_guess='gauss',
    param_file='sphere_80nmDrude'
    )
the_fit_ms = fit_inst_ms.fit_model_to_image_data(
    check_ini=True)

# ## Plot fit results
# fit_inst_ms.plot_fit_results_as_quiver_map(sim_inst_ms)   
fig5_ms = bem.fig5(sim_inst_ms, fit_inst_ms, draw_quadrant=True)
