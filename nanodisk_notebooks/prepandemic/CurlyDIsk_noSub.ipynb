# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
sys.path.append(module_path)

import numpy as np

## Plotting stuff
import matplotlib.pyplot as plt
import matplotlib as mpl

# %%
## Parameter setting needs to be in cell following mpl import for some reason 
## https://github.com/jupyter/notebook/issues/3385
##
## Default parameters inspired by 
## http://nipunbatra.github.io/2014/08/latexify/
params = {
    'text.latex.preamble': ['\\usepackage{gensymb}'],
    'image.origin': 'lower',
    'image.interpolation': 'nearest',
    'image.cmap': 'magma',
    'axes.grid': False,
    'figure.dpi': 200,  # to adjust notebook inline plot size
    'savefig.dpi': 200,  # to adjust notebook inline plot size
#     'axes.labelsize': 12, # fontsize for x and y labels (was 10)
    'axes.titlesize': 14,
    'font.size': 8, # was 10
#     'savefig.dpi': 150,  # to adjust notebook inline plot size
    'axes.labelsize': 10, # fontsize for x and y labels (was 10)
    'axes.titlesize': 10,
    'font.size': 8, # was 10
    'legend.fontsize': 8, # was 10
    'xtick.labelsize': 8,
    'ytick.labelsize': 8,
    'text.usetex': True,
    'figure.figsize': [3.39, 2.10],
    'font.family': 'serif',
    'figure.max_open_warning':10001
}
mpl.rcParams.update(params)
## For colorbar 
from mpl_toolkits.axes_grid1 import make_axes_locatable

## Get physical constants from Scipy
import scipy.constants as con

## For fitting
import scipy.optimize as opt

## For matlab loading
import scipy.io as sio

## Load custom package modules
from misloc_mispol_package.calc import _BEM_simulation_wrapper as bem
from misloc_mispol_package.calc import _fitting_misLocalization as fit
from misloc_mispol_package.calc import coupled_dipoles as cp
from misloc_mispol_package.optics import diffraction_int as diffi
from misloc_mispol_package.optics import fibonacci as fib

## Some useful numerical constants
hbar = con.physical_constants['Planck constant over 2 pi in eV s'][0]
c = con.physical_constants['speed of light in vacuum'][0]*1e2 #cm/m

m_per_nm = fit.m_per_nm

eps_b = 1.778 ## Water
cm_per_nm = 1E-7

hres_obs_pts = diffi.observation_points(
    -480*m_per_nm, 480*m_per_nm, -480*m_per_nm, 480*m_per_nm, 201)

# %%
def label_offset(ax, axis="y"):
    if axis == "y":
        fmt = ax.yaxis.get_major_formatter()
        ax.yaxis.offsetText.set_visible(False)
        set_label = ax.set_ylabel
        label = ax.get_ylabel()

    elif axis == "x":
        fmt = ax.xaxis.get_major_formatter()
        ax.xaxis.offsetText.set_visible(False)
        set_label = ax.set_xlabel
        label = ax.get_xlabel()

    def update_label(event_axes):
        offset = fmt.get_offset()
        if offset == '':
            set_label("{}".format(label))
        else:
            set_label("{} ({})".format(label, offset))
        return

    ax.callbacks.connect("ylim_changed", update_label)
    ax.callbacks.connect("xlim_changed", update_label)
    ax.figure.canvas.draw()
    update_label(None)
    return

# %% [markdown]
# Need a spectrum of the disk in order to parameterize. Will do that now in matlab.

# %%
path_to_spec = os.path.join(
    os.sep,
    'Users',
    'chair',
    'Documents',
    'MATLAB',
    'disk_simulations'
    )

disk_spec = sio.loadmat(os.path.join(
    path_to_spec,
    'bare_disk_spectrum.mat'
    ))

# %%
hw = 1240/disk_spec['enei'][0]
spec = disk_spec['sca']
spec.shape
# Out:
# (50, 3)

# %%
hw.shape
# Out:
# (50,)

# %%
plt.figure(figsize=(4,3), dpi=150)
for i, spectrum in enumerate(spec.T):
    plt.plot(hw, spectrum)

# %% [markdown]
# This is a JC spectrum, should do Drude as well for rigor

# %%
def ret_fit_scat_1(hbarw, eps_inf, hbarw_p, hbargamma, half_height, radius):
    
    a_x = half_height
    a_yz = radius
    
    return cp.long_sigma_scat_ret_pro_ellip(
        hbarw/hbar, 
        eps_inf, 
        hbarw_p/hbar, 
        hbargamma/hbar, 
        eps_b, 
        a_x*cm_per_nm, 
        a_yz*cm_per_nm)

# %%
#+++++++++++++++++++++++++++++++++++++++++++++
def absol_oblate_cost_f(params, *args):
    x=args[0]
    y=args[1]
    
    ## Parameters
#     eps_inf=params[0]
#     w_p=params[1]
#     gamma=params[2]
#     a_x = params[3]
#     a_yz = params[4]
    
    ## Convert data from nm^2 to cm^2
    y = y*(1e-14) ## cm^2/nm^2
    
    ## Define fit function
    yfit = ret_fit_scat_1(x, *params)

    ## Define scale of cost func for rescaling to order unity 
    cost_scale = 1e-10
    
    return (y-yfit).ravel() / cost_scale



def oblate_fit_result(x, params):
    
    amp = params[-1]
    phys_params = params[:-1]
    
    yfit=ret_fit_scat_1(x, *phys_params)
    
    return yfit/yfit.max() * amp

# %%
sigma_scat_data = spec[:,0]

# %%
#+++++++++++++++++++++++++++++++++++++++++++++
# ini_guess_params=np.array([3.48260965,  6.72763066,  0.65709936, 29.24119972, 79.24119972])
ini_guess_params=np.array([11.6817827 ,  9.56022562,  0.8554153, 30.24119972/2, 80.24119972/2,])
# ini_guess_params=np.array([13.99604932, 10.05123876,  0.28443696, 36.1993746]) 
# ini_guess_params=np.array([15.14244193,  8.4634295 , -0.16462349, 64.3292537 , 28.24427368])
params0=ini_guess_params   #parameter guess

## Reduce fit range
energy_cutoff = 2.5
args=[hw[hw<energy_cutoff], sigma_scat_data[hw<energy_cutoff]]
# for c in Ts:
#   args.append(c) 
args=tuple(args)   #doesn't work if args is a list!!

## Perform minimization of cost function
result=opt.least_squares(
    absol_oblate_cost_f, 
    params0, 
    ftol=1e-15,
    xtol=1e-15, 
    gtol=1e-15, 
    args=args,
    bounds=(
        [0,   0,  0,  10, 35],
        [18, 20, 1,  20, 45],
        ),
    x_scale=[10,10,1E-1,10, 10],
    )
                         
#+++++++++++++++++++++++++++++++++++++++++++++
fit_result = ret_fit_scat_1(hw, *result['x'])
ini_guess = ret_fit_scat_1(hw, *ini_guess_params)


## Build figure
plt.figure()

## Plot Data
plt.plot(hw, sigma_scat_data*1E-14, label='data')
plt.plot(
    [2.5, 2.5],
    [np.min(sigma_scat_data*1E-14), np.max(sigma_scat_data*1E-14)],
    ls='dashed',
    c='k',
    lw=1)

## Plot best fit
plt.plot(
    hw, 
    fit_result, 
    label='fit',
    ls='--', 
#     marker='.', 
    markersize=1, 
    alpha=.9)

# ## Plot initial guess
# plt.plot(
#     hw, 
#     ini_guess, 
#     label='initial guess',
#     ls='dotted', 
# #     marker='.', 
#     markersize=1, 
#     alpha=.9)

plt.xlabel(r'$\hbar\omega$ [eV]')
# plt.xlim([1.4, 2.7])
plt.ylabel(r'$\sigma$ [cm$^2$]')
plt.title(r'Oblate spheroid model fit to JC Disk')
plt.legend()

ax = plt.gca()
label_offset(ax, "y")

result['x']
# Out:
# array([12.35045979,  9.28346156,  0.14991186, 20.        , 41.74973417])

# %% [markdown]
# Things that would be interesting to compare,
# - How does fitting just long axis compare to simultaneous fit of long and short axis, like in the rod case
#     - this could be a significant difference between the rod and disk situations that I had not previously acknowledged.
#     - If I do not constrain the fit to the long axis the radii tend to equalize.
#
# Should also maybe check z orientation?

# %%
locations, angles = fit.fixed_ori_mol_placement(
    mol_grid_pts_1D=5, x_max=125, y_max=125)
sim_inst_JC = bem.SimulatedExperiment(
    locations, 
    mol_angle=0,
    param_file='disk_JC',
    simulation_file_name='CurlyDiskJC_NoSub_dipDrive_E')
sim_inst_JC.trial_images = sim_inst_JC.calculate_BEM_fields()

# Model fit
# Gaussian guess, checked

fit_inst_JC = fit.FitModelToData(
    sim_inst_JC.BEM_images, 
#     ini_guess=simTestInst_few_mol.mol_locations,
    ini_guess='gauss',
    param_file='disk_JC'
    )
the_fit = fit_inst_JC.fit_model_to_image_data(
    check_ini=True)

## Plot fit results
# fit_inst_JC.plot_fit_results_as_quiver_map(sim_inst_JC)
# Out:
# starting Matlab...
# given even number of points for Fibonacci lattice,
#   adding 1...
# 1th molecule
# calculating diffracted fields
# 2th molecule
# calculating diffracted fields
# 3th molecule
# calculating diffracted fields
# 4th molecule
# calculating diffracted fields
# 5th molecule
# calculating diffracted fields
# 6th molecule
# calculating diffracted fields
# 7th molecule
# calculating diffracted fields
# 8th molecule
# calculating diffracted fields
# 9th molecule
# calculating diffracted fields
# 10th molecule
# calculating diffracted fields
# 11th molecule
# calculating diffracted fields
# 12th molecule
# calculating diffracted fields
# 13th molecule
# calculating diffracted fields
# 14th molecule
# calculating diffracted fields
# 15th molecule
# calculating diffracted fields
# 16th molecule
# calculating diffracted fields
# 17th molecule
# calculating diffracted fields
# 18th molecule
# calculating diffracted fields
# 19th molecule
# calculating diffracted fields
# 20th molecule
# calculating diffracted fields
# 21th molecule
# calculating diffracted fields
#
#  initial guess for molecule 0 location: (0.10181834403373026,10.041602321057415)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  0.10181834403373026
#  ini_y,  10.041602321057415
#  self.quel_a,  51.74973417
#  self.quel_c,  51.74973417
#
# In quenching zone? True
# Params modified, OG params: (0.10181834403373026, 10.041602321057415, array([1.46824254]))
# but now they are: (0.524697277037313, 51.74707411470851, array([1.46824254]))
#
#  initial guess for molecule 1 location: (0.013925849433767547,127.26282823079339)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  0.013925849433767547
#  ini_y,  127.26282823079339
#  self.quel_a,  51.74973417
#  self.quel_c,  51.74973417
#
# In quenching zone? False
#
#  initial guess for molecule 2 location: (0.012836889317208822,154.0321882354493)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  0.012836889317208822
#  ini_y,  154.0321882354493
#  self.quel_a,  51.74973417
#  self.quel_c,  51.74973417
#
# In quenching zone? False
#
#  initial guess for molecule 3 location: (4.0871784580555,15.597077224942634)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  4.0871784580555
#  ini_y,  15.597077224942634
#  self.quel_a,  51.74973417
#  self.quel_c,  51.74973417
#
# In quenching zone? True
# Params modified, OG params: (4.0871784580555, 15.597077224942634, array([0.45407467]))
# but now they are: (13.117977891182363, 50.05950102340331, array([0.45407467]))
#
#  initial guess for molecule 4 location: (32.164190719802754,109.82208216373823)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  32.164190719802754
#  ini_y,  109.82208216373823
#  self.quel_a,  51.74973417
#  self.quel_c,  51.74973417
#
# In quenching zone? False
#
#  initial guess for molecule 5 location: (35.33114361675472,151.00080361179633)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  35.33114361675472
#  ini_y,  151.00080361179633
#  self.quel_a,  51.74973417
#  self.quel_c,  51.74973417
#
# In quenching zone? False
#
#  initial guess for molecule 6 location: (8.558903114886993,-0.004379260240783198)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  8.558903114886993
#  ini_y,  -0.004379260240783198
#  self.quel_a,  51.74973417
#  self.quel_c,  51.74973417
#
# In quenching zone? True
# Params modified, OG params: (8.558903114886993, -0.004379260240783198, array([0.74634593]))
# but now they are: (51.749727396029044, -0.026478337307356825, array([0.74634593]))
#
#  initial guess for molecule 7 location: (10.483824646998865,6.145716235838758)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  10.483824646998865
#  ini_y,  6.145716235838758
#  self.quel_a,  51.74973417
#  self.quel_c,  51.74973417
#
# In quenching zone? True
# Params modified, OG params: (10.483824646998865, 6.145716235838758, array([0.59580273]))
# but now they are: (44.64434245523224, 26.170931840605412, array([0.59580273]))
#
#  initial guess for molecule 8 location: (24.147748200809122,28.39689964504605)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  24.147748200809122
#  ini_y,  28.39689964504605
#  self.quel_a,  51.74973417
#  self.quel_c,  51.74973417
#
# In quenching zone? True
# Params modified, OG params: (24.147748200809122, 28.39689964504605, array([1.41519833]))
# but now they are: (33.524001633529416, 39.42304276867506, array([1.41519833]))
#
#  initial guess for molecule 9 location: (61.15776634638648,100.4346132091861)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  61.15776634638648
#  ini_y,  100.4346132091861
#  self.quel_a,  51.74973417
#  self.quel_c,  51.74973417
#
# In quenching zone? False
#
#  initial guess for molecule 10 location: (68.00906470759588,145.76031854296258)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  68.00906470759588
#  ini_y,  145.76031854296258
#  self.quel_a,  51.74973417
#  self.quel_c,  51.74973417
#
# In quenching zone? False
#
#  initial guess for molecule 11 location: (34.334750296709856,-0.0029938007973322822)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  34.334750296709856
#  ini_y,  -0.0029938007973322822
#  self.quel_a,  51.74973417
#  self.quel_c,  51.74973417
#
# In quenching zone? True
# Params modified, OG params: (34.334750296709856, -0.0029938007973322822, array([1.27635922]))
# but now they are: (51.74973397327655, -0.004512291293588275, array([1.27635922]))
#
#  initial guess for molecule 12 location: (41.77283639357843,15.559868609347346)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  41.77283639357843
#  ini_y,  15.559868609347346
#  self.quel_a,  51.74973417
#  self.quel_c,  51.74973417
#
# In quenching zone? True
# Params modified, OG params: (41.77283639357843, 15.559868609347346, array([1.48083003]))
# but now they are: (48.49472276188244, 18.063688740504432, array([1.48083003]))
#
#  initial guess for molecule 13 location: (68.36318945103338,50.23707864884514)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  68.36318945103338
#  ini_y,  50.23707864884514
#  self.quel_a,  51.74973417
#  self.quel_c,  51.74973417
#
# In quenching zone? False
#
#  initial guess for molecule 14 location: (98.05360960072765,105.66125540699048)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  98.05360960072765
#  ini_y,  105.66125540699048
#  self.quel_a,  51.74973417
#  self.quel_c,  51.74973417
#
# In quenching zone? False
#
#  initial guess for molecule 15 location: (99.64363674428103,141.92758852534095)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  99.64363674428103
#  ini_y,  141.92758852534095
#  self.quel_a,  51.74973417
#  self.quel_c,  51.74973417
#
# In quenching zone? False
#
#  initial guess for molecule 16 location: (100.81712663759323,0.022639072111523863)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  100.81712663759323
#  ini_y,  0.022639072111523863
#  self.quel_a,  51.74973417
#  self.quel_c,  51.74973417
#
# In quenching zone? False
#
#  initial guess for molecule 17 location: (109.46294421162442,29.747176189925845)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  109.46294421162442
#  ini_y,  29.747176189925845
#  self.quel_a,  51.74973417
#  self.quel_c,  51.74973417
#
# In quenching zone? False
#
#  initial guess for molecule 18 location: (127.79249960565194,68.61054738694013)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  127.79249960565194
#  ini_y,  68.61054738694013
#  self.quel_a,  51.74973417
#  self.quel_c,  51.74973417
#
# In quenching zone? False
#
#  initial guess for molecule 19 location: (135.04556967418438,107.50320809042734)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  135.04556967418438
#  ini_y,  107.50320809042734
#  self.quel_a,  51.74973417
#  self.quel_c,  51.74973417
#
# In quenching zone? False
#
#  initial guess for molecule 20 location: (131.24286555929964,138.8755477952649)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  131.24286555929964
#  ini_y,  138.8755477952649
#  self.quel_a,  51.74973417
#  self.quel_c,  51.74973417
#
# In quenching zone? False

# %%
fig5 = bem.fig5(sim_inst_JC, fit_inst_JC, draw_quadrant=True, show_ax_labels=True)

# %%
sim_inst.drive_energy_eV
# Out:
# 2.0

# %% [markdown]
# ## Move to Drude disk

# %%
diskDrude_spec = sio.loadmat(os.path.join(
    path_to_spec,
    'bare_disk_spectrum_Drude.mat'
    ))

hw = 1240/diskDrude_spec['enei'][0]
spec = diskDrude_spec['sca']
spec.shape

plt.figure(figsize=(4,3), dpi=150)
for i, spectrum in enumerate(spec.T):
    plt.plot(hw, spectrum)
    plt.plot(hw, disk_spec['sca'].T[i], ls='--')

# %%
sigma_scat_data = spec[:,0]

#+++++++++++++++++++++++++++++++++++++++++++++
# ini_guess_params=np.array([3.48260965,  6.72763066,  0.65709936, 29.24119972, 79.24119972])
ini_guess_params=np.array([11.6817827 ,  9.56022562,  0.08554153, 30.24119972/2, 79.24119972/2,])
# ini_guess_params=np.array([13.99604932, 10.05123876,  0.28443696, 36.1993746]) 
# ini_guess_params=np.array([15.14244193,  8.4634295 , -0.16462349, 64.3292537 , 28.24427368])
params0=ini_guess_params   #parameter guess

## Reduce fit range
energy_cutoff = 2.5
args=[hw[hw<energy_cutoff], sigma_scat_data[hw<energy_cutoff]]
# for c in Ts:
#   args.append(c) 
args=tuple(args)   #doesn't work if args is a list!!

## Perform minimization of cost function
result=opt.least_squares(
    absol_oblate_cost_f, 
    params0, 
    ftol=1e-15,
    xtol=1e-15, 
    gtol=1e-15, 
    args=args,
#     bounds=(
#         [0,   0,  0,  5, 35],
#         [25, 20, 1,  20, 45],
#         ),
    x_scale=[10,10,1E-1,10, 10],
    )
                         
#+++++++++++++++++++++++++++++++++++++++++++++
fit_result = ret_fit_scat_1(hw, *result['x'])
ini_guess = ret_fit_scat_1(hw, *ini_guess_params)


## Build figure
plt.figure(dpi=150)

## Plot Data
plt.plot(hw, sigma_scat_data*1E-14, label='data')
plt.plot(
    [2.5, 2.5],
    [np.min(sigma_scat_data*1E-14), np.max(sigma_scat_data*1E-14)],
    ls='dashed',
    c='k',
    lw=1)

## Plot best fit
plt.plot(
    hw, 
    fit_result, 
    label='fit',
    ls='--', 
#     marker='.', 
    markersize=1, 
    alpha=.9)

# ## Plot initial guess
# plt.plot(
#     hw, 
#     ini_guess, 
#     label='initial guess',
#     ls='dotted', 
# #     marker='.', 
#     markersize=1, 
#     alpha=.9)

plt.xlabel(r'$\hbar\omega$ [eV]')
# plt.xlim([1.4, 2.7])
plt.ylabel(r'$\sigma$ [cm$^2$]')
plt.title(r'Oblate spheroid model fit to Drude Disk')
plt.legend(fontsize=8)


ax = plt.gca()
label_offset(ax, "y")

result['x']
# Out:
# array([45.2282245 , 20.13645854,  0.09593564,  2.9856273 , 47.09151229])

# %% [markdown]
# ## Now Drude, no fit bounds

# %%
locations, angles = fit.fixed_ori_mol_placement(
    mol_grid_pts_1D=5, x_max=125, y_max=125)
sim_inst_Drude = bem.SimulatedExperiment(
    locations, 
    mol_angle=0,
    param_file='disk_Drude_noFitBounds',
    simulation_file_name='CurlyDiskDrude_NoSub_dipDrive_E')
sim_inst_Drude.trial_images = sim_inst_Drude.calculate_BEM_fields()

fit_inst_Drude = fit.FitModelToData(
    sim_inst_Drude.BEM_images, 
#     ini_guess=simTestInst_few_mol.mol_locations,
    ini_guess='gauss',
    param_file='disk_Drude_noFitBounds'
    )
the_fit = fit_inst_Drude.fit_model_to_image_data(
    check_ini=True)
# sim_inst_Drude.plot_mispol_map_wMisloc()
# Out:
# starting Matlab...
# given even number of points for Fibonacci lattice,
#   adding 1...
# 1th molecule
# calculating diffracted fields
# 2th molecule
# calculating diffracted fields
# 3th molecule
# calculating diffracted fields
# 4th molecule
# calculating diffracted fields
# 5th molecule
# calculating diffracted fields
# 6th molecule
# calculating diffracted fields
# 7th molecule
# calculating diffracted fields
# 8th molecule
# calculating diffracted fields
# 9th molecule
# calculating diffracted fields
# 10th molecule
# calculating diffracted fields
# 11th molecule
# calculating diffracted fields
# 12th molecule
# calculating diffracted fields
# 13th molecule
# calculating diffracted fields
# 14th molecule
# calculating diffracted fields
# 15th molecule
# calculating diffracted fields
# 16th molecule
# calculating diffracted fields
# 17th molecule
# calculating diffracted fields
# 18th molecule
# calculating diffracted fields
# 19th molecule
# calculating diffracted fields
# 20th molecule
# calculating diffracted fields
# 21th molecule
# calculating diffracted fields
#
#  initial guess for molecule 0 location: (0.04508164461616864,2.8477720880675936)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  0.04508164461616864
#  ini_y,  2.8477720880675936
#  self.quel_a,  57.09151229
#  self.quel_c,  57.09151229
#
# In quenching zone? True
# Params modified, OG params: (0.04508164461616864, 2.8477720880675936, array([0.67788272]))
# but now they are: (0.9036737309761398, 57.08435993638857, array([0.67788272]))
#
#  initial guess for molecule 1 location: (0.020638471869743217,97.79531548716822)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  0.020638471869743217
#  ini_y,  97.79531548716822
#  self.quel_a,  57.09151229
#  self.quel_c,  57.09151229
#
# In quenching zone? False
#
#  initial guess for molecule 2 location: (0.023268046221054262,153.51053441859253)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  0.023268046221054262
#  ini_y,  153.51053441859253
#  self.quel_a,  57.09151229
#  self.quel_c,  57.09151229
#
# In quenching zone? False
#
#  initial guess for molecule 3 location: (1.5938519717885276,7.046441340524239)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  1.5938519717885276
#  ini_y,  7.046441340524239
#  self.quel_a,  57.09151229
#  self.quel_c,  57.09151229
#
# In quenching zone? True
# Params modified, OG params: (1.5938519717885276, 7.046441340524239, array([0.80537261]))
# but now they are: (12.595477907710753, 55.684779893931434, array([0.80537261]))
#
#  initial guess for molecule 4 location: (19.589325360695263,76.0555983765588)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  19.589325360695263
#  ini_y,  76.0555983765588
#  self.quel_a,  57.09151229
#  self.quel_c,  57.09151229
#
# In quenching zone? False
#
#  initial guess for molecule 5 location: (31.224141725656974,150.5644311302856)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  31.224141725656974
#  ini_y,  150.5644311302856
#  self.quel_a,  57.09151229
#  self.quel_c,  57.09151229
#
# In quenching zone? False
#
#  initial guess for molecule 6 location: (4.185350038427654,-0.003739264787398766)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  4.185350038427654
#  ini_y,  -0.003739264787398766
#  self.quel_a,  57.09151229
#  self.quel_c,  57.09151229
#
# In quenching zone? True
# Params modified, OG params: (4.185350038427654, -0.003739264787398766, array([1.19359097]))
# but now they are: (57.09148950494088, -0.05100653336186562, array([1.19359097]))
#
#  initial guess for molecule 7 location: (5.132629249458177,3.0087607322256287)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  5.132629249458177
#  ini_y,  3.0087607322256287
#  self.quel_a,  57.09151229
#  self.quel_c,  57.09151229
#
# In quenching zone? True
# Params modified, OG params: (5.132629249458177, 3.0087607322256287, array([1.23802683]))
# but now they are: (49.25282357913906, 28.872134403978944, array([1.23802683]))
#
#  initial guess for molecule 8 location: (12.40079158394807,15.645839860527383)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  12.40079158394807
#  ini_y,  15.645839860527383
#  self.quel_a,  57.09151229
#  self.quel_c,  57.09151229
#
# In quenching zone? True
# Params modified, OG params: (12.40079158394807, 15.645839860527383, array([1.05540747]))
# but now they are: (35.462356964139886, 44.74217265742847, array([1.05540747]))
#
#  initial guess for molecule 9 location: (42.871055358370434,76.88813663791433)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  42.871055358370434
#  ini_y,  76.88813663791433
#  self.quel_a,  57.09151229
#  self.quel_c,  57.09151229
#
# In quenching zone? False
#
#  initial guess for molecule 10 location: (62.68655963283203,146.6735944234692)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  62.68655963283203
#  ini_y,  146.6735944234692
#  self.quel_a,  57.09151229
#  self.quel_c,  57.09151229
#
# In quenching zone? False
#
#  initial guess for molecule 11 location: (19.10285074086114,-0.006958329634269344)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  19.10285074086114
#  ini_y,  -0.006958329634269344
#  self.quel_a,  57.09151229
#  self.quel_c,  57.09151229
#
# In quenching zone? True
# Params modified, OG params: (19.10285074086114, -0.006958329634269344, array([1.0834346]))
# but now they are: (57.091508502478206, -0.020795929406934175, array([1.0834346]))
#
#  initial guess for molecule 12 location: (24.185978348853894,9.38690302012315)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  24.185978348853894
#  ini_y,  9.38690302012315
#  self.quel_a,  57.09151229
#  self.quel_c,  57.09151229
#
# In quenching zone? True
# Params modified, OG params: (24.185978348853894, 9.38690302012315, array([0.01824184]))
# but now they are: (53.2234860374803, 20.656749734102892, array([0.01824184]))
#
#  initial guess for molecule 13 location: (46.27973575560413,36.28919558374038)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  46.27973575560413
#  ini_y,  36.28919558374038
#  self.quel_a,  57.09151229
#  self.quel_c,  57.09151229
#
# In quenching zone? False
#
#  initial guess for molecule 14 location: (86.59849173252961,100.58332952085371)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  86.59849173252961
#  ini_y,  100.58332952085371
#  self.quel_a,  57.09151229
#  self.quel_c,  57.09151229
#
# In quenching zone? False
#
#  initial guess for molecule 15 location: (95.57214287575735,144.5489583402365)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  95.57214287575735
#  ini_y,  144.5489583402365
#  self.quel_a,  57.09151229
#  self.quel_c,  57.09151229
#
# In quenching zone? False
#
#  initial guess for molecule 16 location: (79.12454092338291,0.01490141694806231)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  79.12454092338291
#  ini_y,  0.01490141694806231
#  self.quel_a,  57.09151229
#  self.quel_c,  57.09151229
#
# In quenching zone? False
#
#  initial guess for molecule 17 location: (90.09151164256987,25.668854318609743)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  90.09151164256987
#  ini_y,  25.668854318609743
#  self.quel_a,  57.09151229
#  self.quel_c,  57.09151229
#
# In quenching zone? False
#
#  initial guess for molecule 18 location: (118.28904928573886,67.0156315458737)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  118.28904928573886
#  ini_y,  67.0156315458737
#  self.quel_a,  57.09151229
#  self.quel_c,  57.09151229
#
# In quenching zone? False
#
#  initial guess for molecule 19 location: (133.43987549198155,111.73830236374552)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  133.43987549198155
#  ini_y,  111.73830236374552
#  self.quel_a,  57.09151229
#  self.quel_c,  57.09151229
#
# In quenching zone? False
#
#  initial guess for molecule 20 location: (128.95680634331717,141.8948740575906)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  128.95680634331717
#  ini_y,  141.8948740575906
#  self.quel_a,  57.09151229
#  self.quel_c,  57.09151229
#
# In quenching zone? False

# %% [markdown]
# Drude sim, no fit bounds

# %%
fig5 = bem.fig5(
    sim_inst_Drude, fit_inst_Drude, draw_quadrant=True,
    show_ax_labels=True)
# fig5.suptitle('Drude')

# %% [markdown]
# JC sim with fit bounds

# %%
fig5 = bem.fig5(sim_inst, fit_inst, draw_quadrant=True)

# %%
disk_sub_locations = locations - np.array([[0, 0, 15]])
disk_sub_locations
# Out:
# array([[  0.  ,   0.  , -15.  ],
#        [  0.  ,  31.25, -15.  ],
#        [  0.  ,  62.5 , -15.  ],
#        [  0.  ,  93.75, -15.  ],
#        [  0.  , 125.  , -15.  ],
#        [ 31.25,   0.  , -15.  ],
#        [ 31.25,  31.25, -15.  ],
#        [ 31.25,  62.5 , -15.  ],
#        [ 31.25,  93.75, -15.  ],
#        [ 31.25, 125.  , -15.  ],
#        [ 62.5 ,   0.  , -15.  ],
#        [ 62.5 ,  31.25, -15.  ],
#        [ 62.5 ,  62.5 , -15.  ],
#        [ 62.5 ,  93.75, -15.  ],
#        [ 62.5 , 125.  , -15.  ],
#        [ 93.75,   0.  , -15.  ],
#        [ 93.75,  31.25, -15.  ],
#        [ 93.75,  62.5 , -15.  ],
#        [ 93.75,  93.75, -15.  ],
#        [ 93.75, 125.  , -15.  ],
#        [125.  ,   0.  , -15.  ],
#        [125.  ,  31.25, -15.  ],
#        [125.  ,  62.5 , -15.  ],
#        [125.  ,  93.75, -15.  ],
#        [125.  , 125.  , -15.  ]])

# %%
# locations, angles = fit.fixed_ori_mol_placement(
#     mol_grid_pts_1D=5, x_max=125, y_max=125)
sim_inst_Drude_oof = bem.SimulatedExperiment(
    disk_sub_locations, 
    mol_angle=0,
    param_file='disk_Drude_noFitBounds',
    simulation_file_name='CurlyDiskDrude_NoSub_dipDrive_E')
sim_inst_Drude_oof.trial_images = sim_inst_Drude_oof.calculate_BEM_fields()

fit_inst_Drude_oof = fit.FitModelToData(
    sim_inst_Drude_oof.BEM_images, 
#     ini_guess=simTestInst_few_mol.mol_locations,
    ini_guess='gauss',
    param_file='disk_Drude_noFitBounds'
    )
the_fit = fit_inst_Drude_oof.fit_model_to_image_data(
    check_ini=True)
# Out:
# starting Matlab...
# given even number of points for Fibonacci lattice,
#   adding 1...
# 1th molecule
# calculating diffracted fields
# 2th molecule
# calculating diffracted fields
# 3th molecule
# calculating diffracted fields
# 4th molecule
# calculating diffracted fields
# 5th molecule
# calculating diffracted fields
# 6th molecule
# calculating diffracted fields
# 7th molecule
# calculating diffracted fields
# 8th molecule
# calculating diffracted fields
# 9th molecule
# calculating diffracted fields
# 10th molecule
# calculating diffracted fields
# 11th molecule
# calculating diffracted fields
# 12th molecule
# calculating diffracted fields
# 13th molecule
# calculating diffracted fields
# 14th molecule
# calculating diffracted fields
# 15th molecule
# calculating diffracted fields
# 16th molecule
# calculating diffracted fields
# 17th molecule
# calculating diffracted fields
# 18th molecule
# calculating diffracted fields
# 19th molecule
# calculating diffracted fields
# 20th molecule
# calculating diffracted fields
# 21th molecule
# calculating diffracted fields
#
#  initial guess for molecule 0 location: (0.024595453415261547,0.3825449314648522)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  0.024595453415261547
#  ini_y,  0.3825449314648522
#  self.quel_a,  57.09151229
#  self.quel_c,  57.09151229
#
# In quenching zone? True
# Params modified, OG params: (0.024595453415261547, 0.3825449314648522, array([1.27168559]))
# but now they are: (3.663094686497153, 56.97387570524737, array([1.27168559]))
#
#  initial guess for molecule 1 location: (0.017948892105072133,116.08167590063813)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  0.017948892105072133
#  ini_y,  116.08167590063813
#  self.quel_a,  57.09151229
#  self.quel_c,  57.09151229
#
# In quenching zone? False
#
#  initial guess for molecule 2 location: (0.021132888337793723,161.59196005814078)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  0.021132888337793723
#  ini_y,  161.59196005814078
#  self.quel_a,  57.09151229
#  self.quel_c,  57.09151229
#
# In quenching zone? False
#
#  initial guess for molecule 3 location: (2.6405483674297785,10.193164727660477)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  2.6405483674297785
#  ini_y,  10.193164727660477
#  self.quel_a,  57.09151229
#  self.quel_c,  57.09151229
#
# In quenching zone? True
# Params modified, OG params: (2.6405483674297785, 10.193164727660477, array([0.4699035]))
# but now they are: (14.317018074947063, 55.267203375970276, array([0.4699035]))
#
#  initial guess for molecule 4 location: (25.29108072092927,83.7843639596069)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  25.29108072092927
#  ini_y,  83.7843639596069
#  self.quel_a,  57.09151229
#  self.quel_c,  57.09151229
#
# In quenching zone? False
#
#  initial guess for molecule 5 location: (35.293880655640415,157.01957403918036)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  35.293880655640415
#  ini_y,  157.01957403918036
#  self.quel_a,  57.09151229
#  self.quel_c,  57.09151229
#
# In quenching zone? False
#
#  initial guess for molecule 6 location: (9.015335306737462,-0.0013094169724733452)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  9.015335306737462
#  ini_y,  -0.0013094169724733452
#  self.quel_a,  57.09151229
#  self.quel_c,  57.09151229
#
# In quenching zone? True
# Params modified, OG params: (9.015335306737462, -0.0013094169724733452, array([0.23175152]))
# but now they are: (57.09151168780976, -0.00829215906506141, array([0.23175152]))
#
#  initial guess for molecule 7 location: (9.05417030983246,5.184156504468696)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  9.05417030983246
#  ini_y,  5.184156504468696
#  self.quel_a,  57.09151229
#  self.quel_c,  57.09151229
#
# In quenching zone? True
# Params modified, OG params: (9.05417030983246, 5.184156504468696, array([0.46158836]))
# but now they are: (49.54491073188909, 28.36798540835006, array([0.46158836]))
#
#  initial guess for molecule 8 location: (16.33440795864659,19.0175785578113)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  16.33440795864659
#  ini_y,  19.0175785578113
#  self.quel_a,  57.09151229
#  self.quel_c,  57.09151229
#
# In quenching zone? True
# Params modified, OG params: (16.33440795864659, 19.0175785578113, array([0.54033481]))
# but now they are: (37.198789490528846, 43.30924654157056, array([0.54033481]))
#
#  initial guess for molecule 9 location: (47.76287993997643,79.29709356153991)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  47.76287993997643
#  ini_y,  79.29709356153991
#  self.quel_a,  57.09151229
#  self.quel_c,  57.09151229
#
# In quenching zone? False
#
#  initial guess for molecule 10 location: (67.35505233361111,149.85211314582466)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  67.35505233361111
#  ini_y,  149.85211314582466
#  self.quel_a,  57.09151229
#  self.quel_c,  57.09151229
#
# In quenching zone? False
#
#  initial guess for molecule 11 location: (24.38184504209821,-0.004686811710435618)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  24.38184504209821
#  ini_y,  -0.004686811710435618
#  self.quel_a,  57.09151229
#  self.quel_c,  57.09151229
#
# In quenching zone? True
# Params modified, OG params: (24.38184504209821, -0.004686811710435618, array([1.4461006]))
# but now they are: (57.091511235216274, -0.010974442785676275, array([1.4461006]))
#
#  initial guess for molecule 12 location: (29.257821638745224,10.801116288275091)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  29.257821638745224
#  ini_y,  10.801116288275091
#  self.quel_a,  57.09151229
#  self.quel_c,  57.09151229
#
# In quenching zone? True
# Params modified, OG params: (29.257821638745224, 10.801116288275091, array([0.6545475]))
# but now they are: (53.55840013278338, 19.772166061812495, array([0.6545475]))
#
#  initial guess for molecule 13 location: (50.01279408893711,37.21931442676515)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  50.01279408893711
#  ini_y,  37.21931442676515
#  self.quel_a,  57.09151229
#  self.quel_c,  57.09151229
#
# In quenching zone? False
#
#  initial guess for molecule 14 location: (88.35585795121817,98.41584887198806)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  88.35585795121817
#  ini_y,  98.41584887198806
#  self.quel_a,  57.09151229
#  self.quel_c,  57.09151229
#
# In quenching zone? False
#
#  initial guess for molecule 15 location: (99.03272839023694,145.70227149311572)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  99.03272839023694
#  ini_y,  145.70227149311572
#  self.quel_a,  57.09151229
#  self.quel_c,  57.09151229
#
# In quenching zone? False
#
#  initial guess for molecule 16 location: (79.08911196045614,0.010717461210729768)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  79.08911196045614
#  ini_y,  0.010717461210729768
#  self.quel_a,  57.09151229
#  self.quel_c,  57.09151229
#
# In quenching zone? False
#
#  initial guess for molecule 17 location: (88.73296963043148,24.587910224894326)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  88.73296963043148
#  ini_y,  24.587910224894326
#  self.quel_a,  57.09151229
#  self.quel_c,  57.09151229
#
# In quenching zone? False
#
#  initial guess for molecule 18 location: (114.84308305968372,63.52776687225028)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  114.84308305968372
#  ini_y,  63.52776687225028
#  self.quel_a,  57.09151229
#  self.quel_c,  57.09151229
#
# In quenching zone? False
#
#  initial guess for molecule 19 location: (133.68756087006756,110.00932773891695)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  133.68756087006756
#  ini_y,  110.00932773891695
#  self.quel_a,  57.09151229
#  self.quel_c,  57.09151229
#
# In quenching zone? False
#
#  initial guess for molecule 20 location: (131.18445494241436,142.51109554558454)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  131.18445494241436
#  ini_y,  142.51109554558454
#  self.quel_a,  57.09151229
#  self.quel_c,  57.09151229
#
# In quenching zone? False

# %%
axs, fig5 = bem.fig5(sim_inst_Drude_oof, fit_inst_Drude_oof, draw_quadrant=True)
# Out:
# Calculating Gaussian centroid with BEM_images

# %%
def connectpoints( cen_x, cen_y, mol_x, mol_y, p, ax=None, zorder=1, ls='k-'):
    x1, x2 = mol_x[p], cen_x[p]
    y1, y2 = mol_y[p], cen_y[p]
    if ax is None:
        plt.plot([x1,x2],[y1,y2], ls, linewidth=.3, zorder=zorder)
    else:
        ax.plot([x1,x2],[y1,y2], ls, linewidth=.3, zorder=zorder)

def scatter_prevCents_wLine(
    self,
    ax,
    x_mol_loc,
    y_mol_loc,
    est_locs,
    ):
    
    if est_locs == 'gauss':
        x_plot, y_plot = sim_inst_Drude.appar_cents

    elif est_locs == 'model':
        x_plot, y_plot = fit_inst_Drude.model_fit_results[:,:2].T
    
    for i in np.arange(x_plot.shape[0]):
        connectpoints(
            cen_x=x_plot,
            cen_y=y_plot,
            mol_x=x_mol_loc,
            mol_y=y_mol_loc,
            p=i,
            ax=ax,
            zorder=1,
            ls='k--'
            )
    localization_handle = ax.scatter(
        x_plot,
        y_plot,
        s=10,
        alpha=.5,
#         c=['C2'],
        zorder=2,
        facecolors='none', edgecolors='C4' 
        )
    return ax

# %%
axs, fig5_Drude_oof = bem.fig5(
    sim_inst_Drude_oof, 
    fit_inst_Drude_oof, 
    draw_quadrant=True, 
    show_ax_labels=True,
#     show_legend=True
    )

scatter_prevCents_wLine(
    fit_inst_Drude_oof,
    axs[1],
    sim_inst_Drude_oof.mol_locations[:,0],
    sim_inst_Drude_oof.mol_locations[:,1],
    est_locs='gauss'
    )

scatter_prevCents_wLine(
    fit_inst_Drude_oof,
    axs[2],
    sim_inst_Drude_oof.mol_locations[:,0],
    sim_inst_Drude_oof.mol_locations[:,1],
    est_locs='model'
    )

# loc_map_legend(axs[2], loc_label='fit localization')

# %% [markdown]
# ### Changing NA

# %%
# locations, angles = fit.fixed_ori_mol_placement(
#     mol_grid_pts_1D=5, x_max=125, y_max=125)
sim_inst_Drude_na = bem.SimulatedExperiment(
    locations, 
    mol_angle=0,
    param_file='disk_Drude_noFitBounds_NApt92',
    simulation_file_name='CurlyDiskDrude_NoSub_dipDrive_E')
sim_inst_Drude_na.trial_images = sim_inst_Drude_na.calculate_BEM_fields()

fit_inst_Drude_na = fit.FitModelToData(
    sim_inst_Drude_na.BEM_images, 
#     ini_guess=simTestInst_few_mol.mol_locations,
    ini_guess='gauss',
    param_file='disk_Drude_noFitBounds_NApt92'
    )
the_fit = fit_inst_Drude_na.fit_model_to_image_data(
    check_ini=True)

## Build plot
axs, fig5_Drude_na = bem.fig5(
    sim_inst_Drude_na, 
    fit_inst_Drude_na, 
    draw_quadrant=True, 
    show_ax_labels=True,
#     show_legend=True
    )

scatter_prevCents_wLine(
    fit_inst_Drude_na,
    axs[1],
    sim_inst_Drude_na.mol_locations[:,0],
    sim_inst_Drude_na.mol_locations[:,1],
    est_locs='gauss'
    )

scatter_prevCents_wLine(
    fit_inst_Drude_na,
    axs[2],
    sim_inst_Drude_na.mol_locations[:,0],
    sim_inst_Drude_na.mol_locations[:,1],
    est_locs='model'
    )

# loc_map_legend(axs[2], loc_label='fit localization')
# Out:
# starting Matlab...
# 1th molecule
# calculating diffracted fields
# 2th molecule
# calculating diffracted fields
# 3th molecule
# calculating diffracted fields
# 4th molecule
# calculating diffracted fields
# 5th molecule
# calculating diffracted fields
# 6th molecule
# calculating diffracted fields
# 7th molecule
# calculating diffracted fields
# 8th molecule
# calculating diffracted fields
# 9th molecule
# calculating diffracted fields
# 10th molecule
# calculating diffracted fields
# 11th molecule
# calculating diffracted fields
# 12th molecule
# calculating diffracted fields
# 13th molecule
# calculating diffracted fields
# 14th molecule
# calculating diffracted fields
# 15th molecule
# calculating diffracted fields
# 16th molecule
# calculating diffracted fields
# 17th molecule
# calculating diffracted fields
# 18th molecule
# calculating diffracted fields
# 19th molecule
# calculating diffracted fields
# 20th molecule
# calculating diffracted fields
# 21th molecule
# calculating diffracted fields
#
#  initial guess for molecule 0 location: (0.036869357325694053,3.1927183470160174)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  0.036869357325694053
#  ini_y,  3.1927183470160174
#  self.quel_a,  57.09151229
#  self.quel_c,  57.09151229
#
# In quenching zone? True
# Params modified, OG params: (0.036869357325694053, 3.1927183470160174, array([1.10283307]))
# but now they are: (0.6592460720482941, 57.08770594598902, array([1.10283307]))
#
#  initial guess for molecule 1 location: (0.02179944727975789,104.79623208265849)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  0.02179944727975789
#  ini_y,  104.79623208265849
#  self.quel_a,  57.09151229
#  self.quel_c,  57.09151229
#
# In quenching zone? False
#
#  initial guess for molecule 2 location: (0.032780723369552754,155.4184531821546)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  0.032780723369552754
#  ini_y,  155.4184531821546
#  self.quel_a,  57.09151229
#  self.quel_c,  57.09151229
#
# In quenching zone? False
#
#  initial guess for molecule 3 location: (1.6636448214028685,7.3495153884047815)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  1.6636448214028685
#  ini_y,  7.3495153884047815
#  self.quel_a,  57.09151229
#  self.quel_c,  57.09151229
#
# In quenching zone? True
# Params modified, OG params: (1.6636448214028685, 7.3495153884047815, array([0.95052601]))
# but now they are: (12.604413625435525, 55.682757948202934, array([0.95052601]))
#
#  initial guess for molecule 4 location: (18.345441470570954,80.4237177083156)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  18.345441470570954
#  ini_y,  80.4237177083156
#  self.quel_a,  57.09151229
#  self.quel_c,  57.09151229
#
# In quenching zone? False
#
#  initial guess for molecule 5 location: (31.662400402651915,151.6814385591441)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  31.662400402651915
#  ini_y,  151.6814385591441
#  self.quel_a,  57.09151229
#  self.quel_c,  57.09151229
#
# In quenching zone? False
#
#  initial guess for molecule 6 location: (3.9744060331945517,-0.0031883409058034717)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  3.9744060331945517
#  ini_y,  -0.0031883409058034717
#  self.quel_a,  57.09151229
#  self.quel_c,  57.09151229
#
# In quenching zone? True
# Params modified, OG params: (3.9744060331945517, -0.0031883409058034717, array([0.53293035]))
# but now they are: (57.091493919271564, -0.04579983623111485, array([0.53293035]))
#
#  initial guess for molecule 7 location: (4.9795948210064465,2.9446395347168104)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  4.9795948210064465
#  ini_y,  2.9446395347168104
#  self.quel_a,  57.09151229
#  self.quel_c,  57.09151229
#
# In quenching zone? True
# Params modified, OG params: (4.9795948210064465, 2.9446395347168104, array([1.36868504]))
# but now they are: (49.14229472780707, 29.059863118131954, array([1.36868504]))
#
#  initial guess for molecule 8 location: (12.495610792503518,15.84010175482743)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  12.495610792503518
#  ini_y,  15.84010175482743
#  self.quel_a,  57.09151229
#  self.quel_c,  57.09151229
#
# In quenching zone? True
# Params modified, OG params: (12.495610792503518, 15.84010175482743, array([0.97144319]))
# but now they are: (35.35946053106256, 44.82353540843749, array([0.97144319]))
#
#  initial guess for molecule 9 location: (43.32059948084462,79.86170206533822)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  43.32059948084462
#  ini_y,  79.86170206533822
#  self.quel_a,  57.09151229
#  self.quel_c,  57.09151229
#
# In quenching zone? False
#
#  initial guess for molecule 10 location: (63.67285370214883,146.95468751061628)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  63.67285370214883
#  ini_y,  146.95468751061628
#  self.quel_a,  57.09151229
#  self.quel_c,  57.09151229
#
# In quenching zone? False
#
#  initial guess for molecule 11 location: (18.757063575698652,-0.006831795657382502)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  18.757063575698652
#  ini_y,  -0.006831795657382502
#  self.quel_a,  57.09151229
#  self.quel_c,  57.09151229
#
# In quenching zone? True
# Params modified, OG params: (18.757063575698652, -0.006831795657382502, array([1.32498463]))
# but now they are: (57.09150850312, -0.020794167396819822, array([1.32498463]))
#
#  initial guess for molecule 12 location: (23.91196581751021,9.320305940709293)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  23.91196581751021
#  ini_y,  9.320305940709293
#  self.quel_a,  57.09151229
#  self.quel_c,  57.09151229
#
# In quenching zone? True
# Params modified, OG params: (23.91196581751021, 9.320305940709293, array([0.99080291]))
# but now they are: (53.19360332323149, 20.73358003456992, array([0.99080291]))
#
#  initial guess for molecule 13 location: (46.33304654169809,36.524182121145266)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  46.33304654169809
#  ini_y,  36.524182121145266
#  self.quel_a,  57.09151229
#  self.quel_c,  57.09151229
#
# In quenching zone? False
#
#  initial guess for molecule 14 location: (86.95812645680058,100.24537599506888)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  86.95812645680058
#  ini_y,  100.24537599506888
#  self.quel_a,  57.09151229
#  self.quel_c,  57.09151229
#
# In quenching zone? False
#
#  initial guess for molecule 15 location: (97.52801438911037,145.01314304317887)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  97.52801438911037
#  ini_y,  145.01314304317887
#  self.quel_a,  57.09151229
#  self.quel_c,  57.09151229
#
# In quenching zone? False
#
#  initial guess for molecule 16 location: (78.13841071522637,0.012119456926119352)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  78.13841071522637
#  ini_y,  0.012119456926119352
#  self.quel_a,  57.09151229
#  self.quel_c,  57.09151229
#
# In quenching zone? False
#
#  initial guess for molecule 17 location: (89.43101485913563,25.460986336352235)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  89.43101485913563
#  ini_y,  25.460986336352235
#  self.quel_a,  57.09151229
#  self.quel_c,  57.09151229
#
# In quenching zone? False
#
#  initial guess for molecule 18 location: (118.30486350184034,66.44253615546278)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  118.30486350184034
#  ini_y,  66.44253615546278
#  self.quel_a,  57.09151229
#  self.quel_c,  57.09151229
#
# In quenching zone? False
#
#  initial guess for molecule 19 location: (135.28693289587005,111.52624197964323)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  135.28693289587005
#  ini_y,  111.52624197964323
#  self.quel_a,  57.09151229
#  self.quel_c,  57.09151229
#
# In quenching zone? False
#
#  initial guess for molecule 20 location: (131.64411250835226,142.5723205281196)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  131.64411250835226
#  ini_y,  142.5723205281196
#  self.quel_a,  57.09151229
#  self.quel_c,  57.09151229
#
# In quenching zone? False
# Calculating Gaussian centroid with BEM_images

# %%
# locations, angles = fit.fixed_ori_mol_placement(
#     mol_grid_pts_1D=5, x_max=125, y_max=125)
sim_inst_Drude_naoof = bem.SimulatedExperiment(
    disk_sub_locations, 
    mol_angle=0,
    param_file='disk_Drude_noFitBounds_NApt92',
    simulation_file_name='CurlyDiskDrude_NoSub_dipDrive_E')
sim_inst_Drude_naoof.trial_images = sim_inst_Drude_naoof.calculate_BEM_fields()

fit_inst_Drude_naoof = fit.FitModelToData(
    sim_inst_Drude_naoof.BEM_images, 
#     ini_guess=simTestInst_few_mol.mol_locations,
    ini_guess='gauss',
    param_file='disk_Drude_noFitBounds_NApt92'
    )
the_fit = fit_inst_Drude_naoof.fit_model_to_image_data(
    check_ini=True)

## Build plot
axs, fig5_Drude_naoof = bem.fig5(
    sim_inst_Drude_naoof, 
    fit_inst_Drude_naoof, 
    draw_quadrant=True, 
    show_ax_labels=True,
#     show_legend=True
    )

scatter_prevCents_wLine(
    fit_inst_Drude_naoof,
    axs[1],
    sim_inst_Drude_naoof.mol_locations[:,0],
    sim_inst_Drude_naoof.mol_locations[:,1],
    est_locs='gauss'
    )

scatter_prevCents_wLine(
    fit_inst_Drude_naoof,
    axs[2],
    sim_inst_Drude_naoof.mol_locations[:,0],
    sim_inst_Drude_naoof.mol_locations[:,1],
    est_locs='model'
    )

# loc_map_legend(axs[2], loc_label='fit localization')
# Out:
# starting Matlab...
# 1th molecule
# calculating diffracted fields
# 2th molecule
# calculating diffracted fields
# 3th molecule
# calculating diffracted fields
# 4th molecule
# calculating diffracted fields
# 5th molecule
# calculating diffracted fields
# 6th molecule
# calculating diffracted fields
# 7th molecule
# calculating diffracted fields
# 8th molecule
# calculating diffracted fields
# 9th molecule
# calculating diffracted fields
# 10th molecule
# calculating diffracted fields
# 11th molecule
# calculating diffracted fields
# 12th molecule
# calculating diffracted fields
# 13th molecule
# calculating diffracted fields
# 14th molecule
# calculating diffracted fields
# 15th molecule
# calculating diffracted fields
# 16th molecule
# calculating diffracted fields
# 17th molecule
# calculating diffracted fields
# 18th molecule
# calculating diffracted fields
# 19th molecule
# calculating diffracted fields
# 20th molecule
# calculating diffracted fields
# 21th molecule
# calculating diffracted fields
#
#  initial guess for molecule 0 location: (0.02382060619791257,-1.3886852849857056)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  0.02382060619791257
#  ini_y,  -1.3886852849857056
#  self.quel_a,  57.09151229
#  self.quel_c,  57.09151229
#
# In quenching zone? True
# Params modified, OG params: (0.02382060619791257, -1.3886852849857056, array([0.68116904]))
# but now they are: (0.9791667093923286, -57.08311491250665, array([0.68116904]))
#
#  initial guess for molecule 1 location: (0.023828581457943535,131.07829902315007)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  0.023828581457943535
#  ini_y,  131.07829902315007
#  self.quel_a,  57.09151229
#  self.quel_c,  57.09151229
#
# In quenching zone? False
#
#  initial guess for molecule 2 location: (0.026207555013366017,167.48323484666074)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  0.026207555013366017
#  ini_y,  167.48323484666074
#  self.quel_a,  57.09151229
#  self.quel_c,  57.09151229
#
# In quenching zone? False
#
#  initial guess for molecule 3 location: (2.6169670132349143,10.966136144070399)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  2.6169670132349143
#  ini_y,  10.966136144070399
#  self.quel_a,  57.09151229
#  self.quel_c,  57.09151229
#
# In quenching zone? True
# Params modified, OG params: (2.6169670132349143, 10.966136144070399, array([0.38201678]))
# but now they are: (13.252232964528053, 55.532144718289935, array([0.38201678]))
#
#  initial guess for molecule 4 location: (24.12973034480634,89.17828040885341)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  24.12973034480634
#  ini_y,  89.17828040885341
#  self.quel_a,  57.09151229
#  self.quel_c,  57.09151229
#
# In quenching zone? False
#
#  initial guess for molecule 5 location: (36.5576388774149,161.03292864853253)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  36.5576388774149
#  ini_y,  161.03292864853253
#  self.quel_a,  57.09151229
#  self.quel_c,  57.09151229
#
# In quenching zone? False
#
#  initial guess for molecule 6 location: (10.030292335024448,-0.0008422820546680466)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  10.030292335024448
#  ini_y,  -0.0008422820546680466
#  self.quel_a,  57.09151229
#  self.quel_c,  57.09151229
#
# In quenching zone? True
# Params modified, OG params: (10.030292335024448, -0.0008422820546680466, array([0.55089062]))
# but now they are: (57.09151208870663, -0.00479419288090147, array([0.55089062]))
#
#  initial guess for molecule 7 location: (9.83209393273534,5.678187512318674)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  9.83209393273534
#  ini_y,  5.678187512318674
#  self.quel_a,  57.09151229
#  self.quel_c,  57.09151229
#
# In quenching zone? True
# Params modified, OG params: (9.83209393273534, 5.678187512318674, array([1.52827775]))
# but now they are: (49.43916048657025, 28.551885856145677, array([1.52827775]))
#
#  initial guess for molecule 8 location: (16.78510973099607,19.737799678632776)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  16.78510973099607
#  ini_y,  19.737799678632776
#  self.quel_a,  57.09151229
#  self.quel_c,  57.09151229
#
# In quenching zone? True
# Params modified, OG params: (16.78510973099607, 19.737799678632776, array([0.74819092]))
# but now they are: (36.985434947041064, 43.491589731089555, array([0.74819092]))
#
#  initial guess for molecule 9 location: (47.921974485743725,81.6567395116183)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  47.921974485743725
#  ini_y,  81.6567395116183
#  self.quel_a,  57.09151229
#  self.quel_c,  57.09151229
#
# In quenching zone? False
#
#  initial guess for molecule 10 location: (69.11607411288074,151.44142715940055)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  69.11607411288074
#  ini_y,  151.44142715940055
#  self.quel_a,  57.09151229
#  self.quel_c,  57.09151229
#
# In quenching zone? False
#
#  initial guess for molecule 11 location: (25.178862951648572,-0.0035597425474665125)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  25.178862951648572
#  ini_y,  -0.0035597425474665125
#  self.quel_a,  57.09151229
#  self.quel_c,  57.09151229
#
# In quenching zone? True
# Params modified, OG params: (25.178862951648572, -0.0035597425474665125, array([0.4365059]))
# but now they are: (57.0915117194332, -0.008071495673061842, array([0.4365059]))
#
#  initial guess for molecule 12 location: (29.924996489631706,11.070864328052238)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  29.924996489631706
#  ini_y,  11.070864328052238
#  self.quel_a,  57.09151229
#  self.quel_c,  57.09151229
#
# In quenching zone? True
# Params modified, OG params: (29.924996489631706, 11.070864328052238, array([0.46899777]))
# but now they are: (53.54475702268362, 19.809083041397805, array([0.46899777]))
#
#  initial guess for molecule 13 location: (50.08505551372734,37.45265140265281)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  50.08505551372734
#  ini_y,  37.45265140265281
#  self.quel_a,  57.09151229
#  self.quel_c,  57.09151229
#
# In quenching zone? False
#
#  initial guess for molecule 14 location: (88.1428861079099,97.45104211890683)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  88.1428861079099
#  ini_y,  97.45104211890683
#  self.quel_a,  57.09151229
#  self.quel_c,  57.09151229
#
# In quenching zone? False
#
#  initial guess for molecule 15 location: (101.56758693842836,146.68223105557288)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  101.56758693842836
#  ini_y,  146.68223105557288
#  self.quel_a,  57.09151229
#  self.quel_c,  57.09151229
#
# In quenching zone? False
#
#  initial guess for molecule 16 location: (78.0722314589196,0.01121076460140109)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  78.0722314589196
#  ini_y,  0.01121076460140109
#  self.quel_a,  57.09151229
#  self.quel_c,  57.09151229
#
# In quenching zone? False
#
#  initial guess for molecule 17 location: (87.53713569917794,24.187114238720717)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  87.53713569917794
#  ini_y,  24.187114238720717
#  self.quel_a,  57.09151229
#  self.quel_c,  57.09151229
#
# In quenching zone? False
#
#  initial guess for molecule 18 location: (113.54101966445606,62.24510300766762)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  113.54101966445606
#  ini_y,  62.24510300766762
#  self.quel_a,  57.09151229
#  self.quel_c,  57.09151229
#
# In quenching zone? False
#
#  initial guess for molecule 19 location: (134.6192209351658,108.97120872657929)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  134.6192209351658
#  ini_y,  108.97120872657929
#  self.quel_a,  57.09151229
#  self.quel_c,  57.09151229
#
# In quenching zone? False
#
#  initial guess for molecule 20 location: (134.4444510920095,143.47570360659896)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  134.4444510920095
#  ini_y,  143.47570360659896
#  self.quel_a,  57.09151229
#  self.quel_c,  57.09151229
#
# In quenching zone? False
# Calculating Gaussian centroid with BEM_images
