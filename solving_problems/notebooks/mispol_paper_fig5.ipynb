# %% [markdown]
# Copied from ``BEM_fit_nanrod_in_vacuum__012419-Copy1`` on 02/07/29

# %% [markdown]
# ## 02/21/19
# Going to remove parameter dependence of module `fitting_misLocalization.py` in order to have one notebook for drude and one for JC far-field fit results

# %%
from __future__ import print_function
from __future__ import division

import pdb
import sys
import os
import yaml

import numpy as np
import scipy.optimize as opt
from scipy import interpolate
import scipy.io as sio
import scipy.special as spf

## import diffrantion integral solver from Optics folder
project_path = ('/Users/chair/Documents/Academia/SuperRes/Biteen_colab/'
    +
    'Mispolarization/python/gitted'
    )
optics_path = project_path + '/Optics'
sys.path.append(optics_path)
# sys.path.append(date_dir)
import diffraction_int as diffi
import fibonacci as fib

## Read parameter file to obtain physical properties 
## of molecule and plasmon, molecule and imaging system.
parameter_files_path = (
    project_path + '/parameter_files'
)

curly_yaml_file_name = '/curly_nrod_water_JC.yaml'
parameters = yaml.load(open(parameter_files_path+curly_yaml_file_name,'r'))


modules_path = project_path + '/solving_problems/modules'
sys.path.append(modules_path)

import fitting_misLocalization as fit

## plotting stuff
import matplotlib.pyplot as plt
import matplotlib as mpl
get_ipython().magic('matplotlib inline')
# mpl.rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']})
## for Palatino and other serif fonts use:
#rc('font',**{'family':'serif','serif':['Palatino']})
mpl.rcParams['text.usetex'] = True

## colorbar stuff 
from mpl_toolkits import axes_grid1

## Import analytic expressions for the focused fields from a point dipole.
import anal_foc_diff_fields as afi

## Import computational solution to two coupled oscillators of arbitrarty 
## anisotropic polarizabilities. 
# import coupled_dipoles as cp 

## Import physical constants from yaml file.
phys_const_file_name = '/physical_constants.yaml'
opened_constant_file = open(
    parameter_files_path+phys_const_file_name,
    'r')
constants = yaml.load(opened_constant_file)
e = constants['physical_constants']['e']
c = constants['physical_constants']['c']  # charge of electron in statcoloumbs
hbar =constants['physical_constants']['hbar']
nm = constants['physical_constants']['nm']
n_a = constants['physical_constants']['nA']   # Avogadro's number
# Z_o = 376.7303 # impedence of free space in ohms (SI)

## Define some useful constants from defined parameters
n_b = parameters['general']['background_ref_index']
eps_b = n_b**2.
# a = parameters['plasmon']['radius']



#######################################################################
## Optics stuff.  
sensor_size = parameters['optics']['sensor_size']*nm
# height = 2*mm  # also defines objective lens focal length 
# height = parameters['optics']['obj_f_len']
resolution = parameters['optics']['sensor_pts']  # image grid resolution
## Build image sensor
eye = diffi.observation_points(
    x_min= -sensor_size/2, 
    x_max= sensor_size/2,
    y_min= -sensor_size/2, 
    y_max= sensor_size/2, 
    points= resolution
    )

## Experimental parameters
magnification = parameters['optics']['magnification']
numerical_aperture = parameters['optics']['numerical_aperture']
max_theta = np.arcsin(numerical_aperture) # defines physical aperture size

## numerical parameters for calculation of scattered field
lens_points = parameters['optics']['lens_points']

# obj_f = 1.*mm  # still dont know what this is supposed to be
obj_f = parameters['optics']['obj_f_len']

tube_f = magnification * obj_f

## calculate dipole magnitudes
drive_hbar_omega = parameters['general']['drive_energy'] ## rod long mode max at 1.8578957289256757 eV
omega_drive = drive_hbar_omega/hbar  # driving frequency
# Out:
# reading parameters from /Users/chair/Documents/Academia/SuperRes/Biteen_colab/Mispolarization/python/gitted/parameter_files/curly_nrod_water_JC.yaml
# reading parameters from /Users/chair/Documents/Academia/SuperRes/Biteen_colab/Mispolarization/python/gitted/parameter_files/curly_nrod_water_JC.yaml

# %% [markdown]
# ##### setup warning tracker

# %%
import traceback
import warnings
import sys

def warn_with_traceback(message, category, filename, lineno, file=None, line=None):

    log = file if hasattr(file,'write') else sys.stderr
    traceback.print_stack(file=log)
    log.write(warnings.formatwarning(message, category, filename, lineno, line))

warnings.showwarning = warn_with_traceback

# %% [markdown]
# # initialize matlab stuff

# %%
## import matlab engine to run BEM
import matlab
import matlab.engine

variable_dict = {'list_of_coodinates':eye[0]/nm, 'meshed_X':eye[1]/nm,'meshed_Y':eye[2]/nm}

# %%
def fixed_ori_mol_placement(x_min=0, x_max=500, y_min=0, y_max=500, mol_grid_pts_1D = 3, mol_angle=0):
    locations = diffi.observation_points(x_min, x_max, y_min, y_max, points=mol_grid_pts_1D)[0]
    locations = np.hstack((locations,np.zeros((locations.shape[0],1))))
    
    mol_linspace_pts = mol_grid_pts_1D
#     random_mol_angles= (np.random.random(mol_linspace_pts**2)*np.pi*2)
    return [locations, mol_angle]

# %%
class Simulation(fit.DipoleProperties):
    """Runs BEM simulation
    
    Collects focused+diffracted far-field information from molecules nearby a nanorod 
    by MNPBEM calculation in an invisible instance of Matlab.
    
    Args:
        locations: list of 3D cartesien coordinates of molecules. 
            One simulation is run per location.  
        mol_angle: Angle on the molecule's dipole moment relatice to the x-axis
        plas_angle: Angle of the long-axis of the nanorod relative to the x-axis
    
    Attributes:
        mol_too_close: named confusingly, this method is built to filter locations
            for points within the fluorescence quenching region around the nanorod, 
            assigned to be 10 nm from the surface of the fit ellipsoid.
            Returns: VALID locations OUTSIDE this region.
        calculate_BEM_fields: runs simulatins and stores results in attributes; 
            bem_E: Focused and diffracted electric field
            BEM_images: 
    
    """
    
    ## set up inverse mapping from observed -> true angle for signle molecule in the plane. 
        
    def __init__(self, locations, mol_angle=0, plas_angle=np.pi/2
                 ):
        self.n_b = n_b ## vacuum
        self.mol_locations = locations
        self.mol_angles = mol_angle
        self.rod_angle = plas_angle
        
        #### Filtering out molecules in region of fluorescence quenching 
        self.el_a = self.a_long_meters/nm
        self.el_c = self.a_short_meters/nm
        self.quel_a = self.el_a + self.fluo_quench_range ## define quenching region
        self.quel_c = self.el_c + self.fluo_quench_range

        self.input_x_mol = locations[:,0]
        self.input_y_mol = locations[:,1]
        
        self.pt_is_in_ellip = self.mol_too_close()
        ## select molecules outside region,
        self.mol_locations = locations[self.pt_is_in_ellip]
        ## select molecule angles if listed per molecule, 
        if type(mol_angle)==np.ndarray and mol_angle.shape[0]>1:
            self.mol_angles = mol_angle[self.pt_is_in_ellip]
        else: self.mol_angles = mol_angle

        self.default_plot_limits = [
            np.min(self.mol_locations)-((np.max(self.mol_locations)-np.min(self.mol_locations))*.1),
            np.max(self.mol_locations)+((np.max(self.mol_locations)-np.min(self.mol_locations))*.1)]
        
        
    def mol_too_close(self):
        '''Returns molecule locations that are outside the fluorescence quenching zone,
            defined as 10 nm from surface of fit spheroid'''
        rotated_x = np.cos(self.rod_angle)*self.input_x_mol + np.sin(self.rod_angle)*self.input_y_mol
        rotated_y = -np.sin(self.rod_angle)*self.input_x_mol + np.cos(self.rod_angle)*self.input_y_mol
        long_quench_radius = self.quel_a
        short_quench_radius = self.quel_c
        rotated_ellip_eq = rotated_x**2./long_quench_radius**2 + rotated_y**2./short_quench_radius**2
        return (rotated_ellip_eq > 1)
        
    def calculate_BEM_fields(self):
        """ Runs BEM simulation in Matlab using parameters initialized parameters 
            """
        if hasattr(self, 'BEM_images'):
            return self.BEM_images
        
        ## start matlab before looping
        print('starting Matlab...')
        eng = matlab.engine.start_matlab()

        # Initialize coordinates of points on hemisphere for field BEM field 
        # calculation.
        sphere_points = fib.fib_alg_k_filter(
            num_points=lens_points, 
            max_ang=max_theta
            )
        # Convert spherical coordinates to Caresian.
        cart_points_on_sph = fib.sphere_to_cart(
            sphere_points[:,0],
            sphere_points[:,1],
            obj_f*np.ones(np.shape(sphere_points[:,0]))
            )
        
        ## convert lens-integration coordinates to matlab variable
        matlab_cart_points_on_sph = matlab.double(cart_points_on_sph.tolist())
        
        # Setup values for field calculation        
        drive_energy = drive_hbar_omega
        number_of_molecules = self.mol_locations.shape[0]
        
        # Initialize outputs.
        self.BEM_images = np.zeros((number_of_molecules, eye[0].shape[0]))
        self.bem_E = np.zeros(
            (number_of_molecules, eye[0].shape[0], 3),
            dtype=np.complex_
            )
        
        # Loop through molecules and run BEM calculation in MATLAB
        for i in range(number_of_molecules):
            print('{}th molecule'.format(int(i+1)))
            mol_location = self.mol_locations[i]
            if np.atleast_1d(self.mol_angles).shape[0] == self.mol_locations.shape[0]:
                mol_angle = self.mol_angles[i]
            elif np.atleast_1d(self.mol_angles).shape[0] == 1:
                mol_angle = self.mol_angles
            mol_orientation = [
                np.cos(mol_angle), 
                np.sin(mol_angle), 
                0.,
            ]

            # Run BEM calculation, return fields and coords.
            [E, sph_p] = eng.BEM_CurlyNanRod_dipDrive_E(
                matlab.double(list(mol_location)), 
                drive_energy, 
                matlab.double(list(mol_orientation)), 
                matlab_cart_points_on_sph,
                float(self.n_b**2.),
                nargout=2)
            
            # Format outputs for np
            BEM_scattered_E = np.asarray(E)
                # print('BEM_scattered_E.shape = ',BEM_scattered_E.shape)
                # BEM_scattered_H = np.asarray(H)
                # print('BEM_scattered_H.shape = ',BEM_scattered_H.shape)
            cart_sphere_points = np.asarray(sph_p)

            sph_sph_points = fib.cart_to_sphere(
                cart_sphere_points[:,0],
                cart_sphere_points[:,1],
                cart_sphere_points[:,2]
                ).T

            thetas_and_phis = sph_sph_points[:,1:]

            # Calculate focused+diffracted fields
            print('calculating diffracted fields')            
            diffracted_E_field = diffi.perform_integral(
                scattered_E=BEM_scattered_E, 
                scattered_sph_coords=thetas_and_phis, 
                obser_pts=eye[0]*np.array([[1,-1]]), 
                z=0, 
                obj_f=obj_f, 
                tube_f=tube_f, 
                k=omega_drive*self.n_b/c,
                alpha_1_max=max_theta
                )

            diffracted_power_flux = np.real(
                np.sum(
                    np.multiply(diffracted_E_field,
                        np.conj(diffracted_E_field)
                        ),
                    axis=-1
                    )
                )

            self.bem_E[i] = diffracted_E_field
            self.BEM_images[i] = diffracted_power_flux
        return self.BEM_images

# %% [markdown]
# ### Wrap Simulation class into an object with same attributes as MolCoupNanoRodExp, so that the Gaussian Localization can be calculated

# %%
class SimulatedExperiment(Simulation,fit.MolCoupNanoRodExp):        
    """ Give BEM simulation class instance same attributes as Model Exp class for easy plotting.
        """
    def __init__(self, locations, mol_angle=0, plas_angle=np.pi/2, 
                 obs_points=None,):
        
        fit.CoupledDipoles.__init__(self, obs_points)
        
        Simulation.__init__(self, locations, mol_angle, plas_angle)
        
    def plot_mispol_map_wMisloc(self, plot_limits=None, given_ax=None,):
        return fit.MolCoupNanoRodExp.plot_mispol_map_wMisloc(
            self,
            plot_limits=plot_limits,
            given_ax=given_ax,
            plot_ellipse=False,
            )

# %%
# locations, angles = fixed_ori_mol_placement(mol_grid_pts_1D=5, x_max=300, y_max=300)
# simTestInst_few_mol = SimulatedExperiment(locations, mol_angle=np.pi/2)
# simTestInst_few_mol.trial_images = simTestInst_few_mol.calculate_BEM_fields()

# %%
# simTestInst_few_mol.plot_mispol_map_wMisloc()

# %% [markdown]
# ### model fit

# %%
# ## Fit naively without knowing true location. 
# naive_fit_BEM_instance = fit.FitModelToData(
#     simTestInst_few_mol.BEM_images, 
# #     ini_guess=simTestInst_few_mol.mol_locations
#     )
# naive_fit_BEM_instance.fit_model_to_image_data()

# naive_fit_BEM_instance.plot_fit_results_as_quiver_map(simTestInst_few_mol)

# %%
# ## Fit smartly, knowing true location. 
# smart_fit_BEM_instance = fit.FitModelToData(
#     simTestInst_few_mol.BEM_images, 
#     ini_guess=simTestInst_few_mol.mol_locations
#     )
# smart_fit_BEM_instance.fit_model_to_image_data()

# %%
# smart_fit_BEM_instance.plot_fit_results_as_quiver_map(simTestInst_few_mol)

# %% [markdown]
# Great, seems to be working, let's do the x oriented molecules

# %%
# ## Run simulations and run Gaussian localization fits and average polarization

# # locations, angles = fixed_ori_mol_placement(mol_grid_pts_1D=5, x_max=300, y_max=300)
# sim_exp_inst_x = SimulatedExperiment(locations, mol_angle=0)
# sim_exp_inst_x.trial_images = sim_exp_inst_x.calculate_BEM_fields()

# ## Plot
# sim_exp_inst_x.plot_mispol_map_wMisloc()

# %%
# ## Fit model to simulated images. 

# naive_BEM_fit_instance_x = fit.FitModelToData(
#     sim_exp_inst_x.BEM_images, 
# #     ini_guess=sim_exp_inst_x.mol_locations
#     )
# naive_BEM_fit_instance_x.fit_model_to_image_data()

# ## Plot
# naive_BEM_fit_instance_x.plot_fit_results_as_quiver_map(sim_exp_inst_x)

# %%
# ## Fit model to simulated images. 

# smart_BEM_fit_instance_x = fit.FitModelToData(
#     sim_exp_inst_x.BEM_images, 
#     ini_guess=sim_exp_inst_x.mol_locations
#     )
# smart_BEM_fit_instance_x.fit_model_to_image_data()

# ## Plot
# smart_BEM_fit_instance_x.plot_fit_results_as_quiver_map(sim_exp_inst_x)

# %% [markdown]
# ### Next up are the closer locations... testing instance save

# %%
locations, angles = fixed_ori_mol_placement(mol_grid_pts_1D=2, x_max=75, y_max=75)
simTestInst_few_mol = SimulatedExperiment(locations, mol_angle=np.pi/2)
simTestInst_few_mol.trial_images = simTestInst_few_mol.calculate_BEM_fields()
# Plot
simTestInst_few_mol.plot_mispol_map_wMisloc()

## Initial guess defaults to position of maximum intensity. 
test_BEM_fit_instance_few_mol = fit.FitModelToData(
    simTestInst_few_mol.BEM_images, 
#     ini_guess=simTestInst_few_mol.mol_locations
    )
test_BEM_fit_few_mol = test_BEM_fit_instance_few_mol.fit_model_to_image_data()

## Plot fit results
test_BEM_fit_instance_few_mol.plot_fit_results_as_quiver_map(simTestInst_few_mol)
# Out:
# starting Matlab...
# given even number of points for Fibonacci lattice,
#   adding 1...
# 1th molecule
# calculating diffracted fields
# 2th molecule
# calculating diffracted fields
# 3th molecule
# calculating diffracted fields

# %% [markdown]
# ### Try to save neccesary data for next plot

# %%
def save_sim_exp_inst(sim_exp_instance, data_dir_name):
    path_to_data = (
        "/Users/chair/Documents/Academia/SuperRes/Biteen_colab/"
        +
        "Mispolarization/python/gitted/solving_problems/data/"
        +
        data_dir_name
        )
    os.mkdir( path_to_data )
#     print(path_to_data+'/BEM_images.txt')
    np.savetxt(path_to_data+'/BEM_images.txt',sim_exp_instance.BEM_images)
    np.savetxt(path_to_data+'/mol_locations.txt',sim_exp_instance.mol_locations)
    np.savetxt(path_to_data+'/default_plot_limits.txt',sim_exp_instance.default_plot_limits)
    np.savetxt(path_to_data+'/mol_angles.txt',np.atleast_1d(sim_exp_instance.mol_angles))
    np.savetxt(path_to_data+'/rod_angle.txt',np.atleast_1d(sim_exp_instance.rod_angle))
    np.savetxt(path_to_data+'/obs_points[0].txt',np.atleast_1d(sim_exp_instance.obs_points[0]))
    np.savetxt(path_to_data+'/obs_points[1].txt',np.atleast_1d(sim_exp_instance.obs_points[1]))
    np.savetxt(path_to_data+'/obs_points[2].txt',np.atleast_1d(sim_exp_instance.obs_points[2]))
    
    np.savetxt(path_to_data+'/mispol_angle.txt',np.atleast_1d(sim_exp_instance.mispol_angle))

# %%
save_sim_exp_inst(simTestInst_few_mol,'test_041619')

# %% [markdown]
# Build load class

# %%
class LoadedSimExp(SimulatedExperiment):
    
    def __init__(self, 
        data_dir_name
                ):
        
        fit.DipoleProperties.__init__(self,
#             isolate_mode=isolate_mode,
#             drive_energy_eV=drive_energy_eV,
            )
        
        self.path_to_data = (
            "/Users/chair/Documents/Academia/SuperRes/Biteen_colab/"
            +
            "Mispolarization/python/gitted/solving_problems/data/"
            +
            data_dir_name
            )


        self.BEM_images = np.loadtxt(self.path_to_data+'/BEM_images.txt')
        self.trial_images = np.loadtxt(self.path_to_data+'/BEM_images.txt')
        self.mol_locations = np.loadtxt(self.path_to_data+'/mol_locations.txt')
        self.default_plot_limits = np.loadtxt(self.path_to_data+'/default_plot_limits.txt')
        self.mol_angles = np.loadtxt(self.path_to_data+'/mol_angles.txt')
#         self.angles = self.mol_angles
        self.rod_angle = np.atleast_1d(np.loadtxt(self.path_to_data+'/rod_angle.txt'))[0]
        
        obs_points_0 = np.loadtxt(self.path_to_data+'/obs_points[0].txt')
        obs_points_1 = np.loadtxt(self.path_to_data+'/obs_points[1].txt')
        obs_points_2 = np.loadtxt(self.path_to_data+'/obs_points[2].txt')
        
        self.obs_points = np.array([obs_points_0, obs_points_1, obs_points_2])
        
        self.mispol_angle = np.loadtxt(self.path_to_data+'/mispol_angle.txt')

# %%
loaded_inst = LoadedSimExp('test_041619')

# %%
loaded_inst.rod_angle
# Out:
# 1.5707963267948966

# %%
loaded_inst.plot_mispol_map_wMisloc()

# %% [markdown]
# That works, now try running fits on the loaded instance

# %%
## Initial guess defaults to position of maximum intensity. 
test_BEM_fit_instance_few_mol = fit.FitModelToData(
    loaded_inst.BEM_images, 
#     ini_guess=simTestInst_few_mol.mol_locations
    )
test_BEM_fit_few_mol = test_BEM_fit_instance_few_mol.fit_model_to_image_data()
# Out:
#  initial guess for molecule 0 location: (-10.0,10.0)
#
#  initial guess for molecule 1 location: (71.0,10.0)
#
#  initial guess for molecule 2 location: (91.0,91.0)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-86d38f1b03bd> in <module>
#       7
#       8 ## Plot fit results
# ----> 9 test_BEM_fit_instance_few_mol.plot_fit_results_as_quiver_map(simTestInst_few_mol)
#
# NameError: name 'simTestInst_few_mol' is not defined

# %%
## Plot fit results
test_BEM_fit_instance_few_mol.plot_fit_results_as_quiver_map(loaded_inst)

# %% [markdown]
# YAY IT WORKS!
# On to saving the fit results instance for replotting

# %%
test_BEM_fit_instance_few_mol.model_fit_results.shape
# Out:
# (3, 3)

# %%
def save_fit_inst(fit_instance, exp_instance, data_dir_name):
    path_to_data = (
        "/Users/chair/Documents/Academia/SuperRes/Biteen_colab/"
        +
        "Mispolarization/python/gitted/solving_problems/data/"
        +
        data_dir_name
        )
    os.mkdir( path_to_data )

    np.savetxt(path_to_data+'/model_fit_results.txt',fit_instance.model_fit_results)
     
    # Directory for exp instance 
#     os.mkdir( path_to_data+'/exp_instance' )
    save_sim_exp_inst(exp_instance, data_dir_name+'/exp_instance')

# %%
class LoadedFit(fit.FitModelToData):
    
    def __init__(self, 
        data_dir_name
                ):
        
        fit.DipoleProperties.__init__(self,
#             isolate_mode=isolate_mode,
#             drive_energy_eV=drive_energy_eV,
            )
        
        self.path_to_data = (
            "/Users/chair/Documents/Academia/SuperRes/Biteen_colab/"
            +
            "Mispolarization/python/gitted/solving_problems/data/"
            +
            data_dir_name
            )


        self.model_fit_results = np.loadtxt(
            self.path_to_data+'/model_fit_results.txt'
            )
    
        self.loaded_sim_exp_instance = LoadedSimExp(
            data_dir_name+'/exp_instance'
            )
        
    def plot_fit_results_as_quiver_map(
        self,
        fitted_exp_instance=None,
        plot_limits=None,
        given_ax=None,
        draw_quadrant=True,
        ):
        
        if fitted_exp_instance is None:
            fitted_exp_instance = self.loaded_sim_exp_instance
            
        if type(plot_limits) == np.ndarray:
            plot_limits.to_list()

        return fit.FitModelToData.plot_fit_results_as_quiver_map(
            self,
            fitted_exp_instance=fitted_exp_instance,
            plot_limits=plot_limits,
            given_ax=given_ax,
            draw_quadrant=draw_quadrant,
            )

# %%
save_fit_inst(test_BEM_fit_instance_few_mol, loaded_inst, "test_fit_save")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-f48ca187cc09> in <module>
# ----> 1 save_fit_inst(test_BEM_fit_instance_few_mol, loaded_inst, "test_fit_save")
#
# NameError: name 'test_BEM_fit_instance_few_mol' is not defined

# %%
meta_loaded_fit = LoadedFit('test_fit_save')

# %%
meta_loaded_fit.plot_fit_results_as_quiver_map()
# Out:
# plot_limits =  [-7.5 82.5]

# %%
meta_loaded_fit.loaded_sim_exp_instance.default_plot_limits
# Out:
# array([-7.5, 82.5])

# %%
fig5(
    meta_loaded_fit.loaded_sim_exp_instance, meta_loaded_fit, 
    quiv_ax_limits=[-25,150,-25,150],
    quiv_tick_list=np.linspace(0,125,6),
    quiv_ticklabel_list=[r'$0$', r'$25$',r'$50$',r'$75$',r'$100$',r'$125$'],
    fig_size=(6.5, 2.9)
    )
# Out:
# plot_limits =  [-7.5 82.5]

# %% [markdown]
# ### Initial guess checker

# %%
# ## Initial guess defaults to position of maximum intensity. 
# test_BEM_fit_instance_few_mol = fit.FitModelToData(
#     loaded_inst.BEM_images, 
# #     ini_guess=loaded_inst.mol_locations
    
#     )

# # New initial guess checker
# test_BEM_fit_few_mol = test_BEM_fit_instance_few_mol.fit_model_to_image_data(
# #     check_ini=False
#     )

# ## Plot fit results
# # Uses plotlimits, 2 angles, and mol locations from simInst for plot. 
# test_BEM_fit_instance_few_mol.plot_fit_results_as_quiver_map(loaded_inst)

# %% [markdown]
# Testing paper plot

# %%
# cbar_width = 0.15
# plot_width = 4
# widths = [cbar_width, plot_width, plot_width, cbar_width]
# heights = [1]
# gs_kw = dict(width_ratios=widths, height_ratios=heights)

# paper_fig, paper_axs = plt.subplots(
#     nrows=1, 
#     ncols=4, 
# #     sharey=True, 
#     figsize=(6.5, 3), 
#     dpi=300, 
#     constrained_layout=True,
#     gridspec_kw=gs_kw
#     )

# left_ax = simTestInst_few_mol.plot_mispol_map_wMisloc(given_ax=paper_axs.flatten()[1]) 
# left_ax.yaxis.tick_right()
# left_ax.yaxis.set_label_position("right")
# left_ax.set_title(None)

# right_ax = test_BEM_fit_instance_few_mol.plot_fit_results_as_quiver_map(simTestInst_few_mol, given_ax=paper_axs.flatten()[2])  
# right_ax.set_ylabel(None)
# right_ax.yaxis.set_ticklabels([None])
# right_ax.set_title(None)

# test_BEM_fit_instance_few_mol.build_colorbar(
#     paper_axs.flatten()[3],
#     'Molecule angle from best model fit [deg]',
#     fit.PlottingStuff.curlycm
#     )

# test_BEM_fit_instance_few_mol.build_colorbar(
#     paper_axs.flatten()[0],
#     'PBD polarization angle [deg]',
#     fit.PlottingStuff.curlycm
#     )

# paper_axs.flatten()[0].yaxis.tick_left()
# paper_axs.flatten()[0].yaxis.set_label_position("left")

# %%
# ## Initial guess defaults to position of maximum intensity. 
# test_BEM_fit_instance_few_mol = fit.FitModelToData(
#     loaded_inst.BEM_images, 
# #     ini_guess=loaded_inst.mol_locations
#     )

# # New initial guess checker
# test_BEM_fit_few_mol = test_BEM_fit_instance_few_mol.fit_model_to_image_data(
#     check_ini=True
#     )

# ## Plot fit results
# # Uses plotlimits, 2 angles, and mol locations from simInst for plot. 
# test_BEM_fit_instance_few_mol.plot_fit_results_as_quiver_map(loaded_inst)

# %% [markdown]
# ### try with Gaussian initial guess

# %%
# ## Initial guess defaults to position of maximum intensity. 
# test_BEM_fit_instance_few_mol = fit.FitModelToData(
#     loaded_inst.BEM_images, 
# #     ini_guess=loaded_inst.mol_locations,
#     ini_guess='gauss',
#     )

# # New initial guess checker
# test_BEM_fit_few_mol = test_BEM_fit_instance_few_mol.fit_model_to_image_data(
#     check_ini=True,
#     )

# ## Plot fit results
# # Uses plotlimits, 2 angles, and mol locations from simInst for plot. 
# test_BEM_fit_instance_few_mol.plot_fit_results_as_quiver_map(loaded_inst)

# %%
# # Build composite plot comparing gaussian&PBS to model

# comp_fig, axes = plt.subplots(1,2, dpi=600)

# curly_mod_inst_transRes_xMol.plot_mispol_map(given_ax=axes[0])
# curly_mod_inst_transRes_xMol_isoTrans.plot_mispol_map(given_ax=axes[1])

# for i in range(2):
#     for j in range(3):
#         axes[i,j].yaxis.tick_right()
#         axes[i,j].yaxis.set_label_position("right")
#         axes[i,j].set(title=None)
#         if (i == 0) or (i == 1 and j != 2):            
#             axes[i,j].set(
#                 xticklabels=[None],yticklabels=[None],
#                 xlabel=None,ylabel=None
#                 )

# plt.tight_layout()

# %% [markdown]
# ## Figure 5 in mispol paper

# %%
locations_100, angles_100 = fixed_ori_mol_placement(mol_grid_pts_1D=5, x_max=125, y_max=125)
simTestInst_few_mol_h_100 = SimulatedExperiment(locations_100, mol_angle=0)
simTestInst_few_mol_h_100.trial_images = simTestInst_few_mol_h_100.calculate_BEM_fields()

simTestInst_few_mol_h_100.plot_mispol_map_wMisloc()
# Out:
# starting Matlab...
# given even number of points for Fibonacci lattice,
#   adding 1...
# 1th molecule
# calculating diffracted fields
# 2th molecule
# calculating diffracted fields
# 3th molecule
# calculating diffracted fields
# 4th molecule
# calculating diffracted fields
# 5th molecule
# calculating diffracted fields
# 6th molecule
# calculating diffracted fields
# 7th molecule
# calculating diffracted fields
# 8th molecule
# calculating diffracted fields
# 9th molecule
# calculating diffracted fields
# 10th molecule
# calculating diffracted fields
# 11th molecule
# calculating diffracted fields
# 12th molecule
# calculating diffracted fields
# 13th molecule
# calculating diffracted fields
# 14th molecule
# calculating diffracted fields
# 15th molecule
# calculating diffracted fields
# 16th molecule
# calculating diffracted fields
# 17th molecule
# calculating diffracted fields
# 18th molecule
# calculating diffracted fields
# 19th molecule
# calculating diffracted fields
# 20th molecule
# calculating diffracted fields
# 21th molecule
# calculating diffracted fields
# 22th molecule
# calculating diffracted fields
# 23th molecule
# calculating diffracted fields

# %%
# Model fit
# Gaussian guess, checked

test_BEM_fit_instance_few_mol_h_100 = fit.FitModelToData(
    simTestInst_few_mol_h_100.BEM_images, 
#     ini_guess=simTestInst_few_mol.mol_locations,
    ini_guess='gauss'
    )
test_BEM_fit_few_mol_h_100 = test_BEM_fit_instance_few_mol_h_100.fit_model_to_image_data(
    check_ini=True)

## Plot fit results
test_BEM_fit_instance_few_mol_h_100.plot_fit_results_as_quiver_map(simTestInst_few_mol_h_100)
# Out:
#  initial guess for molecule 0 location: (0.024364324852450908,71.69308926126834)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  0.024364324852450908
#  ini_y,  71.69308926126834
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 1 location: (0.010346667188950434,96.76896818489736)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  0.010346667188950434
#  ini_y,  96.76896818489736
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 2 location: (0.008965912824922692,127.15093337361)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  0.008965912824922692
#  ini_y,  127.15093337361
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 3 location: (51.11939425172493,0.03662429875275257)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  51.11939425172493
#  ini_y,  0.03662429875275257
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 4 location: (0.940067746163402,2.3344287586340116)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  0.940067746163402
#  ini_y,  2.3344287586340116
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? True
# Params modified, OG params: (0.940067746163402, 2.3344287586340116, array([0.51376816]))
# but now they are: (17.96156876204413, 44.60317124954296, array([0.51376816]))
#
#  initial guess for molecule 5 location: (2.511867239041471,11.102527607342758)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  2.511867239041471
#  ini_y,  11.102527607342758
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? True
# Params modified, OG params: (2.511867239041471, 11.102527607342758, array([1.11334516]))
# but now they are: (12.306379957527398, 54.39456397267087, array([1.11334516]))
#
#  initial guess for molecule 6 location: (23.031035266707587,76.26231537934441)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  23.031035266707587
#  ini_y,  76.26231537934441
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 7 location: (30.75071611725462,123.27772080373613)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  30.75071611725462
#  ini_y,  123.27772080373613
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 8 location: (53.03913677265991,-0.0396777295302285)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  53.03913677265991
#  ini_y,  -0.0396777295302285
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 9 location: (14.732985949664844,11.779752609948174)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  14.732985949664844
#  ini_y,  11.779752609948174
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? True
# Params modified, OG params: (14.732985949664844, 11.779752609948174, array([0.07350033]))
# but now they are: (24.608275544236925, 19.67553617840401, array([0.07350033]))
#
#  initial guess for molecule 10 location: (19.194153676489424,28.833980959336234)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  19.194153676489424
#  ini_y,  28.833980959336234
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? True
# Params modified, OG params: (19.194153676489424, 28.833980959336234, array([1.48134746]))
# but now they are: (21.95206467318275, 32.976990049838825, array([1.48134746]))
#
#  initial guess for molecule 11 location: (42.77335450954519,75.01223689422469)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  42.77335450954519
#  ini_y,  75.01223689422469
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 12 location: (56.6522078833954,119.69531218448542)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  56.6522078833954
#  ini_y,  119.69531218448542
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 13 location: (87.10830303347211,-0.028845131242589188)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  87.10830303347211
#  ini_y,  -0.028845131242589188
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 14 location: (71.55967174194242,26.80085306024156)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  71.55967174194242
#  ini_y,  26.80085306024156
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 15 location: (66.58959475187568,51.530113529357806)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  66.58959475187568
#  ini_y,  51.530113529357806
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 16 location: (76.66244608842133,84.65980402575755)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  76.66244608842133
#  ini_y,  84.65980402575755
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 17 location: (85.07787872895429,120.70304216547238)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  85.07787872895429
#  ini_y,  120.70304216547238
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 18 location: (120.86118616955352,-0.02132117900958149)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  120.86118616955352
#  ini_y,  -0.02132117900958149
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 19 location: (116.4721222229074,30.09105334194904)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  116.4721222229074
#  ini_y,  30.09105334194904
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 20 location: (112.33427815306429,59.42361522319196)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  112.33427815306429
#  ini_y,  59.42361522319196
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 21 location: (113.77252700592305,90.30599713804776)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  113.77252700592305
#  ini_y,  90.30599713804776
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 22 location: (116.8546255493349,122.92416902293027)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  116.8546255493349
#  ini_y,  122.92416902293027
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False

# %%
range(0,90,10)
# Out:
# range(0, 90, 10)

# %%
cbar_width = 0.15
plot_width = 4
widths = [cbar_width, plot_width, plot_width, cbar_width]
heights = [1]
gs_kw = dict(width_ratios=widths, height_ratios=heights)

paper_fig, paper_axs = plt.subplots(
    nrows=1, 
    ncols=4, 
#     sharey=True, 
    figsize=(6.5, 2.9), 
    dpi=300, 
    constrained_layout=True,
    gridspec_kw=gs_kw
    )

left_ax = simTestInst_few_mol_h_100.plot_mispol_map_wMisloc(given_ax=paper_axs.flatten()[1]) 
left_ax.yaxis.tick_right()
left_ax.yaxis.set_label_position("right")
# left_ax.set_title(None)

right_ax = test_BEM_fit_instance_few_mol_h_100.plot_fit_results_as_quiver_map(simTestInst_few_mol_h_100, given_ax=paper_axs.flatten()[2])  
# right_ax.set_title(None)

test_BEM_fit_instance_few_mol_h_100.build_colorbar(
    paper_axs.flatten()[0],
    r'PBD polarization angle [$\Delta^\circ$]',
    fit.PlottingStuff.curlycm
    )

test_BEM_fit_instance_few_mol_h_100.build_colorbar(
    paper_axs.flatten()[3],
    'Molecule angle by model fit [deg]',
    fit.PlottingStuff.curlycm
    )

paper_axs.flatten()[0].yaxis.tick_left()
paper_axs.flatten()[0].yaxis.set_label_position("left")

# Legends
def loc_map_legend(ax, loc_label='fit localization'):
    legend_elements = [
        mpl.lines.Line2D(
            [0], [0], 
            marker='o', 
            color='w', 
            label=loc_label,
            markerfacecolor=fit.PlottingStuff.a_shade_of_green, 
            markersize=10
            ),
        mpl.lines.Line2D(
            [0], [0], 
            marker='o', 
            color='w', 
            label='molecule location',
            markerfacecolor='black', 
            markersize=8
            ),
        ]

    ax.legend(
        handles=legend_elements, 
        loc='upper right',
        bbox_to_anchor=(1,1.11), 
#         ncol=2, mode="expand",
        fontsize=8,
        framealpha=1,
#         loc=1
        )

# loc_map_legend(paper_axs.flatten()[1])
loc_map_legend(paper_axs.flatten()[2], loc_label='fit localization')

# Title
paper_axs.flatten()[1].set_title(None)
paper_axs.flatten()[1].set_title('(a)', loc='left')
paper_axs.flatten()[2].set_title(None)
paper_axs.flatten()[2].set_title('(b)', loc='left')


    
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Quick and dirty fixes 
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

# rotate right colorbar label
paper_axs.flatten()[3].set_ylabel(None)
# paper_axs.flatten()[3].yaxis.set_label_position("right")
paper_axs.flatten()[3].set_ylabel(r'Model fit molecule polarization [$\Delta^\circ$]',rotation=270,va="bottom")

for cbar_ax in [paper_axs.flatten()[3],paper_axs.flatten()[0]]:
#     cbar_ax.yaxis.set_ticks(np.linspace(0,np.pi/2,10))
#     cbar_ax.yaxis.set_ticklabels(
#         [r'$0$', r'$10$',r'$20$',r'$30$',r'$40$',r'$50$',r'$60$',r'$70$',r'$80$',r'$90$',]
#         )
    cbar_ax.yaxis.set_ticks(np.linspace(0,np.pi/2,3))
    cbar_ax.yaxis.set_ticklabels(
        [r'$0$', r'$45$',r'$90$',]
        )

# Redo quiver ticks
for quiver_ax in [paper_axs.flatten()[i+1] for i in range(2)]:
    quiver_ax.tick_params(direction='in'),

#     quiver_ax.set_ylim([-10,165])
    # set axis equal
    quiver_ax.axis('equal')
    quiver_ax.axis([-25,150,-25,150,])
    
    quiver_ticks = np.linspace(0,125,5)
    for quiver_axis in [quiver_ax.yaxis, quiver_ax.xaxis]:
        quiver_axis.set_ticks(np.linspace(0,125,6))
        quiver_axis.set_ticklabels(
            [r'$0$', r'$25$',r'$50$',r'$75$',r'$100$',r'$125$']
            )       
    
    # fix labels
    quiver_ax.set_xlabel(r'$x$ position [nm]')
    quiver_ax.set_ylabel(r'$y$ position [nm]')
    
right_ax.set_ylabel(None)
right_ax.yaxis.set_ticklabels([None])
# Out:
# [Text(0, 0, '')]

# %% [markdown]
# #### Function to make compount figure

# %%
def fig5(
    sim_instance, fit_model_instance, 
    quiv_ax_limits=[-25,150,-25,150],
    quiv_tick_list=np.linspace(0,125,6),
    quiv_ticklabel_list=[r'$0$', r'$25$',r'$50$',r'$75$',r'$100$',r'$125$'],
    fig_size=(6.5, 2.9)
    ):
    
    cbar_width = 0.15
    plot_width = 4
    widths = [cbar_width, plot_width, plot_width, cbar_width]
    heights = [1]
    gs_kw = dict(width_ratios=widths, height_ratios=heights)

    paper_fig, paper_axs = plt.subplots(
        nrows=1, 
        ncols=4, 
    #     sharey=True, 
        figsize=fig_size, 
        dpi=300, 
        constrained_layout=True,
        gridspec_kw=gs_kw
        )

    left_ax = sim_instance.plot_mispol_map_wMisloc(given_ax=paper_axs.flatten()[1]) 
    left_ax.yaxis.tick_right()
    left_ax.yaxis.set_label_position("right")
    # left_ax.set_title(None)

    right_ax = fit_model_instance.plot_fit_results_as_quiver_map(sim_instance, given_ax=paper_axs.flatten()[2])  
    # right_ax.set_title(None)

    fit_model_instance.build_colorbar(
        paper_axs.flatten()[0],
        r'PBD polarization angle [$\Delta^\circ$]',
        fit.PlottingStuff.curlycm
        )

    fit_model_instance.build_colorbar(
        paper_axs.flatten()[3],
        'Molecule angle by model fit [deg]',
        fit.PlottingStuff.curlycm
        )

    paper_axs.flatten()[0].yaxis.tick_left()
    paper_axs.flatten()[0].yaxis.set_label_position("left")

    # Legends
    def loc_map_legend(ax, loc_label='fit localization'):
        legend_elements = [
            mpl.lines.Line2D(
                [0], [0], 
                marker='o', 
                color='w', 
                label=loc_label,
                markerfacecolor=fit.PlottingStuff.a_shade_of_green, 
                markersize=10
                ),
            mpl.lines.Line2D(
                [0], [0], 
                marker='o', 
                color='w', 
                label='molecule location',
                markerfacecolor='black', 
                markersize=8
                ),
            ]

        ax.legend(
            handles=legend_elements, 
            loc='upper right',
            bbox_to_anchor=(1,1.11), 
    #         ncol=2, mode="expand",
            fontsize=8,
            framealpha=1,
    #         loc=1
            )

    # loc_map_legend(paper_axs.flatten()[1])
    loc_map_legend(paper_axs.flatten()[2], loc_label='fit localization')

    # Title
    paper_axs.flatten()[1].set_title(None)
    paper_axs.flatten()[1].set_title('(a)', loc='left')
    paper_axs.flatten()[2].set_title(None)
    paper_axs.flatten()[2].set_title('(b)', loc='left')



    #~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
    # Quick and dirty fixes 
    #~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

    # rotate right colorbar label
    paper_axs.flatten()[3].set_ylabel(None)
    # paper_axs.flatten()[3].yaxis.set_label_position("right")
    paper_axs.flatten()[3].set_ylabel(r'Model fit molecule polarization [$\Delta^\circ$]',rotation=270,va="bottom")

    for cbar_ax in [paper_axs.flatten()[3],paper_axs.flatten()[0]]:
    #     cbar_ax.yaxis.set_ticks(np.linspace(0,np.pi/2,10))
    #     cbar_ax.yaxis.set_ticklabels(
    #         [r'$0$', r'$10$',r'$20$',r'$30$',r'$40$',r'$50$',r'$60$',r'$70$',r'$80$',r'$90$',]
    #         )
        cbar_ax.yaxis.set_ticks(np.linspace(0,np.pi/2,3))
        cbar_ax.yaxis.set_ticklabels(
            [r'$0$', r'$45$',r'$90$',]
            )

    # Redo quiver ticks
    for quiver_ax in [paper_axs.flatten()[i+1] for i in range(2)]:
        quiver_ax.tick_params(direction='in'),

    #     quiver_ax.set_ylim([-10,165])
        # set axis equal
        quiver_ax.axis('equal')
        quiver_ax.axis(quiv_ax_limits)

        quiver_ticks = np.linspace(0,125,5)
        for quiver_axis in [quiver_ax.yaxis, quiver_ax.xaxis]:
            quiver_axis.set_ticks(quiv_tick_list)
            quiver_axis.set_ticklabels(
                quiv_ticklabel_list
                )       

        # fix labels
        quiver_ax.set_xlabel(r'$x$ position [nm]')
        quiver_ax.set_ylabel(r'$y$ position [nm]')

    right_ax.set_ylabel(None)
    right_ax.yaxis.set_ticklabels([None])

# %% [markdown]
# ### Longer range

# %%
locations_300, angles_300 = fixed_ori_mol_placement(mol_grid_pts_1D=6, x_max=300, y_max=300)
simTestInst_few_mol_h_300 = SimulatedExperiment(locations_300, mol_angle=0)
simTestInst_few_mol_h_300.trial_images = simTestInst_few_mol_h_300.calculate_BEM_fields()

simTestInst_few_mol_h_300.plot_mispol_map_wMisloc()
# Out:
# starting Matlab...
# given even number of points for Fibonacci lattice,
#   adding 1...
# 1th molecule
# calculating diffracted fields
# 2th molecule
# calculating diffracted fields
# 3th molecule
# calculating diffracted fields
# 4th molecule
# calculating diffracted fields
# 5th molecule
# calculating diffracted fields
# 6th molecule
# calculating diffracted fields
# 7th molecule
# calculating diffracted fields
# 8th molecule
# calculating diffracted fields
# 9th molecule
# calculating diffracted fields
# 10th molecule
# calculating diffracted fields
# 11th molecule
# calculating diffracted fields
# 12th molecule
# calculating diffracted fields
# 13th molecule
# calculating diffracted fields
# 14th molecule
# calculating diffracted fields
# 15th molecule
# calculating diffracted fields
# 16th molecule
# calculating diffracted fields
# 17th molecule
# calculating diffracted fields
# 18th molecule
# calculating diffracted fields
# 19th molecule
# calculating diffracted fields
# 20th molecule
# calculating diffracted fields
# 21th molecule
# calculating diffracted fields
# 22th molecule
# calculating diffracted fields
# 23th molecule
# calculating diffracted fields
# 24th molecule
# calculating diffracted fields
# 25th molecule
# calculating diffracted fields
# 26th molecule
# calculating diffracted fields
# 27th molecule
# calculating diffracted fields
# 28th molecule
# calculating diffracted fields
# 29th molecule
# calculating diffracted fields
# 30th molecule
# calculating diffracted fields
# 31th molecule
# calculating diffracted fields
# 32th molecule
# calculating diffracted fields
# 33th molecule
# calculating diffracted fields
# 34th molecule
# calculating diffracted fields

# %%
# Model fit
# Gaussian guess, checked

test_BEM_fit_instance_few_mol_h_300 = fit.FitModelToData(
    simTestInst_few_mol_h_300.BEM_images, 
#     ini_guess=simTestInst_few_mol.mol_locations,
    ini_guess='gauss'
    )
test_BEM_fit_few_mol_h_300 = test_BEM_fit_instance_few_mol_h_300.fit_model_to_image_data(
    check_ini=True)

## Plot fit results
test_BEM_fit_instance_few_mol_h_300.plot_fit_results_as_quiver_map(simTestInst_few_mol_h_300)
# Out:
#  initial guess for molecule 0 location: (0.009238515856044873,122.2101142449033)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  0.009238515856044873
#  ini_y,  122.2101142449033
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 1 location: (0.003944760328209293,181.8101989001632)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  0.003944760328209293
#  ini_y,  181.8101989001632
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 2 location: (-0.001273458000729742,241.0333118183495)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  -0.001273458000729742
#  ini_y,  241.0333118183495
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 3 location: (-0.0016737055262746904,300.21860545869254)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  -0.0016737055262746904
#  ini_y,  300.21860545869254
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 4 location: (50.393497740481806,-0.04084671666849235)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  50.393497740481806
#  ini_y,  -0.04084671666849235
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 5 location: (15.375643444879968,24.269290295738465)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  15.375643444879968
#  ini_y,  24.269290295738465
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? True
# Params modified, OG params: (15.375643444879968, 24.269290295738465, array([1.57026048]))
# but now they are: (21.633793166809184, 34.1473063189489, array([1.57026048]))
#
#  initial guess for molecule 6 location: (53.450480826514514,113.43831850976618)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  53.450480826514514
#  ini_y,  113.43831850976618
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 7 location: (56.93517179884498,180.59616981317902)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  56.93517179884498
#  ini_y,  180.59616981317902
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 8 location: (56.72391405711766,241.14462943866505)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  56.72391405711766
#  ini_y,  241.14462943866505
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 9 location: (57.8466846205855,300.6164840062901)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  57.8466846205855
#  ini_y,  300.6164840062901
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 10 location: (115.50884726227363,-0.022350663839328207)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  115.50884726227363
#  ini_y,  -0.022350663839328207
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 11 location: (105.77445347137144,56.398800410722544)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  105.77445347137144
#  ini_y,  56.398800410722544
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 12 location: (111.1152891418905,117.27519082081166)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  111.1152891418905
#  ini_y,  117.27519082081166
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 13 location: (114.48572671595639,180.58099981093613)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  114.48572671595639
#  ini_y,  180.58099981093613
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 14 location: (115.73428389735072,241.74484461150638)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  115.73428389735072
#  ini_y,  241.74484461150638
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 15 location: (117.74352735235531,301.4784950336765)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  117.74352735235531
#  ini_y,  301.4784950336765
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 16 location: (178.71933719647902,-0.014414957648560552)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  178.71933719647902
#  ini_y,  -0.014414957648560552
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 17 location: (176.6203460610649,59.65911103272223)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  176.6203460610649
#  ini_y,  59.65911103272223
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 18 location: (175.68119410656018,120.08147874647815)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  175.68119410656018
#  ini_y,  120.08147874647815
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 19 location: (176.6398951415382,181.4883095248648)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  176.6398951415382
#  ini_y,  181.4883095248648
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 20 location: (178.14118094231256,242.30934707248014)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  178.14118094231256
#  ini_y,  242.30934707248014
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 21 location: (179.72454620118515,301.97103236407764)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  179.72454620118515
#  ini_y,  301.97103236407764
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 22 location: (240.1407576745498,-0.013556516729377343)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  240.1407576745498
#  ini_y,  -0.013556516729377343
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 23 location: (239.82648580278365,59.882806996825096)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  239.82648580278365
#  ini_y,  59.882806996825096
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 24 location: (239.82226341015266,120.41338257802636)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  239.82226341015266
#  ini_y,  120.41338257802636
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 25 location: (240.6136206185536,181.42134141435497)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  240.6136206185536
#  ini_y,  181.42134141435497
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 26 location: (241.43414393583882,241.9723595553423)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  241.43414393583882
#  ini_y,  241.9723595553423
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 27 location: (241.57175628786428,301.57091650110385)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  241.57175628786428
#  ini_y,  301.57091650110385
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 28 location: (300.39048968019347,-0.011123548320228665)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  300.39048968019347
#  ini_y,  -0.011123548320228665
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 29 location: (300.76789765893426,59.7252840659283)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  300.76789765893426
#  ini_y,  59.7252840659283
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 30 location: (301.6798457413035,120.01556817620438)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  301.6798457413035
#  ini_y,  120.01556817620438
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 31 location: (302.5013747338787,180.6768828139458)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  302.5013747338787
#  ini_y,  180.6768828139458
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 32 location: (302.4760571280034,241.00537037660774)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  302.4760571280034
#  ini_y,  241.00537037660774
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 33 location: (301.51380513662446,300.6830134705202)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  301.51380513662446
#  ini_y,  300.6830134705202
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False

# %%
fig5(
    simTestInst_few_mol_h_300, test_BEM_fit_instance_few_mol_h_300, [-50,350,-50,350],
    quiv_tick_list=np.linspace(0,300,3),
    quiv_ticklabel_list=[r'$0$', r'$150$',r'$300$'],)

# %% [markdown]
# ### y-oriented equivalent

# %%
locations_125, angles_125 = fixed_ori_mol_placement(mol_grid_pts_1D=6, x_max=125, y_max=125)
simTestInst_few_mol_v_125 = SimulatedExperiment(locations_125, mol_angle=np.pi/2)
simTestInst_few_mol_v_125.trial_images = simTestInst_few_mol_v_125.calculate_BEM_fields()

# simTestInst_few_mol_v_125.plot_mispol_map_wMisloc()

# Model fit
# Gaussian guess, checked

test_BEM_fit_instance_few_mol_v_125 = fit.FitModelToData(
    simTestInst_few_mol_v_125.BEM_images, 
#     ini_guess=simTestInst_few_mol.mol_locations,
    ini_guess='gauss'
    )
test_BEM_fit_few_mol_v_125 = test_BEM_fit_instance_few_mol_v_125.fit_model_to_image_data(
    check_ini=True)

## Plot fit results
# test_BEM_fit_instance_few_mol_v_125.plot_fit_results_as_quiver_map(simTestInst_few_mol_v_125)
# Out:
# starting Matlab...
# given even number of points for Fibonacci lattice,
#   adding 1...
# 1th molecule
# calculating diffracted fields
# 2th molecule
# calculating diffracted fields
# 3th molecule
# calculating diffracted fields
# 4th molecule
# calculating diffracted fields
# 5th molecule
# calculating diffracted fields
# 6th molecule
# calculating diffracted fields
# 7th molecule
# calculating diffracted fields
# 8th molecule
# calculating diffracted fields
# 9th molecule
# calculating diffracted fields
# 10th molecule
# calculating diffracted fields
# 11th molecule
# calculating diffracted fields
# 12th molecule
# calculating diffracted fields
# 13th molecule
# calculating diffracted fields
# 14th molecule
# calculating diffracted fields
# 15th molecule
# calculating diffracted fields
# 16th molecule
# calculating diffracted fields
# 17th molecule
# calculating diffracted fields
# 18th molecule
# calculating diffracted fields
# 19th molecule
# calculating diffracted fields
# 20th molecule
# calculating diffracted fields
# 21th molecule
# calculating diffracted fields
# 22th molecule
# calculating diffracted fields
# 23th molecule
# calculating diffracted fields
# 24th molecule
# calculating diffracted fields
# 25th molecule
# calculating diffracted fields
# 26th molecule
# calculating diffracted fields
# 27th molecule
# calculating diffracted fields
# 28th molecule
# calculating diffracted fields
# 29th molecule
# calculating diffracted fields
# 30th molecule
# calculating diffracted fields
# 31th molecule
# calculating diffracted fields
# 32th molecule
# calculating diffracted fields
#
#  initial guess for molecule 0 location: (-0.015204728110660029,6.562411541306384)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  -0.015204728110660029
#  ini_y,  6.562411541306384
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? True
# Params modified, OG params: (-0.015204728110660029, 6.562411541306384, array([0.77184135]))
# but now they are: (-0.14313158904314383, 61.77607287852601, array([0.77184135]))
#
#  initial guess for molecule 1 location: (-0.03335288059089358,24.459739758552935)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  -0.03335288059089358
#  ini_y,  24.459739758552935
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? True
# Params modified, OG params: (-0.03335288059089358, 24.459739758552935, array([0.72275627]))
# but now they are: (-0.08423762773732744, 61.77668662585311, array([0.72275627]))
#
#  initial guess for molecule 2 location: (-0.054842407544988786,72.82295542940781)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  -0.054842407544988786
#  ini_y,  72.82295542940781
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 3 location: (0.23584999145370988,0.9853992385519538)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  0.23584999145370988
#  ini_y,  0.9853992385519538
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? True
# Params modified, OG params: (0.23584999145370988, 0.9853992385519538, array([0.56991919]))
# but now they are: (12.848138535452705, 53.680501964868576, array([0.56991919]))
#
#  initial guess for molecule 4 location: (1.206630705512369,3.678211328290433)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  1.206630705512369
#  ini_y,  3.678211328290433
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? True
# Params modified, OG params: (1.206630705512369, 3.678211328290433, array([0.60972591]))
# but now they are: (15.974608164008187, 48.695913708664875, array([0.60972591]))
#
#  initial guess for molecule 5 location: (2.85357129309075,10.080407376290635)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  2.85357129309075
#  ini_y,  10.080407376290635
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? True
# Params modified, OG params: (2.85357129309075, 10.080407376290635, array([0.92466699]))
# but now they are: (14.503932402047063, 51.235988925462706, array([0.92466699]))
#
#  initial guess for molecule 6 location: (7.541250240569964,31.8460442284255)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  7.541250240569964
#  ini_y,  31.8460442284255
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? True
# Params modified, OG params: (7.541250240569964, 31.8460442284255, array([1.07756872]))
# but now they are: (12.744735128721773, 53.81990858828285, array([1.07756872]))
#
#  initial guess for molecule 7 location: (16.780888990303154,84.2351568205381)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  16.780888990303154
#  ini_y,  84.2351568205381
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 8 location: (1.6144649068511987,0.6261078662650946)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  1.6144649068511987
#  ini_y,  0.6261078662650946
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? True
# Params modified, OG params: (1.6144649068511987, 0.6261078662650946, array([1.23943443]))
# but now they are: (25.622131595032563, 9.936554256492034, array([1.23943443]))
#
#  initial guess for molecule 9 location: (31.362221959140033,15.164062375228035)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  31.362221959140033
#  ini_y,  15.164062375228035
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 10 location: (25.47688227898405,26.610884882418507)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  25.47688227898405
#  ini_y,  26.610884882418507
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 11 location: (19.868085158656456,31.173839174285572)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  19.868085158656456
#  ini_y,  31.173839174285572
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? True
# Params modified, OG params: (19.868085158656456, 31.173839174285572, array([0.20975936]))
# but now they are: (21.673077378491286, 34.00594587820975, array([0.20975936]))
#
#  initial guess for molecule 12 location: (30.83903758022118,62.45199961618547)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  30.83903758022118
#  ini_y,  62.45199961618547
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 13 location: (47.10457397085444,116.17777746345342)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  47.10457397085444
#  ini_y,  116.17777746345342
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 14 location: (61.6498554612684,0.14614360212875346)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  61.6498554612684
#  ini_y,  0.14614360212875346
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 15 location: (109.76769013708102,36.036256603803366)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  109.76769013708102
#  ini_y,  36.036256603803366
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 16 location: (110.25065141288034,73.1066336902675)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  110.25065141288034
#  ini_y,  73.1066336902675
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 17 location: (86.12813204543981,85.35387229251234)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  86.12813204543981
#  ini_y,  85.35387229251234
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 18 location: (84.74801809622814,111.01043548181616)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  84.74801809622814
#  ini_y,  111.01043548181616
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 19 location: (89.13910979933897,145.0017327695733)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  89.13910979933897
#  ini_y,  145.0017327695733
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 20 location: (135.45048670880357,-0.16234367124424318)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  135.45048670880357
#  ini_y,  -0.16234367124424318
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 21 location: (140.47929247686716,34.18330092094116)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  140.47929247686716
#  ini_y,  34.18330092094116
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 22 location: (139.64600530095709,68.02749057092251)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  139.64600530095709
#  ini_y,  68.02749057092251
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 23 location: (132.37355504810122,96.78759803441015)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  132.37355504810122
#  ini_y,  96.78759803441015
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 24 location: (126.02434281781667,122.79278101963934)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  126.02434281781667
#  ini_y,  122.79278101963934
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 25 location: (121.58527470952302,148.1214384825206)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  121.58527470952302
#  ini_y,  148.1214384825206
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 26 location: (158.19381835547082,-0.1405906326955976)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  158.19381835547082
#  ini_y,  -0.1405906326955976
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 27 location: (158.61039249016568,30.73815723110222)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  158.61039249016568
#  ini_y,  30.73815723110222
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 28 location: (157.63331457206766,61.19937958763312)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  157.63331457206766
#  ini_y,  61.19937958763312
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 29 location: (154.22813782957894,89.92579719194448)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  154.22813782957894
#  ini_y,  89.92579719194448
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 30 location: (149.76167396485295,116.63825637693097)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  149.76167396485295
#  ini_y,  116.63825637693097
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 31 location: (145.28789686336995,141.77989987299588)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  145.28789686336995
#  ini_y,  141.77989987299588
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False

# %%
fig5(simTestInst_few_mol_v_125, test_BEM_fit_instance_few_mol_v_125,
    [-20,160,-20,160],
#     quiv_tick_list=np.linspace(0,300,3),
#     quiv_ticklabel_list=[r'$0$', r'$150$',r'$300$'],
    fig_size=(6.5, 2.8)
    )

# %% [markdown]
# #### Owch, that doesn't actually work that well... Let's try larger distances

# %%
locations_300, angles_300 = fixed_ori_mol_placement(mol_grid_pts_1D=6, x_max=300, y_max=300)
simTestInst_few_mol_v_300 = SimulatedExperiment(locations_300, mol_angle=np.pi/2)
simTestInst_few_mol_v_300.trial_images = simTestInst_few_mol_v_300.calculate_BEM_fields()

# simTestInst_few_mol_v_300.plot_mispol_map_wMisloc()

# Model fit
# Gaussian guess, checked

test_BEM_fit_instance_few_mol_v_300 = fit.FitModelToData(
    simTestInst_few_mol_v_300.BEM_images, 
#     ini_guess=simTestInst_few_mol.mol_locations,
    ini_guess='gauss'
    )
test_BEM_fit_few_mol_v_300 = test_BEM_fit_instance_few_mol_v_300.fit_model_to_image_data(
    check_ini=True)


## Plot fit results
fig5(simTestInst_few_mol_v_300, test_BEM_fit_instance_few_mol_v_300, [-50,350])
# Out:
# starting Matlab...
# given even number of points for Fibonacci lattice,
#   adding 1...
# 1th molecule
# calculating diffracted fields
# 2th molecule
# calculating diffracted fields
# 3th molecule
# calculating diffracted fields
# 4th molecule
# calculating diffracted fields
# 5th molecule
# calculating diffracted fields
# 6th molecule
# calculating diffracted fields
# 7th molecule
# calculating diffracted fields
# 8th molecule
# calculating diffracted fields
# 9th molecule
# calculating diffracted fields
# 10th molecule
# calculating diffracted fields
# 11th molecule
# calculating diffracted fields
# 12th molecule
# calculating diffracted fields
# 13th molecule
# calculating diffracted fields
# 14th molecule
# calculating diffracted fields
# 15th molecule
# calculating diffracted fields
# 16th molecule
# calculating diffracted fields
# 17th molecule
# calculating diffracted fields
# 18th molecule
# calculating diffracted fields
# 19th molecule
# calculating diffracted fields
# 20th molecule
# calculating diffracted fields
# 21th molecule
# calculating diffracted fields
# 22th molecule
# calculating diffracted fields
# 23th molecule
# calculating diffracted fields
# 24th molecule
# calculating diffracted fields
# 25th molecule
# calculating diffracted fields
# 26th molecule
# calculating diffracted fields
# 27th molecule
# calculating diffracted fields
# 28th molecule
# calculating diffracted fields
# 29th molecule
# calculating diffracted fields
# 30th molecule
# calculating diffracted fields
# 31th molecule
# calculating diffracted fields
# 32th molecule
# calculating diffracted fields
# 33th molecule
# calculating diffracted fields
# 34th molecule
# calculating diffracted fields
#
#  initial guess for molecule 0 location: (-0.050940120656381954,60.062035018358856)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  -0.050940120656381954
#  ini_y,  60.062035018358856
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? True
# Params modified, OG params: (-0.050940120656381954, 60.062035018358856, array([1.1980034]))
# but now they are: (-0.05239452888353747, 61.776886038441845, array([1.1980034]))
#
#  initial guess for molecule 1 location: (-0.036192088133012605,207.02345094492117)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  -0.036192088133012605
#  ini_y,  207.02345094492117
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 2 location: (0.003981274738652242,262.5509342488308)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  0.003981274738652242
#  ini_y,  262.5509342488308
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 3 location: (0.017938294109691902,308.21594652676197)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  0.017938294109691902
#  ini_y,  308.21594652676197
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 4 location: (11.971408377205861,0.5228246406555788)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  11.971408377205861
#  ini_y,  0.5228246406555788
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? True
# Params modified, OG params: (11.971408377205861, 0.5228246406555788, array([1.35437877]))
# but now they are: (25.955772426379184, 1.1335606441760129, array([1.35437877]))
#
#  initial guess for molecule 5 location: (45.635767267128095,46.618198240368464)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  45.635767267128095
#  ini_y,  46.618198240368464
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 6 location: (61.30807088478599,120.56418955550647)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  61.30807088478599
#  ini_y,  120.56418955550647
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 7 location: (70.68963113003572,207.44214613487546)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  70.68963113003572
#  ini_y,  207.44214613487546
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 8 location: (65.27640447474336,257.650233310508)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  65.27640447474336
#  ini_y,  257.650233310508
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 9 location: (61.5372634877745,305.82194314501487)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  61.5372634877745
#  ini_y,  305.82194314501487
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 10 location: (154.57359434937092,-0.14841761100675557)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  154.57359434937092
#  ini_y,  -0.14841761100675557
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 11 location: (153.0103553885694,74.28182391287645)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  153.0103553885694
#  ini_y,  74.28182391287645
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 12 location: (141.8567189083684,138.29265399243587)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  141.8567189083684
#  ini_y,  138.29265399243587
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 13 location: (132.0483669858884,194.54272827541462)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  132.0483669858884
#  ini_y,  194.54272827541462
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 14 location: (124.82946600147758,247.26752825747567)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  124.82946600147758
#  ini_y,  247.26752825747567
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 15 location: (120.83451419395307,301.2172839617607)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  120.83451419395307
#  ini_y,  301.2172839617607
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 16 location: (193.39935140412715,-0.058411623155579594)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  193.39935140412715
#  ini_y,  -0.058411623155579594
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 17 location: (192.29971988136754,62.98357298515676)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  192.29971988136754
#  ini_y,  62.98357298515676
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 18 location: (188.2997231688879,123.88283974664816)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  188.2997231688879
#  ini_y,  123.88283974664816
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 19 location: (183.5466563260517,182.2092197730035)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  183.5466563260517
#  ini_y,  182.2092197730035
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 20 location: (180.2339386413202,239.92298745679986)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  180.2339386413202
#  ini_y,  239.92298745679986
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 21 location: (178.98875064664054,298.9577603078701)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  178.98875064664054
#  ini_y,  298.9577603078701
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 22 location: (236.93421310809637,-0.015890116287799825)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  236.93421310809637
#  ini_y,  -0.015890116287799825
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 23 location: (236.8695775350514,59.46131614645557)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  236.8695775350514
#  ini_y,  59.46131614645557
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 24 location: (236.6535685769382,119.02347963211473)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  236.6535685769382
#  ini_y,  119.02347963211473
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 25 location: (236.74464399909883,178.89353452850133)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  236.74464399909883
#  ini_y,  178.89353452850133
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 26 location: (237.53498933435642,239.421921492842)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  237.53498933435642
#  ini_y,  239.421921492842
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 27 location: (238.76608943822666,300.43293543168255)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  238.76608943822666
#  ini_y,  300.43293543168255
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 28 location: (294.37096464602234,-0.020409855441775124)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  294.37096464602234
#  ini_y,  -0.020409855441775124
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 29 location: (294.86004490697684,60.508457370136654)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  294.86004490697684
#  ini_y,  60.508457370136654
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 30 location: (296.19096240638453,121.2408930402879)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  296.19096240638453
#  ini_y,  121.2408930402879
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 31 location: (297.93940365034086,182.08048560517423)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  297.93940365034086
#  ini_y,  182.08048560517423
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 32 location: (299.5048018359353,242.63109352760497)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  299.5048018359353
#  ini_y,  242.63109352760497
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 33 location: (300.40862779537076,302.495811371451)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  300.40862779537076
#  ini_y,  302.495811371451
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False

# %%
fig5(simTestInst_few_mol_v_300, test_BEM_fit_instance_few_mol_v_300,
    [-75,375,-75,375],
    quiv_tick_list=np.linspace(0,300,3),
    quiv_ticklabel_list=[r'$0$', r'$150$',r'$300$'],)

# %% [markdown]
# ### I want higher res!

# %%
locations_300hires, angles_300hires = fixed_ori_mol_placement(mol_grid_pts_1D=7, x_max=300, y_max=300)
simTestInst_few_mol_v_300hires = SimulatedExperiment(locations_300hires, mol_angle=np.pi/2)
simTestInst_few_mol_v_300hires.trial_images = simTestInst_few_mol_v_300hires.calculate_BEM_fields()

# simTestInst_few_mol_v_300hires.plot_mispol_map_wMisloc()

# Model fit
# Gaussian guess, checked

test_BEM_fit_instance_few_mol_v_300hires = fit.FitModelToData(
    simTestInst_few_mol_v_300hires.BEM_images, 
#     ini_guess=simTestInst_few_mol.mol_locations,
    ini_guess='gauss'
    )
test_BEM_fit_few_mol_v_300hires = test_BEM_fit_instance_few_mol_v_300hires.fit_model_to_image_data(
    check_ini=True)


## Plot fit results
fig5(simTestInst_few_mol_v_300hires, test_BEM_fit_instance_few_mol_v_300hires, [-50,350])
# Out:
# starting Matlab...
# given even number of points for Fibonacci lattice,
#   adding 1...
# 1th molecule
# calculating diffracted fields
# 2th molecule
# calculating diffracted fields
# 3th molecule
# calculating diffracted fields
# 4th molecule
# calculating diffracted fields
# 5th molecule
# calculating diffracted fields
# 6th molecule
# calculating diffracted fields
# 7th molecule
# calculating diffracted fields
# 8th molecule
# calculating diffracted fields
# 9th molecule
# calculating diffracted fields
# 10th molecule
# calculating diffracted fields
# 11th molecule
# calculating diffracted fields
# 12th molecule
# calculating diffracted fields
# 13th molecule
# calculating diffracted fields
# 14th molecule
# calculating diffracted fields
# 15th molecule
# calculating diffracted fields
# 16th molecule
# calculating diffracted fields
# 17th molecule
# calculating diffracted fields
# 18th molecule
# calculating diffracted fields
# 19th molecule
# calculating diffracted fields
# 20th molecule
# calculating diffracted fields
# 21th molecule
# calculating diffracted fields
# 22th molecule
# calculating diffracted fields
# 23th molecule
# calculating diffracted fields
# 24th molecule
# calculating diffracted fields
# 25th molecule
# calculating diffracted fields
# 26th molecule
# calculating diffracted fields
# 27th molecule
# calculating diffracted fields
# 28th molecule
# calculating diffracted fields
# 29th molecule
# calculating diffracted fields
# 30th molecule
# calculating diffracted fields
# 31th molecule
# calculating diffracted fields
# 32th molecule
# calculating diffracted fields
# 33th molecule
# calculating diffracted fields
# 34th molecule
# calculating diffracted fields
# 35th molecule
# calculating diffracted fields
# 36th molecule
# calculating diffracted fields
# 37th molecule
# calculating diffracted fields
# 38th molecule
# calculating diffracted fields
# 39th molecule
# calculating diffracted fields
# 40th molecule
# calculating diffracted fields
# 41th molecule
# calculating diffracted fields
# 42th molecule
# calculating diffracted fields
# 43th molecule
# calculating diffracted fields
# 44th molecule
# calculating diffracted fields
# 45th molecule
# calculating diffracted fields
# 46th molecule
# calculating diffracted fields
# 47th molecule
# calculating diffracted fields
#
#  initial guess for molecule 0 location: (-0.03335288059089358,24.459739758552935)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  -0.03335288059089358
#  ini_y,  24.459739758552935
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? True
# Params modified, OG params: (-0.03335288059089358, 24.459739758552935, array([1.04562889]))
# but now they are: (-0.08423762773732744, 61.77668662585311, array([1.04562889]))
#
#  initial guess for molecule 1 location: (-0.05974048546865638,146.17480890130523)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  -0.05974048546865638
#  ini_y,  146.17480890130523
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 2 location: (-0.019349971330228595,229.84491043498736)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  -0.019349971330228595
#  ini_y,  229.84491043498736
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 3 location: (0.007807769375145507,269.9801758241359)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  0.007807769375145507
#  ini_y,  269.9801758241359
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 4 location: (0.017938294109691902,308.21594652676197)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  0.017938294109691902
#  ini_y,  308.21594652676197
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 5 location: (1.6144649068511987,0.6261078662650946)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  1.6144649068511987
#  ini_y,  0.6261078662650946
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? True
# Params modified, OG params: (1.6144649068511987, 0.6261078662650946, array([0.0309466]))
# but now they are: (25.622131595032563, 9.936554256492034, array([0.0309466]))
#
#  initial guess for molecule 6 location: (25.47688227898405,26.610884882418507)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  25.47688227898405
#  ini_y,  26.610884882418507
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 7 location: (30.83903758022118,62.45199961618547)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  30.83903758022118
#  ini_y,  62.45199961618547
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 8 location: (57.50734480224093,168.31640962565984)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  57.50734480224093
#  ini_y,  168.31640962565984
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 9 location: (57.86376467472181,227.03482446122126)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  57.86376467472181
#  ini_y,  227.03482446122126
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 10 location: (54.01104442068411,266.75420586516657)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  54.01104442068411
#  ini_y,  266.75420586516657
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 11 location: (51.412464730345405,306.50024765500024)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  51.412464730345405
#  ini_y,  306.50024765500024
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 12 location: (135.45048670880357,-0.16234367124424318)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  135.45048670880357
#  ini_y,  -0.16234367124424318
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 13 location: (139.64600530095709,68.02749057092251)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  139.64600530095709
#  ini_y,  68.02749057092251
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 14 location: (126.02434281781667,122.79278101963934)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  126.02434281781667
#  ini_y,  122.79278101963934
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 15 location: (117.7093873069589,172.42052021360965)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  117.7093873069589
#  ini_y,  172.42052021360965
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 16 location: (110.39346743037387,217.06453872347555)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  110.39346743037387
#  ini_y,  217.06453872347555
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 17 location: (104.728139123949,259.2121749637284)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  104.728139123949
#  ini_y,  259.2121749637284
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 18 location: (101.3208673426863,302.6914342692043)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  101.3208673426863
#  ini_y,  302.6914342692043
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 19 location: (174.4987425611694,-0.09974452574246144)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  174.4987425611694
#  ini_y,  -0.09974452574246144
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 20 location: (173.56242702378927,56.349156439236545)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  173.56242702378927
#  ini_y,  56.349156439236545
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 21 location: (168.59611004674466,109.8610125548137)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  168.59611004674466
#  ini_y,  109.8610125548137
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 22 location: (161.96000023293794,159.1812869711038)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  161.96000023293794
#  ini_y,  159.1812869711038
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 23 location: (156.11988135665445,205.89888900234322)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  156.11988135665445
#  ini_y,  205.89888900234322
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 24 location: (152.02249499532812,252.10895357143562)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  152.02249499532812
#  ini_y,  252.10895357143562
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 25 location: (149.87109943429994,299.59138236412826)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  149.87109943429994
#  ini_y,  299.59138236412826
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 26 location: (206.7398857716587,-0.03814157213589649)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  206.7398857716587
#  ini_y,  -0.03814157213589649
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 27 location: (206.2572341435671,50.98175222745538)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  206.2572341435671
#  ini_y,  50.98175222745538
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 28 location: (204.48752387811825,101.36384604393814)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  204.48752387811825
#  ini_y,  101.36384604393814
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 29 location: (201.9864741545337,150.74135797230244)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  201.9864741545337
#  ini_y,  150.74135797230244
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 30 location: (199.84566348200744,199.64326737565545)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  199.84566348200744
#  ini_y,  199.64326737565545
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 31 location: (198.71504236373752,248.93757526023046)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  198.71504236373752
#  ini_y,  248.93757526023046
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 32 location: (198.63535498029387,299.1138587789048)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  198.63535498029387
#  ini_y,  299.1138587789048
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 33 location: (245.41741390288777,-0.013909064579516366)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  245.41741390288777
#  ini_y,  -0.013909064579516366
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 34 location: (245.47556805433436,49.48217882684129)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  245.47556805433436
#  ini_y,  49.48217882684129
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 35 location: (245.61227798320073,99.11596438349231)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  245.61227798320073
#  ini_y,  99.11596438349231
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 36 location: (245.96388349279434,149.011598953785)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  245.96388349279434
#  ini_y,  149.011598953785
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 37 location: (246.71080710425753,199.32083690558972)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  246.71080710425753
#  ini_y,  199.32083690558972
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 38 location: (247.81016247513534,250.0386422936422)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  247.81016247513534
#  ini_y,  250.0386422936422
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 39 location: (248.96661899878399,300.8605106567056)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  248.96661899878399
#  ini_y,  300.8605106567056
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 40 location: (294.37096464602234,-0.020409855441775124)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  294.37096464602234
#  ini_y,  -0.020409855441775124
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 41 location: (294.712543323992,50.40881944176369)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  294.712543323992
#  ini_y,  50.40881944176369
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 42 location: (295.6746124323899,100.97258866111025)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  295.6746124323899
#  ini_y,  100.97258866111025
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 43 location: (297.0490015661293,151.66718604206915)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  297.0490015661293
#  ini_y,  151.66718604206915
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 44 location: (298.51128247215826,202.31990670177345)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  298.51128247215826
#  ini_y,  202.31990670177345
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 45 location: (299.70920970558234,252.66281718534418)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  299.70920970558234
#  ini_y,  252.66281718534418
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 46 location: (300.40862779537076,302.495811371451)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  300.40862779537076
#  ini_y,  302.495811371451
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False

# %% [markdown]
# # Adding histograms to figure 5

# %% [markdown]
# ## PBD polarization histograms

# %%
# locations_125, angles_125 = fixed_ori_mol_placement(mol_grid_pts_1D=6, x_max=125, y_max=125)

locations_randAngle125, randAngle125 = fit.random_ori_mol_placement(
    mol_grid_pts_1D=6, 
    x_max=125, 
    y_max=125,
)

simTestInst_few_mol_randAngle125 = SimulatedExperiment(
    locations_randAngle125, mol_angle=random_angles_125)
simTestInst_few_mol_randAngle125.trial_images = simTestInst_few_mol_randAngle125.calculate_BEM_fields()
# Out:
# starting Matlab...
# given even number of points for Fibonacci lattice,
#   adding 1...
# 1th molecule
# calculating diffracted fields
# 2th molecule
# calculating diffracted fields
# 3th molecule
# calculating diffracted fields
# 4th molecule
# calculating diffracted fields
# 5th molecule
# calculating diffracted fields
# 6th molecule
# calculating diffracted fields
# 7th molecule
# calculating diffracted fields
# 8th molecule
# calculating diffracted fields
# 9th molecule
# calculating diffracted fields
# 10th molecule
# calculating diffracted fields
# 11th molecule
# calculating diffracted fields
# 12th molecule
# calculating diffracted fields
# 13th molecule
# calculating diffracted fields
# 14th molecule
# calculating diffracted fields
# 15th molecule
# calculating diffracted fields
# 16th molecule
# calculating diffracted fields
# 17th molecule
# calculating diffracted fields
# 18th molecule
# calculating diffracted fields
# 19th molecule
# calculating diffracted fields
# 20th molecule
# calculating diffracted fields
# 21th molecule
# calculating diffracted fields
# 22th molecule
# calculating diffracted fields
# 23th molecule
# calculating diffracted fields
# 24th molecule
# calculating diffracted fields
# 25th molecule
# calculating diffracted fields
# 26th molecule
# calculating diffracted fields
# 27th molecule
# calculating diffracted fields
# 28th molecule
# calculating diffracted fields
# 29th molecule
# calculating diffracted fields
# 30th molecule
# calculating diffracted fields
# 31th molecule
# calculating diffracted fields
# 32th molecule
# calculating diffracted fields

# %%
simTestInst_few_mol_randAngle125.plot_mispol_map_wMisloc()

# %%
simTestInst_few_mol_randAngle125.mispol_angle
# Out:
# array([1.23790599, 0.66840486, 0.85158815, 0.80690944, 1.49511122,
#        1.23051271, 1.35737447, 0.18938313, 0.07917287, 0.92472541,
#        1.31562472, 1.12714372, 0.82908715, 1.36774425, 1.29427344,
#        0.72960208, 0.86691417, 1.21642514, 1.26076703, 0.68801205,
#        0.15470516, 1.14424778, 0.8918718 , 1.24443028, 0.44245182,
#        0.58981072, 1.57079633, 0.54406496, 0.28679674, 0.41760822,
#        1.01118935, 0.24151095])

# %%
def map_angles_to_first_quad(angles):
    angle_in_first_quad = np.arctan(
        np.abs(np.sin(angles))
        /
        np.abs(np.cos(angles))
        )
    return angle_in_first_quad

# %%
plt.hist(simTestInst_few_mol_randAngle125.mispol_angle)
plt.hist(
    map_angles_to_first_quad(
        simTestInst_few_mol_randAngle125.mol_angles
        ),
    alpha=.4)
# Out:
# (array([3., 3., 3., 4., 3., 3., 2., 3., 6., 2.]),
#  array([0.01352777, 0.16555641, 0.31758504, 0.46961368, 0.62164232,
#         0.77367095, 0.92569959, 1.07772823, 1.22975686, 1.3817855 ,
#         1.53381414]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ### Going higher res

# %%
# locations_125, angles_125 = fixed_ori_mol_placement(mol_grid_pts_1D=6, x_max=125, y_max=125)

locations_randAngle125_hr, randAngle125_hr = fit.random_ori_mol_placement(
    mol_grid_pts_1D=10, 
    x_max=125, 
    y_max=125,
)

simTestInst_few_mol_randAngle125_hr = SimulatedExperiment(
    locations_randAngle125_hr, mol_angle=randAngle125_hr)
simTestInst_few_mol_randAngle125_hr.trial_images = simTestInst_few_mol_randAngle125_hr.calculate_BEM_fields()
# Out:
# starting Matlab...
# given even number of points for Fibonacci lattice,
#   adding 1...
# 1th molecule
# calculating diffracted fields
# 2th molecule
# calculating diffracted fields
# 3th molecule
# calculating diffracted fields
# 4th molecule
# calculating diffracted fields
# 5th molecule
# calculating diffracted fields
# 6th molecule
# calculating diffracted fields
# 7th molecule
# calculating diffracted fields
# 8th molecule
# calculating diffracted fields
# 9th molecule
# calculating diffracted fields
# 10th molecule
# calculating diffracted fields
# 11th molecule
# calculating diffracted fields
# 12th molecule
# calculating diffracted fields
# 13th molecule
# calculating diffracted fields
# 14th molecule
# calculating diffracted fields
# 15th molecule
# calculating diffracted fields
# 16th molecule
# calculating diffracted fields
# 17th molecule
# calculating diffracted fields
# 18th molecule
# calculating diffracted fields
# 19th molecule
# calculating diffracted fields
# 20th molecule
# calculating diffracted fields
# 21th molecule
# calculating diffracted fields
# 22th molecule
# calculating diffracted fields
# 23th molecule
# calculating diffracted fields
# 24th molecule
# calculating diffracted fields
# 25th molecule
# calculating diffracted fields
# 26th molecule
# calculating diffracted fields
# 27th molecule
# calculating diffracted fields
# 28th molecule
# calculating diffracted fields
# 29th molecule
# calculating diffracted fields
# 30th molecule
# calculating diffracted fields
# 31th molecule
# calculating diffracted fields
# 32th molecule
# calculating diffracted fields
# 33th molecule
# calculating diffracted fields
# 34th molecule
# calculating diffracted fields
# 35th molecule
# calculating diffracted fields
# 36th molecule
# calculating diffracted fields
# 37th molecule
# calculating diffracted fields
# 38th molecule
# calculating diffracted fields
# 39th molecule
# calculating diffracted fields
# 40th molecule
# calculating diffracted fields
# 41th molecule
# calculating diffracted fields
# 42th molecule
# calculating diffracted fields
# 43th molecule
# calculating diffracted fields
# 44th molecule
# calculating diffracted fields
# 45th molecule
# calculating diffracted fields
# 46th molecule
# calculating diffracted fields
# 47th molecule
# calculating diffracted fields
# 48th molecule
# calculating diffracted fields
# 49th molecule
# calculating diffracted fields
# 50th molecule
# calculating diffracted fields
# 51th molecule
# calculating diffracted fields
# 52th molecule
# calculating diffracted fields
# 53th molecule
# calculating diffracted fields
# 54th molecule
# calculating diffracted fields
# 55th molecule
# calculating diffracted fields
# 56th molecule
# calculating diffracted fields
# 57th molecule
# calculating diffracted fields
# 58th molecule
# calculating diffracted fields
# 59th molecule
# calculating diffracted fields
# 60th molecule
# calculating diffracted fields
# 61th molecule
# calculating diffracted fields
# 62th molecule
# calculating diffracted fields
# 63th molecule
# calculating diffracted fields
# 64th molecule
# calculating diffracted fields
# 65th molecule
# calculating diffracted fields
# 66th molecule
# calculating diffracted fields
# 67th molecule
# calculating diffracted fields
# 68th molecule
# calculating diffracted fields
# 69th molecule
# calculating diffracted fields
# 70th molecule
# calculating diffracted fields
# 71th molecule
# calculating diffracted fields
# 72th molecule
# calculating diffracted fields
# 73th molecule
# calculating diffracted fields
# 74th molecule
# calculating diffracted fields
# 75th molecule
# calculating diffracted fields
# 76th molecule
# calculating diffracted fields
# 77th molecule
# calculating diffracted fields
# 78th molecule
# calculating diffracted fields
# 79th molecule
# calculating diffracted fields
# 80th molecule
# calculating diffracted fields
# 81th molecule
# calculating diffracted fields
# 82th molecule
# calculating diffracted fields
# 83th molecule
# calculating diffracted fields
# 84th molecule
# calculating diffracted fields
# 85th molecule
# calculating diffracted fields
# 86th molecule
# calculating diffracted fields
# 87th molecule
# calculating diffracted fields
# 88th molecule
# calculating diffracted fields
# 89th molecule
# calculating diffracted fields
# 90th molecule
# calculating diffracted fields
# 91th molecule
# calculating diffracted fields

# %%
simTestInst_few_mol_randAngle125_hr.plot_mispol_map_wMisloc()

# %%
plt.hist(simTestInst_few_mol_randAngle125_hr.mispol_angle)
plt.hist(
    map_angles_to_first_quad(
        simTestInst_few_mol_randAngle125_hr.mol_angles
        ),
    alpha=.4)
# Out:
# (array([ 6., 10.,  8.,  9.,  7., 14.,  7.,  7., 12., 11.]),
#  array([0.00798022, 0.16254346, 0.31710669, 0.47166993, 0.62623316,
#         0.7807964 , 0.93535963, 1.08992287, 1.2444861 , 1.39904933,
#         1.55361257]),
#  <a list of 10 Patch objects>)

# %%
bins=25

plt.hist(
    simTestInst_few_mol_randAngle125_hr.mispol_angle,
    bins=bins)
plt.hist(
    map_angles_to_first_quad(
        simTestInst_few_mol_randAngle125_hr.mol_angles
        ),
    alpha=.4,
    bins=bins
    )
# Out:
# (array([3., 2., 3., 7., 1., 5., 3., 2., 3., 4., 2., 4., 4., 5., 6., 3., 4.,
#         0., 2., 5., 6., 5., 2., 4., 6.]),
#  array([0.00798022, 0.06980552, 0.13163081, 0.19345611, 0.2552814 ,
#         0.31710669, 0.37893199, 0.44075728, 0.50258257, 0.56440787,
#         0.62623316, 0.68805846, 0.74988375, 0.81170904, 0.87353434,
#         0.93535963, 0.99718493, 1.05901022, 1.12083551, 1.18266081,
#         1.2444861 , 1.30631139, 1.36813669, 1.42996198, 1.49178728,
#         1.55361257]),
#  <a list of 25 Patch objects>)

# %%
# locations_125, angles_125 = fixed_ori_mol_placement(mol_grid_pts_1D=6, x_max=125, y_max=125)

locations_randAngle125_shr, randAngle125_shr = fit.random_ori_mol_placement(
    mol_grid_pts_1D=20, 
    x_max=125, 
    y_max=125,
)

simTestInst_few_mol_randAngle125_shr = SimulatedExperiment(
    locations_randAngle125_shr, mol_angle=randAngle125_shr)
simTestInst_few_mol_randAngle125_shr.trial_images = simTestInst_few_mol_randAngle125_shr.calculate_BEM_fields()
# Out:
# starting Matlab...
# given even number of points for Fibonacci lattice,
#   adding 1...
# 1th molecule
# calculating diffracted fields
# 2th molecule
# calculating diffracted fields
# 3th molecule
# calculating diffracted fields
# 4th molecule
# calculating diffracted fields
# 5th molecule
# calculating diffracted fields
# 6th molecule
# calculating diffracted fields
# 7th molecule
# calculating diffracted fields
# 8th molecule
# calculating diffracted fields
# 9th molecule
# calculating diffracted fields
# 10th molecule
# calculating diffracted fields
# 11th molecule
# calculating diffracted fields
# 12th molecule
# calculating diffracted fields
# 13th molecule
# calculating diffracted fields
# 14th molecule
# calculating diffracted fields
# 15th molecule
# calculating diffracted fields
# 16th molecule
# calculating diffracted fields
# 17th molecule
# calculating diffracted fields
# 18th molecule
# calculating diffracted fields
# 19th molecule
# calculating diffracted fields
# 20th molecule
# calculating diffracted fields
# 21th molecule
# calculating diffracted fields
# 22th molecule
# calculating diffracted fields
# 23th molecule
# calculating diffracted fields
# 24th molecule
# calculating diffracted fields
# 25th molecule
# calculating diffracted fields
# 26th molecule
# calculating diffracted fields
# 27th molecule
# calculating diffracted fields
# 28th molecule
# calculating diffracted fields
# 29th molecule
# calculating diffracted fields
# 30th molecule
# calculating diffracted fields
# 31th molecule
# calculating diffracted fields
# 32th molecule
# calculating diffracted fields
# 33th molecule
# calculating diffracted fields
# 34th molecule
# calculating diffracted fields
# 35th molecule
# calculating diffracted fields
# 36th molecule
# calculating diffracted fields
# 37th molecule
# calculating diffracted fields
# 38th molecule
# calculating diffracted fields
# 39th molecule
# calculating diffracted fields
# 40th molecule
# calculating diffracted fields
# 41th molecule
# calculating diffracted fields
# 42th molecule
# calculating diffracted fields
# 43th molecule
# calculating diffracted fields
# 44th molecule
# calculating diffracted fields
# 45th molecule
# calculating diffracted fields
# 46th molecule
# calculating diffracted fields
# 47th molecule
# calculating diffracted fields
# 48th molecule
# calculating diffracted fields
# 49th molecule
# calculating diffracted fields
# 50th molecule
# calculating diffracted fields
# 51th molecule
# calculating diffracted fields
# 52th molecule
# calculating diffracted fields
# 53th molecule
# calculating diffracted fields
# 54th molecule
# calculating diffracted fields
# 55th molecule
# calculating diffracted fields
# 56th molecule
# calculating diffracted fields
# 57th molecule
# calculating diffracted fields
# 58th molecule
# calculating diffracted fields
# 59th molecule
# calculating diffracted fields
# 60th molecule
# calculating diffracted fields
# 61th molecule
# calculating diffracted fields
# 62th molecule
# calculating diffracted fields
# 63th molecule
# calculating diffracted fields
# 64th molecule
# calculating diffracted fields
# 65th molecule
# calculating diffracted fields
# 66th molecule
# calculating diffracted fields
# 67th molecule
# calculating diffracted fields
# 68th molecule
# calculating diffracted fields
# 69th molecule
# calculating diffracted fields
# 70th molecule
# calculating diffracted fields
# 71th molecule
# calculating diffracted fields
# 72th molecule
# calculating diffracted fields
# 73th molecule
# calculating diffracted fields
# 74th molecule
# calculating diffracted fields
# 75th molecule
# calculating diffracted fields
# 76th molecule
# calculating diffracted fields
# 77th molecule
# calculating diffracted fields
# 78th molecule
# calculating diffracted fields
# 79th molecule
# calculating diffracted fields
# 80th molecule
# calculating diffracted fields
# 81th molecule
# calculating diffracted fields
# 82th molecule
# calculating diffracted fields
# 83th molecule
# calculating diffracted fields
# 84th molecule
# calculating diffracted fields
# 85th molecule
# calculating diffracted fields
# 86th molecule
# calculating diffracted fields
# 87th molecule
# calculating diffracted fields
# 88th molecule
# calculating diffracted fields
# 89th molecule
# calculating diffracted fields
# 90th molecule
# calculating diffracted fields
# 91th molecule
# calculating diffracted fields
# 92th molecule
# calculating diffracted fields
# 93th molecule
# calculating diffracted fields
# 94th molecule
# calculating diffracted fields
# 95th molecule
# calculating diffracted fields
# 96th molecule
# calculating diffracted fields
# 97th molecule
# calculating diffracted fields
# 98th molecule
# calculating diffracted fields
# 99th molecule
# calculating diffracted fields
# 100th molecule
# calculating diffracted fields
# 101th molecule
# calculating diffracted fields
# 102th molecule
# calculating diffracted fields
# 103th molecule
# calculating diffracted fields
# 104th molecule
# calculating diffracted fields
# 105th molecule
# calculating diffracted fields
# 106th molecule
# calculating diffracted fields
# 107th molecule
# calculating diffracted fields
# 108th molecule
# calculating diffracted fields
# 109th molecule
# calculating diffracted fields
# 110th molecule
# calculating diffracted fields
# 111th molecule
# calculating diffracted fields
# 112th molecule
# calculating diffracted fields
# 113th molecule
# calculating diffracted fields
# 114th molecule
# calculating diffracted fields
# 115th molecule
# calculating diffracted fields
# 116th molecule
# calculating diffracted fields
# 117th molecule
# calculating diffracted fields
# 118th molecule
# calculating diffracted fields
# 119th molecule
# calculating diffracted fields
# 120th molecule
# calculating diffracted fields
# 121th molecule
# calculating diffracted fields
# 122th molecule
# calculating diffracted fields
# 123th molecule
# calculating diffracted fields
# 124th molecule
# calculating diffracted fields
# 125th molecule
# calculating diffracted fields
# 126th molecule
# calculating diffracted fields
# 127th molecule
# calculating diffracted fields
# 128th molecule
# calculating diffracted fields
# 129th molecule
# calculating diffracted fields
# 130th molecule
# calculating diffracted fields
# 131th molecule
# calculating diffracted fields
# 132th molecule
# calculating diffracted fields
# 133th molecule
# calculating diffracted fields
# 134th molecule
# calculating diffracted fields
# 135th molecule
# calculating diffracted fields
# 136th molecule
# calculating diffracted fields
# 137th molecule
# calculating diffracted fields
# 138th molecule
# calculating diffracted fields
# 139th molecule
# calculating diffracted fields
# 140th molecule
# calculating diffracted fields
# 141th molecule
# calculating diffracted fields
# 142th molecule
# calculating diffracted fields
# 143th molecule
# calculating diffracted fields
# 144th molecule
# calculating diffracted fields
# 145th molecule
# calculating diffracted fields
# 146th molecule
# calculating diffracted fields
# 147th molecule
# calculating diffracted fields
# 148th molecule
# calculating diffracted fields
# 149th molecule
# calculating diffracted fields
# 150th molecule
# calculating diffracted fields
# 151th molecule
# calculating diffracted fields
# 152th molecule
# calculating diffracted fields
# 153th molecule
# calculating diffracted fields
# 154th molecule
# calculating diffracted fields
# 155th molecule
# calculating diffracted fields
# 156th molecule
# calculating diffracted fields
# 157th molecule
# calculating diffracted fields
# 158th molecule
# calculating diffracted fields
# 159th molecule
# calculating diffracted fields
# 160th molecule
# calculating diffracted fields
# 161th molecule
# calculating diffracted fields
# 162th molecule
# calculating diffracted fields
# 163th molecule
# calculating diffracted fields
# 164th molecule
# calculating diffracted fields
# 165th molecule
# calculating diffracted fields
# 166th molecule
# calculating diffracted fields
# 167th molecule
# calculating diffracted fields
# 168th molecule
# calculating diffracted fields
# 169th molecule
# calculating diffracted fields
# 170th molecule
# calculating diffracted fields
# 171th molecule
# calculating diffracted fields
# 172th molecule
# calculating diffracted fields
# 173th molecule
# calculating diffracted fields
# 174th molecule
# calculating diffracted fields
# 175th molecule
# calculating diffracted fields
# 176th molecule
# calculating diffracted fields
# 177th molecule
# calculating diffracted fields
# 178th molecule
# calculating diffracted fields
# 179th molecule
# calculating diffracted fields
# 180th molecule
# calculating diffracted fields
# 181th molecule
# calculating diffracted fields
# 182th molecule
# calculating diffracted fields
# 183th molecule
# calculating diffracted fields
# 184th molecule
# calculating diffracted fields
# 185th molecule
# calculating diffracted fields
# 186th molecule
# calculating diffracted fields
# 187th molecule
# calculating diffracted fields
# 188th molecule
# calculating diffracted fields
# 189th molecule
# calculating diffracted fields
# 190th molecule
# calculating diffracted fields
# 191th molecule
# calculating diffracted fields
# 192th molecule
# calculating diffracted fields
# 193th molecule
# calculating diffracted fields
# 194th molecule
# calculating diffracted fields
# 195th molecule
# calculating diffracted fields
# 196th molecule
# calculating diffracted fields
# 197th molecule
# calculating diffracted fields
# 198th molecule
# calculating diffracted fields
# 199th molecule
# calculating diffracted fields
# 200th molecule
# calculating diffracted fields
# 201th molecule
# calculating diffracted fields
# 202th molecule
# calculating diffracted fields
# 203th molecule
# calculating diffracted fields
# 204th molecule
# calculating diffracted fields
# 205th molecule
# calculating diffracted fields
# 206th molecule
# calculating diffracted fields
# 207th molecule
# calculating diffracted fields
# 208th molecule
# calculating diffracted fields
# 209th molecule
# calculating diffracted fields
# 210th molecule
# calculating diffracted fields
# 211th molecule
# calculating diffracted fields
# 212th molecule
# calculating diffracted fields
# 213th molecule
# calculating diffracted fields
# 214th molecule
# calculating diffracted fields
# 215th molecule
# calculating diffracted fields
# 216th molecule
# calculating diffracted fields
# 217th molecule
# calculating diffracted fields
# 218th molecule
# calculating diffracted fields
# 219th molecule
# calculating diffracted fields
# 220th molecule
# calculating diffracted fields
# 221th molecule
# calculating diffracted fields
# 222th molecule
# calculating diffracted fields
# 223th molecule
# calculating diffracted fields
# 224th molecule
# calculating diffracted fields
# 225th molecule
# calculating diffracted fields
# 226th molecule
# calculating diffracted fields
# 227th molecule
# calculating diffracted fields
# 228th molecule
# calculating diffracted fields
# 229th molecule
# calculating diffracted fields
# 230th molecule
# calculating diffracted fields
# 231th molecule
# calculating diffracted fields
# 232th molecule
# calculating diffracted fields
# 233th molecule
# calculating diffracted fields
# 234th molecule
# calculating diffracted fields
# 235th molecule
# calculating diffracted fields
# 236th molecule
# calculating diffracted fields
# 237th molecule
# calculating diffracted fields
# 238th molecule
# calculating diffracted fields
# 239th molecule
# calculating diffracted fields
# 240th molecule
# calculating diffracted fields
# 241th molecule
# calculating diffracted fields
# 242th molecule
# calculating diffracted fields
# 243th molecule
# calculating diffracted fields
# 244th molecule
# calculating diffracted fields
# 245th molecule
# calculating diffracted fields
# 246th molecule
# calculating diffracted fields
# 247th molecule
# calculating diffracted fields
# 248th molecule
# calculating diffracted fields
# 249th molecule
# calculating diffracted fields
# 250th molecule
# calculating diffracted fields
# 251th molecule
# calculating diffracted fields
# 252th molecule
# calculating diffracted fields
# 253th molecule
# calculating diffracted fields
# 254th molecule
# calculating diffracted fields
# 255th molecule
# calculating diffracted fields
# 256th molecule
# calculating diffracted fields
# 257th molecule
# calculating diffracted fields
# 258th molecule
# calculating diffracted fields
# 259th molecule
# calculating diffracted fields
# 260th molecule
# calculating diffracted fields
# 261th molecule
# calculating diffracted fields
# 262th molecule
# calculating diffracted fields
# 263th molecule
# calculating diffracted fields
# 264th molecule
# calculating diffracted fields
# 265th molecule
# calculating diffracted fields
# 266th molecule
# calculating diffracted fields
# 267th molecule
# calculating diffracted fields
# 268th molecule
# calculating diffracted fields
# 269th molecule
# calculating diffracted fields
# 270th molecule
# calculating diffracted fields
# 271th molecule
# calculating diffracted fields
# 272th molecule
# calculating diffracted fields
# 273th molecule
# calculating diffracted fields
# 274th molecule
# calculating diffracted fields
# 275th molecule
# calculating diffracted fields
# 276th molecule
# calculating diffracted fields
# 277th molecule
# calculating diffracted fields
# 278th molecule
# calculating diffracted fields
# 279th molecule
# calculating diffracted fields
# 280th molecule
# calculating diffracted fields
# 281th molecule
# calculating diffracted fields
# 282th molecule
# calculating diffracted fields
# 283th molecule
# calculating diffracted fields
# 284th molecule
# calculating diffracted fields
# 285th molecule
# calculating diffracted fields
# 286th molecule
# calculating diffracted fields
# 287th molecule
# calculating diffracted fields
# 288th molecule
# calculating diffracted fields
# 289th molecule
# calculating diffracted fields
# 290th molecule
# calculating diffracted fields
# 291th molecule
# calculating diffracted fields
# 292th molecule
# calculating diffracted fields
# 293th molecule
# calculating diffracted fields
# 294th molecule
# calculating diffracted fields
# 295th molecule
# calculating diffracted fields
# 296th molecule
# calculating diffracted fields
# 297th molecule
# calculating diffracted fields
# 298th molecule
# calculating diffracted fields
# 299th molecule
# calculating diffracted fields
# 300th molecule
# calculating diffracted fields
# 301th molecule
# calculating diffracted fields
# 302th molecule
# calculating diffracted fields
# 303th molecule
# calculating diffracted fields
# 304th molecule
# calculating diffracted fields
# 305th molecule
# calculating diffracted fields
# 306th molecule
# calculating diffracted fields
# 307th molecule
# calculating diffracted fields
# 308th molecule
# calculating diffracted fields
# 309th molecule
# calculating diffracted fields
# 310th molecule
# calculating diffracted fields
# 311th molecule
# calculating diffracted fields
# 312th molecule
# calculating diffracted fields
# 313th molecule
# calculating diffracted fields
# 314th molecule
# calculating diffracted fields
# 315th molecule
# calculating diffracted fields
# 316th molecule
# calculating diffracted fields
# 317th molecule
# calculating diffracted fields
# 318th molecule
# calculating diffracted fields
# 319th molecule
# calculating diffracted fields
# 320th molecule
# calculating diffracted fields
# 321th molecule
# calculating diffracted fields
# 322th molecule
# calculating diffracted fields
# 323th molecule
# calculating diffracted fields
# 324th molecule
# calculating diffracted fields
# 325th molecule
# calculating diffracted fields
# 326th molecule
# calculating diffracted fields
# 327th molecule
# calculating diffracted fields
# 328th molecule
# calculating diffracted fields
# 329th molecule
# calculating diffracted fields
# 330th molecule
# calculating diffracted fields
# 331th molecule
# calculating diffracted fields
# 332th molecule
# calculating diffracted fields
# 333th molecule
# calculating diffracted fields
# 334th molecule
# calculating diffracted fields
# 335th molecule
# calculating diffracted fields
# 336th molecule
# calculating diffracted fields
# 337th molecule
# calculating diffracted fields
# 338th molecule
# calculating diffracted fields
# 339th molecule
# calculating diffracted fields
# 340th molecule
# calculating diffracted fields
# 341th molecule
# calculating diffracted fields
# 342th molecule
# calculating diffracted fields
# 343th molecule
# calculating diffracted fields
# 344th molecule
# calculating diffracted fields
# 345th molecule
# calculating diffracted fields
# 346th molecule
# calculating diffracted fields
# 347th molecule
# calculating diffracted fields
# 348th molecule
# calculating diffracted fields
# 349th molecule
# calculating diffracted fields
# 350th molecule
# calculating diffracted fields
# 351th molecule
# calculating diffracted fields
# 352th molecule
# calculating diffracted fields
# 353th molecule
# calculating diffracted fields
# 354th molecule
# calculating diffracted fields
# 355th molecule
# calculating diffracted fields
# 356th molecule
# calculating diffracted fields
# 357th molecule
# calculating diffracted fields
# 358th molecule
# calculating diffracted fields
# 359th molecule
# calculating diffracted fields
# 360th molecule
# calculating diffracted fields
# 361th molecule
# calculating diffracted fields
# 362th molecule
# calculating diffracted fields
# 363th molecule
# calculating diffracted fields
# 364th molecule
# calculating diffracted fields

# %%
simTestInst_few_mol_randAngle125_shr.plot_mispol_map_wMisloc()

# %%
bins=20

plt.hist(
    simTestInst_few_mol_randAngle125_shr.mispol_angle,
    bins=bins)
plt.hist(
    map_angles_to_first_quad(
        simTestInst_few_mol_randAngle125_shr.mol_angles
        ),
    alpha=.5,
    bins=bins
    )
# Out:
# (array([16., 18., 22., 16., 17., 20., 19., 15., 19., 13., 16., 18., 19.,
#         22., 24., 14., 19., 18., 21., 18.]),
#  array([0.00435244, 0.08262879, 0.16090513, 0.23918147, 0.31745782,
#         0.39573416, 0.47401051, 0.55228685, 0.63056319, 0.70883954,
#         0.78711588, 0.86539223, 0.94366857, 1.02194491, 1.10022126,
#         1.1784976 , 1.25677394, 1.33505029, 1.41332663, 1.49160298,
#         1.56987932]),
#  <a list of 20 Patch objects>)

# %%
save_sim_exp_inst(simTestInst_few_mol_randAngle125_shr, 'simInst_randAngle125_shr.txt')

# %%
loaded_randAngle125_shr = LoadedSimExp('simInst_randAngle125_shr.txt')

# %% [markdown]
# Running fits

# %%
## Initial guess defaults to position of maximum intensity. 
randAngle125_shr_fit_instance_few_mol = fit.FitModelToData(
    loaded_randAngle125_shr.BEM_images, 
    ini_guess='gauss'
    )
fit_loaded_randAngle125_shr = randAngle125_shr_fit_instance_few_mol.fit_model_to_image_data(
    check_ini=True)
# Out:
#  initial guess for molecule 0 location: (0.5226425576809655,5.4197053909852615)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  0.5226425576809655
#  ini_y,  5.4197053909852615
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? True
# Params modified, OG params: (0.5226425576809655, 5.4197053909852615, array([0.7500084]))
# but now they are: (5.806460879963864, 60.21191131720819, array([0.7500084]))
#
#  initial guess for molecule 1 location: (0.3743111990046317,74.72217495325634)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  0.3743111990046317
#  ini_y,  74.72217495325634
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 2 location: (0.8603051968154032,9.959567158757414)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  0.8603051968154032
#  ini_y,  9.959567158757414
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? True
# Params modified, OG params: (0.8603051968154032, 9.959567158757414, array([0.63653495]))
# but now they are: (5.22699730405936, 60.51181706344313, array([0.63653495]))
#
#  initial guess for molecule 3 location: (2.0147152316527337,19.36445413176605)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  2.0147152316527337
#  ini_y,  19.36445413176605
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? True
# Params modified, OG params: (2.0147152316527337, 19.36445413176605, array([1.48960504]))
# but now they are: (6.239019492668406, 59.966393709081615, array([1.48960504]))
#
#  initial guess for molecule 4 location: (1.4446929088746177,18.850519982638275)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  1.4446929088746177
#  ini_y,  18.850519982638275
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? True
# Params modified, OG params: (1.4446929088746177, 18.850519982638275, array([0.50607882]))
# but now they are: (4.657726087966693, 60.77454811020434, array([0.50607882]))
#
#  initial guess for molecule 5 location: (-2.6104212040137136,28.760487324424123)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  -2.6104212040137136
#  ini_y,  28.760487324424123
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? True
# Params modified, OG params: (-2.6104212040137136, 28.760487324424123, array([1.02679051]))
# but now they are: (-5.480751799122009, 60.38454346164409, array([1.02679051]))
#
#  initial guess for molecule 6 location: (4.477820615308884,47.22615887244006)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  4.477820615308884
#  ini_y,  47.22615887244006
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? True
# Params modified, OG params: (4.477820615308884, 47.22615887244006, array([0.22812967]))
# but now they are: (5.713840197110638, 60.26206677371932, array([0.22812967]))
#
#  initial guess for molecule 7 location: (6.079621021371914,69.0314807716756)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  6.079621021371914
#  ini_y,  69.0314807716756
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 8 location: (-4.93408162774656,116.89196790400219)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  -4.93408162774656
#  ini_y,  116.89196790400219
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 9 location: (3.8549080264062767,125.99900424365674)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  3.8549080264062767
#  ini_y,  125.99900424365674
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 10 location: (0.05322569883932564,16.044352444013978)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  0.05322569883932564
#  ini_y,  16.044352444013978
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? True
# Params modified, OG params: (0.05322569883932564, 16.044352444013978, array([0.41489814]))
# but now they are: (0.20493330499098145, 61.77508693154765, array([0.41489814]))
#
#  initial guess for molecule 11 location: (0.8796541118906348,6.771169990217122)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  0.8796541118906348
#  ini_y,  6.771169990217122
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? True
# Params modified, OG params: (0.8796541118906348, 6.771169990217122, array([0.79713957]))
# but now they are: (7.667511224660697, 59.02095062397691, array([0.79713957]))
#
#  initial guess for molecule 12 location: (-0.024483978872462817,8.798714137813668)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  -0.024483978872462817
#  ini_y,  8.798714137813668
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? True
# Params modified, OG params: (-0.024483978872462817, 8.798714137813668, array([0.20892223]))
# but now they are: (-0.17190169703497263, 61.77565745725104, array([0.20892223]))
#
#  initial guess for molecule 13 location: (-1.0326747100782274,23.529382736483868)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  -1.0326747100782274
#  ini_y,  23.529382736483868
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? True
# Params modified, OG params: (-1.0326747100782274, 23.529382736483868, array([0.34657385]))
# but now they are: (-2.696646912432186, 61.44281126335312, array([0.34657385]))
#
#  initial guess for molecule 14 location: (1.1602425248487693,16.87364925641344)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  1.1602425248487693
#  ini_y,  16.87364925641344
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? True
# Params modified, OG params: (1.1602425248487693, 16.87364925641344, array([0.40876591]))
# but now they are: (4.192076033742567, 60.966236915690196, array([0.40876591]))
#
#  initial guess for molecule 15 location: (5.677681718198467,96.13481747137426)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  5.677681718198467
#  ini_y,  96.13481747137426
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 16 location: (-1.1897824762009812,74.2547428689149)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  -1.1897824762009812
#  ini_y,  74.2547428689149
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 17 location: (10.23374438973619,113.8450568421866)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  10.23374438973619
#  ini_y,  113.8450568421866
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 18 location: (6.202400927182755,62.022000299856934)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  6.202400927182755
#  ini_y,  62.022000299856934
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 19 location: (-1.4857672236166783,116.40198065884955)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  -1.4857672236166783
#  ini_y,  116.40198065884955
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 20 location: (0.2491840283038581,3.1854209022454487)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  0.2491840283038581
#  ini_y,  3.1854209022454487
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? True
# Params modified, OG params: (0.2491840283038581, 3.1854209022454487, array([0.92726293]))
# but now they are: (4.750975830397189, 60.733658650688845, array([0.92726293]))
#
#  initial guess for molecule 21 location: (20.435307283979256,70.92348676725724)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  20.435307283979256
#  ini_y,  70.92348676725724
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 22 location: (1.0941524872443769,19.24466222400379)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  1.0941524872443769
#  ini_y,  19.24466222400379
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? True
# Params modified, OG params: (1.0941524872443769, 19.24466222400379, array([0.82886306]))
# but now they are: (3.4806108814812684, 61.21923728930708, array([0.82886306]))
#
#  initial guess for molecule 23 location: (0.3950604488476723,9.56723537584637)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  0.3950604488476723
#  ini_y,  9.56723537584637
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? True
# Params modified, OG params: (0.3950604488476723, 9.56723537584637, array([0.33472302]))
# but now they are: (2.538734547752692, 61.48089753350142, array([0.33472302]))
#
#  initial guess for molecule 24 location: (5.986663676460977,27.49981211635756)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  5.986663676460977
#  ini_y,  27.49981211635756
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? True
# Params modified, OG params: (5.986663676460977, 27.49981211635756, array([1.24657597]))
# but now they are: (11.94145827456396, 54.85323323523645, array([1.24657597]))
#
#  initial guess for molecule 25 location: (1.7655852751983694,44.78730926811828)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  1.7655852751983694
#  ini_y,  44.78730926811828
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? True
# Params modified, OG params: (1.7655852751983694, 44.78730926811828, array([1.43506538]))
# but now they are: (2.4246998243389557, 61.50695887674947, array([1.43506538]))
#
#  initial guess for molecule 26 location: (14.279970424333987,73.90440478207329)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  14.279970424333987
#  ini_y,  73.90440478207329
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 27 location: (15.144087526897174,106.06546566651951)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  15.144087526897174
#  ini_y,  106.06546566651951
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 28 location: (9.877416770463395,56.06278607110857)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  9.877416770463395
#  ini_y,  56.06278607110857
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? True
# Params modified, OG params: (9.877416770463395, 56.06278607110857, array([1.35608884]))
# but now they are: (10.037648874086733, 56.97224026909492, array([1.35608884]))
#
#  initial guess for molecule 29 location: (15.927820068672899,120.4411390903356)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  15.927820068672899
#  ini_y,  120.4411390903356
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 30 location: (20.840134251001473,126.34532243856643)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  20.840134251001473
#  ini_y,  126.34532243856643
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 31 location: (-0.0936194084145765,2.5563356248481792)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  -0.0936194084145765
#  ini_y,  2.5563356248481792
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? True
# Params modified, OG params: (-0.0936194084145765, 2.5563356248481792, array([1.54256459]))
# but now they are: (-2.2538856901977864, 61.54373736985767, array([1.54256459]))
#
#  initial guess for molecule 32 location: (0.16160377747742435,3.121456451649644)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  0.16160377747742435
#  ini_y,  3.121456451649644
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? True
# Params modified, OG params: (0.16160377747742435, 3.121456451649644, array([0.41531669]))
# but now they are: (3.1743143001052223, 61.31344208839017, array([0.41531669]))
#
#  initial guess for molecule 33 location: (13.547057154467947,40.18299010626539)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  13.547057154467947
#  ini_y,  40.18299010626539
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? True
# Params modified, OG params: (13.547057154467947, 40.18299010626539, array([0.78145203]))
# but now they are: (16.245229907650717, 48.18625220296216, array([0.78145203]))
#
#  initial guess for molecule 34 location: (0.9216646513542859,5.116653803414921)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  0.9216646513542859
#  ini_y,  5.116653803414921
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? True
# Params modified, OG params: (0.9216646513542859, 5.116653803414921, array([0.55698705]))
# but now they are: (10.227862483473446, 56.78033913959085, array([0.55698705]))
#
#  initial guess for molecule 35 location: (1.1532871869359764,7.061228580694848)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  1.1532871869359764
#  ini_y,  7.061228580694848
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? True
# Params modified, OG params: (1.1532871869359764, 7.061228580694848, array([0.7764266]))
# but now they are: (9.404480605213479, 57.58078992670734, array([0.7764266]))
#
#  initial guess for molecule 36 location: (1.0881279788296987,10.333270015294556)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  1.0881279788296987
#  ini_y,  10.333270015294556
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? True
# Params modified, OG params: (1.0881279788296987, 10.333270015294556, array([0.87639601]))
# but now they are: (6.310218193709034, 59.92419064635122, array([0.87639601]))
#
#  initial guess for molecule 37 location: (2.0479040302767717,13.802973231860738)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  2.0479040302767717
#  ini_y,  13.802973231860738
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? True
# Params modified, OG params: (2.0479040302767717, 13.802973231860738, array([0.2574608]))
# but now they are: (8.642790398786891, 58.25282960496724, array([0.2574608]))
#
#  initial guess for molecule 38 location: (4.241353160595496,20.44401772502739)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  4.241353160595496
#  ini_y,  20.44401772502739
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? True
# Params modified, OG params: (4.241353160595496, 20.44401772502739, array([1.31163973]))
# but now they are: (11.492151491645776, 55.39405465611338, array([1.31163973]))
#
#  initial guess for molecule 39 location: (2.065841592180387,37.4011497743252)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  2.065841592180387
#  ini_y,  37.4011497743252
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? True
# Params modified, OG params: (2.065841592180387, 37.4011497743252, array([0.72534624]))
# but now they are: (3.383135462092738, 61.25017358712977, array([0.72534624]))
#
#  initial guess for molecule 40 location: (21.16936358946983,103.65401935746159)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  21.16936358946983
#  ini_y,  103.65401935746159
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 41 location: (27.28995568572493,114.62865295754253)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  27.28995568572493
#  ini_y,  114.62865295754253
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 42 location: (27.372201385570165,113.75837651871235)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  27.372201385570165
#  ini_y,  113.75837651871235
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 43 location: (10.314667915013095,113.50383110174423)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  10.314667915013095
#  ini_y,  113.50383110174423
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 44 location: (13.74859308589413,-1.6413746220701084)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  13.74859308589413
#  ini_y,  -1.6413746220701084
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? True
# Params modified, OG params: (13.74859308589413, -1.6413746220701084, array([0.35056823]))
# but now they are: (25.92753560891622, -3.095356644525079, array([0.35056823]))
#
#  initial guess for molecule 45 location: (-0.33269654181019653,0.5931178402322786)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  -0.33269654181019653
#  ini_y,  0.5931178402322786
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? True
# Params modified, OG params: (-0.33269654181019653, 0.5931178402322786, array([0.12924552]))
# but now they are: (-20.776517729225475, 37.039529344239746, array([0.12924552]))
#
#  initial guess for molecule 46 location: (114.33985664728924,29.691760200810226)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  114.33985664728924
#  ini_y,  29.691760200810226
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 47 location: (29.184067110778873,17.413087839795594)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  29.184067110778873
#  ini_y,  17.413087839795594
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 48 location: (10.59679195350848,10.07790931396365)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  10.59679195350848
#  ini_y,  10.07790931396365
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? True
# Params modified, OG params: (10.59679195350848, 10.07790931396365, array([0.88046126]))
# but now they are: (24.106323532401767, 22.92593301052566, array([0.88046126]))
#
#  initial guess for molecule 49 location: (1.7596388309834006,3.252095729420144)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  1.7596388309834006
#  ini_y,  3.252095729420144
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? True
# Params modified, OG params: (1.7596388309834006, 3.252095729420144, array([1.50825782]))
# but now they are: (20.502992613009408, 37.892829791575366, array([1.50825782]))
#
#  initial guess for molecule 50 location: (4.368909261832334,11.137455341689773)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  4.368909261832334
#  ini_y,  11.137455341689773
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? True
# Params modified, OG params: (4.368909261832334, 11.137455341689773, array([0.81190063]))
# but now they are: (17.71460713543257, 45.159016597134084, array([0.81190063]))
#
#  initial guess for molecule 51 location: (0.5522932211616253,2.686870756805325)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  0.5522932211616253
#  ini_y,  2.686870756805325
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? True
# Params modified, OG params: (0.5522932211616253, 2.686870756805325, array([0.42971866]))
# but now they are: (11.406886774713692, 55.4937654977996, array([0.42971866]))
#
#  initial guess for molecule 52 location: (1.1464225026097232,3.790303481921268)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  1.1464225026097232
#  ini_y,  3.790303481921268
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? True
# Params modified, OG params: (1.1464225026097232, 3.790303481921268, array([1.15094665]))
# but now they are: (15.165368771135599, 50.13976080110464, array([1.15094665]))
#
#  initial guess for molecule 53 location: (7.88356481608879,23.143300528765526)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  7.88356481608879
#  ini_y,  23.143300528765526
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? True
# Params modified, OG params: (7.88356481608879, 23.143300528765526, array([0.96483843]))
# but now they are: (16.347423732617067, 47.99013506465087, array([0.96483843]))
#
#  initial guess for molecule 54 location: (42.744924382417906,73.68715053261485)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  42.744924382417906
#  ini_y,  73.68715053261485
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 55 location: (10.11898006826895,26.605994564622485)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  10.11898006826895
#  ini_y,  26.605994564622485
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? True
# Params modified, OG params: (10.11898006826895, 26.605994564622485, array([0.97549018]))
# but now they are: (17.420153723278826, 45.80308609657454, array([0.97549018]))
#
#  initial guess for molecule 56 location: (3.214764208754717,22.24480476758735)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  3.214764208754717
#  ini_y,  22.24480476758735
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? True
# Params modified, OG params: (3.214764208754717, 22.24480476758735, array([0.98592189]))
# but now they are: (8.442552399988411, 58.41888166056697, array([0.98592189]))
#
#  initial guess for molecule 57 location: (21.18404516571199,69.86673799120125)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  21.18404516571199
#  ini_y,  69.86673799120125
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 58 location: (7.5771275323283325,25.674725970483102)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  7.5771275323283325
#  ini_y,  25.674725970483102
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? True
# Params modified, OG params: (7.5771275323283325, 25.674725970483102, array([0.64065394]))
# but now they are: (14.919846489399498, 50.555169950966516, array([0.64065394]))
#
#  initial guess for molecule 59 location: (6.317063661294852,49.70767276348527)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  6.317063661294852
#  ini_y,  49.70767276348527
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? True
# Params modified, OG params: (6.317063661294852, 49.70767276348527, array([0.60074716]))
# but now they are: (7.514760439846155, 59.13210201261291, array([0.60074716]))
#
#  initial guess for molecule 60 location: (14.530301889941208,50.5225880165213)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  14.530301889941208
#  ini_y,  50.5225880165213
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? True
# Params modified, OG params: (14.530301889941208, 50.5225880165213, array([1.25849486]))
# but now they are: (14.662013803233293, 50.980556941222744, array([1.25849486]))
#
#  initial guess for molecule 61 location: (8.57977607833534,50.519838727441034)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  8.57977607833534
#  ini_y,  50.519838727441034
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? True
# Params modified, OG params: (8.57977607833534, 50.519838727441034, array([0.49015686]))
# but now they are: (9.727232912264961, 57.276347716434564, array([0.49015686]))
#
#  initial guess for molecule 62 location: (16.092388853429256,103.63522814776526)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  16.092388853429256
#  ini_y,  103.63522814776526
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 63 location: (11.082526699208673,97.23298851255268)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  11.082526699208673
#  ini_y,  97.23298851255268
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 64 location: (-0.5030745288390216,0.7308740962288737)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  -0.5030745288390216
#  ini_y,  0.7308740962288737
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? True
# Params modified, OG params: (-0.5030745288390216, 0.7308740962288737, array([0.8101075]))
# but now they are: (-22.157275230637506, 32.190416291715216, array([0.8101075]))
#
#  initial guess for molecule 65 location: (7.322464805750812,2.488771523212885)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  7.322464805750812
#  ini_y,  2.488771523212885
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? True
# Params modified, OG params: (7.322464805750812, 2.488771523212885, array([0.5848327]))
# but now they are: (25.699341798953963, 8.734735055922613, array([0.5848327]))
#
#  initial guess for molecule 66 location: (-0.10635648765799743,1.0065042262480306)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  -0.10635648765799743
#  ini_y,  1.0065042262480306
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? True
# Params modified, OG params: (-0.10635648765799743, 1.0065042262480306, array([0.3410374]))
# but now they are: (-6.330839123028224, 59.911872546170464, array([0.3410374]))
#
#  initial guess for molecule 67 location: (15.669600368335788,8.981034863967448)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  15.669600368335788
#  ini_y,  8.981034863967448
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? True
# Params modified, OG params: (15.669600368335788, 8.981034863967448, array([1.38855808]))
# but now they are: (25.23843077828051, 14.465412097528805, array([1.38855808]))
#
#  initial guess for molecule 68 location: (2.28415223549718,1.906975316416703)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  2.28415223549718
#  ini_y,  1.906975316416703
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? True
# Params modified, OG params: (2.28415223549718, 1.906975316416703, array([1.01781839]))
# but now they are: (24.49633016596031, 20.451306284807327, array([1.01781839]))
#
#  initial guess for molecule 69 location: (2.2185488637485986,3.5930961451276677)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  2.2185488637485986
#  ini_y,  3.5930961451276677
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? True
# Params modified, OG params: (2.2185488637485986, 3.5930961451276677, array([1.03334052]))
# but now they are: (21.461327490891716, 34.75813146912217, array([1.03334052]))
#
#  initial guess for molecule 70 location: (0.588994609492642,2.7958665647489718)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  0.588994609492642
#  ini_y,  2.7958665647489718
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? True
# Params modified, OG params: (0.588994609492642, 2.7958665647489718, array([1.45211022]))
# but now they are: (11.634222077530435, 55.22585773993913, array([1.45211022]))
#
#  initial guess for molecule 71 location: (0.8651266785818742,3.829412367359162)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  0.8651266785818742
#  ini_y,  3.829412367359162
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? True
# Params modified, OG params: (0.8651266785818742, 3.829412367359162, array([0.68900228]))
# but now they are: (12.292603361107888, 54.412201708113635, array([0.68900228]))
#
#  initial guess for molecule 72 location: (1.1776051710305435,4.313511978319108)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  1.1776051710305435
#  ini_y,  4.313511978319108
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? True
# Params modified, OG params: (1.1776051710305435, 4.313511978319108, array([0.17849723]))
# but now they are: (14.142826494916472, 51.80450374527841, array([0.17849723]))
#
#  initial guess for molecule 73 location: (1.9828195902463441,5.804640740917707)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  1.9828195902463441
#  ini_y,  5.804640740917707
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? True
# Params modified, OG params: (1.9828195902463441, 5.804640740917707, array([0.75650093]))
# but now they are: (16.374913253009808, 47.93703323538628, array([0.75650093]))
#
#  initial guess for molecule 74 location: (52.86665678365589,72.99765959283538)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  52.86665678365589
#  ini_y,  72.99765959283538
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 75 location: (47.26785702112287,75.6378125922046)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  47.26785702112287
#  ini_y,  75.6378125922046
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 76 location: (14.72724378947979,33.545555670837345)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  14.72724378947979
#  ini_y,  33.545555670837345
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? True
# Params modified, OG params: (14.72724378947979, 33.545555670837345, array([0.40054683]))
# but now they are: (18.753716878764834, 42.71701226546678, array([0.40054683]))
#
#  initial guess for molecule 77 location: (47.59003473376522,90.4380970008606)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  47.59003473376522
#  ini_y,  90.4380970008606
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 78 location: (5.431714801619397,24.781319898692292)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  5.431714801619397
#  ini_y,  24.781319898692292
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? True
# Params modified, OG params: (5.431714801619397, 24.781319898692292, array([0.81421322]))
# but now they are: (12.005648547985864, 54.77382891498785, array([0.81421322]))
#
#  initial guess for molecule 79 location: (23.266787411490252,80.66796531319527)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  23.266787411490252
#  ini_y,  80.66796531319527
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 80 location: (8.699807904883762,43.38562172988775)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  8.699807904883762
#  ini_y,  43.38562172988775
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? True
# Params modified, OG params: (8.699807904883762, 43.38562172988775, array([1.10977507]))
# but now they are: (11.180061979985313, 55.75455748948782, array([1.10977507]))
#
#  initial guess for molecule 81 location: (14.408932302871277,56.281250962837404)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  14.408932302871277
#  ini_y,  56.281250962837404
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 82 location: (18.20625302838865,71.89939886474315)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  18.20625302838865
#  ini_y,  71.89939886474315
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 83 location: (45.076481285565656,129.1206703170892)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  45.076481285565656
#  ini_y,  129.1206703170892
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 84 location: (-0.35909324371955276,0.46809973203815186)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  -0.35909324371955276
#  ini_y,  0.46809973203815186
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? True
# Params modified, OG params: (-0.35909324371955276, 0.46809973203815186, array([0.21854257]))
# but now they are: (-22.76793807044494, 29.679382434051096, array([0.21854257]))
#
#  initial guess for molecule 85 location: (4.3842242137262994,2.0638986693946455)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  4.3842242137262994
#  ini_y,  2.0638986693946455
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? True
# Params modified, OG params: (4.3842242137262994, 2.0638986693946455, array([0.70359313]))
# but now they are: (25.466622726614798, 11.988558567528807, array([0.70359313]))
#
#  initial guess for molecule 86 location: (3.9375705593088024,2.7188499378935074)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  3.9375705593088024
#  ini_y,  2.7188499378935074
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? True
# Params modified, OG params: (3.9375705593088024, 2.7188499378935074, array([0.03977727]))
# but now they are: (24.931812616121253, 17.215147300068423, array([0.03977727]))
#
#  initial guess for molecule 87 location: (14.978999388335598,5.900643810065506)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  14.978999388335598
#  ini_y,  5.900643810065506
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? True
# Params modified, OG params: (14.978999388335598, 5.900643810065506, array([0.45132193]))
# but now they are: (25.611601046037592, 10.089120859157822, array([0.45132193]))
#
#  initial guess for molecule 88 location: (1.6529013016785863,2.012311406406065)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  1.6529013016785863
#  ini_y,  2.012311406406065
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? True
# Params modified, OG params: (1.6529013016785863, 2.012311406406065, array([0.16233383]))
# but now they are: (23.111254239005913, 28.136610742742096, array([0.16233383]))
#
#  initial guess for molecule 89 location: (0.9360757022161015,2.7323775998281516)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  0.9360757022161015
#  ini_y,  2.7323775998281516
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? True
# Params modified, OG params: (0.9360757022161015, 2.7323775998281516, array([1.15491212]))
# but now they are: (16.403565411010728, 47.88152772286604, array([1.15491212]))
#
#  initial guess for molecule 90 location: (1.2897898212262626,3.704905575040368)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  1.2897898212262626
#  ini_y,  3.704905575040368
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? True
# Params modified, OG params: (1.2897898212262626, 3.704905575040368, array([1.24296267]))
# but now they are: (16.56148974094574, 47.572677859922244, array([1.24296267]))
#
#  initial guess for molecule 91 location: (35.70016918361154,36.83393980178169)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  35.70016918361154
#  ini_y,  36.83393980178169
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 92 location: (9.07980660786705,13.16886133382775)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  9.07980660786705
#  ini_y,  13.16886133382775
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? True
# Params modified, OG params: (9.07980660786705, 13.16886133382775, array([1.31792967]))
# but now they are: (22.16749665305062, 32.15054044093675, array([1.31792967]))
#
#  initial guess for molecule 93 location: (46.573867630323086,56.28733067009319)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  46.573867630323086
#  ini_y,  56.28733067009319
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 94 location: (63.16178609129323,73.52384967849441)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  63.16178609129323
#  ini_y,  73.52384967849441
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 95 location: (5.467732899532644,13.178505667418703)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  5.467732899532644
#  ini_y,  13.178505667418703
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? True
# Params modified, OG params: (5.467732899532644, 13.178505667418703, array([1.37919566]))
# but now they are: (18.239162505660808, 43.96061601150393, array([1.37919566]))
#
#  initial guess for molecule 96 location: (49.92017657251325,78.6762777933815)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  49.92017657251325
#  ini_y,  78.6762777933815
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 97 location: (11.007476277417949,39.37363936495415)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  11.007476277417949
#  ini_y,  39.37363936495415
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? True
# Params modified, OG params: (11.007476277417949, 39.37363936495415, array([0.97899093]))
# but now they are: (14.379284121183057, 51.43456438558681, array([0.97899093]))
#
#  initial guess for molecule 98 location: (14.024997205117575,34.208251434370325)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  14.024997205117575
#  ini_y,  34.208251434370325
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? True
# Params modified, OG params: (14.024997205117575, 34.208251434370325, array([0.76808141]))
# but now they are: (18.128920521091185, 44.21809590043365, array([0.76808141]))
#
#  initial guess for molecule 99 location: (36.59813808573459,80.586311081301)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  36.59813808573459
#  ini_y,  80.586311081301
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 100 location: (33.1855200867607,94.37172208567199)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  33.1855200867607
#  ini_y,  94.37172208567199
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 101 location: (34.22061321863832,103.38057259444683)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  34.22061321863832
#  ini_y,  103.38057259444683
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 102 location: (38.53426202405147,103.26634600581609)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  38.53426202405147
#  ini_y,  103.26634600581609
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 103 location: (29.91047459386737,97.70387343614219)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  29.91047459386737
#  ini_y,  97.70387343614219
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 104 location: (2.2956036907923147,-0.3739921803484182)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  2.2956036907923147
#  ini_y,  -0.3739921803484182
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? True
# Params modified, OG params: (2.2956036907923147, -0.3739921803484182, array([1.04825547]))
# but now they are: (25.899519010804603, -4.219464197447342, array([1.04825547]))
#
#  initial guess for molecule 105 location: (11.509648224092748,3.264391067835219)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  11.509648224092748
#  ini_y,  3.264391067835219
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? True
# Params modified, OG params: (11.509648224092748, 3.264391067835219, array([0.41559892]))
# but now they are: (25.777702837329336, 7.311127260635405, array([0.41559892]))
#
#  initial guess for molecule 106 location: (0.8651592629981364,1.6648210946390212)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  0.8651592629981364
#  ini_y,  1.6648210946390212
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? True
# Params modified, OG params: (0.8651592629981364, 1.6648210946390212, array([0.11137363]))
# but now they are: (20.186174846744652, 38.84414250905905, array([0.11137363]))
#
#  initial guess for molecule 107 location: (2.7894532174014683,1.953056293117847)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  2.7894532174014683
#  ini_y,  1.953056293117847
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? True
# Params modified, OG params: (2.7894532174014683, 1.953056293117847, array([0.19880241]))
# but now they are: (24.904558796009038, 17.437110965130206, array([0.19880241]))
#
#  initial guess for molecule 108 location: (63.767624753476525,34.89567208233812)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  63.767624753476525
#  ini_y,  34.89567208233812
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 109 location: (2.3318114036756934,4.276363546456102)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  2.3318114036756934
#  ini_y,  4.276363546456102
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? True
# Params modified, OG params: (2.3318114036756934, 4.276363546456102, array([1.26522357]))
# but now they are: (20.56244665843859, 37.70995251909508, array([1.26522357]))
#
#  initial guess for molecule 110 location: (78.19495145343048,64.45309112817192)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  78.19495145343048
#  ini_y,  64.45309112817192
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 111 location: (61.20621051406714,49.18996808860881)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  61.20621051406714
#  ini_y,  49.18996808860881
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 112 location: (4.9889766673849545,8.435071823876267)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  4.9889766673849545
#  ini_y,  8.435071823876267
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? True
# Params modified, OG params: (4.9889766673849545, 8.435071823876267, array([0.2172228]))
# but now they are: (21.162570656468585, 35.78044464151328, array([0.2172228]))
#
#  initial guess for molecule 113 location: (4.71695362514425,9.929434922607042)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  4.71695362514425
#  ini_y,  9.929434922607042
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? True
# Params modified, OG params: (4.71695362514425, 9.929434922607042, array([0.7301512]))
# but now they are: (19.444281547948695, 40.9312330776415, array([0.7301512]))
#
#  initial guess for molecule 114 location: (5.172860298764142,14.045497021207867)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  5.172860298764142
#  ini_y,  14.045497021207867
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? True
# Params modified, OG params: (5.172860298764142, 14.045497021207867, array([0.51732672]))
# but now they are: (17.110596023067476, 46.45917569637484, array([0.51732672]))
#
#  initial guess for molecule 115 location: (6.915578865789194,20.29978389587215)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  6.915578865789194
#  ini_y,  20.29978389587215
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? True
# Params modified, OG params: (6.915578865789194, 20.29978389587215, array([1.51352992]))
# but now they are: (16.348327245325468, 47.988392089753646, array([1.51352992]))
#
#  initial guess for molecule 116 location: (47.09518687524292,73.09531611644461)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  47.09518687524292
#  ini_y,  73.09531611644461
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 117 location: (14.681966998499503,30.372998785412165)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  14.681966998499503
#  ini_y,  30.372998785412165
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? True
# Params modified, OG params: (14.681966998499503, 30.372998785412165, array([1.44220232]))
# but now they are: (19.59196948621696, 40.53045926812912, array([1.44220232]))
#
#  initial guess for molecule 118 location: (63.949479753716666,96.89078793466372)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  63.949479753716666
#  ini_y,  96.89078793466372
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 119 location: (23.62477330060952,68.71386522121914)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  23.62477330060952
#  ini_y,  68.71386522121914
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 120 location: (51.68235591038816,103.85614269193665)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  51.68235591038816
#  ini_y,  103.85614269193665
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 121 location: (33.99571284844789,81.49580494046815)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  33.99571284844789
#  ini_y,  81.49580494046815
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 122 location: (23.604478253791548,82.79197971598131)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  23.604478253791548
#  ini_y,  82.79197971598131
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 123 location: (35.94082609713508,102.99951532619002)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  35.94082609713508
#  ini_y,  102.99951532619002
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 124 location: (42.883602526620905,-0.08387517403883359)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  42.883602526620905
#  ini_y,  -0.08387517403883359
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 125 location: (26.243192639407653,4.649856030813532)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  26.243192639407653
#  ini_y,  4.649856030813532
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 126 location: (3.771209631796341,2.966232918826948)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  3.771209631796341
#  ini_y,  2.966232918826948
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? True
# Params modified, OG params: (3.771209631796341, 2.966232918826948, array([0.86999837]))
# but now they are: (24.648639370919312, 19.3873087536342, array([0.86999837]))
#
# ...
#
# In quenching zone? False
#
#  initial guess for molecule 307 location: (143.93395550256042,30.518688402396158)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  143.93395550256042
#  ini_y,  30.518688402396158
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 308 location: (104.08259438014124,25.181531301738886)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  104.08259438014124
#  ini_y,  25.181531301738886
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 309 location: (149.80143479001853,42.60309505696314)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  149.80143479001853
#  ini_y,  42.60309505696314
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 310 location: (148.99742774093232,55.80024058403708)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  148.99742774093232
#  ini_y,  55.80024058403708
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 311 location: (103.84949096950558,44.15528709474715)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  103.84949096950558
#  ini_y,  44.15528709474715
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 312 location: (111.96037188136029,53.74994544952335)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  111.96037188136029
#  ini_y,  53.74994544952335
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 313 location: (147.03708322543568,77.55833499665765)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  147.03708322543568
#  ini_y,  77.55833499665765
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 314 location: (145.8183966474288,83.49881441112352)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  145.8183966474288
#  ini_y,  83.49881441112352
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 315 location: (108.34009582147009,69.39954790095732)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  108.34009582147009
#  ini_y,  69.39954790095732
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 316 location: (142.45844358475335,99.83379652120256)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  142.45844358475335
#  ini_y,  99.83379652120256
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 317 location: (140.7826884509204,99.48604086714249)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  140.7826884509204
#  ini_y,  99.48604086714249
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 318 location: (112.52483952885049,89.9557224719174)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  112.52483952885049
#  ini_y,  89.9557224719174
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 319 location: (97.28380374263143,93.15154803173779)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  97.28380374263143
#  ini_y,  93.15154803173779
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 320 location: (136.19294166834013,118.56324487579337)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  136.19294166834013
#  ini_y,  118.56324487579337
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 321 location: (135.12619282547195,134.0586247286652)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  135.12619282547195
#  ini_y,  134.0586247286652
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 322 location: (132.0299552462086,127.41117442695418)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  132.0299552462086
#  ini_y,  127.41117442695418
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 323 location: (101.60801305236267,121.95133776430022)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  101.60801305236267
#  ini_y,  121.95133776430022
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 324 location: (115.77808071224298,-0.03989054451240971)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  115.77808071224298
#  ini_y,  -0.03989054451240971
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 325 location: (114.10023564692654,6.351298214888913)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  114.10023564692654
#  ini_y,  6.351298214888913
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 326 location: (146.980968828536,9.94040082246156)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  146.980968828536
#  ini_y,  9.94040082246156
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 327 location: (111.81611924482662,18.996856469341964)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  111.81611924482662
#  ini_y,  18.996856469341964
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 328 location: (109.6617801208698,25.308364664436954)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  109.6617801208698
#  ini_y,  25.308364664436954
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 329 location: (154.64062154895853,44.53941716706894)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  154.64062154895853
#  ini_y,  44.53941716706894
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 330 location: (128.74641178040065,38.03377401531363)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  128.74641178040065
#  ini_y,  38.03377401531363
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 331 location: (153.68100407412723,58.25439063564653)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  153.68100407412723
#  ini_y,  58.25439063564653
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 332 location: (119.98733591400537,54.08771128120724)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  119.98733591400537
#  ini_y,  54.08771128120724
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 333 location: (148.6591121303616,65.4361438656066)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  148.6591121303616
#  ini_y,  65.4361438656066
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 334 location: (103.76748765676686,61.564758429140745)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  103.76748765676686
#  ini_y,  61.564758429140745
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 335 location: (114.30615863049216,69.80257851002105)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  114.30615863049216
#  ini_y,  69.80257851002105
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 336 location: (134.12692880696002,90.05917621073678)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  134.12692880696002
#  ini_y,  90.05917621073678
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 337 location: (134.30817428595532,97.52570306513744)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  134.30817428595532
#  ini_y,  97.52570306513744
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 338 location: (136.29660869500339,94.34038847080859)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  136.29660869500339
#  ini_y,  94.34038847080859
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 339 location: (143.36635409022156,119.2840389209173)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  143.36635409022156
#  ini_y,  119.2840389209173
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 340 location: (121.33473355784268,104.0838574777351)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  121.33473355784268
#  ini_y,  104.0838574777351
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 341 location: (110.94894163908685,108.96142862840846)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  110.94894163908685
#  ini_y,  108.96142862840846
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 342 location: (108.9154839664508,115.41213080552039)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  108.9154839664508
#  ini_y,  115.41213080552039
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 343 location: (134.45399487483968,141.53103657869326)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  134.45399487483968
#  ini_y,  141.53103657869326
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 344 location: (121.44032879452749,-0.06258506618463094)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  121.44032879452749
#  ini_y,  -0.06258506618463094
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 345 location: (144.1903249399626,11.210995200975082)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  144.1903249399626
#  ini_y,  11.210995200975082
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 346 location: (143.94102424125794,10.023725678688262)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  143.94102424125794
#  ini_y,  10.023725678688262
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 347 location: (145.95458762901103,17.06801664099339)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  145.95458762901103
#  ini_y,  17.06801664099339
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 348 location: (150.1462094824662,24.72880618127876)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  150.1462094824662
#  ini_y,  24.72880618127876
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 349 location: (138.93970283392756,31.31789862155506)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  138.93970283392756
#  ini_y,  31.31789862155506
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 350 location: (117.38344772953243,38.03696565095593)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  117.38344772953243
#  ini_y,  38.03696565095593
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 351 location: (129.47830599183382,44.7777898955956)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  129.47830599183382
#  ini_y,  44.7777898955956
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 352 location: (123.58659373635626,51.10595816801762)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  123.58659373635626
#  ini_y,  51.10595816801762
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 353 location: (151.87064683894954,63.176249155773114)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  151.87064683894954
#  ini_y,  63.176249155773114
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 354 location: (122.79181977868126,63.95469683129531)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  122.79181977868126
#  ini_y,  63.95469683129531
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 355 location: (112.51462583373714,68.98295857653876)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  112.51462583373714
#  ini_y,  68.98295857653876
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 356 location: (153.67528794658432,94.98578513941939)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  153.67528794658432
#  ini_y,  94.98578513941939
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 357 location: (115.63015500468619,82.91737623620938)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  115.63015500468619
#  ini_y,  82.91737623620938
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 358 location: (148.12533494003105,99.79164302920182)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  148.12533494003105
#  ini_y,  99.79164302920182
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 359 location: (129.43649308524215,97.81813497770757)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  129.43649308524215
#  ini_y,  97.81813497770757
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 360 location: (118.14035428090688,103.96497950034562)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  118.14035428090688
#  ini_y,  103.96497950034562
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 361 location: (142.51684547837547,116.8994690563661)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  142.51684547837547
#  ini_y,  116.8994690563661
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 362 location: (143.80735434997803,127.3656668409105)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  143.80735434997803
#  ini_y,  127.3656668409105
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False
#
#  initial guess for molecule 363 location: (142.5951087773614,141.97349372555067)
# Checking inital guess
# self.rod_angle,  1.5707963267948966
#  ini_x,  142.5951087773614
#  ini_y,  141.97349372555067
#  self.quel_a,  61.77701186
#  self.quel_c,  25.96014311
#
# In quenching zone? False

# %%
save_fit_inst(
    randAngle125_shr_fit_instance_few_mol, 
    loaded_randAngle125_shr,
    'randAngle125_shr')

# %% [markdown]
# ### Plotting histograms

# %%
def plot_hist_true_appar(inst, bins=20):

    if type(inst) is fit.FitModelToData:
        angle_attr_str = inst.model_fit_results[:,2]
        mol_angles = inst.mol_angle
    elif (type(inst) is LoadedSimExp) or (type(inst) is SimulatedExperiment):
        angle_attr_str = inst.mispol_angle
        mol_angles = inst.mol_angles
        
#     fig, axs = plt.subplots(
#         fig_size=(6.5, 2.9)
#         )
    plt.hist(
        angle_attr_str,
        bins=bins)
    plt.hist(
        map_angles_to_first_quad(
            mol_angles
            ),
        alpha=.5,
        bins=bins
        )
    
    return plt.gca()

# %%
type(loaded_randAngle125_shr)
# Out:
# __main__.LoadedSimExp

# %%
plot_hist_true_appar(loaded_randAngle125_shr, bins=15)

# %%
randAngle125_shr_fit_instance_few_mol.mol_angle
# Out:
# 0

# %%
bins=15

plt.hist(
    randAngle125_shr_fit_instance_few_mol.model_fit_results[:,2],
    bins=bins)

plt.hist(
    map_angles_to_first_quad(
        loaded_randAngle125_shr.mol_angles
        ),
    alpha=.5,
    bins=bins
    )
# Out:
# (array([22., 24., 26., 22., 29., 20., 24., 19., 23., 25., 37., 17., 24.,
#         27., 25.]),
#  array([0.00435244, 0.1087209 , 0.21308936, 0.31745782, 0.42182628,
#         0.52619474, 0.63056319, 0.73493165, 0.83930011, 0.94366857,
#         1.04803703, 1.15240549, 1.25677394, 1.3611424 , 1.46551086,
#         1.56987932]),
#  <a list of 15 Patch objects>)

# %%
type(randAngle125_shr_fit_instance_few_mol)
# Out:
# fitting_misLocalization.FitModelToData

# %% [markdown]
# Let do some more for the smooths

# %%
# locations_125, angles_125 = fixed_ori_mol_placement(mol_grid_pts_1D=6, x_max=125, y_max=125)

locations_randAngle125_sshr, randAngle125_sshr = fit.random_ori_mol_placement(
    mol_grid_pts_1D=30, 
    x_max=125, 
    y_max=125,
)

simTestInst_randAngle125_sshr = SimulatedExperiment(
    locations_randAngle125_sshr, 
    mol_angle=randAngle125_sshr
    )
simTestInst_randAngle125_sshr.trial_images = simTestInst_randAngle125_sshr.calculate_BEM_fields()
# Out:
# starting Matlab...
# given even number of points for Fibonacci lattice,
#   adding 1...
# 1th molecule
# calculating diffracted fields
# 2th molecule
# calculating diffracted fields
# 3th molecule
# calculating diffracted fields
# 4th molecule
# calculating diffracted fields
# 5th molecule
# calculating diffracted fields
# 6th molecule
# calculating diffracted fields
# 7th molecule
# calculating diffracted fields
# 8th molecule
# calculating diffracted fields
# 9th molecule
# calculating diffracted fields
# 10th molecule
# calculating diffracted fields
# 11th molecule
# calculating diffracted fields
# 12th molecule
# calculating diffracted fields
# 13th molecule
# calculating diffracted fields
# 14th molecule
# calculating diffracted fields
# 15th molecule
# calculating diffracted fields
# 16th molecule
# calculating diffracted fields
# 17th molecule
# calculating diffracted fields
# 18th molecule
# calculating diffracted fields
# 19th molecule
# calculating diffracted fields
# 20th molecule
# calculating diffracted fields
# 21th molecule
# calculating diffracted fields
# 22th molecule
# calculating diffracted fields
# 23th molecule
# calculating diffracted fields
# 24th molecule
# calculating diffracted fields
# 25th molecule
# calculating diffracted fields
# 26th molecule
# calculating diffracted fields
# 27th molecule
# calculating diffracted fields
# 28th molecule
# calculating diffracted fields
# 29th molecule
# calculating diffracted fields
# 30th molecule
# calculating diffracted fields
# 31th molecule
# calculating diffracted fields
# 32th molecule
# calculating diffracted fields
# 33th molecule
# calculating diffracted fields
# 34th molecule
# calculating diffracted fields
# 35th molecule
# calculating diffracted fields
# 36th molecule
# calculating diffracted fields
# 37th molecule
# calculating diffracted fields
# 38th molecule
# calculating diffracted fields
# 39th molecule
# calculating diffracted fields
# 40th molecule
# calculating diffracted fields
# 41th molecule
# calculating diffracted fields
# 42th molecule
# calculating diffracted fields
# 43th molecule
# calculating diffracted fields
# 44th molecule
# calculating diffracted fields
# 45th molecule
# calculating diffracted fields
# 46th molecule
# calculating diffracted fields
# 47th molecule
# calculating diffracted fields
# 48th molecule
# calculating diffracted fields
# 49th molecule
# calculating diffracted fields
# 50th molecule
# calculating diffracted fields
# 51th molecule
# calculating diffracted fields
# 52th molecule
# calculating diffracted fields
# 53th molecule
# calculating diffracted fields
# 54th molecule
# calculating diffracted fields
# 55th molecule
# calculating diffracted fields
# 56th molecule
# calculating diffracted fields
# 57th molecule
# calculating diffracted fields
# 58th molecule
# calculating diffracted fields
# 59th molecule
# calculating diffracted fields
# 60th molecule
# calculating diffracted fields
# 61th molecule
# calculating diffracted fields
# 62th molecule
# calculating diffracted fields
# 63th molecule
# calculating diffracted fields
# 64th molecule
# calculating diffracted fields
# 65th molecule
# calculating diffracted fields
# 66th molecule
# calculating diffracted fields
# 67th molecule
# calculating diffracted fields
# 68th molecule
# calculating diffracted fields
# 69th molecule
# calculating diffracted fields
# 70th molecule
# calculating diffracted fields
# 71th molecule
# calculating diffracted fields
# 72th molecule
# calculating diffracted fields
# 73th molecule
# calculating diffracted fields
# 74th molecule
# calculating diffracted fields
# 75th molecule
# calculating diffracted fields
# 76th molecule
# calculating diffracted fields
# 77th molecule
# calculating diffracted fields
# 78th molecule
# calculating diffracted fields
# 79th molecule
# calculating diffracted fields
# 80th molecule
# calculating diffracted fields
# 81th molecule
# calculating diffracted fields
# 82th molecule
# calculating diffracted fields
# 83th molecule
# calculating diffracted fields
# 84th molecule
# calculating diffracted fields
# 85th molecule
# calculating diffracted fields
# 86th molecule
# calculating diffracted fields
# 87th molecule
# calculating diffracted fields
# 88th molecule
# calculating diffracted fields
# 89th molecule
# calculating diffracted fields
# 90th molecule
# calculating diffracted fields
# 91th molecule
# calculating diffracted fields
# 92th molecule
# calculating diffracted fields
# 93th molecule
# calculating diffracted fields
# 94th molecule
# calculating diffracted fields
# 95th molecule
# calculating diffracted fields
# 96th molecule
# calculating diffracted fields
# 97th molecule
# calculating diffracted fields
# 98th molecule
# calculating diffracted fields
# 99th molecule
# calculating diffracted fields
# 100th molecule
# calculating diffracted fields
# 101th molecule
# calculating diffracted fields
# 102th molecule
# calculating diffracted fields
# 103th molecule
# calculating diffracted fields
# 104th molecule
# calculating diffracted fields
# 105th molecule
# calculating diffracted fields
# 106th molecule
# calculating diffracted fields
# 107th molecule
# calculating diffracted fields
# 108th molecule
# calculating diffracted fields
# 109th molecule
# calculating diffracted fields
# 110th molecule
# calculating diffracted fields
# 111th molecule
# calculating diffracted fields
# 112th molecule
# calculating diffracted fields
# 113th molecule
# calculating diffracted fields
# 114th molecule
# calculating diffracted fields
# 115th molecule
# calculating diffracted fields
# 116th molecule
# calculating diffracted fields
# 117th molecule
# calculating diffracted fields
# 118th molecule
# calculating diffracted fields
# 119th molecule
# calculating diffracted fields
# 120th molecule
# calculating diffracted fields
# 121th molecule
# calculating diffracted fields
# 122th molecule
# calculating diffracted fields
# 123th molecule
# calculating diffracted fields
# 124th molecule
# calculating diffracted fields
# 125th molecule
# calculating diffracted fields
# 126th molecule
# calculating diffracted fields
# 127th molecule
# calculating diffracted fields
# 128th molecule
# calculating diffracted fields
# 129th molecule
# calculating diffracted fields
# 130th molecule
# calculating diffracted fields
# 131th molecule
# calculating diffracted fields
# 132th molecule
# calculating diffracted fields
# 133th molecule
# calculating diffracted fields
# 134th molecule
# calculating diffracted fields
# 135th molecule
# calculating diffracted fields
# 136th molecule
# calculating diffracted fields
# 137th molecule
# calculating diffracted fields
# 138th molecule
# calculating diffracted fields
# 139th molecule
# calculating diffracted fields
# 140th molecule
# calculating diffracted fields
# 141th molecule
# calculating diffracted fields
# 142th molecule
# calculating diffracted fields
# 143th molecule
# calculating diffracted fields
# 144th molecule
# calculating diffracted fields
# 145th molecule
# calculating diffracted fields
# 146th molecule
# calculating diffracted fields
# 147th molecule
# calculating diffracted fields
# 148th molecule
# calculating diffracted fields
# 149th molecule
# calculating diffracted fields
# 150th molecule
# calculating diffracted fields
# 151th molecule
# calculating diffracted fields
# 152th molecule
# calculating diffracted fields
# 153th molecule
# calculating diffracted fields
# 154th molecule
# calculating diffracted fields
# 155th molecule
# calculating diffracted fields
# 156th molecule
# calculating diffracted fields
# 157th molecule
# calculating diffracted fields
# 158th molecule
# calculating diffracted fields
# 159th molecule
# calculating diffracted fields
# 160th molecule
# calculating diffracted fields
# 161th molecule
# calculating diffracted fields
# 162th molecule
# calculating diffracted fields
# 163th molecule
# calculating diffracted fields
# 164th molecule
# calculating diffracted fields
# 165th molecule
# calculating diffracted fields
# 166th molecule
# calculating diffracted fields
# 167th molecule
# calculating diffracted fields
# 168th molecule
# calculating diffracted fields
# 169th molecule
# calculating diffracted fields
# 170th molecule
# calculating diffracted fields
# 171th molecule
# calculating diffracted fields
# 172th molecule
# calculating diffracted fields
# 173th molecule
# calculating diffracted fields
# 174th molecule
# calculating diffracted fields
# 175th molecule
# calculating diffracted fields
# 176th molecule
# calculating diffracted fields
# 177th molecule
# calculating diffracted fields
# 178th molecule
# calculating diffracted fields
# 179th molecule
# calculating diffracted fields
# 180th molecule
# calculating diffracted fields
# 181th molecule
# calculating diffracted fields
# 182th molecule
# calculating diffracted fields
# 183th molecule
# calculating diffracted fields
# 184th molecule
# calculating diffracted fields
# 185th molecule
# calculating diffracted fields
# 186th molecule
# calculating diffracted fields
# 187th molecule
# calculating diffracted fields
# 188th molecule
# calculating diffracted fields
# 189th molecule
# calculating diffracted fields
# 190th molecule
# calculating diffracted fields
# 191th molecule
# calculating diffracted fields
# 192th molecule
# calculating diffracted fields
# 193th molecule
# calculating diffracted fields
# 194th molecule
# calculating diffracted fields
# 195th molecule
# calculating diffracted fields
# 196th molecule
# calculating diffracted fields
# 197th molecule
# calculating diffracted fields
# 198th molecule
# calculating diffracted fields
# 199th molecule
# calculating diffracted fields
# 200th molecule
# calculating diffracted fields
# 201th molecule
# calculating diffracted fields
# 202th molecule
# calculating diffracted fields
# 203th molecule
# calculating diffracted fields
# 204th molecule
# calculating diffracted fields
# 205th molecule
# calculating diffracted fields
# 206th molecule
# calculating diffracted fields
# 207th molecule
# calculating diffracted fields
# 208th molecule
# calculating diffracted fields
# 209th molecule
# calculating diffracted fields
# 210th molecule
# calculating diffracted fields
# 211th molecule
# calculating diffracted fields
# 212th molecule
# calculating diffracted fields
# 213th molecule
# calculating diffracted fields
# 214th molecule
# calculating diffracted fields
# 215th molecule
# calculating diffracted fields
# 216th molecule
# calculating diffracted fields
# 217th molecule
# calculating diffracted fields
# 218th molecule
# calculating diffracted fields
# 219th molecule
# calculating diffracted fields
# 220th molecule
# calculating diffracted fields
# 221th molecule
# calculating diffracted fields
# 222th molecule
# calculating diffracted fields
# 223th molecule
# calculating diffracted fields
# 224th molecule
# calculating diffracted fields
# 225th molecule
# calculating diffracted fields
# 226th molecule
# calculating diffracted fields
# 227th molecule
# calculating diffracted fields
# 228th molecule
# calculating diffracted fields
# 229th molecule
# calculating diffracted fields
# 230th molecule
# calculating diffracted fields
# 231th molecule
# calculating diffracted fields
# 232th molecule
# calculating diffracted fields
# 233th molecule
# calculating diffracted fields
# 234th molecule
# calculating diffracted fields
# 235th molecule
# calculating diffracted fields
# 236th molecule
# calculating diffracted fields
# 237th molecule
# calculating diffracted fields
# 238th molecule
# calculating diffracted fields
# 239th molecule
# calculating diffracted fields
# 240th molecule
# calculating diffracted fields
# 241th molecule
# calculating diffracted fields
# 242th molecule
# calculating diffracted fields
# 243th molecule
# calculating diffracted fields
# 244th molecule
# calculating diffracted fields
# 245th molecule
# calculating diffracted fields
# 246th molecule
# calculating diffracted fields
# 247th molecule
# calculating diffracted fields
# 248th molecule
# calculating diffracted fields
# 249th molecule
# calculating diffracted fields
# 250th molecule
# calculating diffracted fields
# 251th molecule
# calculating diffracted fields
# 252th molecule
# calculating diffracted fields
# 253th molecule
# calculating diffracted fields
# 254th molecule
# calculating diffracted fields
# 255th molecule
# calculating diffracted fields
# 256th molecule
# calculating diffracted fields
# 257th molecule
# calculating diffracted fields
# 258th molecule
# calculating diffracted fields
# 259th molecule
# calculating diffracted fields
# 260th molecule
# calculating diffracted fields
# 261th molecule
# calculating diffracted fields
# 262th molecule
# calculating diffracted fields
# 263th molecule
# calculating diffracted fields
# 264th molecule
# calculating diffracted fields
# 265th molecule
# calculating diffracted fields
# 266th molecule
# calculating diffracted fields
# 267th molecule
# calculating diffracted fields
# 268th molecule
# calculating diffracted fields
# 269th molecule
# calculating diffracted fields
# 270th molecule
# calculating diffracted fields
# 271th molecule
# calculating diffracted fields
# 272th molecule
# calculating diffracted fields
# 273th molecule
# calculating diffracted fields
# 274th molecule
# calculating diffracted fields
# 275th molecule
# calculating diffracted fields
# 276th molecule
# calculating diffracted fields
# 277th molecule
# calculating diffracted fields
# 278th molecule
# calculating diffracted fields
# 279th molecule
# calculating diffracted fields
# 280th molecule
# calculating diffracted fields
# 281th molecule
# calculating diffracted fields
# 282th molecule
# calculating diffracted fields
# 283th molecule
# calculating diffracted fields
# 284th molecule
# calculating diffracted fields
# 285th molecule
# calculating diffracted fields
# 286th molecule
# calculating diffracted fields
# 287th molecule
# calculating diffracted fields
# 288th molecule
# calculating diffracted fields
# 289th molecule
# calculating diffracted fields
# 290th molecule
# calculating diffracted fields
# 291th molecule
# calculating diffracted fields
# 292th molecule
# calculating diffracted fields
# 293th molecule
# calculating diffracted fields
# 294th molecule
# calculating diffracted fields
# 295th molecule
# calculating diffracted fields
# 296th molecule
# calculating diffracted fields
# 297th molecule
# calculating diffracted fields
# 298th molecule
# calculating diffracted fields
# 299th molecule
# calculating diffracted fields
# 300th molecule
# calculating diffracted fields
# 301th molecule
# calculating diffracted fields
# 302th molecule
# calculating diffracted fields
# 303th molecule
# calculating diffracted fields
# 304th molecule
# calculating diffracted fields
# 305th molecule
# calculating diffracted fields
# 306th molecule
# calculating diffracted fields
# 307th molecule
# calculating diffracted fields
# 308th molecule
# calculating diffracted fields
# 309th molecule
# calculating diffracted fields
# 310th molecule
# calculating diffracted fields
# 311th molecule
# calculating diffracted fields
# 312th molecule
# calculating diffracted fields
# 313th molecule
# calculating diffracted fields
# 314th molecule
# calculating diffracted fields
# 315th molecule
# calculating diffracted fields
# 316th molecule
# calculating diffracted fields
# 317th molecule
# calculating diffracted fields
# 318th molecule
# calculating diffracted fields
# 319th molecule
# calculating diffracted fields
# 320th molecule
# calculating diffracted fields
# 321th molecule
# calculating diffracted fields
# 322th molecule
# calculating diffracted fields
# 323th molecule
# calculating diffracted fields
# 324th molecule
# calculating diffracted fields
# 325th molecule
# calculating diffracted fields
# 326th molecule
# calculating diffracted fields
# 327th molecule
# calculating diffracted fields
# 328th molecule
# calculating diffracted fields
# 329th molecule
# calculating diffracted fields
# 330th molecule
# calculating diffracted fields
# 331th molecule
# calculating diffracted fields
# 332th molecule
# calculating diffracted fields
# 333th molecule
# calculating diffracted fields
# 334th molecule
# calculating diffracted fields
# 335th molecule
# calculating diffracted fields
# 336th molecule
# calculating diffracted fields
# 337th molecule
# calculating diffracted fields
# 338th molecule
# calculating diffracted fields
# 339th molecule
# calculating diffracted fields
# 340th molecule
# calculating diffracted fields
# 341th molecule
# calculating diffracted fields
# 342th molecule
# calculating diffracted fields
# 343th molecule
# calculating diffracted fields
# 344th molecule
# calculating diffracted fields
# 345th molecule
# calculating diffracted fields
# 346th molecule
# calculating diffracted fields
# 347th molecule
# calculating diffracted fields
# 348th molecule
# calculating diffracted fields
# 349th molecule
# calculating diffracted fields
# 350th molecule
# calculating diffracted fields
# 351th molecule
# calculating diffracted fields
# 352th molecule
# calculating diffracted fields
# 353th molecule
# calculating diffracted fields
# 354th molecule
# calculating diffracted fields
# 355th molecule
# calculating diffracted fields
# 356th molecule
# calculating diffracted fields
# 357th molecule
# calculating diffracted fields
# 358th molecule
# calculating diffracted fields
# 359th molecule
# calculating diffracted fields
# 360th molecule
# calculating diffracted fields
# 361th molecule
# calculating diffracted fields
# 362th molecule
# calculating diffracted fields
# 363th molecule
# calculating diffracted fields
# 364th molecule
# calculating diffracted fields
# 365th molecule
# calculating diffracted fields
# 366th molecule
# calculating diffracted fields
# 367th molecule
# calculating diffracted fields
# 368th molecule
# calculating diffracted fields
# 369th molecule
# calculating diffracted fields
# 370th molecule
# calculating diffracted fields
# 371th molecule
# calculating diffracted fields
# 372th molecule
# calculating diffracted fields
# 373th molecule
# calculating diffracted fields
# 374th molecule
# calculating diffracted fields
# 375th molecule
# calculating diffracted fields
# 376th molecule
# calculating diffracted fields
# 377th molecule
# calculating diffracted fields
# 378th molecule
# calculating diffracted fields
# 379th molecule
# calculating diffracted fields
# 380th molecule
# calculating diffracted fields
# 381th molecule
# calculating diffracted fields
# 382th molecule
# calculating diffracted fields
# 383th molecule
# calculating diffracted fields
# 384th molecule
# calculating diffracted fields
# 385th molecule
# calculating diffracted fields
# 386th molecule
# calculating diffracted fields
# 387th molecule
# calculating diffracted fields
# 388th molecule
# calculating diffracted fields
# 389th molecule
# calculating diffracted fields
# 390th molecule
# calculating diffracted fields
# 391th molecule
# calculating diffracted fields
# 392th molecule
# calculating diffracted fields
# 393th molecule
# calculating diffracted fields
# 394th molecule
# calculating diffracted fields
# 395th molecule
# calculating diffracted fields
# 396th molecule
# calculating diffracted fields
# 397th molecule
# calculating diffracted fields
# 398th molecule
# calculating diffracted fields
# 399th molecule
# calculating diffracted fields
# 400th molecule
# calculating diffracted fields
# 401th molecule
# calculating diffracted fields
# 402th molecule
# calculating diffracted fields
# 403th molecule
# calculating diffracted fields
# 404th molecule
# calculating diffracted fields
# 405th molecule
# calculating diffracted fields
# 406th molecule
# calculating diffracted fields
# 407th molecule
# calculating diffracted fields
# 408th molecule
# calculating diffracted fields
# 409th molecule
# calculating diffracted fields
# 410th molecule
# calculating diffracted fields
# 411th molecule
# calculating diffracted fields
# 412th molecule
# calculating diffracted fields
# 413th molecule
# calculating diffracted fields
# 414th molecule
# calculating diffracted fields
# 415th molecule
# calculating diffracted fields
# 416th molecule
# calculating diffracted fields
# 417th molecule
# calculating diffracted fields
# 418th molecule
# calculating diffracted fields
# 419th molecule
# calculating diffracted fields
# 420th molecule
# calculating diffracted fields
# 421th molecule
# calculating diffracted fields
# 422th molecule
# calculating diffracted fields
# 423th molecule
# calculating diffracted fields
# 424th molecule
# calculating diffracted fields
# 425th molecule
# calculating diffracted fields
# 426th molecule
# calculating diffracted fields
# 427th molecule
# calculating diffracted fields
# 428th molecule
# calculating diffracted fields
# 429th molecule
# calculating diffracted fields
# 430th molecule
# calculating diffracted fields
# 431th molecule
# calculating diffracted fields
# 432th molecule
# calculating diffracted fields
# 433th molecule
# calculating diffracted fields
# 434th molecule
# calculating diffracted fields
# 435th molecule
# calculating diffracted fields
# 436th molecule
# calculating diffracted fields
# 437th molecule
# calculating diffracted fields
# 438th molecule
# calculating diffracted fields
# 439th molecule
# calculating diffracted fields
# 440th molecule
# calculating diffracted fields
# 441th molecule
# calculating diffracted fields
# 442th molecule
# calculating diffracted fields
# 443th molecule
# calculating diffracted fields
# 444th molecule
# calculating diffracted fields
# 445th molecule
# calculating diffracted fields
# 446th molecule
# calculating diffracted fields
# 447th molecule
# calculating diffracted fields
# 448th molecule
# calculating diffracted fields
# 449th molecule
# calculating diffracted fields
# 450th molecule
# calculating diffracted fields
# 451th molecule
# calculating diffracted fields
# 452th molecule
# calculating diffracted fields
# 453th molecule
# calculating diffracted fields
# 454th molecule
# calculating diffracted fields
# 455th molecule
# calculating diffracted fields
# 456th molecule
# calculating diffracted fields
# 457th molecule
# calculating diffracted fields
# 458th molecule
# calculating diffracted fields
# 459th molecule
# calculating diffracted fields
# 460th molecule
# calculating diffracted fields
# 461th molecule
# calculating diffracted fields
# 462th molecule
# calculating diffracted fields
# 463th molecule
# calculating diffracted fields
# 464th molecule
# calculating diffracted fields
# 465th molecule
# calculating diffracted fields
# 466th molecule
# calculating diffracted fields
# 467th molecule
# calculating diffracted fields
# 468th molecule
# calculating diffracted fields
# 469th molecule
# calculating diffracted fields
# 470th molecule
# calculating diffracted fields
# 471th molecule
# calculating diffracted fields
# 472th molecule
# calculating diffracted fields
# 473th molecule
# calculating diffracted fields
# 474th molecule
# calculating diffracted fields
# 475th molecule
# calculating diffracted fields
# 476th molecule
# calculating diffracted fields
# 477th molecule
# calculating diffracted fields
# 478th molecule
# calculating diffracted fields
# 479th molecule
# calculating diffracted fields
# 480th molecule
# calculating diffracted fields
# 481th molecule
# calculating diffracted fields
# 482th molecule
# calculating diffracted fields
# 483th molecule
# calculating diffracted fields
# 484th molecule
# calculating diffracted fields
# 485th molecule
# calculating diffracted fields
# 486th molecule
# calculating diffracted fields
# 487th molecule
# calculating diffracted fields
# 488th molecule
# calculating diffracted fields
# 489th molecule
# calculating diffracted fields
# 490th molecule
# calculating diffracted fields
# 491th molecule
# calculating diffracted fields
# 492th molecule
# calculating diffracted fields
# 493th molecule
# calculating diffracted fields
# 494th molecule
# calculating diffracted fields
# 495th molecule
# calculating diffracted fields
# 496th molecule
# calculating diffracted fields
# 497th molecule
# calculating diffracted fields
# 498th molecule
# calculating diffracted fields
# 499th molecule
# calculating diffracted fields
# 500th molecule
# calculating diffracted fields
# 501th molecule
# calculating diffracted fields
# 502th molecule
# calculating diffracted fields
# 503th molecule
# calculating diffracted fields
# 504th molecule
# calculating diffracted fields
# 505th molecule
# calculating diffracted fields
# 506th molecule
# calculating diffracted fields
# 507th molecule
# calculating diffracted fields
# 508th molecule
# calculating diffracted fields
# 509th molecule
# calculating diffracted fields
# 510th molecule
# calculating diffracted fields
# 511th molecule
# calculating diffracted fields
# 512th molecule
# calculating diffracted fields
# 513th molecule
# calculating diffracted fields
# 514th molecule
# calculating diffracted fields
# 515th molecule
# calculating diffracted fields
# 516th molecule
# calculating diffracted fields
# 517th molecule
# calculating diffracted fields
# 518th molecule
# calculating diffracted fields
# 519th molecule
# calculating diffracted fields
# 520th molecule
# calculating diffracted fields
# 521th molecule
# calculating diffracted fields
# 522th molecule
# calculating diffracted fields
# 523th molecule
# calculating diffracted fields
# 524th molecule
# calculating diffracted fields
# 525th molecule
# calculating diffracted fields
# 526th molecule
# calculating diffracted fields
# 527th molecule
# calculating diffracted fields
# 528th molecule
# calculating diffracted fields
# 529th molecule
# calculating diffracted fields
# 530th molecule
# calculating diffracted fields
# 531th molecule
# calculating diffracted fields
# 532th molecule
# calculating diffracted fields
# 533th molecule
# calculating diffracted fields
# 534th molecule
# calculating diffracted fields
# 535th molecule
# calculating diffracted fields
# 536th molecule
# calculating diffracted fields
# 537th molecule
# calculating diffracted fields
# 538th molecule
# calculating diffracted fields
# 539th molecule
# calculating diffracted fields
# 540th molecule
# calculating diffracted fields
# 541th molecule
# calculating diffracted fields
# 542th molecule
# calculating diffracted fields
# 543th molecule
# calculating diffracted fields
# 544th molecule
# calculating diffracted fields
# 545th molecule
# calculating diffracted fields
# 546th molecule
# calculating diffracted fields
# 547th molecule
# calculating diffracted fields
# 548th molecule
# calculating diffracted fields
# 549th molecule
# calculating diffracted fields
# 550th molecule
# calculating diffracted fields
# 551th molecule
# calculating diffracted fields
# 552th molecule
# calculating diffracted fields
# 553th molecule
# calculating diffracted fields
# 554th molecule
# calculating diffracted fields
# 555th molecule
# calculating diffracted fields
# 556th molecule
# calculating diffracted fields
# 557th molecule
# calculating diffracted fields
# 558th molecule
# calculating diffracted fields
# 559th molecule
# calculating diffracted fields
# 560th molecule
# calculating diffracted fields
# 561th molecule
# calculating diffracted fields
# 562th molecule
# calculating diffracted fields
# 563th molecule
# calculating diffracted fields
# 564th molecule
# calculating diffracted fields
# 565th molecule
# calculating diffracted fields
# 566th molecule
# calculating diffracted fields
# 567th molecule
# calculating diffracted fields
# 568th molecule
# calculating diffracted fields
# 569th molecule
# calculating diffracted fields
# 570th molecule
# calculating diffracted fields
# 571th molecule
# calculating diffracted fields
# 572th molecule
# calculating diffracted fields
# 573th molecule
# calculating diffracted fields
# 574th molecule
# calculating diffracted fields
# 575th molecule
# calculating diffracted fields
# 576th molecule
# calculating diffracted fields
# 577th molecule
# calculating diffracted fields
# 578th molecule
# calculating diffracted fields
# 579th molecule
# calculating diffracted fields
# 580th molecule
# calculating diffracted fields
# 581th molecule
# calculating diffracted fields
# 582th molecule
# calculating diffracted fields
# 583th molecule
# calculating diffracted fields
# 584th molecule
# calculating diffracted fields
# 585th molecule
# calculating diffracted fields
# 586th molecule
# calculating diffracted fields
# 587th molecule
# calculating diffracted fields
# 588th molecule
# calculating diffracted fields
# 589th molecule
# calculating diffracted fields
# 590th molecule
# calculating diffracted fields
# 591th molecule
# calculating diffracted fields
# 592th molecule
# calculating diffracted fields
# 593th molecule
# calculating diffracted fields
# 594th molecule
# calculating diffracted fields
# 595th molecule
# calculating diffracted fields
# 596th molecule
# calculating diffracted fields
# 597th molecule
# calculating diffracted fields
# 598th molecule
# calculating diffracted fields
# 599th molecule
# calculating diffracted fields
# 600th molecule
# calculating diffracted fields
# 601th molecule
# calculating diffracted fields
# 602th molecule
# calculating diffracted fields
# 603th molecule
# calculating diffracted fields
# 604th molecule
# calculating diffracted fields
# 605th molecule
# calculating diffracted fields
# 606th molecule
# calculating diffracted fields
# 607th molecule
# calculating diffracted fields
# 608th molecule
# calculating diffracted fields
# 609th molecule
# calculating diffracted fields
# 610th molecule
# calculating diffracted fields
# 611th molecule
# calculating diffracted fields
# 612th molecule
# calculating diffracted fields
# 613th molecule
# calculating diffracted fields
# 614th molecule
# calculating diffracted fields
# 615th molecule
# calculating diffracted fields
# 616th molecule
# calculating diffracted fields
# 617th molecule
# calculating diffracted fields
# 618th molecule
# calculating diffracted fields
# 619th molecule
# calculating diffracted fields
# 620th molecule
# calculating diffracted fields
# 621th molecule
# calculating diffracted fields
# 622th molecule
# calculating diffracted fields
# 623th molecule
# calculating diffracted fields
# 624th molecule
# calculating diffracted fields
# 625th molecule
# calculating diffracted fields
# 626th molecule
# calculating diffracted fields
# 627th molecule
# calculating diffracted fields
# 628th molecule
# calculating diffracted fields
# 629th molecule
# calculating diffracted fields
# 630th molecule
# calculating diffracted fields
# 631th molecule
# calculating diffracted fields
# 632th molecule
# calculating diffracted fields
# 633th molecule
# calculating diffracted fields
# 634th molecule
# calculating diffracted fields
# 635th molecule
# calculating diffracted fields
# 636th molecule
# calculating diffracted fields
# 637th molecule
# calculating diffracted fields
# 638th molecule
# calculating diffracted fields
# 639th molecule
# calculating diffracted fields
# 640th molecule
# calculating diffracted fields
# 641th molecule
# calculating diffracted fields
# 642th molecule
# calculating diffracted fields
# 643th molecule
# calculating diffracted fields
# 644th molecule
# calculating diffracted fields
# 645th molecule
# calculating diffracted fields
# 646th molecule
# calculating diffracted fields
# 647th molecule
# calculating diffracted fields
# 648th molecule
# calculating diffracted fields
# 649th molecule
# calculating diffracted fields
# 650th molecule
# calculating diffracted fields
# 651th molecule
# calculating diffracted fields
# 652th molecule
# calculating diffracted fields
# 653th molecule
# calculating diffracted fields
# 654th molecule
# calculating diffracted fields
# 655th molecule
# calculating diffracted fields
# 656th molecule
# calculating diffracted fields
# 657th molecule
# calculating diffracted fields
# 658th molecule
# calculating diffracted fields
# 659th molecule
# calculating diffracted fields
# 660th molecule
# calculating diffracted fields
# 661th molecule
# calculating diffracted fields
# 662th molecule
# calculating diffracted fields
# 663th molecule
# calculating diffracted fields
# 664th molecule
# calculating diffracted fields
# 665th molecule
# calculating diffracted fields
# 666th molecule
# calculating diffracted fields
# 667th molecule
# calculating diffracted fields
# 668th molecule
# calculating diffracted fields
# 669th molecule
# calculating diffracted fields
# 670th molecule
# calculating diffracted fields
# 671th molecule
# calculating diffracted fields
# 672th molecule
# calculating diffracted fields
# 673th molecule
# calculating diffracted fields
# 674th molecule
# calculating diffracted fields
# 675th molecule
# calculating diffracted fields
# 676th molecule
# calculating diffracted fields
# 677th molecule
# calculating diffracted fields
# 678th molecule
# calculating diffracted fields
# 679th molecule
# calculating diffracted fields
# 680th molecule
# calculating diffracted fields
# 681th molecule
# calculating diffracted fields
# 682th molecule
# calculating diffracted fields
# 683th molecule
# calculating diffracted fields
# 684th molecule
# calculating diffracted fields
# 685th molecule
# calculating diffracted fields
# 686th molecule
# calculating diffracted fields
# 687th molecule
# calculating diffracted fields
# 688th molecule
# calculating diffracted fields
# 689th molecule
# calculating diffracted fields
# 690th molecule
# calculating diffracted fields
# 691th molecule
# calculating diffracted fields
# 692th molecule
# calculating diffracted fields
# 693th molecule
# calculating diffracted fields
# 694th molecule
# calculating diffracted fields
# 695th molecule
# calculating diffracted fields
# 696th molecule
# calculating diffracted fields
# 697th molecule
# calculating diffracted fields
# 698th molecule
# calculating diffracted fields
# 699th molecule
# calculating diffracted fields
# 700th molecule
# calculating diffracted fields
# 701th molecule
# calculating diffracted fields
# 702th molecule
# calculating diffracted fields
# 703th molecule
# calculating diffracted fields
# 704th molecule
# calculating diffracted fields
# 705th molecule
# calculating diffracted fields
# 706th molecule
# calculating diffracted fields
# 707th molecule
# calculating diffracted fields
# 708th molecule
# calculating diffracted fields
# 709th molecule
# calculating diffracted fields
# 710th molecule
# calculating diffracted fields
# 711th molecule
# calculating diffracted fields
# 712th molecule
# calculating diffracted fields
# 713th molecule
# calculating diffracted fields
# 714th molecule
# calculating diffracted fields
# 715th molecule
# calculating diffracted fields
# 716th molecule
# calculating diffracted fields
# 717th molecule
# calculating diffracted fields
# 718th molecule
# calculating diffracted fields
# 719th molecule
# calculating diffracted fields
# 720th molecule
# calculating diffracted fields
# 721th molecule
# calculating diffracted fields
# 722th molecule
# calculating diffracted fields
# 723th molecule
# calculating diffracted fields
# 724th molecule
# calculating diffracted fields
# 725th molecule
# calculating diffracted fields
# 726th molecule
# calculating diffracted fields
# 727th molecule
# calculating diffracted fields
# 728th molecule
# calculating diffracted fields
# 729th molecule
# calculating diffracted fields
# 730th molecule
# calculating diffracted fields
# 731th molecule
# calculating diffracted fields
# 732th molecule
# calculating diffracted fields
# 733th molecule
# calculating diffracted fields
# 734th molecule
# calculating diffracted fields
# 735th molecule
# calculating diffracted fields
# 736th molecule
# calculating diffracted fields
# 737th molecule
# calculating diffracted fields
# 738th molecule
# calculating diffracted fields
# 739th molecule
# calculating diffracted fields
# 740th molecule
# calculating diffracted fields
# 741th molecule
# calculating diffracted fields
# 742th molecule
# calculating diffracted fields
# 743th molecule
# calculating diffracted fields
# 744th molecule
# calculating diffracted fields
# 745th molecule
# calculating diffracted fields
# 746th molecule
# calculating diffracted fields
# 747th molecule
# calculating diffracted fields
# 748th molecule
# calculating diffracted fields
# 749th molecule
# calculating diffracted fields
# 750th molecule
# calculating diffracted fields
# 751th molecule
# calculating diffracted fields
# 752th molecule
# calculating diffracted fields
# 753th molecule
# calculating diffracted fields
# 754th molecule
# calculating diffracted fields
# 755th molecule
# calculating diffracted fields
# 756th molecule
# calculating diffracted fields
# 757th molecule
# calculating diffracted fields
# 758th molecule
# calculating diffracted fields
# 759th molecule
# calculating diffracted fields
# 760th molecule
# calculating diffracted fields
# 761th molecule
# calculating diffracted fields
# 762th molecule
# calculating diffracted fields
# 763th molecule
# calculating diffracted fields
# 764th molecule
# calculating diffracted fields
# 765th molecule
# calculating diffracted fields
# 766th molecule
# calculating diffracted fields
# 767th molecule
# calculating diffracted fields
# 768th molecule
# calculating diffracted fields
# 769th molecule
# calculating diffracted fields
# 770th molecule
# calculating diffracted fields
# 771th molecule
# calculating diffracted fields
# 772th molecule
# calculating diffracted fields
# 773th molecule
# calculating diffracted fields
# 774th molecule
# calculating diffracted fields
# 775th molecule
# calculating diffracted fields
# 776th molecule
# calculating diffracted fields
# 777th molecule
# calculating diffracted fields
# 778th molecule
# calculating diffracted fields
# 779th molecule
# calculating diffracted fields
# 780th molecule
# calculating diffracted fields
# 781th molecule
# calculating diffracted fields
# 782th molecule
# calculating diffracted fields
# 783th molecule
# calculating diffracted fields
# 784th molecule
# calculating diffracted fields
# 785th molecule
# calculating diffracted fields
# 786th molecule
# calculating diffracted fields
# 787th molecule
# calculating diffracted fields
# 788th molecule
# calculating diffracted fields
# 789th molecule
# calculating diffracted fields
# 790th molecule
# calculating diffracted fields
# 791th molecule
# calculating diffracted fields
# 792th molecule
# calculating diffracted fields
# 793th molecule
# calculating diffracted fields
# 794th molecule
# calculating diffracted fields
# 795th molecule
# calculating diffracted fields
# 796th molecule
# calculating diffracted fields
# 797th molecule
# calculating diffracted fields
# 798th molecule
# calculating diffracted fields
# 799th molecule
# calculating diffracted fields
# 800th molecule
# calculating diffracted fields
# 801th molecule
# calculating diffracted fields
# 802th molecule
# calculating diffracted fields
# 803th molecule
# calculating diffracted fields
# 804th molecule
# calculating diffracted fields
# 805th molecule
# calculating diffracted fields
# 806th molecule
# calculating diffracted fields
# 807th molecule
# calculating diffracted fields
# 808th molecule
# calculating diffracted fields
# 809th molecule
# calculating diffracted fields
# 810th molecule
# calculating diffracted fields
# 811th molecule
# calculating diffracted fields
# 812th molecule
# calculating diffracted fields
# 813th molecule
# calculating diffracted fields
# 814th molecule
# calculating diffracted fields
# 815th molecule
# calculating diffracted fields
# 816th molecule
# calculating diffracted fields
# 817th molecule
# calculating diffracted fields
# 818th molecule
# calculating diffracted fields
# 819th molecule
# calculating diffracted fields
# 820th molecule
# calculating diffracted fields
# 821th molecule
# calculating diffracted fields
# 822th molecule
# calculating diffracted fields

# %%
simTestInst_randAngle125_sshr.calculate_polarization()
save_sim_exp_inst(simTestInst_randAngle125_sshr,'simTestInst_randAngle125_sshr')

# %%
simTestInst_randAngle125_sshr.mispol_angle.shape
# Out:
# (822,)

# %%
plot_hist_true_appar(simTestInst_randAngle125_sshr, bins=15)

# %%
# locations_125, angles_125 = fixed_ori_mol_placement(mol_grid_pts_1D=6, x_max=125, y_max=125)

locations_randAngle125_100shr, randAngle125_100shr = fit.random_ori_mol_placement(
    mol_grid_pts_1D=100, 
    x_max=125, 
    y_max=125,
)

simTestInst_randAngle125_100shr = SimulatedExperiment(
    locations_randAngle125_100shr, 
    mol_angle=randAngle125_100shr
    )
simTestInst_randAngle125_100shr.trial_images = simTestInst_randAngle125_100shr.calculate_BEM_fields()

# %% [markdown]
# ^ ran fine, should be saved under instance name `simTestInst_randAngle125_100shr`

# %%
plot_hist_true_appar(simTestInst_randAngle125_100shr, bins=15)

# %%
simTestInst_randAngle125_100shr.calculate_polarization()
save_sim_exp_inst(simTestInst_randAngle125_100shr, 'fig5/simTestInst_randAngle125_100shr')

# %%
## Initial guess defaults to position of maximum intensity. 
fitInst_randAngle125_100shr = fit.FitModelToData(
    simTestInst_randAngle125_100shr.BEM_images, 
    ini_guess='gauss'
    )
fitInst_randAngle125_100shr.fit_model_to_image_data(
    check_ini=True)

# %% [markdown]
# ^ That broke but I had to erase the output because the notebook was slow as balls

# %%
save_fit_inst(fitInst_randAngle125_100shr, simTestInst_randAngle125_100shr, 'fig5/fitInst_randAngle125_100shr')

# %% [markdown]
# #### x oriented moelcules

# %%
locations_xOr125_100shr, xOr125_100shr = fit.fixed_ori_mol_placement(
    mol_grid_pts_1D=100, 
    x_max=125, 
    y_max=125,
)

simTestInst_xOr125_100shr = SimulatedExperiment(
    locations_xOr125_100shr, 
    mol_angle=xOr125_100shr
    )
simTestInst_xOr125_100shr.trial_images = simTestInst_xOr125_100shr.calculate_BEM_fields()
# Out:
# starting Matlab...
# unknown error
# given even number of points for Fibonacci lattice,
#   adding 1...
# 1th molecule
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-e4947e78b312> in <module>
#       9     mol_angle=xOr125_100shr
#      10     )
# ---> 11 simTestInst_xOr125_100shr.trial_images = simTestInst_xOr125_100shr.calculate_BEM_fields()
#
# <ipython-input-5-b45f7d1dfed2> in calculate_BEM_fields(self)
#     115
#     116             # Run BEM calculation, return fields and coords.
# --> 117             [E, sph_p] = eng.BEM_CurlyNanRod_dipDrive_E(
#     118                 matlab.double(list(mol_location)),
#     119                 drive_energy,
#
# AttributeError: 'NoneType' object has no attribute 'BEM_CurlyNanRod_dipDrive_E'

# %% [markdown]
# ##
