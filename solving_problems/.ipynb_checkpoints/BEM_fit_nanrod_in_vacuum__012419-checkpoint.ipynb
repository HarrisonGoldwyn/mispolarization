# %% [markdown]
# Last edited on 121918. Reviewing this code on 010818. What I remember it doing is fitting both a Gaussian and ModelImage to the BEM Images. Of course in order to do that it also interfaces with matlab and runs a BEM calculation. I hope that all the pieces are here to try fitting Curly's images tonight so I can write him an email. Worst case scenario I can make a figure of fitting results to my own BEM simulation and send them over to him with questions.

# %%
from __future__ import print_function
from __future__ import division

import pdb
import sys
import os
import numpy as np
import scipy.optimize as opt
from scipy import interpolate
import scipy.io as sio
import scipy.special as spf
import yaml

## import diffrantion integral solver from Optics folder
work_dir = os.getcwd()
date_dir = os.path.split(work_dir)[0]
optics_folder = os.path.join(date_dir, 'Optics')
sys.path.append(optics_folder)
sys.path.append(date_dir)
import diffraction_int as diffi
import fibonacci as fib

## Read parameter file to obtain physical properties 
## of molecule and plasmon, molecule and imaging system.
stream = open('../curly_param.yaml','r')
parameters = yaml.load(stream)


## plotting stuff
import matplotlib.pyplot as plt
import matplotlib as mpl
get_ipython().magic('matplotlib inline')
# mpl.rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']})
## for Palatino and other serif fonts use:
#rc('font',**{'family':'serif','serif':['Palatino']})
mpl.rcParams['text.usetex'] = True

## colorbar stuff 
from mpl_toolkits import axes_grid1

## Import analytic expressions for the focused fields from a point dipole.
import anal_foc_diff_fields as afi

## Import computational solution to two coupled oscillators of arbitrarty 
## anisotropic polarizabilities. 
import coupled_dipoles as cp 

## Import physical constants from yaml file.
full_path_to_constant_yaml = os.path.join(date_dir,'physical_constants.yaml')
opened_constant_file = open(full_path_to_constant_yaml,'r')
constants = yaml.load(opened_constant_file)
e = constants['physical_constants']['e']
c = constants['physical_constants']['c']  # charge of electron in statcoloumbs
hbar =constants['physical_constants']['hbar']
nm = constants['physical_constants']['nm']
n_a = constants['physical_constants']['nA']   # Avogadro's number
# Z_o = 376.7303 # impedence of free space in ohms (SI)

## Define some useful constants from defined parameters
n_b = parameters['general']['background_ref_index']
eps_b = n_b**2.
a = parameters['plasmon']['radius']



#######################################################################
## Optics stuff.  
sensor_size = parameters['optics']['sensor_size']*nm
# height = 2*mm  # also defines objective lens focal length 
# height = parameters['optics']['obj_f_len']
resolution = parameters['optics']['sensor_pts']  # image grid resolution
## Build image sensor
eye = diffi.observation_points(
    x_min= -sensor_size/2, 
    x_max= sensor_size/2,
    y_min= -sensor_size/2, 
    y_max= sensor_size/2, 
    points= resolution
    )

## Experimental parameters
magnification = parameters['optics']['magnification']
numerical_aperture = parameters['optics']['numerical_aperture']
max_theta = np.arcsin(numerical_aperture) # defines physical aperture size

## numerical parameters for calculation of scattered field
lens_points = parameters['optics']['lens_points']

# obj_f = 1.*mm  # still dont know what this is supposed to be
obj_f = parameters['optics']['obj_f_len']

tube_f = magnification * obj_f

## calculate dipole magnitudes
drive_hbar_omega = parameters['general']['drive_energy'] ## rod long mode max at 1.8578957289256757 eV
omega_drive = drive_hbar_omega/hbar  # driving frequency

# %% [markdown]
# # initialize matlab stuff

# %%
## import matlab engine to run BEM
import matlab
import matlab.engine

variable_dict = {'list_of_coodinates':eye[0]/nm, 'meshed_X':eye[1]/nm,'meshed_Y':eye[2]/nm}

# %%
## values required for scattered field calculation of sphere
sphere_points = fib.fib_alg_k_filter(
    num_points=lens_points, 
    max_ang=max_theta
    )

cart_points_on_sph = fib.sphere_to_cart(
    sphere_points[:,0],
    sphere_points[:,1],
    obj_f*np.ones(np.shape(sphere_points[:,0]))
    )
# Out:
# given even number of points for Fibonacci lattice,
#   adding 1...

# %%
## start matlab before looping
print('starting Matlab...')
eng = matlab.engine.start_matlab()

## convert lens-integration coordinates to matlab variable
matlab_cart_points_on_sph = matlab.double(cart_points_on_sph.tolist())
# Out:
# starting Matlab...

# %%
mol_location = [100,0,0]

# %%
def fixed_ori_mol_placement(x_min=0, x_max=500, y_min=0, y_max=500, mol_grid_pts_1D = 3, mol_angle=0):
    locations = diffi.observation_points(x_min, x_max, y_min, y_max, points=mol_grid_pts_1D)[0]
    locations = np.hstack((locations,np.zeros((locations.shape[0],1))))
    
    mol_linspace_pts = mol_grid_pts_1D
#     random_mol_angles= (np.random.random(mol_linspace_pts**2)*np.pi*2)
    return [locations, mol_angle]

# %%
class Simulation(object):
    """Runs BEM simulation
    
    Collects focused+diffracted far-field information from molecules nearby a nanorod 
    by MNPBEM calculation in an invisible instance of Matlab.
    
    Args:
        locations: list of 3D cartesien coordinates of molecules. 
            One simulation is run per location.  
        mol_angle: Angle on the molecule's dipole moment relatice to the x-axis
        plas_angle: Angle of the long-axis of the nanorod relative to the x-axis
    
    Attributes:
        mol_too_close: named confusingly, this method is built to filter locations
            for points within the fluorescence quenching region around the nanorod, 
            assigned to be 10 nm from the surface of the fit ellipsoid.
            Returns: VALID locations OUTSIDE this region.
        calculate_BEM_fields: runs simulatins and stores results in attributes; 
            bem_E: Focused and diffracted electric field
            BEM_images: 
    
    """
    
    ## set up inverse mapping from observed -> true angle for signle molecule in the plane. 
        
    def __init__(self, locations, mol_angle=0, plas_angle=np.pi/2
                 ):
        self.n_b = np.sqrt(1.778) ## Curly's water 
        self.mol_locations = locations
        self.mol_angles = mol_angle
        self.rod_angle = plas_angle
        
        #### Filtering out molecules in region of fluorescence quenching 
        self.el_a = 19 ## ranorod degenerate radius
        self.el_c = 67
        self.quel_a = self.el_a + 10 ## define quenching region
        self.quel_c = self.el_c + 10
        self.input_x_mol = locations[:,0]
        self.input_y_mol = locations[:,1]
        
        self.pt_is_in_ellip = self.mol_too_close()
        ## select molecules outside region,
        self.mol_locations = locations[self.pt_is_in_ellip]
        ## select molecule angles if listed per molecule, 
        if type(mol_angle)==np.ndarray and mol_angle.shape[0]>1:
            self.mol_angles = mol_angle[self.pt_is_in_ellip]
        else: self.mol_angles = mol_angle

        self.default_plot_limits = [
            np.min(self.mol_locations)-((np.max(self.mol_locations)-np.min(self.mol_locations))*.1),
            np.max(self.mol_locations)+((np.max(self.mol_locations)-np.min(self.mol_locations))*.1)]
        
    def mol_too_close(self):
        '''Returns molecule locations that are outside the fluorescence quenching zone,
            defined as 10 nm from surface of fit spheroid'''
        rotated_x = np.cos(self.rod_angle)*self.input_x_mol + np.sin(self.rod_angle)*self.input_y_mol
        rotated_y = -np.sin(self.rod_angle)*self.input_x_mol + np.cos(self.rod_angle)*self.input_y_mol
        long_quench_radius = self.quel_c
        short_quench_radius = self.quel_a
        rotated_ellip_eq = rotated_x**2./long_quench_radius**2 + rotated_y**2./short_quench_radius**2
        return (rotated_ellip_eq > 1)
        
    def calculate_BEM_fields(self):
        """"""
        if hasattr(self, 'BEM_images'):
            return self.BEM_images
            
        mol_locations = self.mol_locations
        mol_angle = self.mol_angles
        drive_energy = drive_hbar_omega
        
        number_of_molecules = mol_locations.shape[0]

        self.BEM_images = np.zeros((number_of_molecules, eye[0].shape[0]))
        self.bem_E = np.zeros((number_of_molecules, eye[0].shape[0], 3))
        
        for i in range(number_of_molecules):
            print('{}th molecule'.format(int(i+1)))
            mol_location = mol_locations[i]
            mol_orientation = [np.cos(mol_angle), np.sin(mol_angle), 0]

            [E, sph_p] = eng.BEM_CurlyNanRod_dipDrive_E(
                matlab.double(list(mol_location)), 
                drive_energy, 
                matlab.double(list(mol_orientation)), 
                matlab_cart_points_on_sph,
                float(self.n_b**2.),
                nargout=2)


            BEM_scattered_E = np.asarray(E)
                # print('BEM_scattered_E.shape = ',BEM_scattered_E.shape)
                # BEM_scattered_H = np.asarray(H)
                # print('BEM_scattered_H.shape = ',BEM_scattered_H.shape)
            cart_sphere_points = np.asarray(sph_p)

            sph_sph_points = fib.cart_to_sphere(
                cart_sphere_points[:,0],
                cart_sphere_points[:,1],
                cart_sphere_points[:,2]
                ).T

            thetas_and_phis = sph_sph_points[:,1:]

            print(
                'calculating diffracted fields')
            
            diffracted_E_field = diffi.perform_integral(
                scattered_E=BEM_scattered_E, 
                scattered_sph_coords=thetas_and_phis, 
                obser_pts=eye[0]*np.array([[1,-1]]), 
                z=0, 
                obj_f=obj_f, 
                tube_f=tube_f, 
                k=omega_drive*self.n_b/c,
                alpha_1_max=max_theta
                )

            diffracted_power_flux = np.real(
                np.sum(
                    np.multiply(diffracted_E_field,
                        np.conj(diffracted_E_field)
                        ),
                    axis=-1
                    )
                )

            self.bem_E[i] = diffracted_E_field
            self.BEM_images[i] = diffracted_power_flux
        return self.BEM_images

# %% [markdown]
# ### Wrap Simulation class into an object with same attributes as MolCoupNanoRodExp, so that the Gaussian Localization can be calculated

# %%
import fitting_misLocalization_adding_noise_to_modeled_images__011619v10 as fit

# %%
class SimulatedExperiment(Simulation,fit.MolCoupNanoRodExp):        
        
    def __init__(self, locations, mol_angle=0, plas_angle=np.pi/2, 
                 obs_points=None,):
        
        fit.CoupledDipoles.__init__(self, obs_points)
        
        self.n_b = np.sqrt(1.778) ## Curly's water 
        ###### from fit.MolCoupNanoRodExp
        self.mol_locations = locations
        self.mol_angles = mol_angle
        self.rod_angle = plas_angle
        
        #### Filtering out molecules in region of fluorescence quenching 
        self.el_a = 19 ## ranorod degenerate radius
        self.el_c = 67
        self.quel_a = self.el_a + 10 ## define quenching region
        self.quel_c = self.el_c + 10
        self.input_x_mol = locations[:,0]
        self.input_y_mol = locations[:,1]

        self.pt_is_in_ellip = self.mol_too_close()
        ## select molecules outside region,
        self.mol_locations = locations[self.pt_is_in_ellip]
        ## select molecule angles if listed per molecule, 
        if type(mol_angle)==np.ndarray and mol_angle.shape[0]>1:
            self.mol_angles = mol_angle[self.pt_is_in_ellip]
        else: self.mol_angles = mol_angle

#         (self.mol_E, 
#          self.plas_E, 
#          self.p0_unc_E, 
#          self.p0, 
#          self.p1) = self.dipole_fields(self.mol_locations, self.mol_angles, self.rod_angle)

#         self.trial_images = self.calculate_BEM_fields()

        self.default_plot_limits = [
            np.min(self.mol_locations)-((np.max(self.mol_locations)-np.min(self.mol_locations))*.1),
            np.max(self.mol_locations)+((np.max(self.mol_locations)-np.min(self.mol_locations))*.1)]

# %%
locations, angles = fixed_ori_mol_placement(mol_grid_pts_1D=10, x_max=300, y_max=300)

# %%
simTestInst = SimulatedExperiment(locations, mol_angle=np.pi/2)

# %%
simTestInst.trial_images = simTestInst.calculate_BEM_fields()
# Out:
# 1th molecule
# calculating diffracted fields
# /Users/chair/anaconda/envs/py36/lib/python3.6/site-packages/ipykernel/__main__.py:128: ComplexWarning: Casting complex values to real discards the imaginary part
# 2th molecule
# calculating diffracted fields
# 3th molecule
# calculating diffracted fields
# 4th molecule
# calculating diffracted fields
# 5th molecule
# calculating diffracted fields
# 6th molecule
# calculating diffracted fields
# 7th molecule
# calculating diffracted fields
# 8th molecule
# calculating diffracted fields
# 9th molecule
# calculating diffracted fields
# 10th molecule
# calculating diffracted fields
# 11th molecule
# calculating diffracted fields
# 12th molecule
# calculating diffracted fields
# 13th molecule
# calculating diffracted fields
# 14th molecule
# calculating diffracted fields
# 15th molecule
# calculating diffracted fields
# 16th molecule
# calculating diffracted fields
# 17th molecule
# calculating diffracted fields
# 18th molecule
# calculating diffracted fields
# 19th molecule
# calculating diffracted fields
# 20th molecule
# calculating diffracted fields
# 21th molecule
# calculating diffracted fields
# 22th molecule
# calculating diffracted fields
# 23th molecule
# calculating diffracted fields
# 24th molecule
# calculating diffracted fields
# 25th molecule
# calculating diffracted fields
# 26th molecule
# calculating diffracted fields
# 27th molecule
# calculating diffracted fields
# 28th molecule
# calculating diffracted fields
# 29th molecule
# calculating diffracted fields
# 30th molecule
# calculating diffracted fields
# 31th molecule
# calculating diffracted fields
# 32th molecule
# calculating diffracted fields
# 33th molecule
# calculating diffracted fields
# 34th molecule
# calculating diffracted fields
# 35th molecule
# calculating diffracted fields
# 36th molecule
# calculating diffracted fields
# 37th molecule
# calculating diffracted fields
# 38th molecule
# calculating diffracted fields
# 39th molecule
# calculating diffracted fields
# 40th molecule
# calculating diffracted fields
# 41th molecule
# calculating diffracted fields
# 42th molecule
# calculating diffracted fields
# 43th molecule
# calculating diffracted fields
# 44th molecule
# calculating diffracted fields
# 45th molecule
# calculating diffracted fields
# 46th molecule
# calculating diffracted fields
# 47th molecule
# calculating diffracted fields
# 48th molecule
# calculating diffracted fields
# 49th molecule
# calculating diffracted fields
# 50th molecule
# calculating diffracted fields
# 51th molecule
# calculating diffracted fields
# 52th molecule
# calculating diffracted fields
# 53th molecule
# calculating diffracted fields
# 54th molecule
# calculating diffracted fields
# 55th molecule
# calculating diffracted fields
# 56th molecule
# calculating diffracted fields
# 57th molecule
# calculating diffracted fields
# 58th molecule
# calculating diffracted fields
# 59th molecule
# calculating diffracted fields
# 60th molecule
# calculating diffracted fields
# 61th molecule
# calculating diffracted fields
# 62th molecule
# calculating diffracted fields
# 63th molecule
# calculating diffracted fields
# 64th molecule
# calculating diffracted fields
# 65th molecule
# calculating diffracted fields
# 66th molecule
# calculating diffracted fields
# 67th molecule
# calculating diffracted fields
# 68th molecule
# calculating diffracted fields
# 69th molecule
# calculating diffracted fields
# 70th molecule
# calculating diffracted fields
# 71th molecule
# calculating diffracted fields
# 72th molecule
# calculating diffracted fields
# 73th molecule
# calculating diffracted fields
# 74th molecule
# calculating diffracted fields
# 75th molecule
# calculating diffracted fields
# 76th molecule
# calculating diffracted fields
# 77th molecule
# calculating diffracted fields
# 78th molecule
# calculating diffracted fields
# 79th molecule
# calculating diffracted fields
# 80th molecule
# calculating diffracted fields
# 81th molecule
# calculating diffracted fields
# 82th molecule
# calculating diffracted fields
# 83th molecule
# calculating diffracted fields
# 84th molecule
# calculating diffracted fields
# 85th molecule
# calculating diffracted fields
# 86th molecule
# calculating diffracted fields
# 87th molecule
# calculating diffracted fields
# 88th molecule
# calculating diffracted fields
# 89th molecule
# calculating diffracted fields
# 90th molecule
# calculating diffracted fields
# 91th molecule
# calculating diffracted fields
# 92th molecule
# calculating diffracted fields
# 93th molecule
# calculating diffracted fields
# 94th molecule
# calculating diffracted fields
# 95th molecule
# calculating diffracted fields
# 96th molecule
# calculating diffracted fields
# 97th molecule
# calculating diffracted fields

# %%
simTestInst.plot_mispol_map_wMisloc()

# %% [markdown]
# Compare to model fit.

# %%
import fitting_misLocalization_adding_noise_to_modeled_images__011619v11 as fit

# %%
test_BEM_fit_instance = fit.FitModelToData(simTestInst.BEM_images)
test_BEM_fit_instance.fit_model_to_image_data()
# test_BEM_fit_instance.plot_contour_fit_over_data(0)
# Out:
# initial guess for molecule 0 location: (-10.0,30.0)
# initial guess for molecule 1 location: (-10.0,111.0)
# initial guess for molecule 2 location: (-10.0,192.0)
# initial guess for molecule 3 location: (-10.0,232.0)
# initial guess for molecule 4 location: (-10.0,253.0)
# initial guess for molecule 5 location: (10.0,293.0)
# initial guess for molecule 6 location: (10.0,313.0)
# initial guess for molecule 7 location: (-10.0,10.0)
# initial guess for molecule 8 location: (30.0,10.0)
# initial guess for molecule 9 location: (10.0,10.0)
# initial guess for molecule 10 location: (10.0,30.0)
# initial guess for molecule 11 location: (30.0,131.0)
# initial guess for molecule 12 location: (51.0,192.0)
# initial guess for molecule 13 location: (30.0,232.0)
# initial guess for molecule 14 location: (30.0,253.0)
# initial guess for molecule 15 location: (30.0,273.0)
# initial guess for molecule 16 location: (30.0,313.0)
# initial guess for molecule 17 location: (30.0,10.0)
# initial guess for molecule 18 location: (111.0,51.0)
# initial guess for molecule 19 location: (71.0,71.0)
# initial guess for molecule 20 location: (71.0,111.0)
# initial guess for molecule 21 location: (91.0,152.0)
# initial guess for molecule 22 location: (71.0,192.0)
# initial guess for molecule 23 location: (71.0,232.0)
# initial guess for molecule 24 location: (71.0,253.0)
# initial guess for molecule 25 location: (71.0,273.0)
# initial guess for molecule 26 location: (71.0,313.0)
# initial guess for molecule 27 location: (131.0,-10.0)
# initial guess for molecule 28 location: (152.0,51.0)
# initial guess for molecule 29 location: (131.0,91.0)
# initial guess for molecule 30 location: (131.0,131.0)
# initial guess for molecule 31 location: (111.0,152.0)
# initial guess for molecule 32 location: (111.0,192.0)
# initial guess for molecule 33 location: (111.0,212.0)
# initial guess for molecule 34 location: (111.0,253.0)
# initial guess for molecule 35 location: (111.0,273.0)
# initial guess for molecule 36 location: (111.0,293.0)
# initial guess for molecule 37 location: (172.0,-10.0)
# initial guess for molecule 38 location: (172.0,30.0)
# initial guess for molecule 39 location: (152.0,71.0)
# initial guess for molecule 40 location: (152.0,111.0)
# initial guess for molecule 41 location: (152.0,152.0)
# initial guess for molecule 42 location: (152.0,172.0)
# initial guess for molecule 43 location: (131.0,212.0)
# initial guess for molecule 44 location: (131.0,232.0)
# initial guess for molecule 45 location: (131.0,273.0)
# initial guess for molecule 46 location: (131.0,293.0)
# initial guess for molecule 47 location: (192.0,-10.0)
# initial guess for molecule 48 location: (192.0,30.0)
# initial guess for molecule 49 location: (192.0,71.0)
# initial guess for molecule 50 location: (172.0,111.0)
# initial guess for molecule 51 location: (172.0,131.0)
# initial guess for molecule 52 location: (172.0,172.0)
# initial guess for molecule 53 location: (172.0,212.0)
# initial guess for molecule 54 location: (172.0,232.0)
# initial guess for molecule 55 location: (172.0,273.0)
# initial guess for molecule 56 location: (172.0,293.0)
# initial guess for molecule 57 location: (212.0,-10.0)
# initial guess for molecule 58 location: (212.0,30.0)
# initial guess for molecule 59 location: (212.0,71.0)
# initial guess for molecule 60 location: (212.0,111.0)
# initial guess for molecule 61 location: (212.0,131.0)
# initial guess for molecule 62 location: (192.0,172.0)
# initial guess for molecule 63 location: (192.0,192.0)
# initial guess for molecule 64 location: (192.0,232.0)
# initial guess for molecule 65 location: (192.0,273.0)
# initial guess for molecule 66 location: (192.0,293.0)
# initial guess for molecule 67 location: (232.0,-10.0)
# initial guess for molecule 68 location: (232.0,30.0)
# initial guess for molecule 69 location: (232.0,71.0)
# initial guess for molecule 70 location: (232.0,91.0)
# initial guess for molecule 71 location: (232.0,131.0)
# initial guess for molecule 72 location: (232.0,172.0)
# initial guess for molecule 73 location: (232.0,192.0)
# initial guess for molecule 74 location: (232.0,232.0)
# initial guess for molecule 75 location: (232.0,273.0)
# initial guess for molecule 76 location: (232.0,293.0)
# initial guess for molecule 77 location: (253.0,-10.0)
# initial guess for molecule 78 location: (253.0,30.0)
# initial guess for molecule 79 location: (253.0,71.0)
# initial guess for molecule 80 location: (253.0,91.0)
# initial guess for molecule 81 location: (253.0,131.0)
# initial guess for molecule 82 location: (273.0,172.0)
# initial guess for molecule 83 location: (273.0,212.0)
# initial guess for molecule 84 location: (273.0,232.0)
# initial guess for molecule 85 location: (273.0,273.0)
# initial guess for molecule 86 location: (273.0,293.0)
# initial guess for molecule 87 location: (293.0,-10.0)
# initial guess for molecule 88 location: (293.0,30.0)
# initial guess for molecule 89 location: (293.0,71.0)
# initial guess for molecule 90 location: (293.0,111.0)
# initial guess for molecule 91 location: (293.0,131.0)
# initial guess for molecule 92 location: (293.0,172.0)
# initial guess for molecule 93 location: (293.0,212.0)
# initial guess for molecule 94 location: (293.0,232.0)
# initial guess for molecule 95 location: (293.0,273.0)
# initial guess for molecule 96 location: (293.0,313.0)

# %%
test_BEM_fit_instance.plot_fit_results_as_quiver_map(simTestInst)

# %%
locations, angles = fixed_ori_mol_placement(mol_grid_pts_1D=5, x_max=300, y_max=300)
simTestInst_few_mol = SimulatedExperiment(locations, mol_angle=np.pi/2)
simTestInst_few_mol.trial_images = simTestInst_few_mol.calculate_BEM_fields()
# Out:
# 1th molecule
# calculating diffracted fields
# /Users/chair/anaconda/envs/py36/lib/python3.6/site-packages/ipykernel/__main__.py:128: ComplexWarning: Casting complex values to real discards the imaginary part
# 2th molecule
# calculating diffracted fields
# 3th molecule
# calculating diffracted fields
# 4th molecule
# calculating diffracted fields
# 5th molecule
# calculating diffracted fields
# 6th molecule
# calculating diffracted fields
# 7th molecule
# calculating diffracted fields
# 8th molecule
# calculating diffracted fields
# 9th molecule
# calculating diffracted fields
# 10th molecule
# calculating diffracted fields
# 11th molecule
# calculating diffracted fields
# 12th molecule
# calculating diffracted fields
# 13th molecule
# calculating diffracted fields
# 14th molecule
# calculating diffracted fields
# 15th molecule
# calculating diffracted fields
# 16th molecule
# calculating diffracted fields
# 17th molecule
# calculating diffracted fields
# 18th molecule
# calculating diffracted fields
# 19th molecule
# calculating diffracted fields
# 20th molecule
# calculating diffracted fields
# 21th molecule
# calculating diffracted fields
# 22th molecule
# calculating diffracted fields
# 23th molecule
# calculating diffracted fields

# %%
simTestInst_few_mol.plot_mispol_map_wMisloc()

# %%
test_BEM_fit_instance_few_mol = fit.FitModelToData(simTestInst_few_mol.BEM_images)
test_BEM_fit_few_mol = test_BEM_fit_instance_few_mol.fit_model_to_image_data()
# test_BEM_fit_instance.plot_contour_fit_over_data(0)
# Out:
# initial guess for molecule 0 location: (-10.0,172.0)
# initial guess for molecule 1 location: (10.0,253.0)
# initial guess for molecule 2 location: (10.0,313.0)
# initial guess for molecule 3 location: (71.0,10.0)
# initial guess for molecule 4 location: (91.0,91.0)
# initial guess for molecule 5 location: (91.0,172.0)
# initial guess for molecule 6 location: (91.0,253.0)
# initial guess for molecule 7 location: (71.0,313.0)
# initial guess for molecule 8 location: (172.0,-10.0)
# initial guess for molecule 9 location: (172.0,91.0)
# initial guess for molecule 10 location: (172.0,152.0)
# initial guess for molecule 11 location: (152.0,232.0)
# initial guess for molecule 12 location: (152.0,293.0)
# initial guess for molecule 13 location: (232.0,-10.0)
# initial guess for molecule 14 location: (232.0,71.0)
# initial guess for molecule 15 location: (232.0,152.0)
# initial guess for molecule 16 location: (232.0,232.0)
# initial guess for molecule 17 location: (232.0,293.0)
# initial guess for molecule 18 location: (293.0,-10.0)
# initial guess for molecule 19 location: (293.0,71.0)
# initial guess for molecule 20 location: (293.0,152.0)
# initial guess for molecule 21 location: (293.0,232.0)
# initial guess for molecule 22 location: (293.0,313.0)

# %%
test_BEM_fit_instance_few_mol.plot_fit_results_as_quiver_map(simTestInst_few_mol)

# %%
locations, angles = fixed_ori_mol_placement(mol_grid_pts_1D=7, x_max=300, y_max=300)
simTestInst_few_more_mol = SimulatedExperiment(locations, mol_angle=np.pi/2)
simTestInst_few_more_mol.trial_images = simTestInst_few_more_mol.calculate_BEM_fields()
# Out:
# 1th molecule
# calculating diffracted fields
# /Users/chair/anaconda/envs/py36/lib/python3.6/site-packages/ipykernel/__main__.py:128: ComplexWarning: Casting complex values to real discards the imaginary part
# 2th molecule
# calculating diffracted fields
# 3th molecule
# calculating diffracted fields
# 4th molecule
# calculating diffracted fields
# 5th molecule
# calculating diffracted fields
# 6th molecule
# calculating diffracted fields
# 7th molecule
# calculating diffracted fields
# 8th molecule
# calculating diffracted fields
# 9th molecule
# calculating diffracted fields
# 10th molecule
# calculating diffracted fields
# 11th molecule
# calculating diffracted fields
# 12th molecule
# calculating diffracted fields
# 13th molecule
# calculating diffracted fields
# 14th molecule
# calculating diffracted fields
# 15th molecule
# calculating diffracted fields
# 16th molecule
# calculating diffracted fields
# 17th molecule
# calculating diffracted fields
# 18th molecule
# calculating diffracted fields
# 19th molecule
# calculating diffracted fields
# 20th molecule
# calculating diffracted fields
# 21th molecule
# calculating diffracted fields
# 22th molecule
# calculating diffracted fields
# 23th molecule
# calculating diffracted fields
# 24th molecule
# calculating diffracted fields
# 25th molecule
# calculating diffracted fields
# 26th molecule
# calculating diffracted fields
# 27th molecule
# calculating diffracted fields
# 28th molecule
# calculating diffracted fields
# 29th molecule
# calculating diffracted fields
# 30th molecule
# calculating diffracted fields
# 31th molecule
# calculating diffracted fields
# 32th molecule
# calculating diffracted fields
# 33th molecule
# calculating diffracted fields
# 34th molecule
# calculating diffracted fields
# 35th molecule
# calculating diffracted fields
# 36th molecule
# calculating diffracted fields
# 37th molecule
# calculating diffracted fields
# 38th molecule
# calculating diffracted fields
# 39th molecule
# calculating diffracted fields
# 40th molecule
# calculating diffracted fields
# 41th molecule
# calculating diffracted fields
# 42th molecule
# calculating diffracted fields
# 43th molecule
# calculating diffracted fields
# 44th molecule
# calculating diffracted fields
# 45th molecule
# calculating diffracted fields
# 46th molecule
# calculating diffracted fields
# 47th molecule
# calculating diffracted fields

# %%
simTestInst_few_more_mol.plot_mispol_map_wMisloc()

# %%
test_BEM_fit_instance_few_more_mol = fit.FitModelToData(simTestInst_few_more_mol.BEM_images)
test_BEM_fit_few_more_mol = test_BEM_fit_instance_few_more_mol.fit_model_to_image_data()
test_BEM_fit_instance_few_more_mol.plot_fit_results_as_quiver_map(simTestInst_few_more_mol)
# Out:
# initial guess for molecule 0 location: (-10.0,30.0)
# initial guess for molecule 1 location: (-10.0,172.0)
# initial guess for molecule 2 location: (-10.0,232.0)
# initial guess for molecule 3 location: (10.0,273.0)
# initial guess for molecule 4 location: (10.0,313.0)
# initial guess for molecule 5 location: (10.0,10.0)
# initial guess for molecule 6 location: (30.0,30.0)
# initial guess for molecule 7 location: (30.0,71.0)
# initial guess for molecule 8 location: (71.0,172.0)
# initial guess for molecule 9 location: (51.0,232.0)
# initial guess for molecule 10 location: (51.0,273.0)
# initial guess for molecule 11 location: (51.0,313.0)
# initial guess for molecule 12 location: (131.0,-10.0)
# initial guess for molecule 13 location: (131.0,71.0)
# initial guess for molecule 14 location: (131.0,131.0)
# initial guess for molecule 15 location: (111.0,172.0)
# initial guess for molecule 16 location: (111.0,212.0)
# initial guess for molecule 17 location: (111.0,253.0)
# initial guess for molecule 18 location: (111.0,293.0)
# initial guess for molecule 19 location: (172.0,-10.0)
# initial guess for molecule 20 location: (172.0,51.0)
# initial guess for molecule 21 location: (172.0,111.0)
# initial guess for molecule 22 location: (172.0,152.0)
# initial guess for molecule 23 location: (152.0,212.0)
# initial guess for molecule 24 location: (152.0,253.0)
# initial guess for molecule 25 location: (152.0,293.0)
# initial guess for molecule 26 location: (212.0,-10.0)
# initial guess for molecule 27 location: (212.0,51.0)
# initial guess for molecule 28 location: (212.0,111.0)
# initial guess for molecule 29 location: (212.0,152.0)
# initial guess for molecule 30 location: (192.0,192.0)
# initial guess for molecule 31 location: (192.0,253.0)
# initial guess for molecule 32 location: (192.0,293.0)
# initial guess for molecule 33 location: (253.0,-10.0)
# initial guess for molecule 34 location: (253.0,51.0)
# initial guess for molecule 35 location: (253.0,91.0)
# initial guess for molecule 36 location: (253.0,152.0)
# initial guess for molecule 37 location: (253.0,192.0)
# initial guess for molecule 38 location: (253.0,253.0)
# initial guess for molecule 39 location: (253.0,293.0)
# initial guess for molecule 40 location: (293.0,-10.0)
# initial guess for molecule 41 location: (293.0,51.0)
# initial guess for molecule 42 location: (293.0,111.0)
# initial guess for molecule 43 location: (293.0,152.0)
# initial guess for molecule 44 location: (293.0,212.0)
# initial guess for molecule 45 location: (293.0,253.0)
# initial guess for molecule 46 location: (293.0,313.0)

# %%
test_BEM_fit_instance.model_fit_results

# %%
# test_BEM_fit_instance.model_fit_results = test_BEM_fit_instance.model_fit_results*np.array([[1,-1,1]])

# %%
test_BEM_fit_instance.plot_fit_results_as_quiver_map(simTestInst)

# %%
simTestInst_yMol = SimulatedExperiment(locations, mol_angle=0)
simTestInst_yMol.plot_mispol_map_wMisloc()

test_BEM_fit_instance_yMol = fit.FitModelToData(simTestInst_yMol.BEM_images)
test_BEM_fit_yMol = test_BEM_fit_instance_yMol.fit_model_to_image_data()
# test_BEM_fit_instance.plot_contour_fit_over_data(0)

# test_BEM_fit_instance_yMol.model_fit_results = test_BEM_fit_instance_yMol.model_fit_results*np.array([[1,-1,1]])
test_BEM_fit_instance_yMol.plot_fit_results_as_quiver_map(simTestInst_yMol)
# Out:
# 1th molecule
# calculating diffracted fields
# /Users/chair/anaconda/envs/py36/lib/python3.6/site-packages/ipykernel/__main__.py:128: ComplexWarning: Casting complex values to real discards the imaginary part
# 2th molecule
# calculating diffracted fields
# 3th molecule
# calculating diffracted fields
# 4th molecule
# calculating diffracted fields
# 5th molecule
# calculating diffracted fields
# 6th molecule
# calculating diffracted fields
# 7th molecule
# calculating diffracted fields
# 8th molecule
# calculating diffracted fields
# initial guess for molecule 0 location: (10.0,152.0)
# initial guess for molecule 1 location: (-10.0,293.0)
# initial guess for molecule 2 location: (152.0,-10.0)
# initial guess for molecule 3 location: (152.0,152.0)
# initial guess for molecule 4 location: (152.0,293.0)
# initial guess for molecule 5 location: (293.0,-10.0)
# initial guess for molecule 6 location: (313.0,152.0)
# initial guess for molecule 7 location: (293.0,293.0)

# %% [markdown]
# Seems to be working now, but not much better than the gaussian fits at this point. Arguably worse locatization, polarization seems significantly better but that could be due to the correct initial guess.

# %% [markdown]
# ## Time to try and fit Curly's images. Should be able to feed the data into 'FitModelToData' after first loading the data in from the matlab files.

# %%
import scipy.io as sio

# %%
mol_img_y_700_file = sio.loadmat('/Users/chair/Documents/Academia/SuperRes/Biteen_colab/from_Biteen_group/Curly_simulated_images_nrod_mol_downloaded_010818/mol_img_y_700.mat')

# %%
mol_img_y_700 = mol_img_y_700_file['mol_img_y_700']

# %%
mol_img_y_700.shape
# Out:
# (300, 300, 99)

# %%
simTestInst_yMol.BEM_images.shape
# Out:
# (8, 10000)

# %% [markdown]
# Need to reshape Curly's data to match the BEM_images shape I have been using.

# %%
reshaped_Curly_image_y_700nm = mol_img_y_700.reshape((99, 300*300))

# %%
reshaped_Curly_image_y_700nm.shape
# Out:
# (99, 90000)

# %% [markdown]
# need to load in Curly's x and y coordinates and modify the 'FitModelToData' to accept coordinates different from 'eye' default. But first, lunch.

# %%
x_image_file = sio.loadmat('/Users/chair/Documents/Academia/SuperRes/Biteen_colab/from_Biteen_group/Curly_simulated_images_nrod_mol_downloaded_010818/x_image.mat')
y_image_file = sio.loadmat('/Users/chair/Documents/Academia/SuperRes/Biteen_colab/from_Biteen_group/Curly_simulated_images_nrod_mol_downloaded_010818/y_image.mat')
true_position_file = sio.loadmat('/Users/chair/Documents/Academia/SuperRes/Biteen_colab/from_Biteen_group/Curly_simulated_images_nrod_mol_downloaded_010818/true_position.mat')

# %%
curly_x_space = x_image_file['x_image'][:, 0]
curly_y_space = y_image_file['y_image'][:, 0]

# %%
true_position_file['true_pos'].shape
# Out:
# (99, 2)

# %%
Curly_true_position = np.hstack((true_position_file['true_pos'], np.zeros((99,1))))

# %%
class FitModelToCurlyData(fit.FitModelToData):
    """Should do the same thing as FitModelToData Except handle 
        Curly's grid of observation points 
    
    Args:
        image_data: same as super
        obs_coords: Meshgrid of Curly's points
        
    Attributes:
        default_plot_limits:
        mol_locations:
        mol_angles:
        rod_angle:
        
    """
    pass

# %% [markdown]
# Really I should build an Exp class for Curly's stuff, so the true positions are accessable to plotting functions

# %% [markdown]
# I can actually do this with 'Simulation'

# %%
class SimulatedCurlyExperiment():

# %%
Curly_X, Curly_Y = np.meshgrid(curly_x_space, curly_y_space)
Curly_Simultation = SimulatedExperiment(locations=Curly_true_position,x_obv_grid=Curly_X, y_obv_grid=Curly_Y)

# %% [markdown]
# need a new class that doesnt automatically run BEM calculations. JK just commented out the line in Simulation.\__init\__ that ran the BEM calculations and stored the results as self.BEM_images

# %%
class FitModelToAnyData(fit.FitModelToData):
    
    def __init__(self, image_data, 
                 x_obv_grid=eye[1],
                 y_obv_grid=eye[2]):
        
        self.mol_angle=0 
        self.rod_angle=np.pi/2

        self.x_obv_grid=x_obv_grid
        self.y_obv_grid=y_obv_grid
        
        self.image_data = image_data

# %%
Fit_Curly_images = FitModelToAnyData(reshaped_Curly_image_y_700nm, Curly_X, Curly_Y)

# %%
Fit_Curly_images.plot_fit_results_as_quiver_map(Curly_Simultation)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-47-6fb7d41a874b> in <module>
# ----> 1 Fit_Curly_images.plot_fit_results_as_quiver_map(Curly_Simultation)
#
# ~/Documents/Academia/SuperRes/Biteen_colab/Mispolarization/python/010819/solving_problems/fitting_misLocalization_adding_noise_to_modeled_images__010919v4.py in plot_fit_results_as_quiver_map(self, fitted_exp_instance, plot_limits)
#     813         '''...'''
#     814         if not hasattr(self, 'model_fit_results'):
# --> 815             self.fit_model_to_image_data()
#     816         if plot_limits == None:
#     817             plot_limits = fitted_exp_instance.default_plot_limits
#
# ~/Documents/Academia/SuperRes/Biteen_colab/Mispolarization/python/010819/solving_problems/fitting_misLocalization_adding_noise_to_modeled_images__010919v4.py in fit_model_to_image_data(self, images)
#     746         num_of_images = images.shape[0]
#     747         self.model_fit_results = np.zeros((num_of_images,3))
# --> 748         max_positions = calculate_max_xy(images)
#     749         for i in np.arange(num_of_images):
#     750             ## establish initial guesses and stash in 'params0'
#
# ~/Documents/Academia/SuperRes/Biteen_colab/Mispolarization/python/010819/solving_problems/fitting_misLocalization_adding_noise_to_modeled_images__010919v4.py in calculate_max_xy(images)
#     262     ## define locations for each maximum in physical coordinate system
#     263
# --> 264     x_cen = (eye[1]/nm).ravel()[apparent_centroids_idx]
#     265     y_cen = (eye[2]/nm).ravel()[apparent_centroids_idx]
#     266
#
# IndexError: index 73854 is out of bounds for axis 1 with size 10000
